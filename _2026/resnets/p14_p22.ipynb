# %% [markdown]
# ## P14_P19

# %%
import json, math, re
from pathlib import Path

import numpy as np
import torch, torch.nn as nn, torch.nn.functional as F
import matplotlib.pyplot as plt
from torchvision.models.resnet import ResNet, BasicBlock

RUNS = Path("/home/stephen/Stephencwelch Dropbox/welch_labs/resnet/hackin/aug_17_run")                       # <-- output dir of train_depth_sweep.py
DATA = Path("/home/stephen/imagenet")     # <-- edit
device = "cuda" if torch.cuda.is_available() else "cpu"

MODEL_DEPTHS = {"plain8": 8, "plain14": 14, "plain20": 20, "plain26": 26,
                "plain34": 34, "plain56": 56, "plain74": 74, "resnet74": 74}
MODELS = [m for m in MODEL_DEPTHS if (RUNS / m).exists()]

def color_of(name):
    """Plain nets: dark->light with depth. ResNet: red."""
    if name == "resnet74":
        return "crimson"
    depths = sorted(d for m, d in MODEL_DEPTHS.items() if m != "resnet74")
    return plt.cm.viridis(depths.index(MODEL_DEPTHS[name]) / (len(depths) - 1))

print(torch.__version__, device, "| runs found:", MODELS)
# Out:
# 2.12.1+cu130 cuda | runs found: ['plain8', 'plain14', 'plain20', 'plain26', 'plain34', 'plain56', 'plain74', 'resnet74']

# %%
# --- model definitions (mirrors train_depth_sweep.py) ---
class PlainBasicBlock(BasicBlock):
    def __init__(self, *args, **kwargs):
        super().__init__(*args, **kwargs)
        self.downsample = None

    def forward(self, x):
        out = self.relu(self.bn1(self.conv1(x)))
        out = self.relu(self.bn2(self.conv2(out)))
        return out

LAYER_CFG = {8: [1,1,1,1], 14: [2,1,1,2], 20: [2,2,3,2], 26: [3,3,3,3],
             34: [4,4,4,4], 56: [3,4,17,3], 74: [3,4,26,3]}

def make_net(depth_target, use_skip, num_classes=1000):
    block = BasicBlock if use_skip else PlainBasicBlock
    model = ResNet(block, LAYER_CFG[depth_target], num_classes=num_classes)
    if depth_target == 8:
        model.layer4 = nn.Identity()
        model.fc = nn.Linear(256, num_classes)
    return model

def blocks_of(model):
    return [b for s in (model.layer1, model.layer2, model.layer3, model.layer4)
            if isinstance(s, nn.Sequential) for b in s]

# %%
# --- metrics loading: prefer metrics.npz, fall back to metrics.jsonl ---
def load_metrics(name):
    d = RUNS / name
    if (d / "metrics.npz").exists():
        return dict(np.load(d / "metrics.npz"))
    recs = [json.loads(l) for l in open(d / "metrics.jsonl") if l.strip()]
    out = {}
    for k in recs[0]:
        if k in ("block_grad_norms", "block_acts"):
            continue
        out[k] = np.array([r.get(k, np.nan) for r in recs], dtype=np.float64)
    out["block_grad_norms"] = np.array([r["block_grad_norms"] for r in recs])
    return out

M = {name: load_metrics(name) for name in MODELS}
for name in MODELS:
    print(f"{name:9s} records={len(M[name]['step']):5d} "
          f"last step={int(M[name]['step'][-1])}")
# Out:
# plain8    records=  400 last step=40000
# plain14   records=  500 last step=50000
# plain20   records=  600 last step=60000
# plain26   records=  700 last step=70000
# plain34   records=  800 last step=80000
# plain56   records=  900 last step=90000
# plain74   records= 1000 last step=100000
# resnet74  records= 1100 last step=110000

# %%
def list_ckpts(name):
    return sorted(int(re.search(r"(\d+)", p.stem).group(1))
                  for p in (RUNS / name).glob("ckpt_step*.pt"))

def load_model(name, step=None):
    d = RUNS / name
    path = d / "final.pt" if step is None else d / f"ckpt_step{step:06d}.pt"
    model = make_net(MODEL_DEPTHS[name], use_skip=name.startswith("resnet"))
    model.load_state_dict(torch.load(path, map_location=device))
    return model.to(device).eval()

print("plain74 checkpoints:", list_ckpts("plain74")[:5], "...",
      list_ckpts("plain74")[-2:])
# Out:
# plain74 checkpoints: [1000, 2000, 3000, 4000, 5000] ... [99000, 100000]

# %%
# --- validation data (same transforms as training script) ---
import torchvision.datasets as dsets, torchvision.transforms as T

MEAN, STD = [0.485, 0.456, 0.406], [0.229, 0.224, 0.225]
val_ds = dsets.ImageFolder(DATA / "ILSVRC/Data/CLS-LOC/val",
    T.Compose([T.Resize(256), T.CenterCrop(224), T.ToTensor(),
               T.Normalize(MEAN, STD)]))
val_loader = torch.utils.data.DataLoader(val_ds, 64, shuffle=True,
    num_workers=4, pin_memory=True)

# wnid -> human-readable name (Kaggle CLS-LOC ships this mapping)
wnid_words = {}
mapping = DATA / "LOC_synset_mapping.txt"
if mapping.exists():
    for line in open(mapping):
        wnid, words = line.strip().split(" ", 1)
        wnid_words[wnid] = words.split(",")[0]

def class_name(idx):
    if 0 <= idx < len(val_ds.classes):
        wnid = val_ds.classes[idx]
        return wnid_words.get(wnid, wnid)
    return f"cls{idx}"

def denorm(x):  # CHW tensor -> HWC numpy in [0,1] for imshow
    img = x.cpu() * torch.tensor(STD).view(3,1,1) + torch.tensor(MEAN).view(3,1,1)
    return img.clamp(0, 1).permute(1, 2, 0).numpy()

print(len(val_ds), "val images,", len(val_ds.classes), "classes")
# Out:
# 50000 val images, 1000 classes

# %%
# --- forward + backward on a batch of val images ---
name = "plain74" if "plain74" in MODELS else MODELS[-1]
model = load_model(name)

x, y = next(iter(val_loader))
x, y = x[:16].to(device), y[:16].to(device)

logits = model(x)
loss = F.cross_entropy(logits, y)
model.zero_grad(set_to_none=True)
loss.backward()

probs = logits.softmax(1)
top5p, top5i = probs.topk(5, dim=1)
print(f"{name}: batch loss={loss.item():.3f}, "
      f"batch top-1={(logits.argmax(1) == y).float().mean().item():.3f}\n")
for i in range(3):
    guesses = ", ".join(f"{class_name(top5i[i,j].item())} {top5p[i,j]:.2f}"
                        for j in range(5))
    print(f"true: {class_name(y[i].item()):22s} -> {guesses}")
# Out:
# plain74: batch loss=3.750, batch top-1=0.250
#
# true: carousel               -> comic book 0.14, shoe shop 0.07, toyshop 0.04, jigsaw puzzle 0.03, pick 0.03
# true: water tower            -> castle 0.11, cliff 0.07, monastery 0.06, megalith 0.05, palace 0.04
# true: dingo                  -> dingo 0.36, collie 0.29, Shetland sheepdog 0.08, basenji 0.05, Pembroke 0.04

# %% [markdown]
# ## Intermediate Activations

# %%
# --- cache all intermediate activations through a model ---
class ActivationCache:
    """with ActivationCache(model) as cache: model(x)  ->  cache["layer3.5.bn2"]
    Hooks every leaf module (+ the residual blocks and stages themselves),
    stores detached outputs keyed by qualified module name, in forward order."""
    def __init__(self, model, to_cpu=True, leaf_only=False):
        self.model, self.to_cpu, self.leaf_only = model, to_cpu, leaf_only
        self.cache, self.handles = {}, []

    def _keep(self, name, mod):
        if name == "":                      # the model itself
            return False
        if self.leaf_only:
            return len(list(mod.children())) == 0
        return not isinstance(mod, (nn.Sequential, nn.Identity))

    def __enter__(self):
        def hook(name):
            def fn(mod, inp, out):
                if torch.is_tensor(out):
                    self.cache[name] = out.detach().cpu() if self.to_cpu else out.detach()
            return fn
        for name, mod in self.model.named_modules():
            if self._keep(name, mod):
                self.handles.append(mod.register_forward_hook(hook(name)))
        return self.cache

    def __exit__(self, *a):
        for h in self.handles:
            h.remove()
        self.handles.clear()

# name = "plain74" if "plain74" in MODELS else MODELS[-1]
name = "plain14"
model = load_model(name)
x, y = next(iter(val_loader))
x = x[:8].to(device)

with ActivationCache(model) as cache:
    with torch.no_grad():
        model(x)

total = sum(v.numel() * v.element_size() for v in cache.values()) / 1e9
print(f"{name}: cached {len(cache)} activations, {total:.2f} GB "
      f"for batch of {x.shape[0]}\n")
for k in list(cache)[:6]:
    print(f"{k:20s} {tuple(cache[k].shape)}")
print("...")
# e.g. mean |activation| out of each residual block, through the net:
block_keys = [k for k in cache if k.count(".") == 1 and k.startswith("layer")]
fig, ax = plt.subplots(figsize=(9, 3))
ax.plot([cache[k].abs().mean().item() for k in block_keys], "o-",
        color=color_of(name))
ax.set(xlabel="block index", ylabel="mean |activation|",
       title=f"{name}: activation magnitude through the network")
ax.grid(alpha=0.3); plt.tight_layout()
# Out:
# plain14: cached 42 activations, 0.20 GB for batch of 8
#
# conv1                (8, 64, 112, 112)
# bn1                  (8, 64, 112, 112)
# relu                 (8, 64, 112, 112)
# maxpool              (8, 64, 56, 56)
# layer1.0.conv1       (8, 64, 56, 56)
# layer1.0.bn1         (8, 64, 56, 56)
# ...

# %%
block_keys
# Out:
# ['layer1.0', 'layer1.1', 'layer2.0', 'layer3.0', 'layer4.0', 'layer4.1']

# %%
cache.keys()
# Out:
# dict_keys(['conv1', 'bn1', 'relu', 'maxpool', 'layer1.0.conv1', 'layer1.0.bn1', 'layer1.0.relu', 'layer1.0.conv2', 'layer1.0.bn2', 'layer1.0', 'layer1.1.conv1', 'layer1.1.bn1', 'layer1.1.relu', 'layer1.1.conv2', 'layer1.1.bn2', 'layer1.1', 'layer2.0.conv1', 'layer2.0.bn1', 'layer2.0.relu', 'layer2.0.conv2', 'layer2.0.bn2', 'layer2.0', 'layer3.0.conv1', 'layer3.0.bn1', 'layer3.0.relu', 'layer3.0.conv2', 'layer3.0.bn2', 'layer3.0', 'layer4.0.conv1', 'layer4.0.bn1', 'layer4.0.relu', 'layer4.0.conv2', 'layer4.0.bn2', 'layer4.0', 'layer4.1.conv1', 'layer4.1.bn1', 'layer4.1.relu', 'layer4.1.conv2', 'layer4.1.bn2', 'layer4.1', 'avgpool', 'fc'])

# %%
# for k, v in cache.items():
#     print(k, v.shape)

# %% [markdown]
# ## Activations
# - Examples we're getting right/wrong
# - One will be the Drum
# - This is for ResNet-8

# %%
def load_image(idx):
    x, y = val_ds[idx]
    return x.unsqueeze(0).to(device), torch.tensor([y], device=device)

# %%
@torch.no_grad()
def correct_ans_conf(model, x, y):
    return torch.nn.Softmax()(model(x))[0, y.item()].item()

# %%
model=load_model('plain8')

# %%
save_dir = Path('/home/stephen/Stephencwelch Dropbox/welch_labs/resnet/hackin/p19_samples')
save_dir.mkdir(parents=True, exist_ok=True)

# %%
rI = np.arange(50000)
np.random.shuffle(rI)

# %%
# for img_idx in rI[:1000]:

#     x, y = load_image(img_idx)
#     cls = val_ds.classes[y.item()]
#     # print(wnid_words[cls], correct_ans_conf(model, x, y))
#     yhat_index=model(x).argmax().item()
    
#     plt.imshow(denorm(x[0]))
#     plt.title(wnid_words[cls] + ', ' + wnid_words[val_ds.classes[yhat_index]])
#     plt.savefig(save_dir/(str(img_idx)+'.png'))

# %% [markdown]
# Nice correct examples
#  - `47587` Lemon
#  - `6538` Flamingo
#  - `21299` Barn
#
# Nice incorrect examples
# - `38250` Rocking chair -> turnstyle
# - `38552` safe -> rotisserie

# %%
img_idx=47587

x, y = load_image(img_idx)
cls = val_ds.classes[y.item()]
print(wnid_words[cls], correct_ans_conf(model, x, y))
yhat_index=model(x).argmax().item()
# Out:
# lemon 0.6079088449478149
# /home/stephen/anaconda3/lib/python3.13/site-packages/torch/nn/modules/module.py:1778: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   return self._call_impl(*args, **kwargs)

# %%
yhat_index
# Out:
# 951

# %%
with ActivationCache(model) as cache:
    with torch.no_grad():
        model(x)

# %%
for k, v in cache.items():
    print(k, v.shape)
# Out:
# conv1 torch.Size([1, 64, 112, 112])
# bn1 torch.Size([1, 64, 112, 112])
# relu torch.Size([1, 64, 112, 112])
# maxpool torch.Size([1, 64, 56, 56])
# layer1.0.conv1 torch.Size([1, 64, 56, 56])
# layer1.0.bn1 torch.Size([1, 64, 56, 56])
# layer1.0.relu torch.Size([1, 64, 56, 56])
# layer1.0.conv2 torch.Size([1, 64, 56, 56])
# layer1.0.bn2 torch.Size([1, 64, 56, 56])
# layer1.0 torch.Size([1, 64, 56, 56])
# layer2.0.conv1 torch.Size([1, 128, 28, 28])
# layer2.0.bn1 torch.Size([1, 128, 28, 28])
# layer2.0.relu torch.Size([1, 128, 28, 28])
# layer2.0.conv2 torch.Size([1, 128, 28, 28])
# layer2.0.bn2 torch.Size([1, 128, 28, 28])
# layer2.0 torch.Size([1, 128, 28, 28])
# layer3.0.conv1 torch.Size([1, 256, 14, 14])
# layer3.0.bn1 torch.Size([1, 256, 14, 14])
# layer3.0.relu torch.Size([1, 256, 14, 14])
# layer3.0.conv2 torch.Size([1, 256, 14, 14])
# layer3.0.bn2 torch.Size([1, 256, 14, 14])
# layer3.0 torch.Size([1, 256, 14, 14])
# avgpool torch.Size([1, 256, 1, 1])
# fc torch.Size([1, 1000])

# %%
cache_np={k:v.cpu().numpy() for k,v in cache.items()}

# %%
for k, v in cache_np.items():
    print(k, v.shape)
# Out:
# conv1 (1, 64, 112, 112)
# bn1 (1, 64, 112, 112)
# relu (1, 64, 112, 112)
# maxpool (1, 64, 56, 56)
# layer1.0.conv1 (1, 64, 56, 56)
# layer1.0.bn1 (1, 64, 56, 56)
# layer1.0.relu (1, 64, 56, 56)
# layer1.0.conv2 (1, 64, 56, 56)
# layer1.0.bn2 (1, 64, 56, 56)
# layer1.0 (1, 64, 56, 56)
# layer2.0.conv1 (1, 128, 28, 28)
# layer2.0.bn1 (1, 128, 28, 28)
# layer2.0.relu (1, 128, 28, 28)
# layer2.0.conv2 (1, 128, 28, 28)
# layer2.0.bn2 (1, 128, 28, 28)
# layer2.0 (1, 128, 28, 28)
# layer3.0.conv1 (1, 256, 14, 14)
# layer3.0.bn1 (1, 256, 14, 14)
# layer3.0.relu (1, 256, 14, 14)
# layer3.0.conv2 (1, 256, 14, 14)
# layer3.0.bn2 (1, 256, 14, 14)
# layer3.0 (1, 256, 14, 14)
# avgpool (1, 256, 1, 1)
# fc (1, 1000)

# %%
cache_np['image']=denorm(x[0])

# %%
np.save('/home/stephen/Stephencwelch Dropbox/welch_labs/resnet/hackin/p13/lemon_activations_47587', cache_np)

# %%
all_params={k:v for k, v in model.named_parameters()}

# %%
all_params.keys()
# Out:
# dict_keys(['conv1.weight', 'bn1.weight', 'bn1.bias', 'layer1.0.conv1.weight', 'layer1.0.bn1.weight', 'layer1.0.bn1.bias', 'layer1.0.conv2.weight', 'layer1.0.bn2.weight', 'layer1.0.bn2.bias', 'layer2.0.conv1.weight', 'layer2.0.bn1.weight', 'layer2.0.bn1.bias', 'layer2.0.conv2.weight', 'layer2.0.bn2.weight', 'layer2.0.bn2.bias', 'layer3.0.conv1.weight', 'layer3.0.bn1.weight', 'layer3.0.bn1.bias', 'layer3.0.conv2.weight', 'layer3.0.bn2.weight', 'layer3.0.bn2.bias', 'fc.weight', 'fc.bias'])

# %%
all_params['conv1.weight'].shape
# Out:
# torch.Size([64, 3, 7, 7])

# %%
from matplotlib.colors import LinearSegmentedColormap

# Define white/black to pure magenta ('#ff00ff')
magenta_cmap = LinearSegmentedColormap.from_list(
    'magenta_intensity', ['#000000', '#ff00ff']
)

# %%
# plt.imshow(all_params['conv1.weight'][0].detach().cpu().permute(1, 2, 0))
# plt.imshow(denorm(all_params['conv1.weight'][22].detach()))
fig=plt.figure(0,(5,5), facecolor='k')
plt.imshow(all_params['conv1.weight'][22, 0].detach().cpu(), cmap=magenta_cmap)
plt.axis('off')
plt.savefig('/home/stephen/Stephencwelch Dropbox/welch_labs/resnet/hackin/p13/k20.png')

# %%
all_params['conv1.weight'][22, :].shape
# Out:
# torch.Size([3, 7, 7])

# %%
# np.save('/home/stephen/Stephencwelch Dropbox/welch_labs/resnet/hackin/p13/plain_8_conv_1', 
#         all_params['conv1.weight'].detach().cpu().numpy())

# %%
plt.imshow(denorm(x[0]))

# %%
denorm(x[0]).max()
# Out:
# np.float32(1.0)

# %%
from PIL import Image
img = Image.fromarray((denorm(x[0])*255).astype('uint8'))
# img.save("/home/stephen/Stephencwelch Dropbox/welch_labs/resnet/hackin/p13/lemon.jpg")

# %%
cache_np['conv1'].shape
# Out:
# (1, 64, 112, 112)

# %%
fig=plt.figure(0, (14,14))
count=0
for i in range(8):
    for j in range(8):
        ax=fig.add_subplot(8,8,count+1)
        ax.imshow(cache_np['conv1'][0, count])
        count+=1

# %%
# out_dir='/home/stephen/Stephencwelch Dropbox/welch_labs/resnet/hackin/p13/conv_1_activations'
# Path(out_dir).mkdir(parents=True, exist_ok=True)
# cmap=plt.get_cmap('viridis')

# for c in range(cache_np['conv1'][0].shape[0]):
#     v=cache_np['conv1'][0][c]
#     v=(v-v.min())/(v.max()-v.min())   #imshow's default per-image min-max stretch
#     rgb=(cmap(v)[..., :3]*255).astype(np.uint8)
#     Image.fromarray(rgb).resize((10*v.shape[1], 10*v.shape[0]),
#                                 Image.NEAREST).save(f'{out_dir}/act_{c:02d}.png')

# %%
fig=plt.figure(0, (14,14))
count=0
for i in range(8):
    for j in range(8):
        ax=fig.add_subplot(8,8,count+1)
        ax.imshow(cache_np['layer1.0.conv1'][0, count])
        count+=1

# %%
out_dir='/home/stephen/Stephencwelch Dropbox/welch_labs/resnet/hackin/p13/conv_2_activations'
Path(out_dir).mkdir(parents=True, exist_ok=True)
cmap=plt.get_cmap('viridis')

for c in range(cache_np['layer1.0.conv1'][0].shape[0]):
    v=cache_np['layer1.0.conv1'][0][c]
    v=(v-v.min())/(v.max()-v.min())   #imshow's default per-image min-max stretch
    rgb=(cmap(v)[..., :3]*255).astype(np.uint8)
    Image.fromarray(rgb).resize((10*v.shape[1], 10*v.shape[0]),
                                Image.NEAREST).save(f'{out_dir}/act_{c:02d}.png')

# %%
np.save('/home/stephen/Stephencwelch Dropbox/welch_labs/resnet/hackin/p13/plain_8_layer1_0_conv1.npy', 
        all_params['layer1.0.conv1.weight'].detach().cpu().numpy())

# %%
all_params.keys()
# Out:
# dict_keys(['conv1.weight', 'bn1.weight', 'bn1.bias', 'layer1.0.conv1.weight', 'layer1.0.bn1.weight', 'layer1.0.bn1.bias', 'layer1.0.conv2.weight', 'layer1.0.bn2.weight', 'layer1.0.bn2.bias', 'layer2.0.conv1.weight', 'layer2.0.bn1.weight', 'layer2.0.bn1.bias', 'layer2.0.conv2.weight', 'layer2.0.bn2.weight', 'layer2.0.bn2.bias', 'layer3.0.conv1.weight', 'layer3.0.bn1.weight', 'layer3.0.bn1.bias', 'layer3.0.conv2.weight', 'layer3.0.bn2.weight', 'layer3.0.bn2.bias', 'fc.weight', 'fc.bias'])

# %%
cache_np.keys()
# Out:
# dict_keys(['conv1', 'bn1', 'relu', 'maxpool', 'layer1.0.conv1', 'layer1.0.bn1', 'layer1.0.relu', 'layer1.0.conv2', 'layer1.0.bn2', 'layer1.0', 'layer2.0.conv1', 'layer2.0.bn1', 'layer2.0.relu', 'layer2.0.conv2', 'layer2.0.bn2', 'layer2.0', 'layer3.0.conv1', 'layer3.0.bn1', 'layer3.0.relu', 'layer3.0.conv2', 'layer3.0.bn2', 'layer3.0', 'avgpool', 'fc', 'image'])

# %%
plt.plot(cache_np['fc'].ravel())

# %%
plt.plot(torch.nn.Softmax(1)(cache['fc']).ravel())

# %%
# cache['fc']

# %%
cache['fc'].shape
# Out:
# torch.Size([1, 1000])

# %%
vals, ind = torch.topk(cache['fc'].ravel(), 25)

# %%
vals, ind
# Out:
# (tensor([13.8592, 11.7862, 11.3905, 11.2790, 10.9268, 10.8245, 10.6789, 10.4670,
#          10.3078,  9.9571,  9.8359,  9.8347,  9.5072,  9.3135,  8.8307,  8.8096,
#           8.7618,  8.6089,  8.5629,  8.4040,  8.1796,  8.1317,  8.0336,  7.7388,
#           7.3312]),
#  tensor([951, 986, 952, 948, 950, 988, 955, 940, 956, 942, 954, 957, 852, 997,
#          943, 936, 945, 941, 998, 939, 944, 947, 938, 574,  96]))

# %%
for v, i in zip(vals, ind):
    print(v,i, class_name(i))
# Out:
# tensor(13.8592) tensor(951) lemon
# tensor(11.7862) tensor(986) yellow lady's slipper
# tensor(11.3905) tensor(952) fig
# tensor(11.2790) tensor(948) Granny Smith
# tensor(10.9268) tensor(950) orange
# tensor(10.8245) tensor(988) acorn
# tensor(10.6789) tensor(955) jackfruit
# tensor(10.4670) tensor(940) spaghetti squash
# tensor(10.3078) tensor(956) custard apple
# tensor(9.9571) tensor(942) butternut squash
# tensor(9.8359) tensor(954) banana
# tensor(9.8347) tensor(957) pomegranate
# tensor(9.5072) tensor(852) tennis ball
# tensor(9.3135) tensor(997) bolete
# tensor(8.8307) tensor(943) cucumber
# tensor(8.8096) tensor(936) head cabbage
# tensor(8.7618) tensor(945) bell pepper
# tensor(8.6089) tensor(941) acorn squash
# tensor(8.5629) tensor(998) ear
# tensor(8.4040) tensor(939) zucchini
# tensor(8.1796) tensor(944) artichoke
# tensor(8.1317) tensor(947) mushroom
# tensor(8.0336) tensor(938) cauliflower
# tensor(7.7388) tensor(574) golf ball
# tensor(7.3312) tensor(96) toucan

# %% [markdown]
# # P22

# %%
model=load_model('plain14')

with ActivationCache(model) as cache:
    with torch.no_grad():
        model(x)

cache_np={k:v.cpu().numpy() for k,v in cache.items()}
cache_np['image']=denorm(x[0])

# %%
save_dir=Path('/home/stephen/Stephencwelch Dropbox/welch_labs/resnet/hackin/p22/')
save_dir.mkdir(parents=True, exist_ok=True)

# %%
# np.save(save_dir/'lemon_activations_47587_plain14', cache_np)

# %%
for k, v in cache_np.items():
    print(k, v.shape)
# Out:
# conv1 (1, 64, 112, 112)
# bn1 (1, 64, 112, 112)
# relu (1, 64, 112, 112)
# maxpool (1, 64, 56, 56)
# layer1.0.conv1 (1, 64, 56, 56)
# layer1.0.bn1 (1, 64, 56, 56)
# layer1.0.relu (1, 64, 56, 56)
# layer1.0.conv2 (1, 64, 56, 56)
# layer1.0.bn2 (1, 64, 56, 56)
# layer1.0 (1, 64, 56, 56)
# layer1.1.conv1 (1, 64, 56, 56)
# layer1.1.bn1 (1, 64, 56, 56)
# layer1.1.relu (1, 64, 56, 56)
# layer1.1.conv2 (1, 64, 56, 56)
# layer1.1.bn2 (1, 64, 56, 56)
# layer1.1 (1, 64, 56, 56)
# layer2.0.conv1 (1, 128, 28, 28)
# layer2.0.bn1 (1, 128, 28, 28)
# layer2.0.relu (1, 128, 28, 28)
# layer2.0.conv2 (1, 128, 28, 28)
# layer2.0.bn2 (1, 128, 28, 28)
# layer2.0 (1, 128, 28, 28)
# layer3.0.conv1 (1, 256, 14, 14)
# layer3.0.bn1 (1, 256, 14, 14)
# layer3.0.relu (1, 256, 14, 14)
# layer3.0.conv2 (1, 256, 14, 14)
# layer3.0.bn2 (1, 256, 14, 14)
# layer3.0 (1, 256, 14, 14)
# layer4.0.conv1 (1, 512, 7, 7)
# layer4.0.bn1 (1, 512, 7, 7)
# layer4.0.relu (1, 512, 7, 7)
# layer4.0.conv2 (1, 512, 7, 7)
# layer4.0.bn2 (1, 512, 7, 7)
# layer4.0 (1, 512, 7, 7)
# layer4.1.conv1 (1, 512, 7, 7)
# layer4.1.bn1 (1, 512, 7, 7)
# layer4.1.relu (1, 512, 7, 7)
# layer4.1.conv2 (1, 512, 7, 7)
# layer4.1.bn2 (1, 512, 7, 7)
# layer4.1 (1, 512, 7, 7)
# avgpool (1, 512, 1, 1)
# fc (1, 1000)
# image (224, 224, 3)
