# %% [markdown]
# ## Training 4a

# %%
seed=2
frac_train=0.25 
weight_decay = 1.0 #@param
freq_penalty_weight = 1e-3

# %%
# Import stuff
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import numpy as np
import einops
import tqdm.notebook as tqdm

import random
import time

# from google.colab import drive
from pathlib import Path
import pickle
import os

import matplotlib.pyplot as plt
# %matplotlib inline
import plotly.express as px
import plotly.io as pio
pio.renderers.default = "colab"
import plotly.graph_objects as go

from torch.utils.data import DataLoader

from functools import *
import pandas as pd
import gc

# import comet_ml
import itertools

# %% [markdown]
# ## Support Functions

# %%
# A helper class to get access to intermediate activations (inspired by Garcon)
# It's a dummy module that is the identity function by default
# I can wrap any intermediate activation in a HookPoint and get a convenient 
# way to add PyTorch hooks
class HookPoint(nn.Module):
    def __init__(self):
        super().__init__()
        self.fwd_hooks = []
        self.bwd_hooks = []
    
    def give_name(self, name):
        # Called by the model at initialisation
        self.name = name
    
    def add_hook(self, hook, dir='fwd'):
        # Hook format is fn(activation, hook_name)
        # Change it into PyTorch hook format (this includes input and output, 
        # which are the same for a HookPoint)
        def full_hook(module, module_input, module_output):
            return hook(module_output, name=self.name)
        if dir=='fwd':
            handle = self.register_forward_hook(full_hook)
            self.fwd_hooks.append(handle)
        elif dir=='bwd':
            handle = self.register_backward_hook(full_hook)
            self.bwd_hooks.append(handle)
        else:
            raise ValueError(f"Invalid direction {dir}")
    
    def remove_hooks(self, dir='fwd'):
        if (dir=='fwd') or (dir=='both'):
            for hook in self.fwd_hooks:
                hook.remove()
            self.fwd_hooks = []
        if (dir=='bwd') or (dir=='both'):
            for hook in self.bwd_hooks:
                hook.remove()
            self.bwd_hooks = []
        if dir not in ['fwd', 'bwd', 'both']:
            raise ValueError(f"Invalid direction {dir}")
    
    def forward(self, x):
        return x

# %%
# Define network architecture
# I defined my own transformer from scratch so I'd fully understand each component 
# - I expect this wasn't necessary or particularly important, and a bunch of this 
# replicates existing PyTorch functionality

# Embed & Unembed
class Embed(nn.Module):
    def __init__(self, d_vocab, d_model):
        super().__init__()
        self.W_E = nn.Parameter(torch.randn(d_model, d_vocab)/np.sqrt(d_model))
    
    def forward(self, x):
        return torch.einsum('dbp -> bpd', self.W_E[:, x])

class Unembed(nn.Module):
    def __init__(self, d_vocab, d_model):
        super().__init__()
        self.W_U = nn.Parameter(torch.randn(d_model, d_vocab)/np.sqrt(d_vocab))
    
    def forward(self, x):
        return (x @ self.W_U)

# Positional Embeddings
class PosEmbed(nn.Module):
    def __init__(self, max_ctx, d_model):
        super().__init__()
        self.W_pos = nn.Parameter(torch.randn(max_ctx, d_model)/np.sqrt(d_model))
    
    def forward(self, x):
        return x+self.W_pos[:x.shape[-2]]

# LayerNorm
class LayerNorm(nn.Module):
    def __init__(self, d_model, epsilon = 1e-4, model=[None]):
        super().__init__()
        self.model = model
        self.w_ln = nn.Parameter(torch.ones(d_model))
        self.b_ln = nn.Parameter(torch.zeros(d_model))
        self.epsilon = epsilon
    
    def forward(self, x):
        if self.model[0].use_ln:
            x = x - x.mean(axis=-1)[..., None]
            x = x / (x.std(axis=-1)[..., None] + self.epsilon)
            x = x * self.w_ln
            x = x + self.b_ln
            return x
        else:
            return x

# Attention
class Attention(nn.Module):
    def __init__(self, d_model, num_heads, d_head, n_ctx, model):
        super().__init__()
        self.model = model
        self.W_K = nn.Parameter(torch.randn(num_heads, d_head, d_model)/np.sqrt(d_model))
        self.W_Q = nn.Parameter(torch.randn(num_heads, d_head, d_model)/np.sqrt(d_model))
        self.W_V = nn.Parameter(torch.randn(num_heads, d_head, d_model)/np.sqrt(d_model))
        self.W_O = nn.Parameter(torch.randn(d_model, d_head * num_heads)/np.sqrt(d_model))
        self.register_buffer('mask', torch.tril(torch.ones((n_ctx, n_ctx))))
        self.d_head = d_head
        self.hook_k = HookPoint()
        self.hook_q = HookPoint()
        self.hook_v = HookPoint()
        self.hook_z = HookPoint()
        self.hook_attn = HookPoint()
        self.hook_attn_pre = HookPoint()

    def forward(self, x):
        k = self.hook_k(torch.einsum('ihd,bpd->biph', self.W_K, x))
        q = self.hook_q(torch.einsum('ihd,bpd->biph', self.W_Q, x))
        v = self.hook_v(torch.einsum('ihd,bpd->biph', self.W_V, x))
        attn_scores_pre = torch.einsum('biph,biqh->biqp', k, q)
        attn_scores_masked = torch.tril(attn_scores_pre) - 1e10 * (1 - self.mask[:x.shape[-2], :x.shape[-2]])
        attn_matrix = self.hook_attn(F.softmax(self.hook_attn_pre(attn_scores_masked/np.sqrt(self.d_head)), dim=-1))
        z = self.hook_z(torch.einsum('biph,biqp->biqh', v, attn_matrix))
        z_flat = einops.rearrange(z, 'b i q h -> b q (i h)')
        out = torch.einsum('df,bqf->bqd', self.W_O, z_flat)
        return out

# MLP Layers
class MLP(nn.Module):
    def __init__(self, d_model, d_mlp, act_type, model):
        super().__init__()
        self.model = model
        self.W_in = nn.Parameter(torch.randn(d_mlp, d_model)/np.sqrt(d_model))
        self.b_in = nn.Parameter(torch.zeros(d_mlp))
        self.W_out = nn.Parameter(torch.randn(d_model, d_mlp)/np.sqrt(d_model))
        self.b_out = nn.Parameter(torch.zeros(d_model))
        self.act_type = act_type
        # self.ln = LayerNorm(d_mlp, model=self.model)
        self.hook_pre = HookPoint()
        self.hook_post = HookPoint()
        assert act_type in ['ReLU', 'GeLU']
        
    def forward(self, x):
        x = self.hook_pre(torch.einsum('md,bpd->bpm', self.W_in, x) + self.b_in)
        if self.act_type=='ReLU':
            x = F.relu(x)
        elif self.act_type=='GeLU':
            x = F.gelu(x)
        x = self.hook_post(x)
        x = torch.einsum('dm,bpm->bpd', self.W_out, x) + self.b_out
        return x

# Transformer Block
class TransformerBlock(nn.Module):
    def __init__(self, d_model, d_mlp, d_head, num_heads, n_ctx, act_type, model):
        super().__init__()
        self.model = model
        # self.ln1 = LayerNorm(d_model, model=self.model)
        self.attn = Attention(d_model, num_heads, d_head, n_ctx, model=self.model)
        # self.ln2 = LayerNorm(d_model, model=self.model)
        self.mlp = MLP(d_model, d_mlp, act_type, model=self.model)
        self.hook_attn_out = HookPoint()
        self.hook_mlp_out = HookPoint()
        self.hook_resid_pre = HookPoint()
        self.hook_resid_mid = HookPoint()
        self.hook_resid_post = HookPoint()
    
    def forward(self, x):
        x = self.hook_resid_mid(x + self.hook_attn_out(self.attn((self.hook_resid_pre(x)))))
        x = self.hook_resid_post(x + self.hook_mlp_out(self.mlp((x))))
        return x

# Full transformer
class Transformer(nn.Module):
    def __init__(self, num_layers, d_vocab, d_model, d_mlp, d_head, num_heads, n_ctx, act_type, use_cache=False, use_ln=True):
        super().__init__()
        self.cache = {}
        self.use_cache = use_cache

        self.embed = Embed(d_vocab, d_model)
        self.pos_embed = PosEmbed(n_ctx, d_model)
        self.blocks = nn.ModuleList([TransformerBlock(d_model, d_mlp, d_head, num_heads, n_ctx, act_type, model=[self]) for i in range(num_layers)])
        # self.ln = LayerNorm(d_model, model=[self])
        self.unembed = Unembed(d_vocab, d_model)
        self.use_ln = use_ln

        for name, module in self.named_modules():
            if type(module)==HookPoint:
                module.give_name(name)
    
    def forward(self, x):
        x = self.embed(x)
        x = self.pos_embed(x)
        for block in self.blocks:
            x = block(x)
        # x = self.ln(x)
        x = self.unembed(x)
        return x

    def set_use_cache(self, use_cache):
        self.use_cache = use_cache
    
    def hook_points(self):
        return [module for name, module in self.named_modules() if 'hook' in name]

    def remove_all_hooks(self):
        for hp in self.hook_points():
            hp.remove_hooks('fwd')
            hp.remove_hooks('bwd')
    
    def cache_all(self, cache, incl_bwd=False):
        # Caches all activations wrapped in a HookPoint
        def save_hook(tensor, name):
            cache[name] = tensor.detach()
        def save_hook_back(tensor, name):
            cache[name+'_grad'] = tensor[0].detach()
        for hp in self.hook_points():
            hp.add_hook(save_hook, 'fwd')
            if incl_bwd:
                hp.add_hook(save_hook_back, 'bwd')

# %%
# Helper functions
def cuda_memory():
    print(torch.cuda.memory_allocated()/1e9)

def cross_entropy_high_precision(logits, labels):
    # Shapes: batch x vocab, batch
    # Cast logits to float64 because log_softmax has a float32 underflow on overly 
    # confident data and can only return multiples of 1.2e-7 (the smallest float x
    # such that 1+x is different from 1 in float32). This leads to loss spikes 
    # and dodgy gradients
    logprobs = F.log_softmax(logits.to(torch.float64), dim=-1)
    prediction_logprobs = torch.gather(logprobs, index=labels[:, None], dim=-1)
    loss = -torch.mean(prediction_logprobs)
    return loss

def full_loss(model, data):
    # Take the final position only
    logits = model(data)[:, -1]
    labels = torch.tensor([fn(i, j) for i, j, _ in data]).to('cuda')
    return cross_entropy_high_precision(logits, labels)

def test_logits(logits, bias_correction=False, original_logits=None, mode='all'):
    # Calculates cross entropy loss of logits representing a batch of all p^2 
    # possible inputs
    # Batch dimension is assumed to be first
    if logits.shape[1]==p*p:
        logits = logits.T
    if logits.shape==torch.Size([p*p, p+1]):
        logits = logits[:, :-1]
    logits = logits.reshape(p*p, p)
    if bias_correction:
        # Applies bias correction - we correct for any missing bias terms, 
        # independent of the input, by centering the new logits along the batch 
        # dimension, and then adding the average original logits across all inputs
        logits = einops.reduce(original_logits - logits, 'batch ... -> ...', 'mean') + logits
    if mode=='train':
        return cross_entropy_high_precision(logits[is_train], labels[is_train])
    elif mode=='test':
        return cross_entropy_high_precision(logits[is_test], labels[is_test])
    elif mode=='all':
        return cross_entropy_high_precision(logits, labels)

def unflatten_first(tensor):
    if tensor.shape[0]==p*p:
        return einops.rearrange(tensor, '(x y) ... -> x y ...', x=p, y=p)
    else: 
        return tensor
def cos(x, y):
    return (x.dot(y))/x.norm()/y.norm()
def mod_div(a, b):
    return (a*pow(b, p-2, p))%p
def normalize(tensor, axis=0):
    return tensor/(tensor).pow(2).sum(keepdim=True, axis=axis).sqrt()
def extract_freq_2d(tensor, freq):
    # Takes in a pxpx... or batch x ... tensor, returns a 3x3x... tensor of the 
    # Linear and quadratic terms of frequency freq
    tensor = unflatten_first(tensor)
    # Extracts the linear and quadratic terms corresponding to frequency freq
    index_1d = [0, 2*freq-1, 2*freq]
    # Some dumb manipulation to use fancy array indexing rules
    # Gets the rows and columns in index_1d
    return tensor[[[i]*3 for i in index_1d], [index_1d]*3]
def get_cov(tensor, norm=True):
    # Calculate covariance matrix
    if norm:
        tensor = normalize(tensor, axis=1)
    return tensor @ tensor.T
def is_close(a, b):
    return ((a-b).pow(2).sum()/(a.pow(2).sum().sqrt())/(b.pow(2).sum().sqrt())).item()

# %%
def compute_frequency_components(m):
    """
    Compute canonical frequency components of a real 2D signal m using fft2.

    Returns:
        components: list of dicts with keys:
            - 'kx': frequency index in x (rows)
            - 'ky': frequency index in y (cols)
            - 'coeff': complex FFT coefficient at (kx, ky)
        Nx, Ny: dimensions of the input
    """
    m = np.asarray(m)
    Nx, Ny = m.shape
    F = np.fft.fft2(m)

    components = []
    seen = set()

    for kx in range(Nx):
        for ky in range(Ny):
            # Conjugate partner indices for real-valued input
            kx_conj = (-kx) % Nx
            ky_conj = (-ky) % Ny

            pair = tuple(sorted([(kx, ky), (kx_conj, ky_conj)]))
            if pair in seen:
                continue
            seen.add(pair)

            # Always store the "smaller" one in lexicographic order
            kx_rep, ky_rep = pair[0]
            coeff = F[kx_rep, ky_rep]
            components.append({
                "kx": kx_rep,
                "ky": ky_rep,
                "coeff": coeff
            })

    return components, Nx, Ny


def components_to_terms(components, Nx, Ny, num_freqs, include_dc=True):
    """
    Convert FFT components into real cosine terms with amplitude & phase.

    Args:
        components: output from compute_frequency_components
        Nx, Ny: grid size
        num_freqs: number of *non-DC* frequencies to keep
        include_dc: whether to include the constant (DC) term

    Returns:
        terms: list of dicts with keys:
            - 'kx', 'ky'
            - 'amplitude'  (real, >= 0)
            - 'phase'      (in radians)
            - 'is_dc'      (bool, True only for the constant term)
    """
    terms = []
    dc_term = None

    for c in components:
        kx = c["kx"]
        ky = c["ky"]
        coeff = c["coeff"]

        # DC component (constant offset)
        if kx == 0 and ky == 0:
            dc_value = coeff.real / (Nx * Ny)
            dc_term = {
                "kx": 0,
                "ky": 0,
                "amplitude": dc_value,  # directly the constant offset
                "phase": 0.0,
                "is_dc": True,
            }
        else:
            # For real signals, combine (k, l) and (-k, -l) into:
            #   2*|F|/(Nx*Ny) * cos(2π(kx i/Nx + ky j/Ny) + phase)
            amp = 2.0 * np.abs(coeff) / (Nx * Ny)
            phase = np.angle(coeff)
            terms.append({
                "kx": kx,
                "ky": ky,
                "amplitude": amp,
                "phase": phase,
                "is_dc": False,
            })

    # Sort non-DC terms by amplitude (largest first)
    terms.sort(key=lambda t: t["amplitude"], reverse=True)

    # Keep only the top num_freqs
    terms = terms[:num_freqs]

    # Optionally prepend DC term
    if include_dc and dc_term is not None:
        terms = [dc_term] + terms

    return terms

def generate_python_reconstructor(terms, Nx, Ny, func_name="recon_func", decimals=4):
    """
    Generate a Python function as a string that reconstructs the signal
    using explicit 1D and product-of-cosine terms from a sparse Fourier representation.

    Types of terms:
      - DC term (constant)
      - Row-only:   A * cos(2π * (kx*i/Nx) + φ)
      - Col-only:   B * cos(2π * (ky*j/Ny) + φ)
      - Product:    C * cos(2π * (kx*i/Nx) + φ) * cos(2π * (ky*j/Ny) + φ)

    You must have `import numpy as np` in the scope where you paste/run this.
    """
    lines = []
    lines.append(f"def {func_name}(i, j):")

    if not terms:
        lines.append("    return 0.0")
        return "\n".join(lines)

    # Separate DC from others
    dc_terms = [t for t in terms if t.get("is_dc", False)]
    non_dc_terms = [t for t in terms if not t.get("is_dc", False)]

    if dc_terms:
        dc_val = round(dc_terms[0]["amplitude"], decimals)
        lines.append(f"    val = {dc_val}")
    else:
        lines.append("    val = 0.0")

    for t in non_dc_terms:
        kx, ky = t["kx"], t["ky"]
        A = round(t["amplitude"], decimals)
        phi = round(t["phase"], decimals)

        if A == 0:
            continue

        if kx != 0 and ky == 0:
            # Row-only cosine
            line = (
                f"    val += {A} * np.cos(2*np.pi*(({kx}*i)/{Nx}) + {phi})"
            )
        elif kx == 0 and ky != 0:
            # Column-only cosine
            line = (
                f"    val += {A} * np.cos(2*np.pi*(({ky}*j)/{Ny}) + {phi})"
            )
        else:
            # Product-of-cosines term (your desired "third" type)
            line = (
                f"    val += {A} * np.cos(2*np.pi*(({kx}*i)/{Nx}) + {phi})"
                f" * np.cos(2*np.pi*(({ky}*j)/{Ny}) + {phi})"
            )

        lines.append(line)

    lines.append("    return val")

    return "\n".join(lines)

# %%
def set_seed(seed):
        torch.manual_seed(seed)
        torch.cuda.manual_seed_all(seed) # For all CUDA devices
        np.random.seed(seed)
        random.seed(seed)
        torch.backends.cudnn.deterministic = True
        torch.backends.cudnn.benchmark = False # Set to False for determinism

# %%
def embedding_frequency_penalty(model: Transformer) -> torch.Tensor:
    """
    Encourage neighboring tokens in the embedding space to be similar.
    This is a graph-Laplacian-style smoothness penalty on W_E, which
    corresponds to penalizing high-frequency Fourier modes on Z_p.

    W_E has shape [d_model, d_vocab].
    We smooth along the vocab dimension (the modular arithmetic axis).
    """
    E = model.embed.W_E  # [d_model, d_vocab]

    # Differences between consecutive tokens (0-1, 1-2, ..., (V-2)-(V-1))
    diff = E[:, 1:] - E[:, :-1]  # [d_model, d_vocab-1]

    # Wrap-around difference to respect modular structure: token V-1 vs 0
    wrap = E[:, :1] - E[:, -1:]  # [d_model, 1]

    # Mean squared differences (Laplacian smoothness)
    penalty = (diff.pow(2).mean() + wrap.pow(2).mean())
    return penalty

# %% [markdown]
# ## Hyperparameters

# %%
root = Path('/home/stephen/grokking')


p=113
# seed=2 ##Set at top

lr=1e-3 #@param
p=113 #@param
d_model = 128 #@param
fn_name = 'add' #@param ['add', 'subtract', 'x2xyy2','rand']
num_epochs = 20000 #@param
save_models = True #@param
save_every = 10 # Maybe crank this down
# Stop training when test loss is <stopping_thresh
stopping_thresh = -1 #@param

num_layers = 1
batch_style = 'full'
d_vocab = p+1
n_ctx = 3
d_mlp = 4*d_model
num_heads = 4
assert d_model % num_heads == 0
d_head = d_model//num_heads
act_type = 'ReLU' #@param ['ReLU', 'GeLU']
# batch_size = 512
use_ln = False
random_answers = np.random.randint(low=0, high=p, size=(p, p))
fns_dict = {'add': lambda x,y:(x+y)%p, 'subtract': lambda x,y:(x-y)%p, 'x2xyy2':lambda x,y:(x**2+x*y+y**2)%p, 'rand':lambda x,y:random_answers[x][y]}
fn = fns_dict[fn_name]

# %%
frac_train, seed
# Out:
# (0.25, 2)

# %%
def gen_train_test(frac_train, num, seed=0):
    # Generate train and test split
    pairs = [(i, j, num) for i in range(num) for j in range(num)]
    random.seed(seed)
    random.shuffle(pairs)
    div = int(frac_train*len(pairs))
    return pairs[:div], pairs[div:]

train, test = gen_train_test(frac_train, p, seed)
print(len(train), len(test))
# Out:
# 3192 9577

# %%
# Creates an array of Boolean indices according to whether each data point is in 
# train or test
# Used to index into the big batch of all possible data
is_train = []
is_test = []
for x in range(p):
    for y in range(p):
        if (x, y, 113) in train:
            is_train.append(True)
            is_test.append(False)
        else:
            is_train.append(False)
            is_test.append(True)
is_train = np.array(is_train)
is_test = np.array(is_test)

# %% [markdown]
# ## Training Loop

# %%
set_seed(seed)
model = Transformer(num_layers=num_layers, d_vocab=d_vocab, d_model=d_model, d_mlp=d_mlp, d_head=d_head, num_heads=num_heads, n_ctx=n_ctx, act_type=act_type, use_cache=False, use_ln=use_ln)
model.to('cuda')
optimizer = optim.AdamW(model.parameters(), lr=lr, weight_decay=weight_decay, betas=(0.9, 0.98))
scheduler = optim.lr_scheduler.LambdaLR(optimizer, lambda step: min(step/10, 1))
run_name = f"grok_{int(time.time())}"
print(f'Run name {run_name}')
if save_models:
    os.mkdir(root/run_name)
    save_dict = {'model':model.state_dict(), 'train_data':train, 'test_data':test}
    torch.save(save_dict, root/run_name/'init.pth')
train_losses = []
test_losses = []
train_accs = []
test_accs = []
for epoch in range(num_epochs):

    # 1. Compute base cross-entropy losses (no regularization)
    train_ce_loss = full_loss(model, train)
    test_loss = full_loss(model, test)  # leave test as-is

    # 2. Compute smoothness / frequency penalty on embeddings
    freq_pen = embedding_frequency_penalty(model)

    # 3. Total train loss = CE + λ * penalty
    train_loss = train_ce_loss + freq_penalty_weight * freq_pen

    # 4. Track (usually you want to log CE only for grokking plots)
    train_losses.append(train_ce_loss.item())
    test_losses.append(test_loss.item())

    logits = model(train)[:, -1]
    labels = torch.tensor([fn(i, j) for i, j, _ in train]).to('cuda')
    train_acc=((logits.detach().cpu().argmax(1)==labels.detach().cpu()).sum()/len(labels)).item()
    train_accs.append(train_acc)
    
    logits = model(test)[:, -1]
    labels = torch.tensor([fn(i, j) for i, j, _ in test]).to('cuda')
    test_acc=((logits.detach().cpu().argmax(1)==labels.detach().cpu()).sum()/len(labels)).item()
    test_accs.append(test_acc)

    if epoch % 100 == 0:
        print(
            f"{epoch}_"
            f"{np.log(train_ce_loss.item()):.4f}_"
            f"{np.log(test_loss.item()):.4f}_"
            f"pen={freq_pen.item():.3e}"
        )

    # 5. Backprop / step
    train_loss.backward()
    optimizer.step()
    scheduler.step()
    optimizer.zero_grad()
    if test_loss.item() < stopping_thresh:
        break
    if (save_models) and (epoch%save_every == 0):
        if test_loss.item() < stopping_thresh:
            break
        save_dict = {
            'model': model.state_dict(),
            'optimizer': optimizer.state_dict(),
            'scheduler': scheduler.state_dict(),
            'train_loss': train_loss,
            'test_loss': test_loss,
            'epoch': epoch,
        }
        torch.save(save_dict, root/run_name/f"{epoch}.pth")
        print(f"Saved model to {root/run_name/f'{epoch}.pth'}")
if not save_models:
    os.mkdir(root/run_name)
save_dict = {
    'model': model.state_dict(),
    'optimizer': optimizer.state_dict(),
    'scheduler': scheduler.state_dict(),
    'train_loss': train_loss,
    'test_loss': test_loss,
    'train_losses': train_losses,
    'test_losses': test_losses,
    'train_accs': train_accs,
    'test_accs':test_accs,
    'epoch': epoch,
}
torch.save(save_dict, root/run_name/f"final.pth")
print(f"Saved model to {root/run_name/f'final.pth'}")

# save_models = False
# Out:
# Run name grok_1764706124
# 0_1.5605_1.5598_pen=3.216e-02
# Saved model to /home/stephen/grokking/grok_1764706124/0.pth
# Saved model to /home/stephen/grokking/grok_1764706124/10.pth
# Saved model to /home/stephen/grokking/grok_1764706124/20.pth
# Saved model to /home/stephen/grokking/grok_1764706124/30.pth
# Saved model to /home/stephen/grokking/grok_1764706124/40.pth
# Saved model to /home/stephen/grokking/grok_1764706124/50.pth
# Saved model to /home/stephen/grokking/grok_1764706124/60.pth
# Saved model to /home/stephen/grokking/grok_1764706124/70.pth
# Saved model to /home/stephen/grokking/grok_1764706124/80.pth
# Saved model to /home/stephen/grokking/grok_1764706124/90.pth
# 100_0.6338_2.1446_pen=5.509e-02
# Saved model to /home/stephen/grokking/grok_1764706124/100.pth
# Saved model to /home/stephen/grokking/grok_1764706124/110.pth
# Saved model to /home/stephen/grokking/grok_1764706124/120.pth
# Saved model to /home/stephen/grokking/grok_1764706124/130.pth
# Saved model to /home/stephen/grokking/grok_1764706124/140.pth
# Saved model to /home/stephen/grokking/grok_1764706124/150.pth
# Saved model to /home/stephen/grokking/grok_1764706124/160.pth
# Saved model to /home/stephen/grokking/grok_1764706124/170.pth
# Saved model to /home/stephen/grokking/grok_1764706124/180.pth
# Saved model to /home/stephen/grokking/grok_1764706124/190.pth
# 200_-4.0661_2.8506_pen=7.544e-02
# Saved model to /home/stephen/grokking/grok_1764706124/200.pth
# Saved model to /home/stephen/grokking/grok_1764706124/210.pth
# Saved model to /home/stephen/grokking/grok_1764706124/220.pth
# Saved model to /home/stephen/grokking/grok_1764706124/230.pth
# Saved model to /home/stephen/grokking/grok_1764706124/240.pth
# Saved model to /home/stephen/grokking/grok_1764706124/250.pth
# Saved model to /home/stephen/grokking/grok_1764706124/260.pth
# Saved model to /home/stephen/grokking/grok_1764706124/270.pth
# Saved model to /home/stephen/grokking/grok_1764706124/280.pth
# Saved model to /home/stephen/grokking/grok_1764706124/290.pth
# 300_-5.1161_2.8809_pen=7.506e-02
# Saved model to /home/stephen/grokking/grok_1764706124/300.pth
# Saved model to /home/stephen/grokking/grok_1764706124/310.pth
# Saved model to /home/stephen/grokking/grok_1764706124/320.pth
# Saved model to /home/stephen/grokking/grok_1764706124/330.pth
# Saved model to /home/stephen/grokking/grok_1764706124/340.pth
# Saved model to /home/stephen/grokking/grok_1764706124/350.pth
# Saved model to /home/stephen/grokking/grok_1764706124/360.pth
# Saved model to /home/stephen/grokking/grok_1764706124/370.pth
# Saved model to /home/stephen/grokking/grok_1764706124/380.pth
# Saved model to /home/stephen/grokking/grok_1764706124/390.pth
# 400_-6.2389_2.9353_pen=7.451e-02
# Saved model to /home/stephen/grokking/grok_1764706124/400.pth
# Saved model to /home/stephen/grokking/grok_1764706124/410.pth
# Saved model to /home/stephen/grokking/grok_1764706124/420.pth
# Saved model to /home/stephen/grokking/grok_1764706124/430.pth
# Saved model to /home/stephen/grokking/grok_1764706124/440.pth
# Saved model to /home/stephen/grokking/grok_1764706124/450.pth
# Saved model to /home/stephen/grokking/grok_1764706124/460.pth
# Saved model to /home/stephen/grokking/grok_1764706124/470.pth
# Saved model to /home/stephen/grokking/grok_1764706124/480.pth
# Saved model to /home/stephen/grokking/grok_1764706124/490.pth
# 500_-7.3371_2.9928_pen=7.229e-02
# Saved model to /home/stephen/grokking/grok_1764706124/500.pth
# Saved model to /home/stephen/grokking/grok_1764706124/510.pth
# Saved model to /home/stephen/grokking/grok_1764706124/520.pth
# Saved model to /home/stephen/grokking/grok_1764706124/530.pth
# Saved model to /home/stephen/grokking/grok_1764706124/540.pth
# Saved model to /home/stephen/grokking/grok_1764706124/550.pth
# Saved model to /home/stephen/grokking/grok_1764706124/560.pth
# Saved model to /home/stephen/grokking/grok_1764706124/570.pth
# Saved model to /home/stephen/grokking/grok_1764706124/580.pth
# Saved model to /home/stephen/grokking/grok_1764706124/590.pth
# 600_-8.4185_3.0502_pen=6.662e-02
# Saved model to /home/stephen/grokking/grok_1764706124/600.pth
# Saved model to /home/stephen/grokking/grok_1764706124/610.pth
# Saved model to /home/stephen/grokking/grok_1764706124/620.pth
# Saved model to /home/stephen/grokking/grok_1764706124/630.pth
# Saved model to /home/stephen/grokking/grok_1764706124/640.pth
# Saved model to /home/stephen/grokking/grok_1764706124/650.pth
# Saved model to /home/stephen/grokking/grok_1764706124/660.pth
# Saved model to /home/stephen/grokking/grok_1764706124/670.pth
# Saved model to /home/stephen/grokking/grok_1764706124/680.pth
# Saved model to /home/stephen/grokking/grok_1764706124/690.pth
# 700_-9.4781_3.1058_pen=5.694e-02
# Saved model to /home/stephen/grokking/grok_1764706124/700.pth
# Saved model to /home/stephen/grokking/grok_1764706124/710.pth
# Saved model to /home/stephen/grokking/grok_1764706124/720.pth
# Saved model to /home/stephen/grokking/grok_1764706124/730.pth
# Saved model to /home/stephen/grokking/grok_1764706124/740.pth
# Saved model to /home/stephen/grokking/grok_1764706124/750.pth
# Saved model to /home/stephen/grokking/grok_1764706124/760.pth
# Saved model to /home/stephen/grokking/grok_1764706124/770.pth
# Saved model to /home/stephen/grokking/grok_1764706124/780.pth
# Saved model to /home/stephen/grokking/grok_1764706124/790.pth
# 800_-10.5064_3.1581_pen=4.640e-02
# Saved model to /home/stephen/grokking/grok_1764706124/800.pth
# Saved model to /home/stephen/grokking/grok_1764706124/810.pth
# Saved model to /home/stephen/grokking/grok_1764706124/820.pth
# Saved model to /home/stephen/grokking/grok_1764706124/830.pth
# Saved model to /home/stephen/grokking/grok_1764706124/840.pth
# Saved model to /home/stephen/grokking/grok_1764706124/850.pth
# Saved model to /home/stephen/grokking/grok_1764706124/860.pth
# Saved model to /home/stephen/grokking/grok_1764706124/870.pth
# Saved model to /home/stephen/grokking/grok_1764706124/880.pth
# Saved model to /home/stephen/grokking/grok_1764706124/890.pth
# 900_-11.4754_3.2045_pen=3.869e-02
# Saved model to /home/stephen/grokking/grok_1764706124/900.pth
# Saved model to /home/stephen/grokking/grok_1764706124/910.pth
# Saved model to /home/stephen/grokking/grok_1764706124/920.pth
# Saved model to /home/stephen/grokking/grok_1764706124/930.pth
# Saved model to /home/stephen/grokking/grok_1764706124/940.pth
# Saved model to /home/stephen/grokking/grok_1764706124/950.pth
# Saved model to /home/stephen/grokking/grok_1764706124/960.pth
# Saved model to /home/stephen/grokking/grok_1764706124/970.pth
# Saved model to /home/stephen/grokking/grok_1764706124/980.pth
# Saved model to /home/stephen/grokking/grok_1764706124/990.pth
# 1000_-12.3132_3.2419_pen=3.068e-02
# Saved model to /home/stephen/grokking/grok_1764706124/1000.pth
# Saved model to /home/stephen/grokking/grok_1764706124/1010.pth
# Saved model to /home/stephen/grokking/grok_1764706124/1020.pth
# Saved model to /home/stephen/grokking/grok_1764706124/1030.pth
# Saved model to /home/stephen/grokking/grok_1764706124/1040.pth
# Saved model to /home/stephen/grokking/grok_1764706124/1050.pth
# Saved model to /home/stephen/grokking/grok_1764706124/1060.pth
# Saved model to /home/stephen/grokking/grok_1764706124/1070.pth
# Saved model to /home/stephen/grokking/grok_1764706124/1080.pth
# Saved model to /home/stephen/grokking/grok_1764706124/1090.pth
# 1100_-12.9707_3.2710_pen=2.064e-02
# Saved model to /home/stephen/grokking/grok_1764706124/1100.pth
# Saved model to /home/stephen/grokking/grok_1764706124/1110.pth
# Saved model to /home/stephen/grokking/grok_1764706124/1120.pth
# Saved model to /home/stephen/grokking/grok_1764706124/1130.pth
# Saved model to /home/stephen/grokking/grok_1764706124/1140.pth
# Saved model to /home/stephen/grokking/grok_1764706124/1150.pth
# Saved model to /home/stephen/grokking/grok_1764706124/1160.pth
# Saved model to /home/stephen/grokking/grok_1764706124/1170.pth
# Saved model to /home/stephen/grokking/grok_1764706124/1180.pth
# Saved model to /home/stephen/grokking/grok_1764706124/1190.pth
# 1200_-13.4905_3.2918_pen=1.250e-02
# Saved model to /home/stephen/grokking/grok_1764706124/1200.pth
# Saved model to /home/stephen/grokking/grok_1764706124/1210.pth
# Saved model to /home/stephen/grokking/grok_1764706124/1220.pth
# Saved model to /home/stephen/grokking/grok_1764706124/1230.pth
# Saved model to /home/stephen/grokking/grok_1764706124/1240.pth
# Saved model to /home/stephen/grokking/grok_1764706124/1250.pth
# Saved model to /home/stephen/grokking/grok_1764706124/1260.pth
# Saved model to /home/stephen/grokking/grok_1764706124/1270.pth
# Saved model to /home/stephen/grokking/grok_1764706124/1280.pth
# Saved model to /home/stephen/grokking/grok_1764706124/1290.pth
# 1300_-13.8941_3.2996_pen=7.988e-03
# Saved model to /home/stephen/grokking/grok_1764706124/1300.pth
# Saved model to /home/stephen/grokking/grok_1764706124/1310.pth
# Saved model to /home/stephen/grokking/grok_1764706124/1320.pth
# Saved model to /home/stephen/grokking/grok_1764706124/1330.pth
# Saved model to /home/stephen/grokking/grok_1764706124/1340.pth
# Saved model to /home/stephen/grokking/grok_1764706124/1350.pth
# Saved model to /home/stephen/grokking/grok_1764706124/1360.pth
# Saved model to /home/stephen/grokking/grok_1764706124/1370.pth
# Saved model to /home/stephen/grokking/grok_1764706124/1380.pth
# Saved model to /home/stephen/grokking/grok_1764706124/1390.pth
# 1400_-14.1657_3.2972_pen=5.861e-03
# Saved model to /home/stephen/grokking/grok_1764706124/1400.pth
# Saved model to /home/stephen/grokking/grok_1764706124/1410.pth
# Saved model to /home/stephen/grokking/grok_1764706124/1420.pth
# Saved model to /home/stephen/grokking/grok_1764706124/1430.pth
# Saved model to /home/stephen/grokking/grok_1764706124/1440.pth
# Saved model to /home/stephen/grokking/grok_1764706124/1450.pth
# Saved model to /home/stephen/grokking/grok_1764706124/1460.pth
# Saved model to /home/stephen/grokking/grok_1764706124/1470.pth
# Saved model to /home/stephen/grokking/grok_1764706124/1480.pth
# Saved model to /home/stephen/grokking/grok_1764706124/1490.pth
# 1500_-14.3219_3.2875_pen=4.872e-03
# Saved model to /home/stephen/grokking/grok_1764706124/1500.pth
# Saved model to /home/stephen/grokking/grok_1764706124/1510.pth
# Saved model to /home/stephen/grokking/grok_1764706124/1520.pth
# Saved model to /home/stephen/grokking/grok_1764706124/1530.pth
# Saved model to /home/stephen/grokking/grok_1764706124/1540.pth
# Saved model to /home/stephen/grokking/grok_1764706124/1550.pth
# Saved model to /home/stephen/grokking/grok_1764706124/1560.pth
# Saved model to /home/stephen/grokking/grok_1764706124/1570.pth
# Saved model to /home/stephen/grokking/grok_1764706124/1580.pth
# Saved model to /home/stephen/grokking/grok_1764706124/1590.pth
# 1600_-14.4078_3.2750_pen=4.384e-03
# Saved model to /home/stephen/grokking/grok_1764706124/1600.pth
# Saved model to /home/stephen/grokking/grok_1764706124/1610.pth
# Saved model to /home/stephen/grokking/grok_1764706124/1620.pth
# Saved model to /home/stephen/grokking/grok_1764706124/1630.pth
# Saved model to /home/stephen/grokking/grok_1764706124/1640.pth
# Saved model to /home/stephen/grokking/grok_1764706124/1650.pth
# Saved model to /home/stephen/grokking/grok_1764706124/1660.pth
# Saved model to /home/stephen/grokking/grok_1764706124/1670.pth
# Saved model to /home/stephen/grokking/grok_1764706124/1680.pth
# Saved model to /home/stephen/grokking/grok_1764706124/1690.pth
# 1700_-14.4564_3.2603_pen=4.125e-03
# Saved model to /home/stephen/grokking/grok_1764706124/1700.pth
# Saved model to /home/stephen/grokking/grok_1764706124/1710.pth
# Saved model to /home/stephen/grokking/grok_1764706124/1720.pth
# Saved model to /home/stephen/grokking/grok_1764706124/1730.pth
# Saved model to /home/stephen/grokking/grok_1764706124/1740.pth
# Saved model to /home/stephen/grokking/grok_1764706124/1750.pth
# Saved model to /home/stephen/grokking/grok_1764706124/1760.pth
# Saved model to /home/stephen/grokking/grok_1764706124/1770.pth
# Saved model to /home/stephen/grokking/grok_1764706124/1780.pth
# Saved model to /home/stephen/grokking/grok_1764706124/1790.pth
# 1800_-14.4848_3.2444_pen=3.970e-03
# Saved model to /home/stephen/grokking/grok_1764706124/1800.pth
# Saved model to /home/stephen/grokking/grok_1764706124/1810.pth
# Saved model to /home/stephen/grokking/grok_1764706124/1820.pth
# Saved model to /home/stephen/grokking/grok_1764706124/1830.pth
# Saved model to /home/stephen/grokking/grok_1764706124/1840.pth
# Saved model to /home/stephen/grokking/grok_1764706124/1850.pth
# Saved model to /home/stephen/grokking/grok_1764706124/1860.pth
# Saved model to /home/stephen/grokking/grok_1764706124/1870.pth
# Saved model to /home/stephen/grokking/grok_1764706124/1880.pth
# Saved model to /home/stephen/grokking/grok_1764706124/1890.pth
# 1900_-14.5032_3.2274_pen=3.864e-03
# Saved model to /home/stephen/grokking/grok_1764706124/1900.pth
# Saved model to /home/stephen/grokking/grok_1764706124/1910.pth
# Saved model to /home/stephen/grokking/grok_1764706124/1920.pth
# Saved model to /home/stephen/grokking/grok_1764706124/1930.pth
# Saved model to /home/stephen/grokking/grok_1764706124/1940.pth
# Saved model to /home/stephen/grokking/grok_1764706124/1950.pth
# Saved model to /home/stephen/grokking/grok_1764706124/1960.pth
# Saved model to /home/stephen/grokking/grok_1764706124/1970.pth
# Saved model to /home/stephen/grokking/grok_1764706124/1980.pth
# Saved model to /home/stephen/grokking/grok_1764706124/1990.pth
# 2000_-14.5199_3.2096_pen=3.782e-03
# Saved model to /home/stephen/grokking/grok_1764706124/2000.pth
# Saved model to /home/stephen/grokking/grok_1764706124/2010.pth
# Saved model to /home/stephen/grokking/grok_1764706124/2020.pth
# Saved model to /home/stephen/grokking/grok_1764706124/2030.pth
# Saved model to /home/stephen/grokking/grok_1764706124/2040.pth
# Saved model to /home/stephen/grokking/grok_1764706124/2050.pth
# Saved model to /home/stephen/grokking/grok_1764706124/2060.pth
# Saved model to /home/stephen/grokking/grok_1764706124/2070.pth
# Saved model to /home/stephen/grokking/grok_1764706124/2080.pth
# Saved model to /home/stephen/grokking/grok_1764706124/2090.pth
# 2100_-14.5345_3.1903_pen=3.712e-03
# Saved model to /home/stephen/grokking/grok_1764706124/2100.pth
# Saved model to /home/stephen/grokking/grok_1764706124/2110.pth
# Saved model to /home/stephen/grokking/grok_1764706124/2120.pth
# Saved model to /home/stephen/grokking/grok_1764706124/2130.pth
# Saved model to /home/stephen/grokking/grok_1764706124/2140.pth
# Saved model to /home/stephen/grokking/grok_1764706124/2150.pth
# Saved model to /home/stephen/grokking/grok_1764706124/2160.pth
# Saved model to /home/stephen/grokking/grok_1764706124/2170.pth
# Saved model to /home/stephen/grokking/grok_1764706124/2180.pth
# Saved model to /home/stephen/grokking/grok_1764706124/2190.pth
# 2200_-14.5469_3.1704_pen=3.645e-03
# Saved model to /home/stephen/grokking/grok_1764706124/2200.pth
# Saved model to /home/stephen/grokking/grok_1764706124/2210.pth
# Saved model to /home/stephen/grokking/grok_1764706124/2220.pth
# Saved model to /home/stephen/grokking/grok_1764706124/2230.pth
# Saved model to /home/stephen/grokking/grok_1764706124/2240.pth
# Saved model to /home/stephen/grokking/grok_1764706124/2250.pth
# Saved model to /home/stephen/grokking/grok_1764706124/2260.pth
# Saved model to /home/stephen/grokking/grok_1764706124/2270.pth
# Saved model to /home/stephen/grokking/grok_1764706124/2280.pth
# Saved model to /home/stephen/grokking/grok_1764706124/2290.pth
# 2300_-14.5567_3.1490_pen=3.583e-03
# Saved model to /home/stephen/grokking/grok_1764706124/2300.pth
# Saved model to /home/stephen/grokking/grok_1764706124/2310.pth
# Saved model to /home/stephen/grokking/grok_1764706124/2320.pth
# Saved model to /home/stephen/grokking/grok_1764706124/2330.pth
# Saved model to /home/stephen/grokking/grok_1764706124/2340.pth
# Saved model to /home/stephen/grokking/grok_1764706124/2350.pth
# Saved model to /home/stephen/grokking/grok_1764706124/2360.pth
# Saved model to /home/stephen/grokking/grok_1764706124/2370.pth
# Saved model to /home/stephen/grokking/grok_1764706124/2380.pth
# Saved model to /home/stephen/grokking/grok_1764706124/2390.pth
# 2400_-14.5719_3.1254_pen=3.519e-03
# Saved model to /home/stephen/grokking/grok_1764706124/2400.pth
# Saved model to /home/stephen/grokking/grok_1764706124/2410.pth
# Saved model to /home/stephen/grokking/grok_1764706124/2420.pth
# Saved model to /home/stephen/grokking/grok_1764706124/2430.pth
# Saved model to /home/stephen/grokking/grok_1764706124/2440.pth
# Saved model to /home/stephen/grokking/grok_1764706124/2450.pth
# Saved model to /home/stephen/grokking/grok_1764706124/2460.pth
# Saved model to /home/stephen/grokking/grok_1764706124/2470.pth
# Saved model to /home/stephen/grokking/grok_1764706124/2480.pth
# Saved model to /home/stephen/grokking/grok_1764706124/2490.pth
# 2500_-14.5846_3.0988_pen=3.452e-03
# Saved model to /home/stephen/grokking/grok_1764706124/2500.pth
# Saved model to /home/stephen/grokking/grok_1764706124/2510.pth
# Saved model to /home/stephen/grokking/grok_1764706124/2520.pth
# Saved model to /home/stephen/grokking/grok_1764706124/2530.pth
# Saved model to /home/stephen/grokking/grok_1764706124/2540.pth
# Saved model to /home/stephen/grokking/grok_1764706124/2550.pth
# Saved model to /home/stephen/grokking/grok_1764706124/2560.pth
# Saved model to /home/stephen/grokking/grok_1764706124/2570.pth
# Saved model to /home/stephen/grokking/grok_1764706124/2580.pth
# Saved model to /home/stephen/grokking/grok_1764706124/2590.pth
# 2600_-14.5964_3.0691_pen=3.386e-03
# Saved model to /home/stephen/grokking/grok_1764706124/2600.pth
# Saved model to /home/stephen/grokking/grok_1764706124/2610.pth
# Saved model to /home/stephen/grokking/grok_1764706124/2620.pth
# Saved model to /home/stephen/grokking/grok_1764706124/2630.pth
# Saved model to /home/stephen/grokking/grok_1764706124/2640.pth
# Saved model to /home/stephen/grokking/grok_1764706124/2650.pth
# Saved model to /home/stephen/grokking/grok_1764706124/2660.pth
# Saved model to /home/stephen/grokking/grok_1764706124/2670.pth
# Saved model to /home/stephen/grokking/grok_1764706124/2680.pth
# Saved model to /home/stephen/grokking/grok_1764706124/2690.pth
# 2700_-14.6100_3.0351_pen=3.318e-03
# Saved model to /home/stephen/grokking/grok_1764706124/2700.pth
# Saved model to /home/stephen/grokking/grok_1764706124/2710.pth
# Saved model to /home/stephen/grokking/grok_1764706124/2720.pth
# Saved model to /home/stephen/grokking/grok_1764706124/2730.pth
# Saved model to /home/stephen/grokking/grok_1764706124/2740.pth
# Saved model to /home/stephen/grokking/grok_1764706124/2750.pth
# Saved model to /home/stephen/grokking/grok_1764706124/2760.pth
# Saved model to /home/stephen/grokking/grok_1764706124/2770.pth
# Saved model to /home/stephen/grokking/grok_1764706124/2780.pth
# Saved model to /home/stephen/grokking/grok_1764706124/2790.pth
# 2800_-14.6220_2.9967_pen=3.246e-03
# Saved model to /home/stephen/grokking/grok_1764706124/2800.pth
# Saved model to /home/stephen/grokking/grok_1764706124/2810.pth
# Saved model to /home/stephen/grokking/grok_1764706124/2820.pth
# Saved model to /home/stephen/grokking/grok_1764706124/2830.pth
# Saved model to /home/stephen/grokking/grok_1764706124/2840.pth
# Saved model to /home/stephen/grokking/grok_1764706124/2850.pth
# Saved model to /home/stephen/grokking/grok_1764706124/2860.pth
# Saved model to /home/stephen/grokking/grok_1764706124/2870.pth
# Saved model to /home/stephen/grokking/grok_1764706124/2880.pth
# Saved model to /home/stephen/grokking/grok_1764706124/2890.pth
# 2900_-14.6423_2.9526_pen=3.174e-03
# Saved model to /home/stephen/grokking/grok_1764706124/2900.pth
# Saved model to /home/stephen/grokking/grok_1764706124/2910.pth
# Saved model to /home/stephen/grokking/grok_1764706124/2920.pth
# Saved model to /home/stephen/grokking/grok_1764706124/2930.pth
# Saved model to /home/stephen/grokking/grok_1764706124/2940.pth
# Saved model to /home/stephen/grokking/grok_1764706124/2950.pth
# Saved model to /home/stephen/grokking/grok_1764706124/2960.pth
# Saved model to /home/stephen/grokking/grok_1764706124/2970.pth
# Saved model to /home/stephen/grokking/grok_1764706124/2980.pth
# Saved model to /home/stephen/grokking/grok_1764706124/2990.pth
# 3000_-14.6567_2.9029_pen=3.100e-03
# Saved model to /home/stephen/grokking/grok_1764706124/3000.pth
# Saved model to /home/stephen/grokking/grok_1764706124/3010.pth
# Saved model to /home/stephen/grokking/grok_1764706124/3020.pth
# Saved model to /home/stephen/grokking/grok_1764706124/3030.pth
# Saved model to /home/stephen/grokking/grok_1764706124/3040.pth
# Saved model to /home/stephen/grokking/grok_1764706124/3050.pth
# Saved model to /home/stephen/grokking/grok_1764706124/3060.pth
# Saved model to /home/stephen/grokking/grok_1764706124/3070.pth
# Saved model to /home/stephen/grokking/grok_1764706124/3080.pth
# Saved model to /home/stephen/grokking/grok_1764706124/3090.pth
# 3100_-14.6726_2.8466_pen=3.022e-03
# Saved model to /home/stephen/grokking/grok_1764706124/3100.pth
# Saved model to /home/stephen/grokking/grok_1764706124/3110.pth
# Saved model to /home/stephen/grokking/grok_1764706124/3120.pth
# Saved model to /home/stephen/grokking/grok_1764706124/3130.pth
# Saved model to /home/stephen/grokking/grok_1764706124/3140.pth
# Saved model to /home/stephen/grokking/grok_1764706124/3150.pth
# Saved model to /home/stephen/grokking/grok_1764706124/3160.pth
# Saved model to /home/stephen/grokking/grok_1764706124/3170.pth
# Saved model to /home/stephen/grokking/grok_1764706124/3180.pth
# Saved model to /home/stephen/grokking/grok_1764706124/3190.pth
# 3200_-14.6929_2.7818_pen=2.941e-03
# Saved model to /home/stephen/grokking/grok_1764706124/3200.pth
# Saved model to /home/stephen/grokking/grok_1764706124/3210.pth
# Saved model to /home/stephen/grokking/grok_1764706124/3220.pth
# Saved model to /home/stephen/grokking/grok_1764706124/3230.pth
# Saved model to /home/stephen/grokking/grok_1764706124/3240.pth
# Saved model to /home/stephen/grokking/grok_1764706124/3250.pth
# Saved model to /home/stephen/grokking/grok_1764706124/3260.pth
# Saved model to /home/stephen/grokking/grok_1764706124/3270.pth
# Saved model to /home/stephen/grokking/grok_1764706124/3280.pth
# Saved model to /home/stephen/grokking/grok_1764706124/3290.pth
# 3300_-14.7138_2.7071_pen=2.855e-03
# Saved model to /home/stephen/grokking/grok_1764706124/3300.pth
# Saved model to /home/stephen/grokking/grok_1764706124/3310.pth
# Saved model to /home/stephen/grokking/grok_1764706124/3320.pth
# Saved model to /home/stephen/grokking/grok_1764706124/3330.pth
# Saved model to /home/stephen/grokking/grok_1764706124/3340.pth
# Saved model to /home/stephen/grokking/grok_1764706124/3350.pth
# Saved model to /home/stephen/grokking/grok_1764706124/3360.pth
# Saved model to /home/stephen/grokking/grok_1764706124/3370.pth
# Saved model to /home/stephen/grokking/grok_1764706124/3380.pth
# Saved model to /home/stephen/grokking/grok_1764706124/3390.pth
# 3400_-14.7350_2.6219_pen=2.771e-03
# Saved model to /home/stephen/grokking/grok_1764706124/3400.pth
# Saved model to /home/stephen/grokking/grok_1764706124/3410.pth
# Saved model to /home/stephen/grokking/grok_1764706124/3420.pth
# Saved model to /home/stephen/grokking/grok_1764706124/3430.pth
# Saved model to /home/stephen/grokking/grok_1764706124/3440.pth
# Saved model to /home/stephen/grokking/grok_1764706124/3450.pth
# Saved model to /home/stephen/grokking/grok_1764706124/3460.pth
# Saved model to /home/stephen/grokking/grok_1764706124/3470.pth
# Saved model to /home/stephen/grokking/grok_1764706124/3480.pth
# Saved model to /home/stephen/grokking/grok_1764706124/3490.pth
# 3500_-14.7600_2.5238_pen=2.684e-03
# Saved model to /home/stephen/grokking/grok_1764706124/3500.pth
# Saved model to /home/stephen/grokking/grok_1764706124/3510.pth
# Saved model to /home/stephen/grokking/grok_1764706124/3520.pth
# Saved model to /home/stephen/grokking/grok_1764706124/3530.pth
# Saved model to /home/stephen/grokking/grok_1764706124/3540.pth
# Saved model to /home/stephen/grokking/grok_1764706124/3550.pth
# Saved model to /home/stephen/grokking/grok_1764706124/3560.pth
# Saved model to /home/stephen/grokking/grok_1764706124/3570.pth
# Saved model to /home/stephen/grokking/grok_1764706124/3580.pth
# Saved model to /home/stephen/grokking/grok_1764706124/3590.pth
# 3600_-14.7872_2.4085_pen=2.596e-03
# Saved model to /home/stephen/grokking/grok_1764706124/3600.pth
# Saved model to /home/stephen/grokking/grok_1764706124/3610.pth
# Saved model to /home/stephen/grokking/grok_1764706124/3620.pth
# Saved model to /home/stephen/grokking/grok_1764706124/3630.pth
# Saved model to /home/stephen/grokking/grok_1764706124/3640.pth
# Saved model to /home/stephen/grokking/grok_1764706124/3650.pth
# Saved model to /home/stephen/grokking/grok_1764706124/3660.pth
# Saved model to /home/stephen/grokking/grok_1764706124/3670.pth
# Saved model to /home/stephen/grokking/grok_1764706124/3680.pth
# Saved model to /home/stephen/grokking/grok_1764706124/3690.pth
# 3700_-14.8192_2.2701_pen=2.504e-03
# Saved model to /home/stephen/grokking/grok_1764706124/3700.pth
# Saved model to /home/stephen/grokking/grok_1764706124/3710.pth
# Saved model to /home/stephen/grokking/grok_1764706124/3720.pth
# Saved model to /home/stephen/grokking/grok_1764706124/3730.pth
# Saved model to /home/stephen/grokking/grok_1764706124/3740.pth
# Saved model to /home/stephen/grokking/grok_1764706124/3750.pth
# Saved model to /home/stephen/grokking/grok_1764706124/3760.pth
# Saved model to /home/stephen/grokking/grok_1764706124/3770.pth
# Saved model to /home/stephen/grokking/grok_1764706124/3780.pth
# Saved model to /home/stephen/grokking/grok_1764706124/3790.pth
# 3800_-14.8525_2.0961_pen=2.409e-03
# Saved model to /home/stephen/grokking/grok_1764706124/3800.pth
# Saved model to /home/stephen/grokking/grok_1764706124/3810.pth
# Saved model to /home/stephen/grokking/grok_1764706124/3820.pth
# Saved model to /home/stephen/grokking/grok_1764706124/3830.pth
# Saved model to /home/stephen/grokking/grok_1764706124/3840.pth
# Saved model to /home/stephen/grokking/grok_1764706124/3850.pth
# Saved model to /home/stephen/grokking/grok_1764706124/3860.pth
# Saved model to /home/stephen/grokking/grok_1764706124/3870.pth
# Saved model to /home/stephen/grokking/grok_1764706124/3880.pth
# Saved model to /home/stephen/grokking/grok_1764706124/3890.pth
# 3900_-14.8905_1.8706_pen=2.306e-03
# Saved model to /home/stephen/grokking/grok_1764706124/3900.pth
# Saved model to /home/stephen/grokking/grok_1764706124/3910.pth
# Saved model to /home/stephen/grokking/grok_1764706124/3920.pth
# Saved model to /home/stephen/grokking/grok_1764706124/3930.pth
# Saved model to /home/stephen/grokking/grok_1764706124/3940.pth
# Saved model to /home/stephen/grokking/grok_1764706124/3950.pth
# Saved model to /home/stephen/grokking/grok_1764706124/3960.pth
# Saved model to /home/stephen/grokking/grok_1764706124/3970.pth
# Saved model to /home/stephen/grokking/grok_1764706124/3980.pth
# Saved model to /home/stephen/grokking/grok_1764706124/3990.pth
# 4000_-14.9415_1.5530_pen=2.182e-03
# Saved model to /home/stephen/grokking/grok_1764706124/4000.pth
# Saved model to /home/stephen/grokking/grok_1764706124/4010.pth
# Saved model to /home/stephen/grokking/grok_1764706124/4020.pth
# Saved model to /home/stephen/grokking/grok_1764706124/4030.pth
# Saved model to /home/stephen/grokking/grok_1764706124/4040.pth
# Saved model to /home/stephen/grokking/grok_1764706124/4050.pth
# Saved model to /home/stephen/grokking/grok_1764706124/4060.pth
# Saved model to /home/stephen/grokking/grok_1764706124/4070.pth
# Saved model to /home/stephen/grokking/grok_1764706124/4080.pth
# Saved model to /home/stephen/grokking/grok_1764706124/4090.pth
# 4100_-14.9976_1.1088_pen=2.042e-03
# Saved model to /home/stephen/grokking/grok_1764706124/4100.pth
# Saved model to /home/stephen/grokking/grok_1764706124/4110.pth
# Saved model to /home/stephen/grokking/grok_1764706124/4120.pth
# Saved model to /home/stephen/grokking/grok_1764706124/4130.pth
# Saved model to /home/stephen/grokking/grok_1764706124/4140.pth
# Saved model to /home/stephen/grokking/grok_1764706124/4150.pth
# Saved model to /home/stephen/grokking/grok_1764706124/4160.pth
# Saved model to /home/stephen/grokking/grok_1764706124/4170.pth
# Saved model to /home/stephen/grokking/grok_1764706124/4180.pth
# Saved model to /home/stephen/grokking/grok_1764706124/4190.pth
# 4200_-15.0727_0.5299_pen=1.902e-03
# Saved model to /home/stephen/grokking/grok_1764706124/4200.pth
# Saved model to /home/stephen/grokking/grok_1764706124/4210.pth
# Saved model to /home/stephen/grokking/grok_1764706124/4220.pth
# Saved model to /home/stephen/grokking/grok_1764706124/4230.pth
# Saved model to /home/stephen/grokking/grok_1764706124/4240.pth
# Saved model to /home/stephen/grokking/grok_1764706124/4250.pth
# Saved model to /home/stephen/grokking/grok_1764706124/4260.pth
# Saved model to /home/stephen/grokking/grok_1764706124/4270.pth
# Saved model to /home/stephen/grokking/grok_1764706124/4280.pth
# Saved model to /home/stephen/grokking/grok_1764706124/4290.pth
# 4300_-15.1216_-0.1157_pen=1.781e-03
# Saved model to /home/stephen/grokking/grok_1764706124/4300.pth
# Saved model to /home/stephen/grokking/grok_1764706124/4310.pth
# Saved model to /home/stephen/grokking/grok_1764706124/4320.pth
# Saved model to /home/stephen/grokking/grok_1764706124/4330.pth
# Saved model to /home/stephen/grokking/grok_1764706124/4340.pth
# Saved model to /home/stephen/grokking/grok_1764706124/4350.pth
# Saved model to /home/stephen/grokking/grok_1764706124/4360.pth
# Saved model to /home/stephen/grokking/grok_1764706124/4370.pth
# Saved model to /home/stephen/grokking/grok_1764706124/4380.pth
# Saved model to /home/stephen/grokking/grok_1764706124/4390.pth
# 4400_-15.1708_-0.7496_pen=1.691e-03
# Saved model to /home/stephen/grokking/grok_1764706124/4400.pth
# Saved model to /home/stephen/grokking/grok_1764706124/4410.pth
# Saved model to /home/stephen/grokking/grok_1764706124/4420.pth
# Saved model to /home/stephen/grokking/grok_1764706124/4430.pth
# Saved model to /home/stephen/grokking/grok_1764706124/4440.pth
# Saved model to /home/stephen/grokking/grok_1764706124/4450.pth
# Saved model to /home/stephen/grokking/grok_1764706124/4460.pth
# Saved model to /home/stephen/grokking/grok_1764706124/4470.pth
# Saved model to /home/stephen/grokking/grok_1764706124/4480.pth
# Saved model to /home/stephen/grokking/grok_1764706124/4490.pth
# 4500_-15.2032_-1.3249_pen=1.619e-03
# Saved model to /home/stephen/grokking/grok_1764706124/4500.pth
# Saved model to /home/stephen/grokking/grok_1764706124/4510.pth
# Saved model to /home/stephen/grokking/grok_1764706124/4520.pth
# Saved model to /home/stephen/grokking/grok_1764706124/4530.pth
# Saved model to /home/stephen/grokking/grok_1764706124/4540.pth
# Saved model to /home/stephen/grokking/grok_1764706124/4550.pth
# Saved model to /home/stephen/grokking/grok_1764706124/4560.pth
# Saved model to /home/stephen/grokking/grok_1764706124/4570.pth
# Saved model to /home/stephen/grokking/grok_1764706124/4580.pth
# Saved model to /home/stephen/grokking/grok_1764706124/4590.pth
# 4600_-15.2307_-1.8461_pen=1.560e-03
# Saved model to /home/stephen/grokking/grok_1764706124/4600.pth
# Saved model to /home/stephen/grokking/grok_1764706124/4610.pth
# Saved model to /home/stephen/grokking/grok_1764706124/4620.pth
# Saved model to /home/stephen/grokking/grok_1764706124/4630.pth
# Saved model to /home/stephen/grokking/grok_1764706124/4640.pth
# Saved model to /home/stephen/grokking/grok_1764706124/4650.pth
# Saved model to /home/stephen/grokking/grok_1764706124/4660.pth
# Saved model to /home/stephen/grokking/grok_1764706124/4670.pth
# Saved model to /home/stephen/grokking/grok_1764706124/4680.pth
# Saved model to /home/stephen/grokking/grok_1764706124/4690.pth
# 4700_-15.2636_-2.3222_pen=1.507e-03
# Saved model to /home/stephen/grokking/grok_1764706124/4700.pth
# Saved model to /home/stephen/grokking/grok_1764706124/4710.pth
# Saved model to /home/stephen/grokking/grok_1764706124/4720.pth
# Saved model to /home/stephen/grokking/grok_1764706124/4730.pth
# Saved model to /home/stephen/grokking/grok_1764706124/4740.pth
# Saved model to /home/stephen/grokking/grok_1764706124/4750.pth
# Saved model to /home/stephen/grokking/grok_1764706124/4760.pth
# Saved model to /home/stephen/grokking/grok_1764706124/4770.pth
# Saved model to /home/stephen/grokking/grok_1764706124/4780.pth
# Saved model to /home/stephen/grokking/grok_1764706124/4790.pth
# 4800_-15.2987_-2.7891_pen=1.458e-03
# Saved model to /home/stephen/grokking/grok_1764706124/4800.pth
# Saved model to /home/stephen/grokking/grok_1764706124/4810.pth
# Saved model to /home/stephen/grokking/grok_1764706124/4820.pth
# Saved model to /home/stephen/grokking/grok_1764706124/4830.pth
# Saved model to /home/stephen/grokking/grok_1764706124/4840.pth
# Saved model to /home/stephen/grokking/grok_1764706124/4850.pth
# Saved model to /home/stephen/grokking/grok_1764706124/4860.pth
# Saved model to /home/stephen/grokking/grok_1764706124/4870.pth
# Saved model to /home/stephen/grokking/grok_1764706124/4880.pth
# Saved model to /home/stephen/grokking/grok_1764706124/4890.pth
# 4900_-15.3349_-3.2706_pen=1.409e-03
# Saved model to /home/stephen/grokking/grok_1764706124/4900.pth
# Saved model to /home/stephen/grokking/grok_1764706124/4910.pth
# Saved model to /home/stephen/grokking/grok_1764706124/4920.pth
# Saved model to /home/stephen/grokking/grok_1764706124/4930.pth
# Saved model to /home/stephen/grokking/grok_1764706124/4940.pth
# Saved model to /home/stephen/grokking/grok_1764706124/4950.pth
# Saved model to /home/stephen/grokking/grok_1764706124/4960.pth
# Saved model to /home/stephen/grokking/grok_1764706124/4970.pth
# Saved model to /home/stephen/grokking/grok_1764706124/4980.pth
# Saved model to /home/stephen/grokking/grok_1764706124/4990.pth
# 5000_-15.3755_-3.7802_pen=1.359e-03
# Saved model to /home/stephen/grokking/grok_1764706124/5000.pth
# Saved model to /home/stephen/grokking/grok_1764706124/5010.pth
# Saved model to /home/stephen/grokking/grok_1764706124/5020.pth
# Saved model to /home/stephen/grokking/grok_1764706124/5030.pth
# Saved model to /home/stephen/grokking/grok_1764706124/5040.pth
# Saved model to /home/stephen/grokking/grok_1764706124/5050.pth
# Saved model to /home/stephen/grokking/grok_1764706124/5060.pth
# Saved model to /home/stephen/grokking/grok_1764706124/5070.pth
# Saved model to /home/stephen/grokking/grok_1764706124/5080.pth
# Saved model to /home/stephen/grokking/grok_1764706124/5090.pth
# 5100_-15.4231_-4.3878_pen=1.309e-03
# Saved model to /home/stephen/grokking/grok_1764706124/5100.pth
# Saved model to /home/stephen/grokking/grok_1764706124/5110.pth
# Saved model to /home/stephen/grokking/grok_1764706124/5120.pth
# Saved model to /home/stephen/grokking/grok_1764706124/5130.pth
# Saved model to /home/stephen/grokking/grok_1764706124/5140.pth
# Saved model to /home/stephen/grokking/grok_1764706124/5150.pth
# Saved model to /home/stephen/grokking/grok_1764706124/5160.pth
# Saved model to /home/stephen/grokking/grok_1764706124/5170.pth
# Saved model to /home/stephen/grokking/grok_1764706124/5180.pth
# Saved model to /home/stephen/grokking/grok_1764706124/5190.pth
# 5200_-15.4714_-5.1312_pen=1.257e-03
# Saved model to /home/stephen/grokking/grok_1764706124/5200.pth
# Saved model to /home/stephen/grokking/grok_1764706124/5210.pth
# Saved model to /home/stephen/grokking/grok_1764706124/5220.pth
# Saved model to /home/stephen/grokking/grok_1764706124/5230.pth
# Saved model to /home/stephen/grokking/grok_1764706124/5240.pth
# Saved model to /home/stephen/grokking/grok_1764706124/5250.pth
# Saved model to /home/stephen/grokking/grok_1764706124/5260.pth
# Saved model to /home/stephen/grokking/grok_1764706124/5270.pth
# Saved model to /home/stephen/grokking/grok_1764706124/5280.pth
# Saved model to /home/stephen/grokking/grok_1764706124/5290.pth
# 5300_-15.5341_-6.1082_pen=1.203e-03
# Saved model to /home/stephen/grokking/grok_1764706124/5300.pth
# Saved model to /home/stephen/grokking/grok_1764706124/5310.pth
# Saved model to /home/stephen/grokking/grok_1764706124/5320.pth
# Saved model to /home/stephen/grokking/grok_1764706124/5330.pth
# Saved model to /home/stephen/grokking/grok_1764706124/5340.pth
# Saved model to /home/stephen/grokking/grok_1764706124/5350.pth
# Saved model to /home/stephen/grokking/grok_1764706124/5360.pth
# Saved model to /home/stephen/grokking/grok_1764706124/5370.pth
# Saved model to /home/stephen/grokking/grok_1764706124/5380.pth
# Saved model to /home/stephen/grokking/grok_1764706124/5390.pth
# 5400_-15.5975_-7.6214_pen=1.149e-03
# Saved model to /home/stephen/grokking/grok_1764706124/5400.pth
# Saved model to /home/stephen/grokking/grok_1764706124/5410.pth
# Saved model to /home/stephen/grokking/grok_1764706124/5420.pth
# Saved model to /home/stephen/grokking/grok_1764706124/5430.pth
# Saved model to /home/stephen/grokking/grok_1764706124/5440.pth
# Saved model to /home/stephen/grokking/grok_1764706124/5450.pth
# Saved model to /home/stephen/grokking/grok_1764706124/5460.pth
# Saved model to /home/stephen/grokking/grok_1764706124/5470.pth
# Saved model to /home/stephen/grokking/grok_1764706124/5480.pth
# Saved model to /home/stephen/grokking/grok_1764706124/5490.pth
# 5500_-15.6530_-9.6997_pen=1.100e-03
# Saved model to /home/stephen/grokking/grok_1764706124/5500.pth
# Saved model to /home/stephen/grokking/grok_1764706124/5510.pth
# Saved model to /home/stephen/grokking/grok_1764706124/5520.pth
# Saved model to /home/stephen/grokking/grok_1764706124/5530.pth
# Saved model to /home/stephen/grokking/grok_1764706124/5540.pth
# Saved model to /home/stephen/grokking/grok_1764706124/5550.pth
# Saved model to /home/stephen/grokking/grok_1764706124/5560.pth
# Saved model to /home/stephen/grokking/grok_1764706124/5570.pth
# Saved model to /home/stephen/grokking/grok_1764706124/5580.pth
# Saved model to /home/stephen/grokking/grok_1764706124/5590.pth
# 5600_-15.6972_-11.4470_pen=1.060e-03
# Saved model to /home/stephen/grokking/grok_1764706124/5600.pth
# Saved model to /home/stephen/grokking/grok_1764706124/5610.pth
# Saved model to /home/stephen/grokking/grok_1764706124/5620.pth
# Saved model to /home/stephen/grokking/grok_1764706124/5630.pth
# Saved model to /home/stephen/grokking/grok_1764706124/5640.pth
# Saved model to /home/stephen/grokking/grok_1764706124/5650.pth
# Saved model to /home/stephen/grokking/grok_1764706124/5660.pth
# Saved model to /home/stephen/grokking/grok_1764706124/5670.pth
# Saved model to /home/stephen/grokking/grok_1764706124/5680.pth
# Saved model to /home/stephen/grokking/grok_1764706124/5690.pth
# 5700_-15.7262_-12.6019_pen=1.031e-03
# Saved model to /home/stephen/grokking/grok_1764706124/5700.pth
# Saved model to /home/stephen/grokking/grok_1764706124/5710.pth
# Saved model to /home/stephen/grokking/grok_1764706124/5720.pth
# Saved model to /home/stephen/grokking/grok_1764706124/5730.pth
# Saved model to /home/stephen/grokking/grok_1764706124/5740.pth
# Saved model to /home/stephen/grokking/grok_1764706124/5750.pth
# Saved model to /home/stephen/grokking/grok_1764706124/5760.pth
# Saved model to /home/stephen/grokking/grok_1764706124/5770.pth
# Saved model to /home/stephen/grokking/grok_1764706124/5780.pth
# Saved model to /home/stephen/grokking/grok_1764706124/5790.pth
# 5800_-15.7448_-13.3060_pen=1.013e-03
# Saved model to /home/stephen/grokking/grok_1764706124/5800.pth
# Saved model to /home/stephen/grokking/grok_1764706124/5810.pth
# Saved model to /home/stephen/grokking/grok_1764706124/5820.pth
# Saved model to /home/stephen/grokking/grok_1764706124/5830.pth
# Saved model to /home/stephen/grokking/grok_1764706124/5840.pth
# Saved model to /home/stephen/grokking/grok_1764706124/5850.pth
# Saved model to /home/stephen/grokking/grok_1764706124/5860.pth
# Saved model to /home/stephen/grokking/grok_1764706124/5870.pth
# Saved model to /home/stephen/grokking/grok_1764706124/5880.pth
# Saved model to /home/stephen/grokking/grok_1764706124/5890.pth
# 5900_-15.7577_-13.7494_pen=1.002e-03
# Saved model to /home/stephen/grokking/grok_1764706124/5900.pth
# Saved model to /home/stephen/grokking/grok_1764706124/5910.pth
# Saved model to /home/stephen/grokking/grok_1764706124/5920.pth
# Saved model to /home/stephen/grokking/grok_1764706124/5930.pth
# Saved model to /home/stephen/grokking/grok_1764706124/5940.pth
# Saved model to /home/stephen/grokking/grok_1764706124/5950.pth
# Saved model to /home/stephen/grokking/grok_1764706124/5960.pth
# Saved model to /home/stephen/grokking/grok_1764706124/5970.pth
# Saved model to /home/stephen/grokking/grok_1764706124/5980.pth
# Saved model to /home/stephen/grokking/grok_1764706124/5990.pth
# 6000_-15.7659_-14.0669_pen=9.950e-04
# Saved model to /home/stephen/grokking/grok_1764706124/6000.pth
# Saved model to /home/stephen/grokking/grok_1764706124/6010.pth
# Saved model to /home/stephen/grokking/grok_1764706124/6020.pth
# Saved model to /home/stephen/grokking/grok_1764706124/6030.pth
# Saved model to /home/stephen/grokking/grok_1764706124/6040.pth
# Saved model to /home/stephen/grokking/grok_1764706124/6050.pth
# Saved model to /home/stephen/grokking/grok_1764706124/6060.pth
# Saved model to /home/stephen/grokking/grok_1764706124/6070.pth
# Saved model to /home/stephen/grokking/grok_1764706124/6080.pth
# Saved model to /home/stephen/grokking/grok_1764706124/6090.pth
# 6100_-15.7713_-14.2631_pen=9.897e-04
# Saved model to /home/stephen/grokking/grok_1764706124/6100.pth
# Saved model to /home/stephen/grokking/grok_1764706124/6110.pth
# Saved model to /home/stephen/grokking/grok_1764706124/6120.pth
# Saved model to /home/stephen/grokking/grok_1764706124/6130.pth
# Saved model to /home/stephen/grokking/grok_1764706124/6140.pth
# Saved model to /home/stephen/grokking/grok_1764706124/6150.pth
# Saved model to /home/stephen/grokking/grok_1764706124/6160.pth
# Saved model to /home/stephen/grokking/grok_1764706124/6170.pth
# Saved model to /home/stephen/grokking/grok_1764706124/6180.pth
# Saved model to /home/stephen/grokking/grok_1764706124/6190.pth
# 6200_-15.7764_-14.4209_pen=9.857e-04
# Saved model to /home/stephen/grokking/grok_1764706124/6200.pth
# Saved model to /home/stephen/grokking/grok_1764706124/6210.pth
# Saved model to /home/stephen/grokking/grok_1764706124/6220.pth
# Saved model to /home/stephen/grokking/grok_1764706124/6230.pth
# Saved model to /home/stephen/grokking/grok_1764706124/6240.pth
# Saved model to /home/stephen/grokking/grok_1764706124/6250.pth
# Saved model to /home/stephen/grokking/grok_1764706124/6260.pth
# Saved model to /home/stephen/grokking/grok_1764706124/6270.pth
# Saved model to /home/stephen/grokking/grok_1764706124/6280.pth
# Saved model to /home/stephen/grokking/grok_1764706124/6290.pth
# 6300_-15.7812_-14.5334_pen=9.825e-04
# Saved model to /home/stephen/grokking/grok_1764706124/6300.pth
# Saved model to /home/stephen/grokking/grok_1764706124/6310.pth
# Saved model to /home/stephen/grokking/grok_1764706124/6320.pth
# Saved model to /home/stephen/grokking/grok_1764706124/6330.pth
# Saved model to /home/stephen/grokking/grok_1764706124/6340.pth
# Saved model to /home/stephen/grokking/grok_1764706124/6350.pth
# Saved model to /home/stephen/grokking/grok_1764706124/6360.pth
# Saved model to /home/stephen/grokking/grok_1764706124/6370.pth
# Saved model to /home/stephen/grokking/grok_1764706124/6380.pth
# Saved model to /home/stephen/grokking/grok_1764706124/6390.pth
# 6400_-15.7853_-14.6223_pen=9.803e-04
# Saved model to /home/stephen/grokking/grok_1764706124/6400.pth
# Saved model to /home/stephen/grokking/grok_1764706124/6410.pth
# Saved model to /home/stephen/grokking/grok_1764706124/6420.pth
# Saved model to /home/stephen/grokking/grok_1764706124/6430.pth
# Saved model to /home/stephen/grokking/grok_1764706124/6440.pth
# Saved model to /home/stephen/grokking/grok_1764706124/6450.pth
# Saved model to /home/stephen/grokking/grok_1764706124/6460.pth
# Saved model to /home/stephen/grokking/grok_1764706124/6470.pth
# Saved model to /home/stephen/grokking/grok_1764706124/6480.pth
# Saved model to /home/stephen/grokking/grok_1764706124/6490.pth
# 6500_-15.7896_-14.6847_pen=9.783e-04
# Saved model to /home/stephen/grokking/grok_1764706124/6500.pth
# Saved model to /home/stephen/grokking/grok_1764706124/6510.pth
# Saved model to /home/stephen/grokking/grok_1764706124/6520.pth
# Saved model to /home/stephen/grokking/grok_1764706124/6530.pth
# Saved model to /home/stephen/grokking/grok_1764706124/6540.pth
# Saved model to /home/stephen/grokking/grok_1764706124/6550.pth
# Saved model to /home/stephen/grokking/grok_1764706124/6560.pth
# Saved model to /home/stephen/grokking/grok_1764706124/6570.pth
# Saved model to /home/stephen/grokking/grok_1764706124/6580.pth
# Saved model to /home/stephen/grokking/grok_1764706124/6590.pth
# 6600_-15.7914_-14.7343_pen=9.769e-04
# Saved model to /home/stephen/grokking/grok_1764706124/6600.pth
# Saved model to /home/stephen/grokking/grok_1764706124/6610.pth
# Saved model to /home/stephen/grokking/grok_1764706124/6620.pth
# Saved model to /home/stephen/grokking/grok_1764706124/6630.pth
# Saved model to /home/stephen/grokking/grok_1764706124/6640.pth
# Saved model to /home/stephen/grokking/grok_1764706124/6650.pth
# Saved model to /home/stephen/grokking/grok_1764706124/6660.pth
# Saved model to /home/stephen/grokking/grok_1764706124/6670.pth
# Saved model to /home/stephen/grokking/grok_1764706124/6680.pth
# Saved model to /home/stephen/grokking/grok_1764706124/6690.pth
# 6700_-15.7928_-14.7729_pen=9.754e-04
# Saved model to /home/stephen/grokking/grok_1764706124/6700.pth
# Saved model to /home/stephen/grokking/grok_1764706124/6710.pth
# Saved model to /home/stephen/grokking/grok_1764706124/6720.pth
# Saved model to /home/stephen/grokking/grok_1764706124/6730.pth
# Saved model to /home/stephen/grokking/grok_1764706124/6740.pth
# Saved model to /home/stephen/grokking/grok_1764706124/6750.pth
# Saved model to /home/stephen/grokking/grok_1764706124/6760.pth
# Saved model to /home/stephen/grokking/grok_1764706124/6770.pth
# Saved model to /home/stephen/grokking/grok_1764706124/6780.pth
# Saved model to /home/stephen/grokking/grok_1764706124/6790.pth
# 6800_-15.7954_-14.8068_pen=9.743e-04
# Saved model to /home/stephen/grokking/grok_1764706124/6800.pth
# Saved model to /home/stephen/grokking/grok_1764706124/6810.pth
# Saved model to /home/stephen/grokking/grok_1764706124/6820.pth
# Saved model to /home/stephen/grokking/grok_1764706124/6830.pth
# Saved model to /home/stephen/grokking/grok_1764706124/6840.pth
# Saved model to /home/stephen/grokking/grok_1764706124/6850.pth
# Saved model to /home/stephen/grokking/grok_1764706124/6860.pth
# Saved model to /home/stephen/grokking/grok_1764706124/6870.pth
# Saved model to /home/stephen/grokking/grok_1764706124/6880.pth
# Saved model to /home/stephen/grokking/grok_1764706124/6890.pth
# 6900_-15.7977_-14.8355_pen=9.732e-04
# Saved model to /home/stephen/grokking/grok_1764706124/6900.pth
# Saved model to /home/stephen/grokking/grok_1764706124/6910.pth
# Saved model to /home/stephen/grokking/grok_1764706124/6920.pth
# Saved model to /home/stephen/grokking/grok_1764706124/6930.pth
# Saved model to /home/stephen/grokking/grok_1764706124/6940.pth
# Saved model to /home/stephen/grokking/grok_1764706124/6950.pth
# Saved model to /home/stephen/grokking/grok_1764706124/6960.pth
# Saved model to /home/stephen/grokking/grok_1764706124/6970.pth
# Saved model to /home/stephen/grokking/grok_1764706124/6980.pth
# Saved model to /home/stephen/grokking/grok_1764706124/6990.pth
# 7000_-15.7982_-14.8607_pen=9.722e-04
# Saved model to /home/stephen/grokking/grok_1764706124/7000.pth
# Saved model to /home/stephen/grokking/grok_1764706124/7010.pth
# Saved model to /home/stephen/grokking/grok_1764706124/7020.pth
# Saved model to /home/stephen/grokking/grok_1764706124/7030.pth
# Saved model to /home/stephen/grokking/grok_1764706124/7040.pth
# Saved model to /home/stephen/grokking/grok_1764706124/7050.pth
# Saved model to /home/stephen/grokking/grok_1764706124/7060.pth
# Saved model to /home/stephen/grokking/grok_1764706124/7070.pth
# Saved model to /home/stephen/grokking/grok_1764706124/7080.pth
# Saved model to /home/stephen/grokking/grok_1764706124/7090.pth
# 7100_-15.8009_-14.8817_pen=9.716e-04
# Saved model to /home/stephen/grokking/grok_1764706124/7100.pth
# Saved model to /home/stephen/grokking/grok_1764706124/7110.pth
# Saved model to /home/stephen/grokking/grok_1764706124/7120.pth
# Saved model to /home/stephen/grokking/grok_1764706124/7130.pth
# Saved model to /home/stephen/grokking/grok_1764706124/7140.pth
# Saved model to /home/stephen/grokking/grok_1764706124/7150.pth
# Saved model to /home/stephen/grokking/grok_1764706124/7160.pth
# Saved model to /home/stephen/grokking/grok_1764706124/7170.pth
# Saved model to /home/stephen/grokking/grok_1764706124/7180.pth
# Saved model to /home/stephen/grokking/grok_1764706124/7190.pth
# 7200_-15.8020_-14.9005_pen=9.706e-04
# Saved model to /home/stephen/grokking/grok_1764706124/7200.pth
# Saved model to /home/stephen/grokking/grok_1764706124/7210.pth
# ...
# Saved model to /home/stephen/grokking/grok_1764706124/17650.pth
# Saved model to /home/stephen/grokking/grok_1764706124/17660.pth
# Saved model to /home/stephen/grokking/grok_1764706124/17670.pth
# Saved model to /home/stephen/grokking/grok_1764706124/17680.pth
# Saved model to /home/stephen/grokking/grok_1764706124/17690.pth
# 17700_-15.8353_-15.1084_pen=9.479e-04
# Saved model to /home/stephen/grokking/grok_1764706124/17700.pth
# Saved model to /home/stephen/grokking/grok_1764706124/17710.pth
# Saved model to /home/stephen/grokking/grok_1764706124/17720.pth
# Saved model to /home/stephen/grokking/grok_1764706124/17730.pth
# Saved model to /home/stephen/grokking/grok_1764706124/17740.pth
# Saved model to /home/stephen/grokking/grok_1764706124/17750.pth
# Saved model to /home/stephen/grokking/grok_1764706124/17760.pth
# Saved model to /home/stephen/grokking/grok_1764706124/17770.pth
# Saved model to /home/stephen/grokking/grok_1764706124/17780.pth
# Saved model to /home/stephen/grokking/grok_1764706124/17790.pth
# 17800_-15.8341_-15.0994_pen=9.474e-04
# Saved model to /home/stephen/grokking/grok_1764706124/17800.pth
# Saved model to /home/stephen/grokking/grok_1764706124/17810.pth
# Saved model to /home/stephen/grokking/grok_1764706124/17820.pth
# Saved model to /home/stephen/grokking/grok_1764706124/17830.pth
# Saved model to /home/stephen/grokking/grok_1764706124/17840.pth
# Saved model to /home/stephen/grokking/grok_1764706124/17850.pth
# Saved model to /home/stephen/grokking/grok_1764706124/17860.pth
# Saved model to /home/stephen/grokking/grok_1764706124/17870.pth
# Saved model to /home/stephen/grokking/grok_1764706124/17880.pth
# Saved model to /home/stephen/grokking/grok_1764706124/17890.pth
# 17900_-15.8366_-15.1057_pen=9.476e-04
# Saved model to /home/stephen/grokking/grok_1764706124/17900.pth
# Saved model to /home/stephen/grokking/grok_1764706124/17910.pth
# Saved model to /home/stephen/grokking/grok_1764706124/17920.pth
# Saved model to /home/stephen/grokking/grok_1764706124/17930.pth
# Saved model to /home/stephen/grokking/grok_1764706124/17940.pth
# Saved model to /home/stephen/grokking/grok_1764706124/17950.pth
# Saved model to /home/stephen/grokking/grok_1764706124/17960.pth
# Saved model to /home/stephen/grokking/grok_1764706124/17970.pth
# Saved model to /home/stephen/grokking/grok_1764706124/17980.pth
# Saved model to /home/stephen/grokking/grok_1764706124/17990.pth
# 18000_-15.8347_-15.1025_pen=9.473e-04
# Saved model to /home/stephen/grokking/grok_1764706124/18000.pth
# Saved model to /home/stephen/grokking/grok_1764706124/18010.pth
# Saved model to /home/stephen/grokking/grok_1764706124/18020.pth
# Saved model to /home/stephen/grokking/grok_1764706124/18030.pth
# Saved model to /home/stephen/grokking/grok_1764706124/18040.pth
# Saved model to /home/stephen/grokking/grok_1764706124/18050.pth
# Saved model to /home/stephen/grokking/grok_1764706124/18060.pth
# Saved model to /home/stephen/grokking/grok_1764706124/18070.pth
# Saved model to /home/stephen/grokking/grok_1764706124/18080.pth
# Saved model to /home/stephen/grokking/grok_1764706124/18090.pth
# 18100_-15.8300_-15.0935_pen=9.473e-04
# Saved model to /home/stephen/grokking/grok_1764706124/18100.pth
# Saved model to /home/stephen/grokking/grok_1764706124/18110.pth
# Saved model to /home/stephen/grokking/grok_1764706124/18120.pth
# Saved model to /home/stephen/grokking/grok_1764706124/18130.pth
# Saved model to /home/stephen/grokking/grok_1764706124/18140.pth
# Saved model to /home/stephen/grokking/grok_1764706124/18150.pth
# Saved model to /home/stephen/grokking/grok_1764706124/18160.pth
# Saved model to /home/stephen/grokking/grok_1764706124/18170.pth
# Saved model to /home/stephen/grokking/grok_1764706124/18180.pth
# Saved model to /home/stephen/grokking/grok_1764706124/18190.pth
# 18200_-15.8356_-15.1065_pen=9.473e-04
# Saved model to /home/stephen/grokking/grok_1764706124/18200.pth
# Saved model to /home/stephen/grokking/grok_1764706124/18210.pth
# Saved model to /home/stephen/grokking/grok_1764706124/18220.pth
# Saved model to /home/stephen/grokking/grok_1764706124/18230.pth
# Saved model to /home/stephen/grokking/grok_1764706124/18240.pth
# Saved model to /home/stephen/grokking/grok_1764706124/18250.pth
# Saved model to /home/stephen/grokking/grok_1764706124/18260.pth
# Saved model to /home/stephen/grokking/grok_1764706124/18270.pth
# Saved model to /home/stephen/grokking/grok_1764706124/18280.pth
# Saved model to /home/stephen/grokking/grok_1764706124/18290.pth
# 18300_-15.8348_-15.1081_pen=9.473e-04
# Saved model to /home/stephen/grokking/grok_1764706124/18300.pth
# Saved model to /home/stephen/grokking/grok_1764706124/18310.pth
# Saved model to /home/stephen/grokking/grok_1764706124/18320.pth
# Saved model to /home/stephen/grokking/grok_1764706124/18330.pth
# Saved model to /home/stephen/grokking/grok_1764706124/18340.pth
# Saved model to /home/stephen/grokking/grok_1764706124/18350.pth
# Saved model to /home/stephen/grokking/grok_1764706124/18360.pth
# Saved model to /home/stephen/grokking/grok_1764706124/18370.pth
# Saved model to /home/stephen/grokking/grok_1764706124/18380.pth
# Saved model to /home/stephen/grokking/grok_1764706124/18390.pth
# 18400_-15.8367_-15.1065_pen=9.471e-04
# Saved model to /home/stephen/grokking/grok_1764706124/18400.pth
# Saved model to /home/stephen/grokking/grok_1764706124/18410.pth
# Saved model to /home/stephen/grokking/grok_1764706124/18420.pth
# Saved model to /home/stephen/grokking/grok_1764706124/18430.pth
# Saved model to /home/stephen/grokking/grok_1764706124/18440.pth
# Saved model to /home/stephen/grokking/grok_1764706124/18450.pth
# Saved model to /home/stephen/grokking/grok_1764706124/18460.pth
# Saved model to /home/stephen/grokking/grok_1764706124/18470.pth
# Saved model to /home/stephen/grokking/grok_1764706124/18480.pth
# Saved model to /home/stephen/grokking/grok_1764706124/18490.pth
# 18500_-15.8360_-15.1029_pen=9.471e-04
# Saved model to /home/stephen/grokking/grok_1764706124/18500.pth
# Saved model to /home/stephen/grokking/grok_1764706124/18510.pth
# Saved model to /home/stephen/grokking/grok_1764706124/18520.pth
# Saved model to /home/stephen/grokking/grok_1764706124/18530.pth
# Saved model to /home/stephen/grokking/grok_1764706124/18540.pth
# Saved model to /home/stephen/grokking/grok_1764706124/18550.pth
# Saved model to /home/stephen/grokking/grok_1764706124/18560.pth
# Saved model to /home/stephen/grokking/grok_1764706124/18570.pth
# Saved model to /home/stephen/grokking/grok_1764706124/18580.pth
# Saved model to /home/stephen/grokking/grok_1764706124/18590.pth
# 18600_-15.8323_-15.1037_pen=9.469e-04
# Saved model to /home/stephen/grokking/grok_1764706124/18600.pth
# Saved model to /home/stephen/grokking/grok_1764706124/18610.pth
# Saved model to /home/stephen/grokking/grok_1764706124/18620.pth
# Saved model to /home/stephen/grokking/grok_1764706124/18630.pth
# Saved model to /home/stephen/grokking/grok_1764706124/18640.pth
# Saved model to /home/stephen/grokking/grok_1764706124/18650.pth
# Saved model to /home/stephen/grokking/grok_1764706124/18660.pth
# Saved model to /home/stephen/grokking/grok_1764706124/18670.pth
# Saved model to /home/stephen/grokking/grok_1764706124/18680.pth
# Saved model to /home/stephen/grokking/grok_1764706124/18690.pth
# 18700_-15.8377_-15.1064_pen=9.471e-04
# Saved model to /home/stephen/grokking/grok_1764706124/18700.pth
# Saved model to /home/stephen/grokking/grok_1764706124/18710.pth
# Saved model to /home/stephen/grokking/grok_1764706124/18720.pth
# Saved model to /home/stephen/grokking/grok_1764706124/18730.pth
# Saved model to /home/stephen/grokking/grok_1764706124/18740.pth
# Saved model to /home/stephen/grokking/grok_1764706124/18750.pth
# Saved model to /home/stephen/grokking/grok_1764706124/18760.pth
# Saved model to /home/stephen/grokking/grok_1764706124/18770.pth
# Saved model to /home/stephen/grokking/grok_1764706124/18780.pth
# Saved model to /home/stephen/grokking/grok_1764706124/18790.pth
# 18800_-15.8347_-15.1029_pen=9.467e-04
# Saved model to /home/stephen/grokking/grok_1764706124/18800.pth
# Saved model to /home/stephen/grokking/grok_1764706124/18810.pth
# Saved model to /home/stephen/grokking/grok_1764706124/18820.pth
# Saved model to /home/stephen/grokking/grok_1764706124/18830.pth
# Saved model to /home/stephen/grokking/grok_1764706124/18840.pth
# Saved model to /home/stephen/grokking/grok_1764706124/18850.pth
# Saved model to /home/stephen/grokking/grok_1764706124/18860.pth
# Saved model to /home/stephen/grokking/grok_1764706124/18870.pth
# Saved model to /home/stephen/grokking/grok_1764706124/18880.pth
# Saved model to /home/stephen/grokking/grok_1764706124/18890.pth
# 18900_-15.8355_-15.1030_pen=9.468e-04
# Saved model to /home/stephen/grokking/grok_1764706124/18900.pth
# Saved model to /home/stephen/grokking/grok_1764706124/18910.pth
# Saved model to /home/stephen/grokking/grok_1764706124/18920.pth
# Saved model to /home/stephen/grokking/grok_1764706124/18930.pth
# Saved model to /home/stephen/grokking/grok_1764706124/18940.pth
# Saved model to /home/stephen/grokking/grok_1764706124/18950.pth
# Saved model to /home/stephen/grokking/grok_1764706124/18960.pth
# Saved model to /home/stephen/grokking/grok_1764706124/18970.pth
# Saved model to /home/stephen/grokking/grok_1764706124/18980.pth
# Saved model to /home/stephen/grokking/grok_1764706124/18990.pth
# 19000_-15.8364_-15.1039_pen=9.470e-04
# Saved model to /home/stephen/grokking/grok_1764706124/19000.pth
# Saved model to /home/stephen/grokking/grok_1764706124/19010.pth
# Saved model to /home/stephen/grokking/grok_1764706124/19020.pth
# Saved model to /home/stephen/grokking/grok_1764706124/19030.pth
# Saved model to /home/stephen/grokking/grok_1764706124/19040.pth
# Saved model to /home/stephen/grokking/grok_1764706124/19050.pth
# Saved model to /home/stephen/grokking/grok_1764706124/19060.pth
# Saved model to /home/stephen/grokking/grok_1764706124/19070.pth
# Saved model to /home/stephen/grokking/grok_1764706124/19080.pth
# Saved model to /home/stephen/grokking/grok_1764706124/19090.pth
# 19100_-15.8365_-15.1087_pen=9.467e-04
# Saved model to /home/stephen/grokking/grok_1764706124/19100.pth
# Saved model to /home/stephen/grokking/grok_1764706124/19110.pth
# Saved model to /home/stephen/grokking/grok_1764706124/19120.pth
# Saved model to /home/stephen/grokking/grok_1764706124/19130.pth
# Saved model to /home/stephen/grokking/grok_1764706124/19140.pth
# Saved model to /home/stephen/grokking/grok_1764706124/19150.pth
# Saved model to /home/stephen/grokking/grok_1764706124/19160.pth
# Saved model to /home/stephen/grokking/grok_1764706124/19170.pth
# Saved model to /home/stephen/grokking/grok_1764706124/19180.pth
# Saved model to /home/stephen/grokking/grok_1764706124/19190.pth
# 19200_-15.8336_-15.0992_pen=9.466e-04
# Saved model to /home/stephen/grokking/grok_1764706124/19200.pth
# Saved model to /home/stephen/grokking/grok_1764706124/19210.pth
# Saved model to /home/stephen/grokking/grok_1764706124/19220.pth
# Saved model to /home/stephen/grokking/grok_1764706124/19230.pth
# Saved model to /home/stephen/grokking/grok_1764706124/19240.pth
# Saved model to /home/stephen/grokking/grok_1764706124/19250.pth
# Saved model to /home/stephen/grokking/grok_1764706124/19260.pth
# Saved model to /home/stephen/grokking/grok_1764706124/19270.pth
# Saved model to /home/stephen/grokking/grok_1764706124/19280.pth
# Saved model to /home/stephen/grokking/grok_1764706124/19290.pth
# 19300_-15.8348_-15.1047_pen=9.466e-04
# Saved model to /home/stephen/grokking/grok_1764706124/19300.pth
# Saved model to /home/stephen/grokking/grok_1764706124/19310.pth
# Saved model to /home/stephen/grokking/grok_1764706124/19320.pth
# Saved model to /home/stephen/grokking/grok_1764706124/19330.pth
# Saved model to /home/stephen/grokking/grok_1764706124/19340.pth
# Saved model to /home/stephen/grokking/grok_1764706124/19350.pth
# Saved model to /home/stephen/grokking/grok_1764706124/19360.pth
# Saved model to /home/stephen/grokking/grok_1764706124/19370.pth
# Saved model to /home/stephen/grokking/grok_1764706124/19380.pth
# Saved model to /home/stephen/grokking/grok_1764706124/19390.pth
# 19400_-15.8382_-15.1084_pen=9.466e-04
# Saved model to /home/stephen/grokking/grok_1764706124/19400.pth
# Saved model to /home/stephen/grokking/grok_1764706124/19410.pth
# Saved model to /home/stephen/grokking/grok_1764706124/19420.pth
# Saved model to /home/stephen/grokking/grok_1764706124/19430.pth
# Saved model to /home/stephen/grokking/grok_1764706124/19440.pth
# Saved model to /home/stephen/grokking/grok_1764706124/19450.pth
# Saved model to /home/stephen/grokking/grok_1764706124/19460.pth
# Saved model to /home/stephen/grokking/grok_1764706124/19470.pth
# Saved model to /home/stephen/grokking/grok_1764706124/19480.pth
# Saved model to /home/stephen/grokking/grok_1764706124/19490.pth
# 19500_-15.8350_-15.1090_pen=9.465e-04
# Saved model to /home/stephen/grokking/grok_1764706124/19500.pth
# Saved model to /home/stephen/grokking/grok_1764706124/19510.pth
# Saved model to /home/stephen/grokking/grok_1764706124/19520.pth
# Saved model to /home/stephen/grokking/grok_1764706124/19530.pth
# Saved model to /home/stephen/grokking/grok_1764706124/19540.pth
# Saved model to /home/stephen/grokking/grok_1764706124/19550.pth
# Saved model to /home/stephen/grokking/grok_1764706124/19560.pth
# Saved model to /home/stephen/grokking/grok_1764706124/19570.pth
# Saved model to /home/stephen/grokking/grok_1764706124/19580.pth
# Saved model to /home/stephen/grokking/grok_1764706124/19590.pth
# 19600_-15.8369_-15.1091_pen=9.465e-04
# Saved model to /home/stephen/grokking/grok_1764706124/19600.pth
# Saved model to /home/stephen/grokking/grok_1764706124/19610.pth
# Saved model to /home/stephen/grokking/grok_1764706124/19620.pth
# Saved model to /home/stephen/grokking/grok_1764706124/19630.pth
# Saved model to /home/stephen/grokking/grok_1764706124/19640.pth
# Saved model to /home/stephen/grokking/grok_1764706124/19650.pth
# Saved model to /home/stephen/grokking/grok_1764706124/19660.pth
# Saved model to /home/stephen/grokking/grok_1764706124/19670.pth
# Saved model to /home/stephen/grokking/grok_1764706124/19680.pth
# Saved model to /home/stephen/grokking/grok_1764706124/19690.pth
# 19700_-15.8362_-15.1046_pen=9.464e-04
# Saved model to /home/stephen/grokking/grok_1764706124/19700.pth
# Saved model to /home/stephen/grokking/grok_1764706124/19710.pth
# Saved model to /home/stephen/grokking/grok_1764706124/19720.pth
# Saved model to /home/stephen/grokking/grok_1764706124/19730.pth
# Saved model to /home/stephen/grokking/grok_1764706124/19740.pth
# Saved model to /home/stephen/grokking/grok_1764706124/19750.pth
# Saved model to /home/stephen/grokking/grok_1764706124/19760.pth
# Saved model to /home/stephen/grokking/grok_1764706124/19770.pth
# Saved model to /home/stephen/grokking/grok_1764706124/19780.pth
# Saved model to /home/stephen/grokking/grok_1764706124/19790.pth
# 19800_-15.8372_-15.1090_pen=9.463e-04
# Saved model to /home/stephen/grokking/grok_1764706124/19800.pth
# Saved model to /home/stephen/grokking/grok_1764706124/19810.pth
# Saved model to /home/stephen/grokking/grok_1764706124/19820.pth
# Saved model to /home/stephen/grokking/grok_1764706124/19830.pth
# Saved model to /home/stephen/grokking/grok_1764706124/19840.pth
# Saved model to /home/stephen/grokking/grok_1764706124/19850.pth
# Saved model to /home/stephen/grokking/grok_1764706124/19860.pth
# Saved model to /home/stephen/grokking/grok_1764706124/19870.pth
# Saved model to /home/stephen/grokking/grok_1764706124/19880.pth
# Saved model to /home/stephen/grokking/grok_1764706124/19890.pth
# 19900_-15.8364_-15.1075_pen=9.462e-04
# Saved model to /home/stephen/grokking/grok_1764706124/19900.pth
# Saved model to /home/stephen/grokking/grok_1764706124/19910.pth
# Saved model to /home/stephen/grokking/grok_1764706124/19920.pth
# Saved model to /home/stephen/grokking/grok_1764706124/19930.pth
# Saved model to /home/stephen/grokking/grok_1764706124/19940.pth
# Saved model to /home/stephen/grokking/grok_1764706124/19950.pth
# Saved model to /home/stephen/grokking/grok_1764706124/19960.pth
# Saved model to /home/stephen/grokking/grok_1764706124/19970.pth
# Saved model to /home/stephen/grokking/grok_1764706124/19980.pth
# Saved model to /home/stephen/grokking/grok_1764706124/19990.pth
# Saved model to /home/stephen/grokking/grok_1764706124/final.pth

# %% [markdown]
# ## Viz Results

# %%
CHILL_BROWN='#948979'
YELLOW='#ffd35a'
YELLOW_FADE='#7f6a2d'
BLUE='#65c8d0'
GREEN='#6e9671' 
CHILL_GREEN='#6c946f'
CHILL_BLUE='#3d5c6f'
FRESH_TAN='#dfd0b9'
CYAN='#00FFFF'

# %%
plt.plot(train_accs)
plt.plot(test_accs)

# %%
plt.clf()        
fig=plt.figure(0,(14,6), facecolor='k') 
ax=fig.add_subplot(111, facecolor='k')

plt.plot(train_accs[:500], c=BLUE, linewidth=2.5, alpha=0.95) #'#dfd0b9')
plt.plot(test_accs[:500], c=YELLOW, linewidth=2.5, alpha=0.95) #'#dfd0b9')
plt.tick_params(axis='x', colors='#948979', labelsize=16)  # Add labelsize here
plt.tick_params(axis='y', colors='#948979', labelsize=16)  # Add labelsize here

plt.gca().spines['top'].set_color('#948979')
plt.gca().spines['bottom'].set_color('#948979')
plt.gca().spines['left'].set_color('#948979')
plt.gca().spines['right'].set_color('#948979')
plt.subplots_adjust(bottom=0.2)  # Add fixed bottom margin
# plt.xlim([-10, len(to_plot)+10])
plt.ylim([0,1.05]) #Bad idea to fix or is it fine?
plt.grid(True, color='#948979', alpha=0.3)

# %%
plt.clf()        
fig=plt.figure(0,(14,6), facecolor='k') 
ax=fig.add_subplot(111, facecolor='k')

plt.plot(train_accs, c=BLUE, linewidth=2.5, alpha=0.95) #'#dfd0b9')
plt.plot(test_accs, c=YELLOW, linewidth=2.5, alpha=0.95) #'#dfd0b9')
plt.tick_params(axis='x', colors='#948979', labelsize=16)  # Add labelsize here
plt.tick_params(axis='y', colors='#948979', labelsize=16)  # Add labelsize here

plt.gca().spines['top'].set_color('#948979')
plt.gca().spines['bottom'].set_color('#948979')
plt.gca().spines['left'].set_color('#948979')
plt.gca().spines['right'].set_color('#948979')
plt.subplots_adjust(bottom=0.2)  # Add fixed bottom margin
# plt.xlim([-10, len(to_plot)+10])
plt.ylim([0,1.05]) #Bad idea to fix or is it fine?
plt.grid(True, color='#948979', alpha=0.3)

# %%
from tqdm import tqdm

# %%
all_data = torch.tensor([(i, j, p) for i in range(p) for j in range(p)]).to('cuda')
labels = torch.tensor([fn(i, j) for i, j, _ in all_data]).to('cuda')
cache = {}
model.remove_all_hooks()
model.cache_all(cache)
# Final position only
original_logits = model(all_data)[:, -1]
# Remove equals sign from output logits
original_logits = original_logits[:, :-1]
original_loss = cross_entropy_high_precision(original_logits, labels)
print(f"Original loss: {original_loss.item()}")

#Ok let's try pre -> the og. 
mr = einops.rearrange(cache['blocks.0.mlp.hook_pre'], "(x y) ... -> x y ...", x=p).detach().cpu().numpy()
# Out:
# Original loss: 2.3926518553524695e-07

# %%
# ---- Helper for classifying term type ----
def classify_term_type(kx, ky, is_dc):
    if is_dc:
        return "dc"
    if kx != 0 and ky == 0:
        return "row"
    if kx == 0 and ky != 0:
        return "col"
    if kx == 0 and ky == 0:
        return "dc"
    return "cross"  # kx != 0 and ky != 0


# ---- Loop over neurons and build DataFrame ----
all_rows = []

for neuron_idx in tqdm(range(512)):
    # 113 x 113 slice for this neuron
    m_slice = mr[:, :, 2, neuron_idx]

    components, Nx, Ny = compute_frequency_components(m_slice)
    terms = components_to_terms(components, Nx, Ny, num_freqs=4, include_dc=True)

    # Max amplitude (non-DC) for this neuron, for "strong" comparison later
    non_dc_terms = [t for t in terms if not t.get("is_dc", False)]
    max_amp = max((t["amplitude"] for t in non_dc_terms), default=0.0)

    for rank, t in enumerate(terms):
        is_dc = t.get("is_dc", False)
        kx = t["kx"]
        ky = t["ky"]
        amp = t["amplitude"]
        phase = t["phase"]

        term_type = classify_term_type(kx, ky, is_dc)

        all_rows.append({
            "neuron_idx": neuron_idx,
            "term_rank": rank,          # 0 = DC if include_dc=True
            "is_dc": is_dc,
            "term_type": term_type,     # "dc", "row", "col", "cross"
            "kx": kx,
            "ky": ky,
            "amplitude": amp,
            "phase": phase,
            "max_amp_neuron": max_amp,  # per neuron
        })

df = pd.DataFrame(all_rows)
df['relative_amplitude']=df['amplitude']/df['max_amp_neuron']
# Out:
# 100%|██████████████████████| 512/512 [00:20<00:00, 25.48it/s]

# %%
df['kx'].value_counts()
# Out:
# kx
# 0     1119
# 6      453
# 10     337
# 7      287
# 38     126
# 37     126
# 12      69
# 20      24
# 14      19
# Name: count, dtype: int64

# %%
dff=df[df['kx']==6]
dff=dff[dff['ky']==6]

# %%
dff.sort_values(by='relative_amplitude', ascending=False)[:15]
# Out:
#       neuron_idx  term_rank  is_dc term_type  kx  ky  amplitude     phase  \
# 6              1          1  False     cross   6   6   0.182464  1.786005
# 1261         252          1  False     cross   6   6   0.165037 -2.512036
# 1706         341          1  False     cross   6   6   0.129545 -2.289198
# 1701         340          1  False     cross   6   6   0.141893 -2.719023
# 1681         336          1  False     cross   6   6   0.162372 -2.494673
# 1656         331          1  False     cross   6   6   0.125113  2.308578
# 1601         320          1  False     cross   6   6   0.191590  0.985035
# 1586         317          1  False     cross   6   6   0.228210  1.730858
# 1576         315          1  False     cross   6   6   0.191239  2.800101
# 1506         301          1  False     cross   6   6   0.124638  2.311905
# 1426         285          1  False     cross   6   6   0.178816 -2.077263
# 1401         280          1  False     cross   6   6   0.221798 -3.050713
# 1391         278          1  False     cross   6   6   0.153136 -2.668643
# 1341         268          1  False     cross   6   6   0.213315  2.381109
# 1266         253          1  False     cross   6   6   0.075737 -0.386271
#
#       max_amp_neuron  relative_amplitude
# 6           0.182464                 1.0
# 1261        0.165037                 1.0
# 1706        0.129545                 1.0
# 1701        0.141893                 1.0
# 1681        0.162372                 1.0
# 1656        0.125113                 1.0
# 1601        0.191590                 1.0
# 1586        0.228210                 1.0
# 1576        0.191239                 1.0
# 1506        0.124638                 1.0
# 1426        0.178816                 1.0
# 1401        0.221798                 1.0
# 1391        0.153136                 1.0
# 1341        0.213315                 1.0
# 1266        0.075737                 1.0

# %%
neuron_idx=341
FT = np.fft.fft2(mr[:,:,2,neuron_idx])

components, Nx, Ny = compute_frequency_components(mr[:,:,2,neuron_idx])
terms = components_to_terms(components, Nx, Ny, num_freqs=4, include_dc=True)
code_str = generate_python_reconstructor(terms, Nx, Ny,
                                         func_name="approx_M",
                                         decimals=3)
print(code_str)
# Out:
# def approx_M(i, j):
#     val = 0.384
#     val += 0.13 * np.cos(2*np.pi*((6*i)/113) + -2.289) * np.cos(2*np.pi*((6*j)/113) + -2.289)
#     val += 0.071 * np.cos(2*np.pi*((6*i)/113) + 0.0) * np.cos(2*np.pi*((107*j)/113) + 0.0)
#     val += 0.063 * np.cos(2*np.pi*((12*j)/113) + 0.838)
#     val += 0.063 * np.cos(2*np.pi*((12*i)/113) + 0.838)
#     return val

# %%
def approx_M(i, j):
    val = 0.75
    val += 0.182 * np.cos(2*np.pi*((6*i)/113) + 1.786) * np.cos(2*np.pi*((6*j)/113) + 1.786)
    val += 0.143 * np.cos(2*np.pi*((10*i)/113) + 1.436) * np.cos(2*np.pi*((10*j)/113) + 1.436)
    val += 0.099 * np.cos(2*np.pi*((7*i)/113) + 1.702) * np.cos(2*np.pi*((7*j)/113) + 1.702)
    val += 0.099 * np.cos(2*np.pi*((7*i)/113) + 0.0) * np.cos(2*np.pi*((106*j)/113) + 0.0)
    return val

# %%
m_approx=np.zeros((p,p))
for i in range(p):
    for j in range(p):
        m_approx[i,j]=approx_M(i,j)

fig=plt.figure(0, (12, 6))
fig.add_subplot(1,3,1); plt.imshow(mr[:,:,2,neuron_idx]); plt.axis('off')
fig.add_subplot(1,3,2); plt.imshow(np.abs(FT));  plt.axis('off')
fig.add_subplot(1,3,3); plt.imshow(m_approx); plt.axis('off');

# %%
run_name
# Out:
# 'grok_1764706124'
