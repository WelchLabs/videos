# %% [markdown]
# ## Training 4a

# %%
seed=0
frac_train=0.25 
weight_decay = 1.0 #@param
freq_penalty_weight = 1e-3

# %%
# Import stuff
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import numpy as np
import einops
import tqdm.notebook as tqdm

import random
import time

# from google.colab import drive
from pathlib import Path
import pickle
import os

import matplotlib.pyplot as plt
# %matplotlib inline
import plotly.express as px
import plotly.io as pio
pio.renderers.default = "colab"
import plotly.graph_objects as go

from torch.utils.data import DataLoader

from functools import *
import pandas as pd
import gc

# import comet_ml
import itertools

# %% [markdown]
# ## Support Functions

# %%
# A helper class to get access to intermediate activations (inspired by Garcon)
# It's a dummy module that is the identity function by default
# I can wrap any intermediate activation in a HookPoint and get a convenient 
# way to add PyTorch hooks
class HookPoint(nn.Module):
    def __init__(self):
        super().__init__()
        self.fwd_hooks = []
        self.bwd_hooks = []
    
    def give_name(self, name):
        # Called by the model at initialisation
        self.name = name
    
    def add_hook(self, hook, dir='fwd'):
        # Hook format is fn(activation, hook_name)
        # Change it into PyTorch hook format (this includes input and output, 
        # which are the same for a HookPoint)
        def full_hook(module, module_input, module_output):
            return hook(module_output, name=self.name)
        if dir=='fwd':
            handle = self.register_forward_hook(full_hook)
            self.fwd_hooks.append(handle)
        elif dir=='bwd':
            handle = self.register_backward_hook(full_hook)
            self.bwd_hooks.append(handle)
        else:
            raise ValueError(f"Invalid direction {dir}")
    
    def remove_hooks(self, dir='fwd'):
        if (dir=='fwd') or (dir=='both'):
            for hook in self.fwd_hooks:
                hook.remove()
            self.fwd_hooks = []
        if (dir=='bwd') or (dir=='both'):
            for hook in self.bwd_hooks:
                hook.remove()
            self.bwd_hooks = []
        if dir not in ['fwd', 'bwd', 'both']:
            raise ValueError(f"Invalid direction {dir}")
    
    def forward(self, x):
        return x

# %%
# Define network architecture
# I defined my own transformer from scratch so I'd fully understand each component 
# - I expect this wasn't necessary or particularly important, and a bunch of this 
# replicates existing PyTorch functionality

# Embed & Unembed
class Embed(nn.Module):
    def __init__(self, d_vocab, d_model):
        super().__init__()
        self.W_E = nn.Parameter(torch.randn(d_model, d_vocab)/np.sqrt(d_model))
    
    def forward(self, x):
        return torch.einsum('dbp -> bpd', self.W_E[:, x])

class Unembed(nn.Module):
    def __init__(self, d_vocab, d_model):
        super().__init__()
        self.W_U = nn.Parameter(torch.randn(d_model, d_vocab)/np.sqrt(d_vocab))
    
    def forward(self, x):
        return (x @ self.W_U)

# Positional Embeddings
class PosEmbed(nn.Module):
    def __init__(self, max_ctx, d_model):
        super().__init__()
        self.W_pos = nn.Parameter(torch.randn(max_ctx, d_model)/np.sqrt(d_model))
    
    def forward(self, x):
        return x+self.W_pos[:x.shape[-2]]

# LayerNorm
class LayerNorm(nn.Module):
    def __init__(self, d_model, epsilon = 1e-4, model=[None]):
        super().__init__()
        self.model = model
        self.w_ln = nn.Parameter(torch.ones(d_model))
        self.b_ln = nn.Parameter(torch.zeros(d_model))
        self.epsilon = epsilon
    
    def forward(self, x):
        if self.model[0].use_ln:
            x = x - x.mean(axis=-1)[..., None]
            x = x / (x.std(axis=-1)[..., None] + self.epsilon)
            x = x * self.w_ln
            x = x + self.b_ln
            return x
        else:
            return x

# Attention
class Attention(nn.Module):
    def __init__(self, d_model, num_heads, d_head, n_ctx, model):
        super().__init__()
        self.model = model
        self.W_K = nn.Parameter(torch.randn(num_heads, d_head, d_model)/np.sqrt(d_model))
        self.W_Q = nn.Parameter(torch.randn(num_heads, d_head, d_model)/np.sqrt(d_model))
        self.W_V = nn.Parameter(torch.randn(num_heads, d_head, d_model)/np.sqrt(d_model))
        self.W_O = nn.Parameter(torch.randn(d_model, d_head * num_heads)/np.sqrt(d_model))
        self.register_buffer('mask', torch.tril(torch.ones((n_ctx, n_ctx))))
        self.d_head = d_head
        self.hook_k = HookPoint()
        self.hook_q = HookPoint()
        self.hook_v = HookPoint()
        self.hook_z = HookPoint()
        self.hook_attn = HookPoint()
        self.hook_attn_pre = HookPoint()

    def forward(self, x):
        k = self.hook_k(torch.einsum('ihd,bpd->biph', self.W_K, x))
        q = self.hook_q(torch.einsum('ihd,bpd->biph', self.W_Q, x))
        v = self.hook_v(torch.einsum('ihd,bpd->biph', self.W_V, x))
        attn_scores_pre = torch.einsum('biph,biqh->biqp', k, q)
        attn_scores_masked = torch.tril(attn_scores_pre) - 1e10 * (1 - self.mask[:x.shape[-2], :x.shape[-2]])
        attn_matrix = self.hook_attn(F.softmax(self.hook_attn_pre(attn_scores_masked/np.sqrt(self.d_head)), dim=-1))
        z = self.hook_z(torch.einsum('biph,biqp->biqh', v, attn_matrix))
        z_flat = einops.rearrange(z, 'b i q h -> b q (i h)')
        out = torch.einsum('df,bqf->bqd', self.W_O, z_flat)
        return out

# MLP Layers
class MLP(nn.Module):
    def __init__(self, d_model, d_mlp, act_type, model):
        super().__init__()
        self.model = model
        self.W_in = nn.Parameter(torch.randn(d_mlp, d_model)/np.sqrt(d_model))
        self.b_in = nn.Parameter(torch.zeros(d_mlp))
        self.W_out = nn.Parameter(torch.randn(d_model, d_mlp)/np.sqrt(d_model))
        self.b_out = nn.Parameter(torch.zeros(d_model))
        self.act_type = act_type
        # self.ln = LayerNorm(d_mlp, model=self.model)
        self.hook_pre = HookPoint()
        self.hook_post = HookPoint()
        assert act_type in ['ReLU', 'GeLU']
        
    def forward(self, x):
        x = self.hook_pre(torch.einsum('md,bpd->bpm', self.W_in, x) + self.b_in)
        if self.act_type=='ReLU':
            x = F.relu(x)
        elif self.act_type=='GeLU':
            x = F.gelu(x)
        x = self.hook_post(x)
        x = torch.einsum('dm,bpm->bpd', self.W_out, x) + self.b_out
        return x

# Transformer Block
class TransformerBlock(nn.Module):
    def __init__(self, d_model, d_mlp, d_head, num_heads, n_ctx, act_type, model):
        super().__init__()
        self.model = model
        # self.ln1 = LayerNorm(d_model, model=self.model)
        self.attn = Attention(d_model, num_heads, d_head, n_ctx, model=self.model)
        # self.ln2 = LayerNorm(d_model, model=self.model)
        self.mlp = MLP(d_model, d_mlp, act_type, model=self.model)
        self.hook_attn_out = HookPoint()
        self.hook_mlp_out = HookPoint()
        self.hook_resid_pre = HookPoint()
        self.hook_resid_mid = HookPoint()
        self.hook_resid_post = HookPoint()
    
    def forward(self, x):
        x = self.hook_resid_mid(x + self.hook_attn_out(self.attn((self.hook_resid_pre(x)))))
        x = self.hook_resid_post(x + self.hook_mlp_out(self.mlp((x))))
        return x

# Full transformer
class Transformer(nn.Module):
    def __init__(self, num_layers, d_vocab, d_model, d_mlp, d_head, num_heads, n_ctx, act_type, use_cache=False, use_ln=True):
        super().__init__()
        self.cache = {}
        self.use_cache = use_cache

        self.embed = Embed(d_vocab, d_model)
        self.pos_embed = PosEmbed(n_ctx, d_model)
        self.blocks = nn.ModuleList([TransformerBlock(d_model, d_mlp, d_head, num_heads, n_ctx, act_type, model=[self]) for i in range(num_layers)])
        # self.ln = LayerNorm(d_model, model=[self])
        self.unembed = Unembed(d_vocab, d_model)
        self.use_ln = use_ln

        for name, module in self.named_modules():
            if type(module)==HookPoint:
                module.give_name(name)
    
    def forward(self, x):
        x = self.embed(x)
        x = self.pos_embed(x)
        for block in self.blocks:
            x = block(x)
        # x = self.ln(x)
        x = self.unembed(x)
        return x

    def set_use_cache(self, use_cache):
        self.use_cache = use_cache
    
    def hook_points(self):
        return [module for name, module in self.named_modules() if 'hook' in name]

    def remove_all_hooks(self):
        for hp in self.hook_points():
            hp.remove_hooks('fwd')
            hp.remove_hooks('bwd')
    
    def cache_all(self, cache, incl_bwd=False):
        # Caches all activations wrapped in a HookPoint
        def save_hook(tensor, name):
            cache[name] = tensor.detach()
        def save_hook_back(tensor, name):
            cache[name+'_grad'] = tensor[0].detach()
        for hp in self.hook_points():
            hp.add_hook(save_hook, 'fwd')
            if incl_bwd:
                hp.add_hook(save_hook_back, 'bwd')

# %%
# Helper functions
def cuda_memory():
    print(torch.cuda.memory_allocated()/1e9)

def cross_entropy_high_precision(logits, labels):
    # Shapes: batch x vocab, batch
    # Cast logits to float64 because log_softmax has a float32 underflow on overly 
    # confident data and can only return multiples of 1.2e-7 (the smallest float x
    # such that 1+x is different from 1 in float32). This leads to loss spikes 
    # and dodgy gradients
    logprobs = F.log_softmax(logits.to(torch.float64), dim=-1)
    prediction_logprobs = torch.gather(logprobs, index=labels[:, None], dim=-1)
    loss = -torch.mean(prediction_logprobs)
    return loss

def full_loss(model, data):
    # Take the final position only
    logits = model(data)[:, -1]
    labels = torch.tensor([fn(i, j) for i, j, _ in data]).to('cuda')
    return cross_entropy_high_precision(logits, labels)

def test_logits(logits, bias_correction=False, original_logits=None, mode='all'):
    # Calculates cross entropy loss of logits representing a batch of all p^2 
    # possible inputs
    # Batch dimension is assumed to be first
    if logits.shape[1]==p*p:
        logits = logits.T
    if logits.shape==torch.Size([p*p, p+1]):
        logits = logits[:, :-1]
    logits = logits.reshape(p*p, p)
    if bias_correction:
        # Applies bias correction - we correct for any missing bias terms, 
        # independent of the input, by centering the new logits along the batch 
        # dimension, and then adding the average original logits across all inputs
        logits = einops.reduce(original_logits - logits, 'batch ... -> ...', 'mean') + logits
    if mode=='train':
        return cross_entropy_high_precision(logits[is_train], labels[is_train])
    elif mode=='test':
        return cross_entropy_high_precision(logits[is_test], labels[is_test])
    elif mode=='all':
        return cross_entropy_high_precision(logits, labels)

def unflatten_first(tensor):
    if tensor.shape[0]==p*p:
        return einops.rearrange(tensor, '(x y) ... -> x y ...', x=p, y=p)
    else: 
        return tensor
def cos(x, y):
    return (x.dot(y))/x.norm()/y.norm()
def mod_div(a, b):
    return (a*pow(b, p-2, p))%p
def normalize(tensor, axis=0):
    return tensor/(tensor).pow(2).sum(keepdim=True, axis=axis).sqrt()
def extract_freq_2d(tensor, freq):
    # Takes in a pxpx... or batch x ... tensor, returns a 3x3x... tensor of the 
    # Linear and quadratic terms of frequency freq
    tensor = unflatten_first(tensor)
    # Extracts the linear and quadratic terms corresponding to frequency freq
    index_1d = [0, 2*freq-1, 2*freq]
    # Some dumb manipulation to use fancy array indexing rules
    # Gets the rows and columns in index_1d
    return tensor[[[i]*3 for i in index_1d], [index_1d]*3]
def get_cov(tensor, norm=True):
    # Calculate covariance matrix
    if norm:
        tensor = normalize(tensor, axis=1)
    return tensor @ tensor.T
def is_close(a, b):
    return ((a-b).pow(2).sum()/(a.pow(2).sum().sqrt())/(b.pow(2).sum().sqrt())).item()

# %%
def compute_frequency_components(m):
    """
    Compute canonical frequency components of a real 2D signal m using fft2.

    Returns:
        components: list of dicts with keys:
            - 'kx': frequency index in x (rows)
            - 'ky': frequency index in y (cols)
            - 'coeff': complex FFT coefficient at (kx, ky)
        Nx, Ny: dimensions of the input
    """
    m = np.asarray(m)
    Nx, Ny = m.shape
    F = np.fft.fft2(m)

    components = []
    seen = set()

    for kx in range(Nx):
        for ky in range(Ny):
            # Conjugate partner indices for real-valued input
            kx_conj = (-kx) % Nx
            ky_conj = (-ky) % Ny

            pair = tuple(sorted([(kx, ky), (kx_conj, ky_conj)]))
            if pair in seen:
                continue
            seen.add(pair)

            # Always store the "smaller" one in lexicographic order
            kx_rep, ky_rep = pair[0]
            coeff = F[kx_rep, ky_rep]
            components.append({
                "kx": kx_rep,
                "ky": ky_rep,
                "coeff": coeff
            })

    return components, Nx, Ny


def components_to_terms(components, Nx, Ny, num_freqs, include_dc=True):
    """
    Convert FFT components into real cosine terms with amplitude & phase.

    Args:
        components: output from compute_frequency_components
        Nx, Ny: grid size
        num_freqs: number of *non-DC* frequencies to keep
        include_dc: whether to include the constant (DC) term

    Returns:
        terms: list of dicts with keys:
            - 'kx', 'ky'
            - 'amplitude'  (real, >= 0)
            - 'phase'      (in radians)
            - 'is_dc'      (bool, True only for the constant term)
    """
    terms = []
    dc_term = None

    for c in components:
        kx = c["kx"]
        ky = c["ky"]
        coeff = c["coeff"]

        # DC component (constant offset)
        if kx == 0 and ky == 0:
            dc_value = coeff.real / (Nx * Ny)
            dc_term = {
                "kx": 0,
                "ky": 0,
                "amplitude": dc_value,  # directly the constant offset
                "phase": 0.0,
                "is_dc": True,
            }
        else:
            # For real signals, combine (k, l) and (-k, -l) into:
            #   2*|F|/(Nx*Ny) * cos(2π(kx i/Nx + ky j/Ny) + phase)
            amp = 2.0 * np.abs(coeff) / (Nx * Ny)
            phase = np.angle(coeff)
            terms.append({
                "kx": kx,
                "ky": ky,
                "amplitude": amp,
                "phase": phase,
                "is_dc": False,
            })

    # Sort non-DC terms by amplitude (largest first)
    terms.sort(key=lambda t: t["amplitude"], reverse=True)

    # Keep only the top num_freqs
    terms = terms[:num_freqs]

    # Optionally prepend DC term
    if include_dc and dc_term is not None:
        terms = [dc_term] + terms

    return terms

def generate_python_reconstructor(terms, Nx, Ny, func_name="recon_func", decimals=4):
    """
    Generate a Python function as a string that reconstructs the signal
    using explicit 1D and product-of-cosine terms from a sparse Fourier representation.

    Types of terms:
      - DC term (constant)
      - Row-only:   A * cos(2π * (kx*i/Nx) + φ)
      - Col-only:   B * cos(2π * (ky*j/Ny) + φ)
      - Product:    C * cos(2π * (kx*i/Nx) + φ) * cos(2π * (ky*j/Ny) + φ)

    You must have `import numpy as np` in the scope where you paste/run this.
    """
    lines = []
    lines.append(f"def {func_name}(i, j):")

    if not terms:
        lines.append("    return 0.0")
        return "\n".join(lines)

    # Separate DC from others
    dc_terms = [t for t in terms if t.get("is_dc", False)]
    non_dc_terms = [t for t in terms if not t.get("is_dc", False)]

    if dc_terms:
        dc_val = round(dc_terms[0]["amplitude"], decimals)
        lines.append(f"    val = {dc_val}")
    else:
        lines.append("    val = 0.0")

    for t in non_dc_terms:
        kx, ky = t["kx"], t["ky"]
        A = round(t["amplitude"], decimals)
        phi = round(t["phase"], decimals)

        if A == 0:
            continue

        if kx != 0 and ky == 0:
            # Row-only cosine
            line = (
                f"    val += {A} * np.cos(2*np.pi*(({kx}*i)/{Nx}) + {phi})"
            )
        elif kx == 0 and ky != 0:
            # Column-only cosine
            line = (
                f"    val += {A} * np.cos(2*np.pi*(({ky}*j)/{Ny}) + {phi})"
            )
        else:
            # Product-of-cosines term (your desired "third" type)
            line = (
                f"    val += {A} * np.cos(2*np.pi*(({kx}*i)/{Nx}) + {phi})"
                f" * np.cos(2*np.pi*(({ky}*j)/{Ny}) + {phi})"
            )

        lines.append(line)

    lines.append("    return val")

    return "\n".join(lines)

# %%
def set_seed(seed):
        torch.manual_seed(seed)
        torch.cuda.manual_seed_all(seed) # For all CUDA devices
        np.random.seed(seed)
        random.seed(seed)
        torch.backends.cudnn.deterministic = True
        torch.backends.cudnn.benchmark = False # Set to False for determinism

# %%
def embedding_frequency_penalty(model: Transformer) -> torch.Tensor:
    """
    Encourage neighboring tokens in the embedding space to be similar.
    This is a graph-Laplacian-style smoothness penalty on W_E, which
    corresponds to penalizing high-frequency Fourier modes on Z_p.

    W_E has shape [d_model, d_vocab].
    We smooth along the vocab dimension (the modular arithmetic axis).
    """
    E = model.embed.W_E  # [d_model, d_vocab]

    # Differences between consecutive tokens (0-1, 1-2, ..., (V-2)-(V-1))
    diff = E[:, 1:] - E[:, :-1]  # [d_model, d_vocab-1]

    # Wrap-around difference to respect modular structure: token V-1 vs 0
    wrap = E[:, :1] - E[:, -1:]  # [d_model, 1]

    # Mean squared differences (Laplacian smoothness)
    penalty = (diff.pow(2).mean() + wrap.pow(2).mean())
    return penalty

# %% [markdown]
# ## Hyperparameters

# %%
root = Path('/home/stephen/grokking')



p=113
# seed=2 ##Set at top

lr=1e-3 #@param

p=113 #@param
d_model = 128 #@param
fn_name = 'add' #@param ['add', 'subtract', 'x2xyy2','rand']
num_epochs = 20000 #@param
save_models = True #@param
save_every = 10 # Maybe crank this down
# Stop training when test loss is <stopping_thresh
stopping_thresh = -1 #@param

num_layers = 1
batch_style = 'full'
d_vocab = p+1
n_ctx = 3
d_mlp = 4*d_model
num_heads = 4
assert d_model % num_heads == 0
d_head = d_model//num_heads
act_type = 'ReLU' #@param ['ReLU', 'GeLU']
# batch_size = 512
use_ln = False
random_answers = np.random.randint(low=0, high=p, size=(p, p))
fns_dict = {'add': lambda x,y:(x+y)%p, 'subtract': lambda x,y:(x-y)%p, 'x2xyy2':lambda x,y:(x**2+x*y+y**2)%p, 'rand':lambda x,y:random_answers[x][y]}
fn = fns_dict[fn_name]

# %%
frac_train, seed
# Out:
# (0.25, 0)

# %%
def gen_train_test(frac_train, num, seed=0):
    # Generate train and test split
    pairs = [(i, j, num) for i in range(num) for j in range(num)]
    random.seed(seed)
    random.shuffle(pairs)
    div = int(frac_train*len(pairs))
    return pairs[:div], pairs[div:]

train, test = gen_train_test(frac_train, p, seed)
print(len(train), len(test))
# Out:
# 3192 9577

# %%
# Creates an array of Boolean indices according to whether each data point is in 
# train or test
# Used to index into the big batch of all possible data
is_train = []
is_test = []
for x in range(p):
    for y in range(p):
        if (x, y, 113) in train:
            is_train.append(True)
            is_test.append(False)
        else:
            is_train.append(False)
            is_test.append(True)
is_train = np.array(is_train)
is_test = np.array(is_test)

# %% [markdown]
# ## Training Loop

# %%
set_seed(seed)
model = Transformer(num_layers=num_layers, d_vocab=d_vocab, d_model=d_model, d_mlp=d_mlp, d_head=d_head, num_heads=num_heads, n_ctx=n_ctx, act_type=act_type, use_cache=False, use_ln=use_ln)
model.to('cuda')
optimizer = optim.AdamW(model.parameters(), lr=lr, weight_decay=weight_decay, betas=(0.9, 0.98))
scheduler = optim.lr_scheduler.LambdaLR(optimizer, lambda step: min(step/10, 1))
run_name = f"grok_{int(time.time())}"
print(f'Run name {run_name}')
if save_models:
    os.mkdir(root/run_name)
    save_dict = {'model':model.state_dict(), 'train_data':train, 'test_data':test}
    torch.save(save_dict, root/run_name/'init.pth')
train_losses = []
test_losses = []
train_accs = []
test_accs = []
for epoch in range(num_epochs):

    # 1. Compute base cross-entropy losses (no regularization)
    train_ce_loss = full_loss(model, train)
    test_loss = full_loss(model, test)  # leave test as-is

    # 2. Compute smoothness / frequency penalty on embeddings
    freq_pen = embedding_frequency_penalty(model)

    # 3. Total train loss = CE + λ * penalty
    train_loss = train_ce_loss + freq_penalty_weight * freq_pen

    # 4. Track (usually you want to log CE only for grokking plots)
    train_losses.append(train_ce_loss.item())
    test_losses.append(test_loss.item())

    logits = model(train)[:, -1]
    labels = torch.tensor([fn(i, j) for i, j, _ in train]).to('cuda')
    train_acc=((logits.detach().cpu().argmax(1)==labels.detach().cpu()).sum()/len(labels)).item()
    train_accs.append(train_acc)
    
    logits = model(test)[:, -1]
    labels = torch.tensor([fn(i, j) for i, j, _ in test]).to('cuda')
    test_acc=((logits.detach().cpu().argmax(1)==labels.detach().cpu()).sum()/len(labels)).item()
    test_accs.append(test_acc)

    if epoch % 100 == 0:
        print(
            f"{epoch}_"
            f"{np.log(train_ce_loss.item()):.4f}_"
            f"{np.log(test_loss.item()):.4f}_"
            f"pen={freq_pen.item():.3e}"
        )

    # 5. Backprop / step
    train_loss.backward()
    optimizer.step()
    scheduler.step()
    optimizer.zero_grad()
    if test_loss.item() < stopping_thresh:
        break
    if (save_models) and (epoch%save_every == 0):
        if test_loss.item() < stopping_thresh:
            break
        save_dict = {
            'model': model.state_dict(),
            'optimizer': optimizer.state_dict(),
            'scheduler': scheduler.state_dict(),
            'train_loss': train_loss,
            'test_loss': test_loss,
            'epoch': epoch,
        }
        torch.save(save_dict, root/run_name/f"{epoch}.pth")
        print(f"Saved model to {root/run_name/f'{epoch}.pth'}")
if not save_models:
    os.mkdir(root/run_name)
save_dict = {
    'model': model.state_dict(),
    'optimizer': optimizer.state_dict(),
    'scheduler': scheduler.state_dict(),
    'train_loss': train_loss,
    'test_loss': test_loss,
    'train_losses': train_losses,
    'test_losses': test_losses,
    'train_accs': train_accs,
    'test_accs':test_accs,
    'epoch': epoch,
}
torch.save(save_dict, root/run_name/f"final.pth")
print(f"Saved model to {root/run_name/f'final.pth'}")

# save_models = False
# Out:
# Run name grok_1764706118
# 0_1.5608_1.5620_pen=3.302e-02
# Saved model to /home/stephen/grokking/grok_1764706118/0.pth
# Saved model to /home/stephen/grokking/grok_1764706118/10.pth
# Saved model to /home/stephen/grokking/grok_1764706118/20.pth
# Saved model to /home/stephen/grokking/grok_1764706118/30.pth
# Saved model to /home/stephen/grokking/grok_1764706118/40.pth
# Saved model to /home/stephen/grokking/grok_1764706118/50.pth
# Saved model to /home/stephen/grokking/grok_1764706118/60.pth
# Saved model to /home/stephen/grokking/grok_1764706118/70.pth
# Saved model to /home/stephen/grokking/grok_1764706118/80.pth
# Saved model to /home/stephen/grokking/grok_1764706118/90.pth
# 100_0.6827_2.1401_pen=5.771e-02
# Saved model to /home/stephen/grokking/grok_1764706118/100.pth
# Saved model to /home/stephen/grokking/grok_1764706118/110.pth
# Saved model to /home/stephen/grokking/grok_1764706118/120.pth
# Saved model to /home/stephen/grokking/grok_1764706118/130.pth
# Saved model to /home/stephen/grokking/grok_1764706118/140.pth
# Saved model to /home/stephen/grokking/grok_1764706118/150.pth
# Saved model to /home/stephen/grokking/grok_1764706118/160.pth
# Saved model to /home/stephen/grokking/grok_1764706118/170.pth
# Saved model to /home/stephen/grokking/grok_1764706118/180.pth
# Saved model to /home/stephen/grokking/grok_1764706118/190.pth
# 200_-3.9947_2.8696_pen=8.210e-02
# Saved model to /home/stephen/grokking/grok_1764706118/200.pth
# Saved model to /home/stephen/grokking/grok_1764706118/210.pth
# Saved model to /home/stephen/grokking/grok_1764706118/220.pth
# Saved model to /home/stephen/grokking/grok_1764706118/230.pth
# Saved model to /home/stephen/grokking/grok_1764706118/240.pth
# Saved model to /home/stephen/grokking/grok_1764706118/250.pth
# Saved model to /home/stephen/grokking/grok_1764706118/260.pth
# Saved model to /home/stephen/grokking/grok_1764706118/270.pth
# Saved model to /home/stephen/grokking/grok_1764706118/280.pth
# Saved model to /home/stephen/grokking/grok_1764706118/290.pth
# 300_-5.0422_2.9007_pen=8.239e-02
# Saved model to /home/stephen/grokking/grok_1764706118/300.pth
# Saved model to /home/stephen/grokking/grok_1764706118/310.pth
# Saved model to /home/stephen/grokking/grok_1764706118/320.pth
# Saved model to /home/stephen/grokking/grok_1764706118/330.pth
# Saved model to /home/stephen/grokking/grok_1764706118/340.pth
# Saved model to /home/stephen/grokking/grok_1764706118/350.pth
# Saved model to /home/stephen/grokking/grok_1764706118/360.pth
# Saved model to /home/stephen/grokking/grok_1764706118/370.pth
# Saved model to /home/stephen/grokking/grok_1764706118/380.pth
# Saved model to /home/stephen/grokking/grok_1764706118/390.pth
# 400_-6.1662_2.9565_pen=8.216e-02
# Saved model to /home/stephen/grokking/grok_1764706118/400.pth
# Saved model to /home/stephen/grokking/grok_1764706118/410.pth
# Saved model to /home/stephen/grokking/grok_1764706118/420.pth
# Saved model to /home/stephen/grokking/grok_1764706118/430.pth
# Saved model to /home/stephen/grokking/grok_1764706118/440.pth
# Saved model to /home/stephen/grokking/grok_1764706118/450.pth
# Saved model to /home/stephen/grokking/grok_1764706118/460.pth
# Saved model to /home/stephen/grokking/grok_1764706118/470.pth
# Saved model to /home/stephen/grokking/grok_1764706118/480.pth
# Saved model to /home/stephen/grokking/grok_1764706118/490.pth
# 500_-7.2673_3.0152_pen=7.999e-02
# Saved model to /home/stephen/grokking/grok_1764706118/500.pth
# Saved model to /home/stephen/grokking/grok_1764706118/510.pth
# Saved model to /home/stephen/grokking/grok_1764706118/520.pth
# Saved model to /home/stephen/grokking/grok_1764706118/530.pth
# Saved model to /home/stephen/grokking/grok_1764706118/540.pth
# Saved model to /home/stephen/grokking/grok_1764706118/550.pth
# Saved model to /home/stephen/grokking/grok_1764706118/560.pth
# Saved model to /home/stephen/grokking/grok_1764706118/570.pth
# Saved model to /home/stephen/grokking/grok_1764706118/580.pth
# Saved model to /home/stephen/grokking/grok_1764706118/590.pth
# 600_-8.3484_3.0739_pen=7.386e-02
# Saved model to /home/stephen/grokking/grok_1764706118/600.pth
# Saved model to /home/stephen/grokking/grok_1764706118/610.pth
# Saved model to /home/stephen/grokking/grok_1764706118/620.pth
# Saved model to /home/stephen/grokking/grok_1764706118/630.pth
# Saved model to /home/stephen/grokking/grok_1764706118/640.pth
# Saved model to /home/stephen/grokking/grok_1764706118/650.pth
# Saved model to /home/stephen/grokking/grok_1764706118/660.pth
# Saved model to /home/stephen/grokking/grok_1764706118/670.pth
# Saved model to /home/stephen/grokking/grok_1764706118/680.pth
# Saved model to /home/stephen/grokking/grok_1764706118/690.pth
# 700_-9.4080_3.1305_pen=6.272e-02
# Saved model to /home/stephen/grokking/grok_1764706118/700.pth
# Saved model to /home/stephen/grokking/grok_1764706118/710.pth
# Saved model to /home/stephen/grokking/grok_1764706118/720.pth
# Saved model to /home/stephen/grokking/grok_1764706118/730.pth
# Saved model to /home/stephen/grokking/grok_1764706118/740.pth
# Saved model to /home/stephen/grokking/grok_1764706118/750.pth
# Saved model to /home/stephen/grokking/grok_1764706118/760.pth
# Saved model to /home/stephen/grokking/grok_1764706118/770.pth
# Saved model to /home/stephen/grokking/grok_1764706118/780.pth
# Saved model to /home/stephen/grokking/grok_1764706118/790.pth
# 800_-10.4368_3.1842_pen=5.037e-02
# Saved model to /home/stephen/grokking/grok_1764706118/800.pth
# Saved model to /home/stephen/grokking/grok_1764706118/810.pth
# Saved model to /home/stephen/grokking/grok_1764706118/820.pth
# Saved model to /home/stephen/grokking/grok_1764706118/830.pth
# Saved model to /home/stephen/grokking/grok_1764706118/840.pth
# Saved model to /home/stephen/grokking/grok_1764706118/850.pth
# Saved model to /home/stephen/grokking/grok_1764706118/860.pth
# Saved model to /home/stephen/grokking/grok_1764706118/870.pth
# Saved model to /home/stephen/grokking/grok_1764706118/880.pth
# Saved model to /home/stephen/grokking/grok_1764706118/890.pth
# 900_-11.4060_3.2318_pen=4.153e-02
# Saved model to /home/stephen/grokking/grok_1764706118/900.pth
# Saved model to /home/stephen/grokking/grok_1764706118/910.pth
# Saved model to /home/stephen/grokking/grok_1764706118/920.pth
# Saved model to /home/stephen/grokking/grok_1764706118/930.pth
# Saved model to /home/stephen/grokking/grok_1764706118/940.pth
# Saved model to /home/stephen/grokking/grok_1764706118/950.pth
# Saved model to /home/stephen/grokking/grok_1764706118/960.pth
# Saved model to /home/stephen/grokking/grok_1764706118/970.pth
# Saved model to /home/stephen/grokking/grok_1764706118/980.pth
# Saved model to /home/stephen/grokking/grok_1764706118/990.pth
# 1000_-12.2455_3.2703_pen=3.305e-02
# Saved model to /home/stephen/grokking/grok_1764706118/1000.pth
# Saved model to /home/stephen/grokking/grok_1764706118/1010.pth
# Saved model to /home/stephen/grokking/grok_1764706118/1020.pth
# Saved model to /home/stephen/grokking/grok_1764706118/1030.pth
# Saved model to /home/stephen/grokking/grok_1764706118/1040.pth
# Saved model to /home/stephen/grokking/grok_1764706118/1050.pth
# Saved model to /home/stephen/grokking/grok_1764706118/1060.pth
# Saved model to /home/stephen/grokking/grok_1764706118/1070.pth
# Saved model to /home/stephen/grokking/grok_1764706118/1080.pth
# Saved model to /home/stephen/grokking/grok_1764706118/1090.pth
# 1100_-12.9025_3.3028_pen=2.228e-02
# Saved model to /home/stephen/grokking/grok_1764706118/1100.pth
# Saved model to /home/stephen/grokking/grok_1764706118/1110.pth
# Saved model to /home/stephen/grokking/grok_1764706118/1120.pth
# Saved model to /home/stephen/grokking/grok_1764706118/1130.pth
# Saved model to /home/stephen/grokking/grok_1764706118/1140.pth
# Saved model to /home/stephen/grokking/grok_1764706118/1150.pth
# Saved model to /home/stephen/grokking/grok_1764706118/1160.pth
# Saved model to /home/stephen/grokking/grok_1764706118/1170.pth
# Saved model to /home/stephen/grokking/grok_1764706118/1180.pth
# Saved model to /home/stephen/grokking/grok_1764706118/1190.pth
# 1200_-13.4233_3.3281_pen=1.342e-02
# Saved model to /home/stephen/grokking/grok_1764706118/1200.pth
# Saved model to /home/stephen/grokking/grok_1764706118/1210.pth
# Saved model to /home/stephen/grokking/grok_1764706118/1220.pth
# Saved model to /home/stephen/grokking/grok_1764706118/1230.pth
# Saved model to /home/stephen/grokking/grok_1764706118/1240.pth
# Saved model to /home/stephen/grokking/grok_1764706118/1250.pth
# Saved model to /home/stephen/grokking/grok_1764706118/1260.pth
# Saved model to /home/stephen/grokking/grok_1764706118/1270.pth
# Saved model to /home/stephen/grokking/grok_1764706118/1280.pth
# Saved model to /home/stephen/grokking/grok_1764706118/1290.pth
# 1300_-13.8327_3.3418_pen=8.502e-03
# Saved model to /home/stephen/grokking/grok_1764706118/1300.pth
# Saved model to /home/stephen/grokking/grok_1764706118/1310.pth
# Saved model to /home/stephen/grokking/grok_1764706118/1320.pth
# Saved model to /home/stephen/grokking/grok_1764706118/1330.pth
# Saved model to /home/stephen/grokking/grok_1764706118/1340.pth
# Saved model to /home/stephen/grokking/grok_1764706118/1350.pth
# Saved model to /home/stephen/grokking/grok_1764706118/1360.pth
# Saved model to /home/stephen/grokking/grok_1764706118/1370.pth
# Saved model to /home/stephen/grokking/grok_1764706118/1380.pth
# Saved model to /home/stephen/grokking/grok_1764706118/1390.pth
# 1400_-14.1153_3.3446_pen=6.199e-03
# Saved model to /home/stephen/grokking/grok_1764706118/1400.pth
# Saved model to /home/stephen/grokking/grok_1764706118/1410.pth
# Saved model to /home/stephen/grokking/grok_1764706118/1420.pth
# Saved model to /home/stephen/grokking/grok_1764706118/1430.pth
# Saved model to /home/stephen/grokking/grok_1764706118/1440.pth
# Saved model to /home/stephen/grokking/grok_1764706118/1450.pth
# Saved model to /home/stephen/grokking/grok_1764706118/1460.pth
# Saved model to /home/stephen/grokking/grok_1764706118/1470.pth
# Saved model to /home/stephen/grokking/grok_1764706118/1480.pth
# Saved model to /home/stephen/grokking/grok_1764706118/1490.pth
# 1500_-14.2735_3.3400_pen=5.130e-03
# Saved model to /home/stephen/grokking/grok_1764706118/1500.pth
# Saved model to /home/stephen/grokking/grok_1764706118/1510.pth
# Saved model to /home/stephen/grokking/grok_1764706118/1520.pth
# Saved model to /home/stephen/grokking/grok_1764706118/1530.pth
# Saved model to /home/stephen/grokking/grok_1764706118/1540.pth
# Saved model to /home/stephen/grokking/grok_1764706118/1550.pth
# Saved model to /home/stephen/grokking/grok_1764706118/1560.pth
# Saved model to /home/stephen/grokking/grok_1764706118/1570.pth
# Saved model to /home/stephen/grokking/grok_1764706118/1580.pth
# Saved model to /home/stephen/grokking/grok_1764706118/1590.pth
# 1600_-14.3659_3.3309_pen=4.606e-03
# Saved model to /home/stephen/grokking/grok_1764706118/1600.pth
# Saved model to /home/stephen/grokking/grok_1764706118/1610.pth
# Saved model to /home/stephen/grokking/grok_1764706118/1620.pth
# Saved model to /home/stephen/grokking/grok_1764706118/1630.pth
# Saved model to /home/stephen/grokking/grok_1764706118/1640.pth
# Saved model to /home/stephen/grokking/grok_1764706118/1650.pth
# Saved model to /home/stephen/grokking/grok_1764706118/1660.pth
# Saved model to /home/stephen/grokking/grok_1764706118/1670.pth
# Saved model to /home/stephen/grokking/grok_1764706118/1680.pth
# Saved model to /home/stephen/grokking/grok_1764706118/1690.pth
# 1700_-14.4121_3.3194_pen=4.330e-03
# Saved model to /home/stephen/grokking/grok_1764706118/1700.pth
# Saved model to /home/stephen/grokking/grok_1764706118/1710.pth
# Saved model to /home/stephen/grokking/grok_1764706118/1720.pth
# Saved model to /home/stephen/grokking/grok_1764706118/1730.pth
# Saved model to /home/stephen/grokking/grok_1764706118/1740.pth
# Saved model to /home/stephen/grokking/grok_1764706118/1750.pth
# Saved model to /home/stephen/grokking/grok_1764706118/1760.pth
# Saved model to /home/stephen/grokking/grok_1764706118/1770.pth
# Saved model to /home/stephen/grokking/grok_1764706118/1780.pth
# Saved model to /home/stephen/grokking/grok_1764706118/1790.pth
# 1800_-14.4436_3.3065_pen=4.168e-03
# Saved model to /home/stephen/grokking/grok_1764706118/1800.pth
# Saved model to /home/stephen/grokking/grok_1764706118/1810.pth
# Saved model to /home/stephen/grokking/grok_1764706118/1820.pth
# Saved model to /home/stephen/grokking/grok_1764706118/1830.pth
# Saved model to /home/stephen/grokking/grok_1764706118/1840.pth
# Saved model to /home/stephen/grokking/grok_1764706118/1850.pth
# Saved model to /home/stephen/grokking/grok_1764706118/1860.pth
# Saved model to /home/stephen/grokking/grok_1764706118/1870.pth
# Saved model to /home/stephen/grokking/grok_1764706118/1880.pth
# Saved model to /home/stephen/grokking/grok_1764706118/1890.pth
# 1900_-14.4624_3.2924_pen=4.063e-03
# Saved model to /home/stephen/grokking/grok_1764706118/1900.pth
# Saved model to /home/stephen/grokking/grok_1764706118/1910.pth
# Saved model to /home/stephen/grokking/grok_1764706118/1920.pth
# Saved model to /home/stephen/grokking/grok_1764706118/1930.pth
# Saved model to /home/stephen/grokking/grok_1764706118/1940.pth
# Saved model to /home/stephen/grokking/grok_1764706118/1950.pth
# Saved model to /home/stephen/grokking/grok_1764706118/1960.pth
# Saved model to /home/stephen/grokking/grok_1764706118/1970.pth
# Saved model to /home/stephen/grokking/grok_1764706118/1980.pth
# Saved model to /home/stephen/grokking/grok_1764706118/1990.pth
# 2000_-14.4776_3.2766_pen=3.982e-03
# Saved model to /home/stephen/grokking/grok_1764706118/2000.pth
# Saved model to /home/stephen/grokking/grok_1764706118/2010.pth
# Saved model to /home/stephen/grokking/grok_1764706118/2020.pth
# Saved model to /home/stephen/grokking/grok_1764706118/2030.pth
# Saved model to /home/stephen/grokking/grok_1764706118/2040.pth
# Saved model to /home/stephen/grokking/grok_1764706118/2050.pth
# Saved model to /home/stephen/grokking/grok_1764706118/2060.pth
# Saved model to /home/stephen/grokking/grok_1764706118/2070.pth
# Saved model to /home/stephen/grokking/grok_1764706118/2080.pth
# Saved model to /home/stephen/grokking/grok_1764706118/2090.pth
# 2100_-14.4873_3.2596_pen=3.915e-03
# Saved model to /home/stephen/grokking/grok_1764706118/2100.pth
# Saved model to /home/stephen/grokking/grok_1764706118/2110.pth
# Saved model to /home/stephen/grokking/grok_1764706118/2120.pth
# Saved model to /home/stephen/grokking/grok_1764706118/2130.pth
# Saved model to /home/stephen/grokking/grok_1764706118/2140.pth
# Saved model to /home/stephen/grokking/grok_1764706118/2150.pth
# Saved model to /home/stephen/grokking/grok_1764706118/2160.pth
# Saved model to /home/stephen/grokking/grok_1764706118/2170.pth
# Saved model to /home/stephen/grokking/grok_1764706118/2180.pth
# Saved model to /home/stephen/grokking/grok_1764706118/2190.pth
# 2200_-14.5020_3.2413_pen=3.853e-03
# Saved model to /home/stephen/grokking/grok_1764706118/2200.pth
# Saved model to /home/stephen/grokking/grok_1764706118/2210.pth
# Saved model to /home/stephen/grokking/grok_1764706118/2220.pth
# Saved model to /home/stephen/grokking/grok_1764706118/2230.pth
# Saved model to /home/stephen/grokking/grok_1764706118/2240.pth
# Saved model to /home/stephen/grokking/grok_1764706118/2250.pth
# Saved model to /home/stephen/grokking/grok_1764706118/2260.pth
# Saved model to /home/stephen/grokking/grok_1764706118/2270.pth
# Saved model to /home/stephen/grokking/grok_1764706118/2280.pth
# Saved model to /home/stephen/grokking/grok_1764706118/2290.pth
# 2300_-14.5150_3.2216_pen=3.793e-03
# Saved model to /home/stephen/grokking/grok_1764706118/2300.pth
# Saved model to /home/stephen/grokking/grok_1764706118/2310.pth
# Saved model to /home/stephen/grokking/grok_1764706118/2320.pth
# Saved model to /home/stephen/grokking/grok_1764706118/2330.pth
# Saved model to /home/stephen/grokking/grok_1764706118/2340.pth
# Saved model to /home/stephen/grokking/grok_1764706118/2350.pth
# Saved model to /home/stephen/grokking/grok_1764706118/2360.pth
# Saved model to /home/stephen/grokking/grok_1764706118/2370.pth
# Saved model to /home/stephen/grokking/grok_1764706118/2380.pth
# Saved model to /home/stephen/grokking/grok_1764706118/2390.pth
# 2400_-14.5245_3.2000_pen=3.733e-03
# Saved model to /home/stephen/grokking/grok_1764706118/2400.pth
# Saved model to /home/stephen/grokking/grok_1764706118/2410.pth
# Saved model to /home/stephen/grokking/grok_1764706118/2420.pth
# Saved model to /home/stephen/grokking/grok_1764706118/2430.pth
# Saved model to /home/stephen/grokking/grok_1764706118/2440.pth
# Saved model to /home/stephen/grokking/grok_1764706118/2450.pth
# Saved model to /home/stephen/grokking/grok_1764706118/2460.pth
# Saved model to /home/stephen/grokking/grok_1764706118/2470.pth
# Saved model to /home/stephen/grokking/grok_1764706118/2480.pth
# Saved model to /home/stephen/grokking/grok_1764706118/2490.pth
# 2500_-14.5395_3.1765_pen=3.672e-03
# Saved model to /home/stephen/grokking/grok_1764706118/2500.pth
# Saved model to /home/stephen/grokking/grok_1764706118/2510.pth
# Saved model to /home/stephen/grokking/grok_1764706118/2520.pth
# Saved model to /home/stephen/grokking/grok_1764706118/2530.pth
# Saved model to /home/stephen/grokking/grok_1764706118/2540.pth
# Saved model to /home/stephen/grokking/grok_1764706118/2550.pth
# Saved model to /home/stephen/grokking/grok_1764706118/2560.pth
# Saved model to /home/stephen/grokking/grok_1764706118/2570.pth
# Saved model to /home/stephen/grokking/grok_1764706118/2580.pth
# Saved model to /home/stephen/grokking/grok_1764706118/2590.pth
# 2600_-14.5452_3.1517_pen=3.613e-03
# Saved model to /home/stephen/grokking/grok_1764706118/2600.pth
# Saved model to /home/stephen/grokking/grok_1764706118/2610.pth
# Saved model to /home/stephen/grokking/grok_1764706118/2620.pth
# Saved model to /home/stephen/grokking/grok_1764706118/2630.pth
# Saved model to /home/stephen/grokking/grok_1764706118/2640.pth
# Saved model to /home/stephen/grokking/grok_1764706118/2650.pth
# Saved model to /home/stephen/grokking/grok_1764706118/2660.pth
# Saved model to /home/stephen/grokking/grok_1764706118/2670.pth
# Saved model to /home/stephen/grokking/grok_1764706118/2680.pth
# Saved model to /home/stephen/grokking/grok_1764706118/2690.pth
# 2700_-14.5606_3.1252_pen=3.554e-03
# Saved model to /home/stephen/grokking/grok_1764706118/2700.pth
# Saved model to /home/stephen/grokking/grok_1764706118/2710.pth
# Saved model to /home/stephen/grokking/grok_1764706118/2720.pth
# Saved model to /home/stephen/grokking/grok_1764706118/2730.pth
# Saved model to /home/stephen/grokking/grok_1764706118/2740.pth
# Saved model to /home/stephen/grokking/grok_1764706118/2750.pth
# Saved model to /home/stephen/grokking/grok_1764706118/2760.pth
# Saved model to /home/stephen/grokking/grok_1764706118/2770.pth
# Saved model to /home/stephen/grokking/grok_1764706118/2780.pth
# Saved model to /home/stephen/grokking/grok_1764706118/2790.pth
# 2800_-14.5719_3.0965_pen=3.490e-03
# Saved model to /home/stephen/grokking/grok_1764706118/2800.pth
# Saved model to /home/stephen/grokking/grok_1764706118/2810.pth
# Saved model to /home/stephen/grokking/grok_1764706118/2820.pth
# Saved model to /home/stephen/grokking/grok_1764706118/2830.pth
# Saved model to /home/stephen/grokking/grok_1764706118/2840.pth
# Saved model to /home/stephen/grokking/grok_1764706118/2850.pth
# Saved model to /home/stephen/grokking/grok_1764706118/2860.pth
# Saved model to /home/stephen/grokking/grok_1764706118/2870.pth
# Saved model to /home/stephen/grokking/grok_1764706118/2880.pth
# Saved model to /home/stephen/grokking/grok_1764706118/2890.pth
# 2900_-14.5846_3.0665_pen=3.424e-03
# Saved model to /home/stephen/grokking/grok_1764706118/2900.pth
# Saved model to /home/stephen/grokking/grok_1764706118/2910.pth
# Saved model to /home/stephen/grokking/grok_1764706118/2920.pth
# Saved model to /home/stephen/grokking/grok_1764706118/2930.pth
# Saved model to /home/stephen/grokking/grok_1764706118/2940.pth
# Saved model to /home/stephen/grokking/grok_1764706118/2950.pth
# Saved model to /home/stephen/grokking/grok_1764706118/2960.pth
# Saved model to /home/stephen/grokking/grok_1764706118/2970.pth
# Saved model to /home/stephen/grokking/grok_1764706118/2980.pth
# Saved model to /home/stephen/grokking/grok_1764706118/2990.pth
# 3000_-14.5973_3.0338_pen=3.355e-03
# Saved model to /home/stephen/grokking/grok_1764706118/3000.pth
# Saved model to /home/stephen/grokking/grok_1764706118/3010.pth
# Saved model to /home/stephen/grokking/grok_1764706118/3020.pth
# Saved model to /home/stephen/grokking/grok_1764706118/3030.pth
# Saved model to /home/stephen/grokking/grok_1764706118/3040.pth
# Saved model to /home/stephen/grokking/grok_1764706118/3050.pth
# Saved model to /home/stephen/grokking/grok_1764706118/3060.pth
# Saved model to /home/stephen/grokking/grok_1764706118/3070.pth
# Saved model to /home/stephen/grokking/grok_1764706118/3080.pth
# Saved model to /home/stephen/grokking/grok_1764706118/3090.pth
# 3100_-14.6143_2.9977_pen=3.285e-03
# Saved model to /home/stephen/grokking/grok_1764706118/3100.pth
# Saved model to /home/stephen/grokking/grok_1764706118/3110.pth
# Saved model to /home/stephen/grokking/grok_1764706118/3120.pth
# Saved model to /home/stephen/grokking/grok_1764706118/3130.pth
# Saved model to /home/stephen/grokking/grok_1764706118/3140.pth
# Saved model to /home/stephen/grokking/grok_1764706118/3150.pth
# Saved model to /home/stephen/grokking/grok_1764706118/3160.pth
# Saved model to /home/stephen/grokking/grok_1764706118/3170.pth
# Saved model to /home/stephen/grokking/grok_1764706118/3180.pth
# Saved model to /home/stephen/grokking/grok_1764706118/3190.pth
# 3200_-14.6296_2.9586_pen=3.211e-03
# Saved model to /home/stephen/grokking/grok_1764706118/3200.pth
# Saved model to /home/stephen/grokking/grok_1764706118/3210.pth
# Saved model to /home/stephen/grokking/grok_1764706118/3220.pth
# Saved model to /home/stephen/grokking/grok_1764706118/3230.pth
# Saved model to /home/stephen/grokking/grok_1764706118/3240.pth
# Saved model to /home/stephen/grokking/grok_1764706118/3250.pth
# Saved model to /home/stephen/grokking/grok_1764706118/3260.pth
# Saved model to /home/stephen/grokking/grok_1764706118/3270.pth
# Saved model to /home/stephen/grokking/grok_1764706118/3280.pth
# Saved model to /home/stephen/grokking/grok_1764706118/3290.pth
# 3300_-14.6441_2.9145_pen=3.133e-03
# Saved model to /home/stephen/grokking/grok_1764706118/3300.pth
# Saved model to /home/stephen/grokking/grok_1764706118/3310.pth
# Saved model to /home/stephen/grokking/grok_1764706118/3320.pth
# Saved model to /home/stephen/grokking/grok_1764706118/3330.pth
# Saved model to /home/stephen/grokking/grok_1764706118/3340.pth
# Saved model to /home/stephen/grokking/grok_1764706118/3350.pth
# Saved model to /home/stephen/grokking/grok_1764706118/3360.pth
# Saved model to /home/stephen/grokking/grok_1764706118/3370.pth
# Saved model to /home/stephen/grokking/grok_1764706118/3380.pth
# Saved model to /home/stephen/grokking/grok_1764706118/3390.pth
# 3400_-14.6569_2.8654_pen=3.054e-03
# Saved model to /home/stephen/grokking/grok_1764706118/3400.pth
# Saved model to /home/stephen/grokking/grok_1764706118/3410.pth
# Saved model to /home/stephen/grokking/grok_1764706118/3420.pth
# Saved model to /home/stephen/grokking/grok_1764706118/3430.pth
# Saved model to /home/stephen/grokking/grok_1764706118/3440.pth
# Saved model to /home/stephen/grokking/grok_1764706118/3450.pth
# Saved model to /home/stephen/grokking/grok_1764706118/3460.pth
# Saved model to /home/stephen/grokking/grok_1764706118/3470.pth
# Saved model to /home/stephen/grokking/grok_1764706118/3480.pth
# Saved model to /home/stephen/grokking/grok_1764706118/3490.pth
# 3500_-14.6810_2.8096_pen=2.971e-03
# Saved model to /home/stephen/grokking/grok_1764706118/3500.pth
# Saved model to /home/stephen/grokking/grok_1764706118/3510.pth
# Saved model to /home/stephen/grokking/grok_1764706118/3520.pth
# Saved model to /home/stephen/grokking/grok_1764706118/3530.pth
# Saved model to /home/stephen/grokking/grok_1764706118/3540.pth
# Saved model to /home/stephen/grokking/grok_1764706118/3550.pth
# Saved model to /home/stephen/grokking/grok_1764706118/3560.pth
# Saved model to /home/stephen/grokking/grok_1764706118/3570.pth
# Saved model to /home/stephen/grokking/grok_1764706118/3580.pth
# Saved model to /home/stephen/grokking/grok_1764706118/3590.pth
# 3600_-14.7000_2.7448_pen=2.881e-03
# Saved model to /home/stephen/grokking/grok_1764706118/3600.pth
# Saved model to /home/stephen/grokking/grok_1764706118/3610.pth
# Saved model to /home/stephen/grokking/grok_1764706118/3620.pth
# Saved model to /home/stephen/grokking/grok_1764706118/3630.pth
# Saved model to /home/stephen/grokking/grok_1764706118/3640.pth
# Saved model to /home/stephen/grokking/grok_1764706118/3650.pth
# Saved model to /home/stephen/grokking/grok_1764706118/3660.pth
# Saved model to /home/stephen/grokking/grok_1764706118/3670.pth
# Saved model to /home/stephen/grokking/grok_1764706118/3680.pth
# Saved model to /home/stephen/grokking/grok_1764706118/3690.pth
# 3700_-14.7134_2.6618_pen=2.778e-03
# Saved model to /home/stephen/grokking/grok_1764706118/3700.pth
# Saved model to /home/stephen/grokking/grok_1764706118/3710.pth
# Saved model to /home/stephen/grokking/grok_1764706118/3720.pth
# Saved model to /home/stephen/grokking/grok_1764706118/3730.pth
# Saved model to /home/stephen/grokking/grok_1764706118/3740.pth
# Saved model to /home/stephen/grokking/grok_1764706118/3750.pth
# Saved model to /home/stephen/grokking/grok_1764706118/3760.pth
# Saved model to /home/stephen/grokking/grok_1764706118/3770.pth
# Saved model to /home/stephen/grokking/grok_1764706118/3780.pth
# Saved model to /home/stephen/grokking/grok_1764706118/3790.pth
# 3800_-14.7542_2.5554_pen=2.661e-03
# Saved model to /home/stephen/grokking/grok_1764706118/3800.pth
# Saved model to /home/stephen/grokking/grok_1764706118/3810.pth
# Saved model to /home/stephen/grokking/grok_1764706118/3820.pth
# Saved model to /home/stephen/grokking/grok_1764706118/3830.pth
# Saved model to /home/stephen/grokking/grok_1764706118/3840.pth
# Saved model to /home/stephen/grokking/grok_1764706118/3850.pth
# Saved model to /home/stephen/grokking/grok_1764706118/3860.pth
# Saved model to /home/stephen/grokking/grok_1764706118/3870.pth
# Saved model to /home/stephen/grokking/grok_1764706118/3880.pth
# Saved model to /home/stephen/grokking/grok_1764706118/3890.pth
# 3900_-14.7744_2.4142_pen=2.524e-03
# Saved model to /home/stephen/grokking/grok_1764706118/3900.pth
# Saved model to /home/stephen/grokking/grok_1764706118/3910.pth
# Saved model to /home/stephen/grokking/grok_1764706118/3920.pth
# Saved model to /home/stephen/grokking/grok_1764706118/3930.pth
# Saved model to /home/stephen/grokking/grok_1764706118/3940.pth
# Saved model to /home/stephen/grokking/grok_1764706118/3950.pth
# Saved model to /home/stephen/grokking/grok_1764706118/3960.pth
# Saved model to /home/stephen/grokking/grok_1764706118/3970.pth
# Saved model to /home/stephen/grokking/grok_1764706118/3980.pth
# Saved model to /home/stephen/grokking/grok_1764706118/3990.pth
# 4000_-14.8157_2.2190_pen=2.361e-03
# Saved model to /home/stephen/grokking/grok_1764706118/4000.pth
# Saved model to /home/stephen/grokking/grok_1764706118/4010.pth
# Saved model to /home/stephen/grokking/grok_1764706118/4020.pth
# Saved model to /home/stephen/grokking/grok_1764706118/4030.pth
# Saved model to /home/stephen/grokking/grok_1764706118/4040.pth
# Saved model to /home/stephen/grokking/grok_1764706118/4050.pth
# Saved model to /home/stephen/grokking/grok_1764706118/4060.pth
# Saved model to /home/stephen/grokking/grok_1764706118/4070.pth
# Saved model to /home/stephen/grokking/grok_1764706118/4080.pth
# Saved model to /home/stephen/grokking/grok_1764706118/4090.pth
# 4100_-14.8917_1.9462_pen=2.176e-03
# Saved model to /home/stephen/grokking/grok_1764706118/4100.pth
# Saved model to /home/stephen/grokking/grok_1764706118/4110.pth
# Saved model to /home/stephen/grokking/grok_1764706118/4120.pth
# Saved model to /home/stephen/grokking/grok_1764706118/4130.pth
# Saved model to /home/stephen/grokking/grok_1764706118/4140.pth
# Saved model to /home/stephen/grokking/grok_1764706118/4150.pth
# Saved model to /home/stephen/grokking/grok_1764706118/4160.pth
# Saved model to /home/stephen/grokking/grok_1764706118/4170.pth
# Saved model to /home/stephen/grokking/grok_1764706118/4180.pth
# Saved model to /home/stephen/grokking/grok_1764706118/4190.pth
# 4200_-14.9601_1.5751_pen=1.973e-03
# Saved model to /home/stephen/grokking/grok_1764706118/4200.pth
# Saved model to /home/stephen/grokking/grok_1764706118/4210.pth
# Saved model to /home/stephen/grokking/grok_1764706118/4220.pth
# Saved model to /home/stephen/grokking/grok_1764706118/4230.pth
# Saved model to /home/stephen/grokking/grok_1764706118/4240.pth
# Saved model to /home/stephen/grokking/grok_1764706118/4250.pth
# Saved model to /home/stephen/grokking/grok_1764706118/4260.pth
# Saved model to /home/stephen/grokking/grok_1764706118/4270.pth
# Saved model to /home/stephen/grokking/grok_1764706118/4280.pth
# Saved model to /home/stephen/grokking/grok_1764706118/4290.pth
# 4300_-15.0292_1.0938_pen=1.771e-03
# Saved model to /home/stephen/grokking/grok_1764706118/4300.pth
# Saved model to /home/stephen/grokking/grok_1764706118/4310.pth
# Saved model to /home/stephen/grokking/grok_1764706118/4320.pth
# Saved model to /home/stephen/grokking/grok_1764706118/4330.pth
# Saved model to /home/stephen/grokking/grok_1764706118/4340.pth
# Saved model to /home/stephen/grokking/grok_1764706118/4350.pth
# Saved model to /home/stephen/grokking/grok_1764706118/4360.pth
# Saved model to /home/stephen/grokking/grok_1764706118/4370.pth
# Saved model to /home/stephen/grokking/grok_1764706118/4380.pth
# Saved model to /home/stephen/grokking/grok_1764706118/4390.pth
# 4400_-15.1026_0.4718_pen=1.581e-03
# Saved model to /home/stephen/grokking/grok_1764706118/4400.pth
# Saved model to /home/stephen/grokking/grok_1764706118/4410.pth
# Saved model to /home/stephen/grokking/grok_1764706118/4420.pth
# Saved model to /home/stephen/grokking/grok_1764706118/4430.pth
# Saved model to /home/stephen/grokking/grok_1764706118/4440.pth
# Saved model to /home/stephen/grokking/grok_1764706118/4450.pth
# Saved model to /home/stephen/grokking/grok_1764706118/4460.pth
# Saved model to /home/stephen/grokking/grok_1764706118/4470.pth
# Saved model to /home/stephen/grokking/grok_1764706118/4480.pth
# Saved model to /home/stephen/grokking/grok_1764706118/4490.pth
# 4500_-15.2031_-0.2819_pen=1.408e-03
# Saved model to /home/stephen/grokking/grok_1764706118/4500.pth
# Saved model to /home/stephen/grokking/grok_1764706118/4510.pth
# Saved model to /home/stephen/grokking/grok_1764706118/4520.pth
# Saved model to /home/stephen/grokking/grok_1764706118/4530.pth
# Saved model to /home/stephen/grokking/grok_1764706118/4540.pth
# Saved model to /home/stephen/grokking/grok_1764706118/4550.pth
# Saved model to /home/stephen/grokking/grok_1764706118/4560.pth
# Saved model to /home/stephen/grokking/grok_1764706118/4570.pth
# Saved model to /home/stephen/grokking/grok_1764706118/4580.pth
# Saved model to /home/stephen/grokking/grok_1764706118/4590.pth
# 4600_-15.2964_-1.2344_pen=1.250e-03
# Saved model to /home/stephen/grokking/grok_1764706118/4600.pth
# Saved model to /home/stephen/grokking/grok_1764706118/4610.pth
# Saved model to /home/stephen/grokking/grok_1764706118/4620.pth
# Saved model to /home/stephen/grokking/grok_1764706118/4630.pth
# Saved model to /home/stephen/grokking/grok_1764706118/4640.pth
# Saved model to /home/stephen/grokking/grok_1764706118/4650.pth
# Saved model to /home/stephen/grokking/grok_1764706118/4660.pth
# Saved model to /home/stephen/grokking/grok_1764706118/4670.pth
# Saved model to /home/stephen/grokking/grok_1764706118/4680.pth
# Saved model to /home/stephen/grokking/grok_1764706118/4690.pth
# 4700_-15.4397_-2.5078_pen=1.105e-03
# Saved model to /home/stephen/grokking/grok_1764706118/4700.pth
# Saved model to /home/stephen/grokking/grok_1764706118/4710.pth
# Saved model to /home/stephen/grokking/grok_1764706118/4720.pth
# Saved model to /home/stephen/grokking/grok_1764706118/4730.pth
# Saved model to /home/stephen/grokking/grok_1764706118/4740.pth
# Saved model to /home/stephen/grokking/grok_1764706118/4750.pth
# Saved model to /home/stephen/grokking/grok_1764706118/4760.pth
# Saved model to /home/stephen/grokking/grok_1764706118/4770.pth
# Saved model to /home/stephen/grokking/grok_1764706118/4780.pth
# Saved model to /home/stephen/grokking/grok_1764706118/4790.pth
# 4800_-15.5616_-4.2412_pen=9.811e-04
# Saved model to /home/stephen/grokking/grok_1764706118/4800.pth
# Saved model to /home/stephen/grokking/grok_1764706118/4810.pth
# Saved model to /home/stephen/grokking/grok_1764706118/4820.pth
# Saved model to /home/stephen/grokking/grok_1764706118/4830.pth
# Saved model to /home/stephen/grokking/grok_1764706118/4840.pth
# Saved model to /home/stephen/grokking/grok_1764706118/4850.pth
# Saved model to /home/stephen/grokking/grok_1764706118/4860.pth
# Saved model to /home/stephen/grokking/grok_1764706118/4870.pth
# Saved model to /home/stephen/grokking/grok_1764706118/4880.pth
# Saved model to /home/stephen/grokking/grok_1764706118/4890.pth
# 4900_-15.6521_-6.3974_pen=8.931e-04
# Saved model to /home/stephen/grokking/grok_1764706118/4900.pth
# Saved model to /home/stephen/grokking/grok_1764706118/4910.pth
# Saved model to /home/stephen/grokking/grok_1764706118/4920.pth
# Saved model to /home/stephen/grokking/grok_1764706118/4930.pth
# Saved model to /home/stephen/grokking/grok_1764706118/4940.pth
# Saved model to /home/stephen/grokking/grok_1764706118/4950.pth
# Saved model to /home/stephen/grokking/grok_1764706118/4960.pth
# Saved model to /home/stephen/grokking/grok_1764706118/4970.pth
# Saved model to /home/stephen/grokking/grok_1764706118/4980.pth
# Saved model to /home/stephen/grokking/grok_1764706118/4990.pth
# 5000_-15.7125_-8.4723_pen=8.337e-04
# Saved model to /home/stephen/grokking/grok_1764706118/5000.pth
# Saved model to /home/stephen/grokking/grok_1764706118/5010.pth
# Saved model to /home/stephen/grokking/grok_1764706118/5020.pth
# Saved model to /home/stephen/grokking/grok_1764706118/5030.pth
# Saved model to /home/stephen/grokking/grok_1764706118/5040.pth
# Saved model to /home/stephen/grokking/grok_1764706118/5050.pth
# Saved model to /home/stephen/grokking/grok_1764706118/5060.pth
# Saved model to /home/stephen/grokking/grok_1764706118/5070.pth
# Saved model to /home/stephen/grokking/grok_1764706118/5080.pth
# Saved model to /home/stephen/grokking/grok_1764706118/5090.pth
# 5100_-15.7518_-10.7023_pen=7.934e-04
# Saved model to /home/stephen/grokking/grok_1764706118/5100.pth
# Saved model to /home/stephen/grokking/grok_1764706118/5110.pth
# Saved model to /home/stephen/grokking/grok_1764706118/5120.pth
# Saved model to /home/stephen/grokking/grok_1764706118/5130.pth
# Saved model to /home/stephen/grokking/grok_1764706118/5140.pth
# Saved model to /home/stephen/grokking/grok_1764706118/5150.pth
# Saved model to /home/stephen/grokking/grok_1764706118/5160.pth
# Saved model to /home/stephen/grokking/grok_1764706118/5170.pth
# Saved model to /home/stephen/grokking/grok_1764706118/5180.pth
# Saved model to /home/stephen/grokking/grok_1764706118/5190.pth
# 5200_-15.7789_-12.5343_pen=7.672e-04
# Saved model to /home/stephen/grokking/grok_1764706118/5200.pth
# Saved model to /home/stephen/grokking/grok_1764706118/5210.pth
# Saved model to /home/stephen/grokking/grok_1764706118/5220.pth
# Saved model to /home/stephen/grokking/grok_1764706118/5230.pth
# Saved model to /home/stephen/grokking/grok_1764706118/5240.pth
# Saved model to /home/stephen/grokking/grok_1764706118/5250.pth
# Saved model to /home/stephen/grokking/grok_1764706118/5260.pth
# Saved model to /home/stephen/grokking/grok_1764706118/5270.pth
# Saved model to /home/stephen/grokking/grok_1764706118/5280.pth
# Saved model to /home/stephen/grokking/grok_1764706118/5290.pth
# 5300_-15.7973_-13.6440_pen=7.507e-04
# Saved model to /home/stephen/grokking/grok_1764706118/5300.pth
# Saved model to /home/stephen/grokking/grok_1764706118/5310.pth
# Saved model to /home/stephen/grokking/grok_1764706118/5320.pth
# Saved model to /home/stephen/grokking/grok_1764706118/5330.pth
# Saved model to /home/stephen/grokking/grok_1764706118/5340.pth
# Saved model to /home/stephen/grokking/grok_1764706118/5350.pth
# Saved model to /home/stephen/grokking/grok_1764706118/5360.pth
# Saved model to /home/stephen/grokking/grok_1764706118/5370.pth
# Saved model to /home/stephen/grokking/grok_1764706118/5380.pth
# Saved model to /home/stephen/grokking/grok_1764706118/5390.pth
# 5400_-15.8079_-14.2695_pen=7.413e-04
# Saved model to /home/stephen/grokking/grok_1764706118/5400.pth
# Saved model to /home/stephen/grokking/grok_1764706118/5410.pth
# Saved model to /home/stephen/grokking/grok_1764706118/5420.pth
# Saved model to /home/stephen/grokking/grok_1764706118/5430.pth
# Saved model to /home/stephen/grokking/grok_1764706118/5440.pth
# Saved model to /home/stephen/grokking/grok_1764706118/5450.pth
# Saved model to /home/stephen/grokking/grok_1764706118/5460.pth
# Saved model to /home/stephen/grokking/grok_1764706118/5470.pth
# Saved model to /home/stephen/grokking/grok_1764706118/5480.pth
# Saved model to /home/stephen/grokking/grok_1764706118/5490.pth
# 5500_-15.8142_-14.6414_pen=7.357e-04
# Saved model to /home/stephen/grokking/grok_1764706118/5500.pth
# Saved model to /home/stephen/grokking/grok_1764706118/5510.pth
# Saved model to /home/stephen/grokking/grok_1764706118/5520.pth
# Saved model to /home/stephen/grokking/grok_1764706118/5530.pth
# Saved model to /home/stephen/grokking/grok_1764706118/5540.pth
# Saved model to /home/stephen/grokking/grok_1764706118/5550.pth
# Saved model to /home/stephen/grokking/grok_1764706118/5560.pth
# Saved model to /home/stephen/grokking/grok_1764706118/5570.pth
# Saved model to /home/stephen/grokking/grok_1764706118/5580.pth
# Saved model to /home/stephen/grokking/grok_1764706118/5590.pth
# 5600_-15.8209_-14.8648_pen=7.323e-04
# Saved model to /home/stephen/grokking/grok_1764706118/5600.pth
# Saved model to /home/stephen/grokking/grok_1764706118/5610.pth
# Saved model to /home/stephen/grokking/grok_1764706118/5620.pth
# Saved model to /home/stephen/grokking/grok_1764706118/5630.pth
# Saved model to /home/stephen/grokking/grok_1764706118/5640.pth
# Saved model to /home/stephen/grokking/grok_1764706118/5650.pth
# Saved model to /home/stephen/grokking/grok_1764706118/5660.pth
# Saved model to /home/stephen/grokking/grok_1764706118/5670.pth
# Saved model to /home/stephen/grokking/grok_1764706118/5680.pth
# Saved model to /home/stephen/grokking/grok_1764706118/5690.pth
# 5700_-15.8250_-15.0043_pen=7.303e-04
# Saved model to /home/stephen/grokking/grok_1764706118/5700.pth
# Saved model to /home/stephen/grokking/grok_1764706118/5710.pth
# Saved model to /home/stephen/grokking/grok_1764706118/5720.pth
# Saved model to /home/stephen/grokking/grok_1764706118/5730.pth
# Saved model to /home/stephen/grokking/grok_1764706118/5740.pth
# Saved model to /home/stephen/grokking/grok_1764706118/5750.pth
# Saved model to /home/stephen/grokking/grok_1764706118/5760.pth
# Saved model to /home/stephen/grokking/grok_1764706118/5770.pth
# Saved model to /home/stephen/grokking/grok_1764706118/5780.pth
# Saved model to /home/stephen/grokking/grok_1764706118/5790.pth
# 5800_-15.8267_-15.0959_pen=7.287e-04
# Saved model to /home/stephen/grokking/grok_1764706118/5800.pth
# Saved model to /home/stephen/grokking/grok_1764706118/5810.pth
# Saved model to /home/stephen/grokking/grok_1764706118/5820.pth
# Saved model to /home/stephen/grokking/grok_1764706118/5830.pth
# Saved model to /home/stephen/grokking/grok_1764706118/5840.pth
# Saved model to /home/stephen/grokking/grok_1764706118/5850.pth
# Saved model to /home/stephen/grokking/grok_1764706118/5860.pth
# Saved model to /home/stephen/grokking/grok_1764706118/5870.pth
# Saved model to /home/stephen/grokking/grok_1764706118/5880.pth
# Saved model to /home/stephen/grokking/grok_1764706118/5890.pth
# 5900_-15.8300_-15.1624_pen=7.277e-04
# Saved model to /home/stephen/grokking/grok_1764706118/5900.pth
# Saved model to /home/stephen/grokking/grok_1764706118/5910.pth
# Saved model to /home/stephen/grokking/grok_1764706118/5920.pth
# Saved model to /home/stephen/grokking/grok_1764706118/5930.pth
# Saved model to /home/stephen/grokking/grok_1764706118/5940.pth
# Saved model to /home/stephen/grokking/grok_1764706118/5950.pth
# Saved model to /home/stephen/grokking/grok_1764706118/5960.pth
# Saved model to /home/stephen/grokking/grok_1764706118/5970.pth
# Saved model to /home/stephen/grokking/grok_1764706118/5980.pth
# Saved model to /home/stephen/grokking/grok_1764706118/5990.pth
# 6000_-15.8318_-15.2127_pen=7.267e-04
# Saved model to /home/stephen/grokking/grok_1764706118/6000.pth
# Saved model to /home/stephen/grokking/grok_1764706118/6010.pth
# Saved model to /home/stephen/grokking/grok_1764706118/6020.pth
# Saved model to /home/stephen/grokking/grok_1764706118/6030.pth
# Saved model to /home/stephen/grokking/grok_1764706118/6040.pth
# Saved model to /home/stephen/grokking/grok_1764706118/6050.pth
# Saved model to /home/stephen/grokking/grok_1764706118/6060.pth
# Saved model to /home/stephen/grokking/grok_1764706118/6070.pth
# Saved model to /home/stephen/grokking/grok_1764706118/6080.pth
# Saved model to /home/stephen/grokking/grok_1764706118/6090.pth
# 6100_-15.8334_-15.2487_pen=7.257e-04
# Saved model to /home/stephen/grokking/grok_1764706118/6100.pth
# Saved model to /home/stephen/grokking/grok_1764706118/6110.pth
# Saved model to /home/stephen/grokking/grok_1764706118/6120.pth
# Saved model to /home/stephen/grokking/grok_1764706118/6130.pth
# Saved model to /home/stephen/grokking/grok_1764706118/6140.pth
# Saved model to /home/stephen/grokking/grok_1764706118/6150.pth
# Saved model to /home/stephen/grokking/grok_1764706118/6160.pth
# Saved model to /home/stephen/grokking/grok_1764706118/6170.pth
# Saved model to /home/stephen/grokking/grok_1764706118/6180.pth
# Saved model to /home/stephen/grokking/grok_1764706118/6190.pth
# 6200_-15.8357_-15.2784_pen=7.249e-04
# Saved model to /home/stephen/grokking/grok_1764706118/6200.pth
# Saved model to /home/stephen/grokking/grok_1764706118/6210.pth
# Saved model to /home/stephen/grokking/grok_1764706118/6220.pth
# Saved model to /home/stephen/grokking/grok_1764706118/6230.pth
# Saved model to /home/stephen/grokking/grok_1764706118/6240.pth
# Saved model to /home/stephen/grokking/grok_1764706118/6250.pth
# Saved model to /home/stephen/grokking/grok_1764706118/6260.pth
# Saved model to /home/stephen/grokking/grok_1764706118/6270.pth
# Saved model to /home/stephen/grokking/grok_1764706118/6280.pth
# Saved model to /home/stephen/grokking/grok_1764706118/6290.pth
# 6300_-15.8363_-15.3018_pen=7.240e-04
# Saved model to /home/stephen/grokking/grok_1764706118/6300.pth
# Saved model to /home/stephen/grokking/grok_1764706118/6310.pth
# Saved model to /home/stephen/grokking/grok_1764706118/6320.pth
# Saved model to /home/stephen/grokking/grok_1764706118/6330.pth
# Saved model to /home/stephen/grokking/grok_1764706118/6340.pth
# Saved model to /home/stephen/grokking/grok_1764706118/6350.pth
# Saved model to /home/stephen/grokking/grok_1764706118/6360.pth
# Saved model to /home/stephen/grokking/grok_1764706118/6370.pth
# Saved model to /home/stephen/grokking/grok_1764706118/6380.pth
# Saved model to /home/stephen/grokking/grok_1764706118/6390.pth
# 6400_-15.8379_-15.3191_pen=7.231e-04
# Saved model to /home/stephen/grokking/grok_1764706118/6400.pth
# Saved model to /home/stephen/grokking/grok_1764706118/6410.pth
# Saved model to /home/stephen/grokking/grok_1764706118/6420.pth
# Saved model to /home/stephen/grokking/grok_1764706118/6430.pth
# Saved model to /home/stephen/grokking/grok_1764706118/6440.pth
# Saved model to /home/stephen/grokking/grok_1764706118/6450.pth
# Saved model to /home/stephen/grokking/grok_1764706118/6460.pth
# Saved model to /home/stephen/grokking/grok_1764706118/6470.pth
# Saved model to /home/stephen/grokking/grok_1764706118/6480.pth
# Saved model to /home/stephen/grokking/grok_1764706118/6490.pth
# 6500_-15.8395_-15.3335_pen=7.223e-04
# Saved model to /home/stephen/grokking/grok_1764706118/6500.pth
# Saved model to /home/stephen/grokking/grok_1764706118/6510.pth
# Saved model to /home/stephen/grokking/grok_1764706118/6520.pth
# Saved model to /home/stephen/grokking/grok_1764706118/6530.pth
# Saved model to /home/stephen/grokking/grok_1764706118/6540.pth
# Saved model to /home/stephen/grokking/grok_1764706118/6550.pth
# Saved model to /home/stephen/grokking/grok_1764706118/6560.pth
# Saved model to /home/stephen/grokking/grok_1764706118/6570.pth
# Saved model to /home/stephen/grokking/grok_1764706118/6580.pth
# Saved model to /home/stephen/grokking/grok_1764706118/6590.pth
# 6600_-15.8405_-15.3452_pen=7.215e-04
# Saved model to /home/stephen/grokking/grok_1764706118/6600.pth
# Saved model to /home/stephen/grokking/grok_1764706118/6610.pth
# Saved model to /home/stephen/grokking/grok_1764706118/6620.pth
# Saved model to /home/stephen/grokking/grok_1764706118/6630.pth
# Saved model to /home/stephen/grokking/grok_1764706118/6640.pth
# Saved model to /home/stephen/grokking/grok_1764706118/6650.pth
# Saved model to /home/stephen/grokking/grok_1764706118/6660.pth
# Saved model to /home/stephen/grokking/grok_1764706118/6670.pth
# Saved model to /home/stephen/grokking/grok_1764706118/6680.pth
# Saved model to /home/stephen/grokking/grok_1764706118/6690.pth
# 6700_-15.8426_-15.3561_pen=7.208e-04
# Saved model to /home/stephen/grokking/grok_1764706118/6700.pth
# Saved model to /home/stephen/grokking/grok_1764706118/6710.pth
# Saved model to /home/stephen/grokking/grok_1764706118/6720.pth
# Saved model to /home/stephen/grokking/grok_1764706118/6730.pth
# Saved model to /home/stephen/grokking/grok_1764706118/6740.pth
# Saved model to /home/stephen/grokking/grok_1764706118/6750.pth
# Saved model to /home/stephen/grokking/grok_1764706118/6760.pth
# Saved model to /home/stephen/grokking/grok_1764706118/6770.pth
# Saved model to /home/stephen/grokking/grok_1764706118/6780.pth
# Saved model to /home/stephen/grokking/grok_1764706118/6790.pth
# 6800_-15.8446_-15.3666_pen=7.200e-04
# Saved model to /home/stephen/grokking/grok_1764706118/6800.pth
# Saved model to /home/stephen/grokking/grok_1764706118/6810.pth
# Saved model to /home/stephen/grokking/grok_1764706118/6820.pth
# Saved model to /home/stephen/grokking/grok_1764706118/6830.pth
# Saved model to /home/stephen/grokking/grok_1764706118/6840.pth
# Saved model to /home/stephen/grokking/grok_1764706118/6850.pth
# Saved model to /home/stephen/grokking/grok_1764706118/6860.pth
# Saved model to /home/stephen/grokking/grok_1764706118/6870.pth
# Saved model to /home/stephen/grokking/grok_1764706118/6880.pth
# Saved model to /home/stephen/grokking/grok_1764706118/6890.pth
# 6900_-15.8461_-15.3742_pen=7.193e-04
# Saved model to /home/stephen/grokking/grok_1764706118/6900.pth
# Saved model to /home/stephen/grokking/grok_1764706118/6910.pth
# Saved model to /home/stephen/grokking/grok_1764706118/6920.pth
# Saved model to /home/stephen/grokking/grok_1764706118/6930.pth
# Saved model to /home/stephen/grokking/grok_1764706118/6940.pth
# Saved model to /home/stephen/grokking/grok_1764706118/6950.pth
# Saved model to /home/stephen/grokking/grok_1764706118/6960.pth
# Saved model to /home/stephen/grokking/grok_1764706118/6970.pth
# Saved model to /home/stephen/grokking/grok_1764706118/6980.pth
# Saved model to /home/stephen/grokking/grok_1764706118/6990.pth
# 7000_-15.8470_-15.3806_pen=7.186e-04
# Saved model to /home/stephen/grokking/grok_1764706118/7000.pth
# Saved model to /home/stephen/grokking/grok_1764706118/7010.pth
# Saved model to /home/stephen/grokking/grok_1764706118/7020.pth
# Saved model to /home/stephen/grokking/grok_1764706118/7030.pth
# Saved model to /home/stephen/grokking/grok_1764706118/7040.pth
# Saved model to /home/stephen/grokking/grok_1764706118/7050.pth
# Saved model to /home/stephen/grokking/grok_1764706118/7060.pth
# Saved model to /home/stephen/grokking/grok_1764706118/7070.pth
# Saved model to /home/stephen/grokking/grok_1764706118/7080.pth
# Saved model to /home/stephen/grokking/grok_1764706118/7090.pth
# 7100_-15.8487_-15.3849_pen=7.179e-04
# Saved model to /home/stephen/grokking/grok_1764706118/7100.pth
# Saved model to /home/stephen/grokking/grok_1764706118/7110.pth
# Saved model to /home/stephen/grokking/grok_1764706118/7120.pth
# Saved model to /home/stephen/grokking/grok_1764706118/7130.pth
# Saved model to /home/stephen/grokking/grok_1764706118/7140.pth
# Saved model to /home/stephen/grokking/grok_1764706118/7150.pth
# Saved model to /home/stephen/grokking/grok_1764706118/7160.pth
# Saved model to /home/stephen/grokking/grok_1764706118/7170.pth
# Saved model to /home/stephen/grokking/grok_1764706118/7180.pth
# Saved model to /home/stephen/grokking/grok_1764706118/7190.pth
# 7200_-15.8498_-15.3892_pen=7.173e-04
# Saved model to /home/stephen/grokking/grok_1764706118/7200.pth
# Saved model to /home/stephen/grokking/grok_1764706118/7210.pth
# ...
# Saved model to /home/stephen/grokking/grok_1764706118/17650.pth
# Saved model to /home/stephen/grokking/grok_1764706118/17660.pth
# Saved model to /home/stephen/grokking/grok_1764706118/17670.pth
# Saved model to /home/stephen/grokking/grok_1764706118/17680.pth
# Saved model to /home/stephen/grokking/grok_1764706118/17690.pth
# 17700_-15.8810_-15.1541_pen=6.920e-04
# Saved model to /home/stephen/grokking/grok_1764706118/17700.pth
# Saved model to /home/stephen/grokking/grok_1764706118/17710.pth
# Saved model to /home/stephen/grokking/grok_1764706118/17720.pth
# Saved model to /home/stephen/grokking/grok_1764706118/17730.pth
# Saved model to /home/stephen/grokking/grok_1764706118/17740.pth
# Saved model to /home/stephen/grokking/grok_1764706118/17750.pth
# Saved model to /home/stephen/grokking/grok_1764706118/17760.pth
# Saved model to /home/stephen/grokking/grok_1764706118/17770.pth
# Saved model to /home/stephen/grokking/grok_1764706118/17780.pth
# Saved model to /home/stephen/grokking/grok_1764706118/17790.pth
# 17800_-15.8816_-15.1479_pen=6.918e-04
# Saved model to /home/stephen/grokking/grok_1764706118/17800.pth
# Saved model to /home/stephen/grokking/grok_1764706118/17810.pth
# Saved model to /home/stephen/grokking/grok_1764706118/17820.pth
# Saved model to /home/stephen/grokking/grok_1764706118/17830.pth
# Saved model to /home/stephen/grokking/grok_1764706118/17840.pth
# Saved model to /home/stephen/grokking/grok_1764706118/17850.pth
# Saved model to /home/stephen/grokking/grok_1764706118/17860.pth
# Saved model to /home/stephen/grokking/grok_1764706118/17870.pth
# Saved model to /home/stephen/grokking/grok_1764706118/17880.pth
# Saved model to /home/stephen/grokking/grok_1764706118/17890.pth
# 17900_-15.8836_-15.1506_pen=6.917e-04
# Saved model to /home/stephen/grokking/grok_1764706118/17900.pth
# Saved model to /home/stephen/grokking/grok_1764706118/17910.pth
# Saved model to /home/stephen/grokking/grok_1764706118/17920.pth
# Saved model to /home/stephen/grokking/grok_1764706118/17930.pth
# Saved model to /home/stephen/grokking/grok_1764706118/17940.pth
# Saved model to /home/stephen/grokking/grok_1764706118/17950.pth
# Saved model to /home/stephen/grokking/grok_1764706118/17960.pth
# Saved model to /home/stephen/grokking/grok_1764706118/17970.pth
# Saved model to /home/stephen/grokking/grok_1764706118/17980.pth
# Saved model to /home/stephen/grokking/grok_1764706118/17990.pth
# 18000_-15.8806_-15.1466_pen=6.915e-04
# Saved model to /home/stephen/grokking/grok_1764706118/18000.pth
# Saved model to /home/stephen/grokking/grok_1764706118/18010.pth
# Saved model to /home/stephen/grokking/grok_1764706118/18020.pth
# Saved model to /home/stephen/grokking/grok_1764706118/18030.pth
# Saved model to /home/stephen/grokking/grok_1764706118/18040.pth
# Saved model to /home/stephen/grokking/grok_1764706118/18050.pth
# Saved model to /home/stephen/grokking/grok_1764706118/18060.pth
# Saved model to /home/stephen/grokking/grok_1764706118/18070.pth
# Saved model to /home/stephen/grokking/grok_1764706118/18080.pth
# Saved model to /home/stephen/grokking/grok_1764706118/18090.pth
# 18100_-15.8842_-15.1291_pen=6.914e-04
# Saved model to /home/stephen/grokking/grok_1764706118/18100.pth
# Saved model to /home/stephen/grokking/grok_1764706118/18110.pth
# Saved model to /home/stephen/grokking/grok_1764706118/18120.pth
# Saved model to /home/stephen/grokking/grok_1764706118/18130.pth
# Saved model to /home/stephen/grokking/grok_1764706118/18140.pth
# Saved model to /home/stephen/grokking/grok_1764706118/18150.pth
# Saved model to /home/stephen/grokking/grok_1764706118/18160.pth
# Saved model to /home/stephen/grokking/grok_1764706118/18170.pth
# Saved model to /home/stephen/grokking/grok_1764706118/18180.pth
# Saved model to /home/stephen/grokking/grok_1764706118/18190.pth
# 18200_-15.8828_-15.1215_pen=6.911e-04
# Saved model to /home/stephen/grokking/grok_1764706118/18200.pth
# Saved model to /home/stephen/grokking/grok_1764706118/18210.pth
# Saved model to /home/stephen/grokking/grok_1764706118/18220.pth
# Saved model to /home/stephen/grokking/grok_1764706118/18230.pth
# Saved model to /home/stephen/grokking/grok_1764706118/18240.pth
# Saved model to /home/stephen/grokking/grok_1764706118/18250.pth
# Saved model to /home/stephen/grokking/grok_1764706118/18260.pth
# Saved model to /home/stephen/grokking/grok_1764706118/18270.pth
# Saved model to /home/stephen/grokking/grok_1764706118/18280.pth
# Saved model to /home/stephen/grokking/grok_1764706118/18290.pth
# 18300_-15.8836_-15.1151_pen=6.910e-04
# Saved model to /home/stephen/grokking/grok_1764706118/18300.pth
# Saved model to /home/stephen/grokking/grok_1764706118/18310.pth
# Saved model to /home/stephen/grokking/grok_1764706118/18320.pth
# Saved model to /home/stephen/grokking/grok_1764706118/18330.pth
# Saved model to /home/stephen/grokking/grok_1764706118/18340.pth
# Saved model to /home/stephen/grokking/grok_1764706118/18350.pth
# Saved model to /home/stephen/grokking/grok_1764706118/18360.pth
# Saved model to /home/stephen/grokking/grok_1764706118/18370.pth
# Saved model to /home/stephen/grokking/grok_1764706118/18380.pth
# Saved model to /home/stephen/grokking/grok_1764706118/18390.pth
# 18400_-15.8836_-15.1106_pen=6.908e-04
# Saved model to /home/stephen/grokking/grok_1764706118/18400.pth
# Saved model to /home/stephen/grokking/grok_1764706118/18410.pth
# Saved model to /home/stephen/grokking/grok_1764706118/18420.pth
# Saved model to /home/stephen/grokking/grok_1764706118/18430.pth
# Saved model to /home/stephen/grokking/grok_1764706118/18440.pth
# Saved model to /home/stephen/grokking/grok_1764706118/18450.pth
# Saved model to /home/stephen/grokking/grok_1764706118/18460.pth
# Saved model to /home/stephen/grokking/grok_1764706118/18470.pth
# Saved model to /home/stephen/grokking/grok_1764706118/18480.pth
# Saved model to /home/stephen/grokking/grok_1764706118/18490.pth
# 18500_-15.8832_-15.1089_pen=6.907e-04
# Saved model to /home/stephen/grokking/grok_1764706118/18500.pth
# Saved model to /home/stephen/grokking/grok_1764706118/18510.pth
# Saved model to /home/stephen/grokking/grok_1764706118/18520.pth
# Saved model to /home/stephen/grokking/grok_1764706118/18530.pth
# Saved model to /home/stephen/grokking/grok_1764706118/18540.pth
# Saved model to /home/stephen/grokking/grok_1764706118/18550.pth
# Saved model to /home/stephen/grokking/grok_1764706118/18560.pth
# Saved model to /home/stephen/grokking/grok_1764706118/18570.pth
# Saved model to /home/stephen/grokking/grok_1764706118/18580.pth
# Saved model to /home/stephen/grokking/grok_1764706118/18590.pth
# 18600_-15.8852_-15.0977_pen=6.906e-04
# Saved model to /home/stephen/grokking/grok_1764706118/18600.pth
# Saved model to /home/stephen/grokking/grok_1764706118/18610.pth
# Saved model to /home/stephen/grokking/grok_1764706118/18620.pth
# Saved model to /home/stephen/grokking/grok_1764706118/18630.pth
# Saved model to /home/stephen/grokking/grok_1764706118/18640.pth
# Saved model to /home/stephen/grokking/grok_1764706118/18650.pth
# Saved model to /home/stephen/grokking/grok_1764706118/18660.pth
# Saved model to /home/stephen/grokking/grok_1764706118/18670.pth
# Saved model to /home/stephen/grokking/grok_1764706118/18680.pth
# Saved model to /home/stephen/grokking/grok_1764706118/18690.pth
# 18700_-15.8846_-15.0939_pen=6.904e-04
# Saved model to /home/stephen/grokking/grok_1764706118/18700.pth
# Saved model to /home/stephen/grokking/grok_1764706118/18710.pth
# Saved model to /home/stephen/grokking/grok_1764706118/18720.pth
# Saved model to /home/stephen/grokking/grok_1764706118/18730.pth
# Saved model to /home/stephen/grokking/grok_1764706118/18740.pth
# Saved model to /home/stephen/grokking/grok_1764706118/18750.pth
# Saved model to /home/stephen/grokking/grok_1764706118/18760.pth
# Saved model to /home/stephen/grokking/grok_1764706118/18770.pth
# Saved model to /home/stephen/grokking/grok_1764706118/18780.pth
# Saved model to /home/stephen/grokking/grok_1764706118/18790.pth
# 18800_-15.8841_-15.0864_pen=6.902e-04
# Saved model to /home/stephen/grokking/grok_1764706118/18800.pth
# Saved model to /home/stephen/grokking/grok_1764706118/18810.pth
# Saved model to /home/stephen/grokking/grok_1764706118/18820.pth
# Saved model to /home/stephen/grokking/grok_1764706118/18830.pth
# Saved model to /home/stephen/grokking/grok_1764706118/18840.pth
# Saved model to /home/stephen/grokking/grok_1764706118/18850.pth
# Saved model to /home/stephen/grokking/grok_1764706118/18860.pth
# Saved model to /home/stephen/grokking/grok_1764706118/18870.pth
# Saved model to /home/stephen/grokking/grok_1764706118/18880.pth
# Saved model to /home/stephen/grokking/grok_1764706118/18890.pth
# 18900_-15.8863_-15.0742_pen=6.902e-04
# Saved model to /home/stephen/grokking/grok_1764706118/18900.pth
# Saved model to /home/stephen/grokking/grok_1764706118/18910.pth
# Saved model to /home/stephen/grokking/grok_1764706118/18920.pth
# Saved model to /home/stephen/grokking/grok_1764706118/18930.pth
# Saved model to /home/stephen/grokking/grok_1764706118/18940.pth
# Saved model to /home/stephen/grokking/grok_1764706118/18950.pth
# Saved model to /home/stephen/grokking/grok_1764706118/18960.pth
# Saved model to /home/stephen/grokking/grok_1764706118/18970.pth
# Saved model to /home/stephen/grokking/grok_1764706118/18980.pth
# Saved model to /home/stephen/grokking/grok_1764706118/18990.pth
# 19000_-15.8836_-15.0779_pen=6.900e-04
# Saved model to /home/stephen/grokking/grok_1764706118/19000.pth
# Saved model to /home/stephen/grokking/grok_1764706118/19010.pth
# Saved model to /home/stephen/grokking/grok_1764706118/19020.pth
# Saved model to /home/stephen/grokking/grok_1764706118/19030.pth
# Saved model to /home/stephen/grokking/grok_1764706118/19040.pth
# Saved model to /home/stephen/grokking/grok_1764706118/19050.pth
# Saved model to /home/stephen/grokking/grok_1764706118/19060.pth
# Saved model to /home/stephen/grokking/grok_1764706118/19070.pth
# Saved model to /home/stephen/grokking/grok_1764706118/19080.pth
# Saved model to /home/stephen/grokking/grok_1764706118/19090.pth
# 19100_-15.8864_-15.0653_pen=6.898e-04
# Saved model to /home/stephen/grokking/grok_1764706118/19100.pth
# Saved model to /home/stephen/grokking/grok_1764706118/19110.pth
# Saved model to /home/stephen/grokking/grok_1764706118/19120.pth
# Saved model to /home/stephen/grokking/grok_1764706118/19130.pth
# Saved model to /home/stephen/grokking/grok_1764706118/19140.pth
# Saved model to /home/stephen/grokking/grok_1764706118/19150.pth
# Saved model to /home/stephen/grokking/grok_1764706118/19160.pth
# Saved model to /home/stephen/grokking/grok_1764706118/19170.pth
# Saved model to /home/stephen/grokking/grok_1764706118/19180.pth
# Saved model to /home/stephen/grokking/grok_1764706118/19190.pth
# 19200_-15.8873_-15.0622_pen=6.897e-04
# Saved model to /home/stephen/grokking/grok_1764706118/19200.pth
# Saved model to /home/stephen/grokking/grok_1764706118/19210.pth
# Saved model to /home/stephen/grokking/grok_1764706118/19220.pth
# Saved model to /home/stephen/grokking/grok_1764706118/19230.pth
# Saved model to /home/stephen/grokking/grok_1764706118/19240.pth
# Saved model to /home/stephen/grokking/grok_1764706118/19250.pth
# Saved model to /home/stephen/grokking/grok_1764706118/19260.pth
# Saved model to /home/stephen/grokking/grok_1764706118/19270.pth
# Saved model to /home/stephen/grokking/grok_1764706118/19280.pth
# Saved model to /home/stephen/grokking/grok_1764706118/19290.pth
# 19300_-15.8878_-15.0558_pen=6.896e-04
# Saved model to /home/stephen/grokking/grok_1764706118/19300.pth
# Saved model to /home/stephen/grokking/grok_1764706118/19310.pth
# Saved model to /home/stephen/grokking/grok_1764706118/19320.pth
# Saved model to /home/stephen/grokking/grok_1764706118/19330.pth
# Saved model to /home/stephen/grokking/grok_1764706118/19340.pth
# Saved model to /home/stephen/grokking/grok_1764706118/19350.pth
# Saved model to /home/stephen/grokking/grok_1764706118/19360.pth
# Saved model to /home/stephen/grokking/grok_1764706118/19370.pth
# Saved model to /home/stephen/grokking/grok_1764706118/19380.pth
# Saved model to /home/stephen/grokking/grok_1764706118/19390.pth
# 19400_-15.8859_-15.0441_pen=6.894e-04
# Saved model to /home/stephen/grokking/grok_1764706118/19400.pth
# Saved model to /home/stephen/grokking/grok_1764706118/19410.pth
# Saved model to /home/stephen/grokking/grok_1764706118/19420.pth
# Saved model to /home/stephen/grokking/grok_1764706118/19430.pth
# Saved model to /home/stephen/grokking/grok_1764706118/19440.pth
# Saved model to /home/stephen/grokking/grok_1764706118/19450.pth
# Saved model to /home/stephen/grokking/grok_1764706118/19460.pth
# Saved model to /home/stephen/grokking/grok_1764706118/19470.pth
# Saved model to /home/stephen/grokking/grok_1764706118/19480.pth
# Saved model to /home/stephen/grokking/grok_1764706118/19490.pth
# 19500_-15.8871_-15.0459_pen=6.892e-04
# Saved model to /home/stephen/grokking/grok_1764706118/19500.pth
# Saved model to /home/stephen/grokking/grok_1764706118/19510.pth
# Saved model to /home/stephen/grokking/grok_1764706118/19520.pth
# Saved model to /home/stephen/grokking/grok_1764706118/19530.pth
# Saved model to /home/stephen/grokking/grok_1764706118/19540.pth
# Saved model to /home/stephen/grokking/grok_1764706118/19550.pth
# Saved model to /home/stephen/grokking/grok_1764706118/19560.pth
# Saved model to /home/stephen/grokking/grok_1764706118/19570.pth
# Saved model to /home/stephen/grokking/grok_1764706118/19580.pth
# Saved model to /home/stephen/grokking/grok_1764706118/19590.pth
# 19600_-15.8878_-15.0419_pen=6.891e-04
# Saved model to /home/stephen/grokking/grok_1764706118/19600.pth
# Saved model to /home/stephen/grokking/grok_1764706118/19610.pth
# Saved model to /home/stephen/grokking/grok_1764706118/19620.pth
# Saved model to /home/stephen/grokking/grok_1764706118/19630.pth
# Saved model to /home/stephen/grokking/grok_1764706118/19640.pth
# Saved model to /home/stephen/grokking/grok_1764706118/19650.pth
# Saved model to /home/stephen/grokking/grok_1764706118/19660.pth
# Saved model to /home/stephen/grokking/grok_1764706118/19670.pth
# Saved model to /home/stephen/grokking/grok_1764706118/19680.pth
# Saved model to /home/stephen/grokking/grok_1764706118/19690.pth
# 19700_-15.8884_-15.0391_pen=6.888e-04
# Saved model to /home/stephen/grokking/grok_1764706118/19700.pth
# Saved model to /home/stephen/grokking/grok_1764706118/19710.pth
# Saved model to /home/stephen/grokking/grok_1764706118/19720.pth
# Saved model to /home/stephen/grokking/grok_1764706118/19730.pth
# Saved model to /home/stephen/grokking/grok_1764706118/19740.pth
# Saved model to /home/stephen/grokking/grok_1764706118/19750.pth
# Saved model to /home/stephen/grokking/grok_1764706118/19760.pth
# Saved model to /home/stephen/grokking/grok_1764706118/19770.pth
# Saved model to /home/stephen/grokking/grok_1764706118/19780.pth
# Saved model to /home/stephen/grokking/grok_1764706118/19790.pth
# 19800_-15.8889_-15.0417_pen=6.886e-04
# Saved model to /home/stephen/grokking/grok_1764706118/19800.pth
# Saved model to /home/stephen/grokking/grok_1764706118/19810.pth
# Saved model to /home/stephen/grokking/grok_1764706118/19820.pth
# Saved model to /home/stephen/grokking/grok_1764706118/19830.pth
# Saved model to /home/stephen/grokking/grok_1764706118/19840.pth
# Saved model to /home/stephen/grokking/grok_1764706118/19850.pth
# Saved model to /home/stephen/grokking/grok_1764706118/19860.pth
# Saved model to /home/stephen/grokking/grok_1764706118/19870.pth
# Saved model to /home/stephen/grokking/grok_1764706118/19880.pth
# Saved model to /home/stephen/grokking/grok_1764706118/19890.pth
# 19900_-15.8901_-15.0374_pen=6.886e-04
# Saved model to /home/stephen/grokking/grok_1764706118/19900.pth
# Saved model to /home/stephen/grokking/grok_1764706118/19910.pth
# Saved model to /home/stephen/grokking/grok_1764706118/19920.pth
# Saved model to /home/stephen/grokking/grok_1764706118/19930.pth
# Saved model to /home/stephen/grokking/grok_1764706118/19940.pth
# Saved model to /home/stephen/grokking/grok_1764706118/19950.pth
# Saved model to /home/stephen/grokking/grok_1764706118/19960.pth
# Saved model to /home/stephen/grokking/grok_1764706118/19970.pth
# Saved model to /home/stephen/grokking/grok_1764706118/19980.pth
# Saved model to /home/stephen/grokking/grok_1764706118/19990.pth
# Saved model to /home/stephen/grokking/grok_1764706118/final.pth

# %% [markdown]
# ## Viz Results

# %%
CHILL_BROWN='#948979'
YELLOW='#ffd35a'
YELLOW_FADE='#7f6a2d'
BLUE='#65c8d0'
GREEN='#6e9671' 
CHILL_GREEN='#6c946f'
CHILL_BLUE='#3d5c6f'
FRESH_TAN='#dfd0b9'
CYAN='#00FFFF'

# %%
plt.plot(train_accs)
plt.plot(test_accs)

# %%
plt.clf()        
fig=plt.figure(0,(14,6), facecolor='k') 
ax=fig.add_subplot(111, facecolor='k')

plt.plot(train_accs[:500], c=BLUE, linewidth=2.5, alpha=0.95) #'#dfd0b9')
plt.plot(test_accs[:500], c=YELLOW, linewidth=2.5, alpha=0.95) #'#dfd0b9')
plt.tick_params(axis='x', colors='#948979', labelsize=16)  # Add labelsize here
plt.tick_params(axis='y', colors='#948979', labelsize=16)  # Add labelsize here

plt.gca().spines['top'].set_color('#948979')
plt.gca().spines['bottom'].set_color('#948979')
plt.gca().spines['left'].set_color('#948979')
plt.gca().spines['right'].set_color('#948979')
plt.subplots_adjust(bottom=0.2)  # Add fixed bottom margin
# plt.xlim([-10, len(to_plot)+10])
plt.ylim([0,1.05]) #Bad idea to fix or is it fine?
plt.grid(True, color='#948979', alpha=0.3)

# %%
plt.clf()        
fig=plt.figure(0,(14,6), facecolor='k') 
ax=fig.add_subplot(111, facecolor='k')

plt.plot(train_accs, c=BLUE, linewidth=2.5, alpha=0.95) #'#dfd0b9')
plt.plot(test_accs, c=YELLOW, linewidth=2.5, alpha=0.95) #'#dfd0b9')
plt.tick_params(axis='x', colors='#948979', labelsize=16)  # Add labelsize here
plt.tick_params(axis='y', colors='#948979', labelsize=16)  # Add labelsize here

plt.gca().spines['top'].set_color('#948979')
plt.gca().spines['bottom'].set_color('#948979')
plt.gca().spines['left'].set_color('#948979')
plt.gca().spines['right'].set_color('#948979')
plt.subplots_adjust(bottom=0.2)  # Add fixed bottom margin
# plt.xlim([-10, len(to_plot)+10])
plt.ylim([0,1.05]) #Bad idea to fix or is it fine?
plt.grid(True, color='#948979', alpha=0.3)

# %%
from tqdm import tqdm

# %%
all_data = torch.tensor([(i, j, p) for i in range(p) for j in range(p)]).to('cuda')
labels = torch.tensor([fn(i, j) for i, j, _ in all_data]).to('cuda')
cache = {}
model.remove_all_hooks()
model.cache_all(cache)
# Final position only
original_logits = model(all_data)[:, -1]
# Remove equals sign from output logits
original_logits = original_logits[:, :-1]
original_loss = cross_entropy_high_precision(original_logits, labels)
print(f"Original loss: {original_loss.item()}")

#Ok let's try pre -> the og. 
mr = einops.rearrange(cache['blocks.0.mlp.hook_pre'], "(x y) ... -> x y ...", x=p).detach().cpu().numpy() 

# np.save(str(root/run_name)+'/mlp_hook_pre', mr)
# Out:
# Original loss: 2.5334372737374274e-07

# %%
# ---- Helper for classifying term type ----
def classify_term_type(kx, ky, is_dc):
    if is_dc:
        return "dc"
    if kx != 0 and ky == 0:
        return "row"
    if kx == 0 and ky != 0:
        return "col"
    if kx == 0 and ky == 0:
        return "dc"
    return "cross"  # kx != 0 and ky != 0


# ---- Loop over neurons and build DataFrame ----
all_rows = []

for neuron_idx in tqdm(range(512)):
    # 113 x 113 slice for this neuron
    m_slice = mr[:, :, 2, neuron_idx]

    components, Nx, Ny = compute_frequency_components(m_slice)
    terms = components_to_terms(components, Nx, Ny, num_freqs=4, include_dc=True)

    # Max amplitude (non-DC) for this neuron, for "strong" comparison later
    non_dc_terms = [t for t in terms if not t.get("is_dc", False)]
    max_amp = max((t["amplitude"] for t in non_dc_terms), default=0.0)

    for rank, t in enumerate(terms):
        is_dc = t.get("is_dc", False)
        kx = t["kx"]
        ky = t["ky"]
        amp = t["amplitude"]
        phase = t["phase"]

        term_type = classify_term_type(kx, ky, is_dc)

        all_rows.append({
            "neuron_idx": neuron_idx,
            "term_rank": rank,          # 0 = DC if include_dc=True
            "is_dc": is_dc,
            "term_type": term_type,     # "dc", "row", "col", "cross"
            "kx": kx,
            "ky": ky,
            "amplitude": amp,
            "phase": phase,
            "max_amp_neuron": max_amp,  # per neuron
        })

df = pd.DataFrame(all_rows)
df['relative_amplitude']=df['amplitude']/df['max_amp_neuron']
# Out:
# 100%|██████████████████████| 512/512 [00:20<00:00, 24.70it/s]

# %%
df['kx'].value_counts()
# Out:
# kx
# 0     1207
# 8      502
# 4      291
# 1      245
# 35     124
# 16     107
# 2       83
# 43       1
# Name: count, dtype: int64

# %%
dff=df[df['kx']==4]
dff=dff[dff['ky']==4]

# %%
dff.sort_values(by='relative_amplitude', ascending=False)[:15]
# Out:
# Empty DataFrame
# Columns: [neuron_idx, term_rank, is_dc, term_type, kx, ky, amplitude, phase, max_amp_neuron, relative_amplitude]
# Index: []

# %%
neuron_idx=6
FT = np.fft.fft2(mr[:,:,2,neuron_idx])

components, Nx, Ny = compute_frequency_components(mr[:,:,2,neuron_idx])
terms = components_to_terms(components, Nx, Ny, num_freqs=4, include_dc=True)
code_str = generate_python_reconstructor(terms, Nx, Ny,
                                         func_name="approx_M",
                                         decimals=3)
print(code_str)
# Out:
# def approx_M(i, j):
#     val = 0.177
#     val += 0.102 * np.cos(2*np.pi*((8*i)/113) + 0.64) * np.cos(2*np.pi*((8*j)/113) + 0.64)
#     val += 0.048 * np.cos(2*np.pi*((16*j)/113) + -2.483)
#     val += 0.048 * np.cos(2*np.pi*((16*i)/113) + -2.483)
#     val += 0.011 * np.cos(2*np.pi*((1*i)/113) + -1.673) * np.cos(2*np.pi*((1*j)/113) + -1.673)
#     return val

# %%
def approx_M(i, j):
    val = 0.699
    val += 0.272 * np.cos(2*np.pi*((5*i)/113) + 0.048) * np.cos(2*np.pi*((5*j)/113) + 0.048)
    val += 0.178 * np.cos(2*np.pi*((5*i)/113) + 0.0) * np.cos(2*np.pi*((108*j)/113) + 0.0)
    val += 0.128 * np.cos(2*np.pi*((10*i)/113) + -3.075)
    val += 0.128 * np.cos(2*np.pi*((10*j)/113) + -3.075)
    return val

# %%
m_approx=np.zeros((p,p))
for i in range(p):
    for j in range(p):
        m_approx[i,j]=approx_M(i,j)

fig=plt.figure(0, (12, 6))
fig.add_subplot(1,3,1); plt.imshow(mr[:,:,2,neuron_idx]); plt.axis('off')
fig.add_subplot(1,3,2); plt.imshow(np.abs(FT));  plt.axis('off')
fig.add_subplot(1,3,3); plt.imshow(m_approx); plt.axis('off');
