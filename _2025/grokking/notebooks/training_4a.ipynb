# %% [markdown]
# ## Training 4a

# %%
seed=1
frac_train=0.25 
weight_decay = 1.0 #@param
freq_penalty_weight = 1e-3

# %%
# Import stuff
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import numpy as np
import einops
import tqdm.notebook as tqdm

import random
import time

# from google.colab import drive
from pathlib import Path
import pickle
import os

import matplotlib.pyplot as plt
# %matplotlib inline
import plotly.express as px
import plotly.io as pio
pio.renderers.default = "colab"
import plotly.graph_objects as go

from torch.utils.data import DataLoader

from functools import *
import pandas as pd
import gc

# import comet_ml
import itertools

# %% [markdown]
# ## Support Functions

# %%
# A helper class to get access to intermediate activations (inspired by Garcon)
# It's a dummy module that is the identity function by default
# I can wrap any intermediate activation in a HookPoint and get a convenient 
# way to add PyTorch hooks
class HookPoint(nn.Module):
    def __init__(self):
        super().__init__()
        self.fwd_hooks = []
        self.bwd_hooks = []
    
    def give_name(self, name):
        # Called by the model at initialisation
        self.name = name
    
    def add_hook(self, hook, dir='fwd'):
        # Hook format is fn(activation, hook_name)
        # Change it into PyTorch hook format (this includes input and output, 
        # which are the same for a HookPoint)
        def full_hook(module, module_input, module_output):
            return hook(module_output, name=self.name)
        if dir=='fwd':
            handle = self.register_forward_hook(full_hook)
            self.fwd_hooks.append(handle)
        elif dir=='bwd':
            handle = self.register_backward_hook(full_hook)
            self.bwd_hooks.append(handle)
        else:
            raise ValueError(f"Invalid direction {dir}")
    
    def remove_hooks(self, dir='fwd'):
        if (dir=='fwd') or (dir=='both'):
            for hook in self.fwd_hooks:
                hook.remove()
            self.fwd_hooks = []
        if (dir=='bwd') or (dir=='both'):
            for hook in self.bwd_hooks:
                hook.remove()
            self.bwd_hooks = []
        if dir not in ['fwd', 'bwd', 'both']:
            raise ValueError(f"Invalid direction {dir}")
    
    def forward(self, x):
        return x

# %%
# Define network architecture
# I defined my own transformer from scratch so I'd fully understand each component 
# - I expect this wasn't necessary or particularly important, and a bunch of this 
# replicates existing PyTorch functionality

# Embed & Unembed
class Embed(nn.Module):
    def __init__(self, d_vocab, d_model):
        super().__init__()
        self.W_E = nn.Parameter(torch.randn(d_model, d_vocab)/np.sqrt(d_model))
    
    def forward(self, x):
        return torch.einsum('dbp -> bpd', self.W_E[:, x])

class Unembed(nn.Module):
    def __init__(self, d_vocab, d_model):
        super().__init__()
        self.W_U = nn.Parameter(torch.randn(d_model, d_vocab)/np.sqrt(d_vocab))
    
    def forward(self, x):
        return (x @ self.W_U)

# Positional Embeddings
class PosEmbed(nn.Module):
    def __init__(self, max_ctx, d_model):
        super().__init__()
        self.W_pos = nn.Parameter(torch.randn(max_ctx, d_model)/np.sqrt(d_model))
    
    def forward(self, x):
        return x+self.W_pos[:x.shape[-2]]

# LayerNorm
class LayerNorm(nn.Module):
    def __init__(self, d_model, epsilon = 1e-4, model=[None]):
        super().__init__()
        self.model = model
        self.w_ln = nn.Parameter(torch.ones(d_model))
        self.b_ln = nn.Parameter(torch.zeros(d_model))
        self.epsilon = epsilon
    
    def forward(self, x):
        if self.model[0].use_ln:
            x = x - x.mean(axis=-1)[..., None]
            x = x / (x.std(axis=-1)[..., None] + self.epsilon)
            x = x * self.w_ln
            x = x + self.b_ln
            return x
        else:
            return x

# Attention
class Attention(nn.Module):
    def __init__(self, d_model, num_heads, d_head, n_ctx, model):
        super().__init__()
        self.model = model
        self.W_K = nn.Parameter(torch.randn(num_heads, d_head, d_model)/np.sqrt(d_model))
        self.W_Q = nn.Parameter(torch.randn(num_heads, d_head, d_model)/np.sqrt(d_model))
        self.W_V = nn.Parameter(torch.randn(num_heads, d_head, d_model)/np.sqrt(d_model))
        self.W_O = nn.Parameter(torch.randn(d_model, d_head * num_heads)/np.sqrt(d_model))
        self.register_buffer('mask', torch.tril(torch.ones((n_ctx, n_ctx))))
        self.d_head = d_head
        self.hook_k = HookPoint()
        self.hook_q = HookPoint()
        self.hook_v = HookPoint()
        self.hook_z = HookPoint()
        self.hook_attn = HookPoint()
        self.hook_attn_pre = HookPoint()

    def forward(self, x):
        k = self.hook_k(torch.einsum('ihd,bpd->biph', self.W_K, x))
        q = self.hook_q(torch.einsum('ihd,bpd->biph', self.W_Q, x))
        v = self.hook_v(torch.einsum('ihd,bpd->biph', self.W_V, x))
        attn_scores_pre = torch.einsum('biph,biqh->biqp', k, q)
        attn_scores_masked = torch.tril(attn_scores_pre) - 1e10 * (1 - self.mask[:x.shape[-2], :x.shape[-2]])
        attn_matrix = self.hook_attn(F.softmax(self.hook_attn_pre(attn_scores_masked/np.sqrt(self.d_head)), dim=-1))
        z = self.hook_z(torch.einsum('biph,biqp->biqh', v, attn_matrix))
        z_flat = einops.rearrange(z, 'b i q h -> b q (i h)')
        out = torch.einsum('df,bqf->bqd', self.W_O, z_flat)
        return out

# MLP Layers
class MLP(nn.Module):
    def __init__(self, d_model, d_mlp, act_type, model):
        super().__init__()
        self.model = model
        self.W_in = nn.Parameter(torch.randn(d_mlp, d_model)/np.sqrt(d_model))
        self.b_in = nn.Parameter(torch.zeros(d_mlp))
        self.W_out = nn.Parameter(torch.randn(d_model, d_mlp)/np.sqrt(d_model))
        self.b_out = nn.Parameter(torch.zeros(d_model))
        self.act_type = act_type
        # self.ln = LayerNorm(d_mlp, model=self.model)
        self.hook_pre = HookPoint()
        self.hook_post = HookPoint()
        assert act_type in ['ReLU', 'GeLU']
        
    def forward(self, x):
        x = self.hook_pre(torch.einsum('md,bpd->bpm', self.W_in, x) + self.b_in)
        if self.act_type=='ReLU':
            x = F.relu(x)
        elif self.act_type=='GeLU':
            x = F.gelu(x)
        x = self.hook_post(x)
        x = torch.einsum('dm,bpm->bpd', self.W_out, x) + self.b_out
        return x

# Transformer Block
class TransformerBlock(nn.Module):
    def __init__(self, d_model, d_mlp, d_head, num_heads, n_ctx, act_type, model):
        super().__init__()
        self.model = model
        # self.ln1 = LayerNorm(d_model, model=self.model)
        self.attn = Attention(d_model, num_heads, d_head, n_ctx, model=self.model)
        # self.ln2 = LayerNorm(d_model, model=self.model)
        self.mlp = MLP(d_model, d_mlp, act_type, model=self.model)
        self.hook_attn_out = HookPoint()
        self.hook_mlp_out = HookPoint()
        self.hook_resid_pre = HookPoint()
        self.hook_resid_mid = HookPoint()
        self.hook_resid_post = HookPoint()
    
    def forward(self, x):
        x = self.hook_resid_mid(x + self.hook_attn_out(self.attn((self.hook_resid_pre(x)))))
        x = self.hook_resid_post(x + self.hook_mlp_out(self.mlp((x))))
        return x

# Full transformer
class Transformer(nn.Module):
    def __init__(self, num_layers, d_vocab, d_model, d_mlp, d_head, num_heads, n_ctx, act_type, use_cache=False, use_ln=True):
        super().__init__()
        self.cache = {}
        self.use_cache = use_cache

        self.embed = Embed(d_vocab, d_model)
        self.pos_embed = PosEmbed(n_ctx, d_model)
        self.blocks = nn.ModuleList([TransformerBlock(d_model, d_mlp, d_head, num_heads, n_ctx, act_type, model=[self]) for i in range(num_layers)])
        # self.ln = LayerNorm(d_model, model=[self])
        self.unembed = Unembed(d_vocab, d_model)
        self.use_ln = use_ln

        for name, module in self.named_modules():
            if type(module)==HookPoint:
                module.give_name(name)
    
    def forward(self, x):
        x = self.embed(x)
        x = self.pos_embed(x)
        for block in self.blocks:
            x = block(x)
        # x = self.ln(x)
        x = self.unembed(x)
        return x

    def set_use_cache(self, use_cache):
        self.use_cache = use_cache
    
    def hook_points(self):
        return [module for name, module in self.named_modules() if 'hook' in name]

    def remove_all_hooks(self):
        for hp in self.hook_points():
            hp.remove_hooks('fwd')
            hp.remove_hooks('bwd')
    
    def cache_all(self, cache, incl_bwd=False):
        # Caches all activations wrapped in a HookPoint
        def save_hook(tensor, name):
            cache[name] = tensor.detach()
        def save_hook_back(tensor, name):
            cache[name+'_grad'] = tensor[0].detach()
        for hp in self.hook_points():
            hp.add_hook(save_hook, 'fwd')
            if incl_bwd:
                hp.add_hook(save_hook_back, 'bwd')

# %%
# Helper functions
def cuda_memory():
    print(torch.cuda.memory_allocated()/1e9)

def cross_entropy_high_precision(logits, labels):
    # Shapes: batch x vocab, batch
    # Cast logits to float64 because log_softmax has a float32 underflow on overly 
    # confident data and can only return multiples of 1.2e-7 (the smallest float x
    # such that 1+x is different from 1 in float32). This leads to loss spikes 
    # and dodgy gradients
    logprobs = F.log_softmax(logits.to(torch.float64), dim=-1)
    prediction_logprobs = torch.gather(logprobs, index=labels[:, None], dim=-1)
    loss = -torch.mean(prediction_logprobs)
    return loss

def full_loss(model, data):
    # Take the final position only
    logits = model(data)[:, -1]
    labels = torch.tensor([fn(i, j) for i, j, _ in data]).to('cuda')
    return cross_entropy_high_precision(logits, labels)

def test_logits(logits, bias_correction=False, original_logits=None, mode='all'):
    # Calculates cross entropy loss of logits representing a batch of all p^2 
    # possible inputs
    # Batch dimension is assumed to be first
    if logits.shape[1]==p*p:
        logits = logits.T
    if logits.shape==torch.Size([p*p, p+1]):
        logits = logits[:, :-1]
    logits = logits.reshape(p*p, p)
    if bias_correction:
        # Applies bias correction - we correct for any missing bias terms, 
        # independent of the input, by centering the new logits along the batch 
        # dimension, and then adding the average original logits across all inputs
        logits = einops.reduce(original_logits - logits, 'batch ... -> ...', 'mean') + logits
    if mode=='train':
        return cross_entropy_high_precision(logits[is_train], labels[is_train])
    elif mode=='test':
        return cross_entropy_high_precision(logits[is_test], labels[is_test])
    elif mode=='all':
        return cross_entropy_high_precision(logits, labels)

def unflatten_first(tensor):
    if tensor.shape[0]==p*p:
        return einops.rearrange(tensor, '(x y) ... -> x y ...', x=p, y=p)
    else: 
        return tensor
def cos(x, y):
    return (x.dot(y))/x.norm()/y.norm()
def mod_div(a, b):
    return (a*pow(b, p-2, p))%p
def normalize(tensor, axis=0):
    return tensor/(tensor).pow(2).sum(keepdim=True, axis=axis).sqrt()
def extract_freq_2d(tensor, freq):
    # Takes in a pxpx... or batch x ... tensor, returns a 3x3x... tensor of the 
    # Linear and quadratic terms of frequency freq
    tensor = unflatten_first(tensor)
    # Extracts the linear and quadratic terms corresponding to frequency freq
    index_1d = [0, 2*freq-1, 2*freq]
    # Some dumb manipulation to use fancy array indexing rules
    # Gets the rows and columns in index_1d
    return tensor[[[i]*3 for i in index_1d], [index_1d]*3]
def get_cov(tensor, norm=True):
    # Calculate covariance matrix
    if norm:
        tensor = normalize(tensor, axis=1)
    return tensor @ tensor.T
def is_close(a, b):
    return ((a-b).pow(2).sum()/(a.pow(2).sum().sqrt())/(b.pow(2).sum().sqrt())).item()

# %%
def compute_frequency_components(m):
    """
    Compute canonical frequency components of a real 2D signal m using fft2.

    Returns:
        components: list of dicts with keys:
            - 'kx': frequency index in x (rows)
            - 'ky': frequency index in y (cols)
            - 'coeff': complex FFT coefficient at (kx, ky)
        Nx, Ny: dimensions of the input
    """
    m = np.asarray(m)
    Nx, Ny = m.shape
    F = np.fft.fft2(m)

    components = []
    seen = set()

    for kx in range(Nx):
        for ky in range(Ny):
            # Conjugate partner indices for real-valued input
            kx_conj = (-kx) % Nx
            ky_conj = (-ky) % Ny

            pair = tuple(sorted([(kx, ky), (kx_conj, ky_conj)]))
            if pair in seen:
                continue
            seen.add(pair)

            # Always store the "smaller" one in lexicographic order
            kx_rep, ky_rep = pair[0]
            coeff = F[kx_rep, ky_rep]
            components.append({
                "kx": kx_rep,
                "ky": ky_rep,
                "coeff": coeff
            })

    return components, Nx, Ny


def components_to_terms(components, Nx, Ny, num_freqs, include_dc=True):
    """
    Convert FFT components into real cosine terms with amplitude & phase.

    Args:
        components: output from compute_frequency_components
        Nx, Ny: grid size
        num_freqs: number of *non-DC* frequencies to keep
        include_dc: whether to include the constant (DC) term

    Returns:
        terms: list of dicts with keys:
            - 'kx', 'ky'
            - 'amplitude'  (real, >= 0)
            - 'phase'      (in radians)
            - 'is_dc'      (bool, True only for the constant term)
    """
    terms = []
    dc_term = None

    for c in components:
        kx = c["kx"]
        ky = c["ky"]
        coeff = c["coeff"]

        # DC component (constant offset)
        if kx == 0 and ky == 0:
            dc_value = coeff.real / (Nx * Ny)
            dc_term = {
                "kx": 0,
                "ky": 0,
                "amplitude": dc_value,  # directly the constant offset
                "phase": 0.0,
                "is_dc": True,
            }
        else:
            # For real signals, combine (k, l) and (-k, -l) into:
            #   2*|F|/(Nx*Ny) * cos(2π(kx i/Nx + ky j/Ny) + phase)
            amp = 2.0 * np.abs(coeff) / (Nx * Ny)
            phase = np.angle(coeff)
            terms.append({
                "kx": kx,
                "ky": ky,
                "amplitude": amp,
                "phase": phase,
                "is_dc": False,
            })

    # Sort non-DC terms by amplitude (largest first)
    terms.sort(key=lambda t: t["amplitude"], reverse=True)

    # Keep only the top num_freqs
    terms = terms[:num_freqs]

    # Optionally prepend DC term
    if include_dc and dc_term is not None:
        terms = [dc_term] + terms

    return terms

def generate_python_reconstructor(terms, Nx, Ny, func_name="recon_func", decimals=4):
    """
    Generate a Python function as a string that reconstructs the signal
    using explicit 1D and product-of-cosine terms from a sparse Fourier representation.

    Types of terms:
      - DC term (constant)
      - Row-only:   A * cos(2π * (kx*i/Nx) + φ)
      - Col-only:   B * cos(2π * (ky*j/Ny) + φ)
      - Product:    C * cos(2π * (kx*i/Nx) + φ) * cos(2π * (ky*j/Ny) + φ)

    You must have `import numpy as np` in the scope where you paste/run this.
    """
    lines = []
    lines.append(f"def {func_name}(i, j):")

    if not terms:
        lines.append("    return 0.0")
        return "\n".join(lines)

    # Separate DC from others
    dc_terms = [t for t in terms if t.get("is_dc", False)]
    non_dc_terms = [t for t in terms if not t.get("is_dc", False)]

    if dc_terms:
        dc_val = round(dc_terms[0]["amplitude"], decimals)
        lines.append(f"    val = {dc_val}")
    else:
        lines.append("    val = 0.0")

    for t in non_dc_terms:
        kx, ky = t["kx"], t["ky"]
        A = round(t["amplitude"], decimals)
        phi = round(t["phase"], decimals)

        if A == 0:
            continue

        if kx != 0 and ky == 0:
            # Row-only cosine
            line = (
                f"    val += {A} * np.cos(2*np.pi*(({kx}*i)/{Nx}) + {phi})"
            )
        elif kx == 0 and ky != 0:
            # Column-only cosine
            line = (
                f"    val += {A} * np.cos(2*np.pi*(({ky}*j)/{Ny}) + {phi})"
            )
        else:
            # Product-of-cosines term (your desired "third" type)
            line = (
                f"    val += {A} * np.cos(2*np.pi*(({kx}*i)/{Nx}) + {phi})"
                f" * np.cos(2*np.pi*(({ky}*j)/{Ny}) + {phi})"
            )

        lines.append(line)

    lines.append("    return val")

    return "\n".join(lines)

# %%
def set_seed(seed):
        torch.manual_seed(seed)
        torch.cuda.manual_seed_all(seed) # For all CUDA devices
        np.random.seed(seed)
        random.seed(seed)
        torch.backends.cudnn.deterministic = True
        torch.backends.cudnn.benchmark = False # Set to False for determinism

# %%
def embedding_frequency_penalty(model: Transformer) -> torch.Tensor:
    """
    Encourage neighboring tokens in the embedding space to be similar.
    This is a graph-Laplacian-style smoothness penalty on W_E, which
    corresponds to penalizing high-frequency Fourier modes on Z_p.

    W_E has shape [d_model, d_vocab].
    We smooth along the vocab dimension (the modular arithmetic axis).
    """
    E = model.embed.W_E  # [d_model, d_vocab]

    # Differences between consecutive tokens (0-1, 1-2, ..., (V-2)-(V-1))
    diff = E[:, 1:] - E[:, :-1]  # [d_model, d_vocab-1]

    # Wrap-around difference to respect modular structure: token V-1 vs 0
    wrap = E[:, :1] - E[:, -1:]  # [d_model, 1]

    # Mean squared differences (Laplacian smoothness)
    penalty = (diff.pow(2).mean() + wrap.pow(2).mean())
    return penalty

# %% [markdown]
# ## Hyperparameters

# %%
root = Path('/home/stephen/grokking')


p=113
# seed=2 ##Set at top

lr=1e-3 #@param
p=113 #@param
d_model = 128 #@param
fn_name = 'add' #@param ['add', 'subtract', 'x2xyy2','rand']
num_epochs = 20000 #@param
save_models = True #@param
save_every = 10 # Maybe crank this down
# Stop training when test loss is <stopping_thresh
stopping_thresh = -1 #@param

num_layers = 1
batch_style = 'full'
d_vocab = p+1
n_ctx = 3
d_mlp = 4*d_model
num_heads = 4
assert d_model % num_heads == 0
d_head = d_model//num_heads
act_type = 'ReLU' #@param ['ReLU', 'GeLU']
# batch_size = 512
use_ln = False
random_answers = np.random.randint(low=0, high=p, size=(p, p))
fns_dict = {'add': lambda x,y:(x+y)%p, 'subtract': lambda x,y:(x-y)%p, 'x2xyy2':lambda x,y:(x**2+x*y+y**2)%p, 'rand':lambda x,y:random_answers[x][y]}
fn = fns_dict[fn_name]

# %%
frac_train, seed
# Out:
# (0.25, 1)

# %%
def gen_train_test(frac_train, num, seed=0):
    # Generate train and test split
    pairs = [(i, j, num) for i in range(num) for j in range(num)]
    random.seed(seed)
    random.shuffle(pairs)
    div = int(frac_train*len(pairs))
    return pairs[:div], pairs[div:]

train, test = gen_train_test(frac_train, p, seed)
print(len(train), len(test))
# Out:
# 3192 9577

# %%
# Creates an array of Boolean indices according to whether each data point is in 
# train or test
# Used to index into the big batch of all possible data
is_train = []
is_test = []
for x in range(p):
    for y in range(p):
        if (x, y, 113) in train:
            is_train.append(True)
            is_test.append(False)
        else:
            is_train.append(False)
            is_test.append(True)
is_train = np.array(is_train)
is_test = np.array(is_test)

# %% [markdown]
# ## Training Loop

# %%
set_seed(seed)
model = Transformer(num_layers=num_layers, d_vocab=d_vocab, d_model=d_model, d_mlp=d_mlp, d_head=d_head, num_heads=num_heads, n_ctx=n_ctx, act_type=act_type, use_cache=False, use_ln=use_ln)
model.to('cuda')
optimizer = optim.AdamW(model.parameters(), lr=lr, weight_decay=weight_decay, betas=(0.9, 0.98))
scheduler = optim.lr_scheduler.LambdaLR(optimizer, lambda step: min(step/10, 1))
run_name = f"grok_{int(time.time())}"
print(f'Run name {run_name}')
if save_models:
    os.mkdir(root/run_name)
    save_dict = {'model':model.state_dict(), 'train_data':train, 'test_data':test}
    torch.save(save_dict, root/run_name/'init.pth')
train_losses = []
test_losses = []
train_accs = []
test_accs = []
for epoch in range(num_epochs):

    # 1. Compute base cross-entropy losses (no regularization)
    train_ce_loss = full_loss(model, train)
    test_loss = full_loss(model, test)  # leave test as-is

    # 2. Compute smoothness / frequency penalty on embeddings
    freq_pen = embedding_frequency_penalty(model)

    # 3. Total train loss = CE + λ * penalty
    train_loss = train_ce_loss + freq_penalty_weight * freq_pen

    # 4. Track (usually you want to log CE only for grokking plots)
    train_losses.append(train_ce_loss.item())
    test_losses.append(test_loss.item())

    logits = model(train)[:, -1]
    labels = torch.tensor([fn(i, j) for i, j, _ in train]).to('cuda')
    train_acc=((logits.detach().cpu().argmax(1)==labels.detach().cpu()).sum()/len(labels)).item()
    train_accs.append(train_acc)
    
    logits = model(test)[:, -1]
    labels = torch.tensor([fn(i, j) for i, j, _ in test]).to('cuda')
    test_acc=((logits.detach().cpu().argmax(1)==labels.detach().cpu()).sum()/len(labels)).item()
    test_accs.append(test_acc)

    if epoch % 100 == 0:
        print(
            f"{epoch}_"
            f"{np.log(train_ce_loss.item()):.4f}_"
            f"{np.log(test_loss.item()):.4f}_"
            f"pen={freq_pen.item():.3e}"
        )

    # 5. Backprop / step
    train_loss.backward()
    optimizer.step()
    scheduler.step()
    optimizer.zero_grad()
    if test_loss.item() < stopping_thresh:
        break
    if (save_models) and (epoch%save_every == 0):
        if test_loss.item() < stopping_thresh:
            break
        save_dict = {
            'model': model.state_dict(),
            'optimizer': optimizer.state_dict(),
            'scheduler': scheduler.state_dict(),
            'train_loss': train_loss,
            'test_loss': test_loss,
            'epoch': epoch,
        }
        torch.save(save_dict, root/run_name/f"{epoch}.pth")
        print(f"Saved model to {root/run_name/f'{epoch}.pth'}")
if not save_models:
    os.mkdir(root/run_name)
save_dict = {
    'model': model.state_dict(),
    'optimizer': optimizer.state_dict(),
    'scheduler': scheduler.state_dict(),
    'train_loss': train_loss,
    'test_loss': test_loss,
    'train_losses': train_losses,
    'test_losses': test_losses,
    'train_accs': train_accs,
    'test_accs':test_accs,
    'epoch': epoch,
}
torch.save(save_dict, root/run_name/f"final.pth")
print(f"Saved model to {root/run_name/f'final.pth'}")

# save_models = False
# Out:
# Run name grok_1764706121
# 0_1.5634_1.5621_pen=3.078e-02
# Saved model to /home/stephen/grokking/grok_1764706121/0.pth
# Saved model to /home/stephen/grokking/grok_1764706121/10.pth
# Saved model to /home/stephen/grokking/grok_1764706121/20.pth
# Saved model to /home/stephen/grokking/grok_1764706121/30.pth
# Saved model to /home/stephen/grokking/grok_1764706121/40.pth
# Saved model to /home/stephen/grokking/grok_1764706121/50.pth
# Saved model to /home/stephen/grokking/grok_1764706121/60.pth
# Saved model to /home/stephen/grokking/grok_1764706121/70.pth
# Saved model to /home/stephen/grokking/grok_1764706121/80.pth
# Saved model to /home/stephen/grokking/grok_1764706121/90.pth
# 100_0.6769_2.1507_pen=5.487e-02
# Saved model to /home/stephen/grokking/grok_1764706121/100.pth
# Saved model to /home/stephen/grokking/grok_1764706121/110.pth
# Saved model to /home/stephen/grokking/grok_1764706121/120.pth
# Saved model to /home/stephen/grokking/grok_1764706121/130.pth
# Saved model to /home/stephen/grokking/grok_1764706121/140.pth
# Saved model to /home/stephen/grokking/grok_1764706121/150.pth
# Saved model to /home/stephen/grokking/grok_1764706121/160.pth
# Saved model to /home/stephen/grokking/grok_1764706121/170.pth
# Saved model to /home/stephen/grokking/grok_1764706121/180.pth
# Saved model to /home/stephen/grokking/grok_1764706121/190.pth
# 200_-3.9803_2.8980_pen=7.702e-02
# Saved model to /home/stephen/grokking/grok_1764706121/200.pth
# Saved model to /home/stephen/grokking/grok_1764706121/210.pth
# Saved model to /home/stephen/grokking/grok_1764706121/220.pth
# Saved model to /home/stephen/grokking/grok_1764706121/230.pth
# Saved model to /home/stephen/grokking/grok_1764706121/240.pth
# Saved model to /home/stephen/grokking/grok_1764706121/250.pth
# Saved model to /home/stephen/grokking/grok_1764706121/260.pth
# Saved model to /home/stephen/grokking/grok_1764706121/270.pth
# Saved model to /home/stephen/grokking/grok_1764706121/280.pth
# Saved model to /home/stephen/grokking/grok_1764706121/290.pth
# 300_-5.0419_2.9329_pen=7.668e-02
# Saved model to /home/stephen/grokking/grok_1764706121/300.pth
# Saved model to /home/stephen/grokking/grok_1764706121/310.pth
# Saved model to /home/stephen/grokking/grok_1764706121/320.pth
# Saved model to /home/stephen/grokking/grok_1764706121/330.pth
# Saved model to /home/stephen/grokking/grok_1764706121/340.pth
# Saved model to /home/stephen/grokking/grok_1764706121/350.pth
# Saved model to /home/stephen/grokking/grok_1764706121/360.pth
# Saved model to /home/stephen/grokking/grok_1764706121/370.pth
# Saved model to /home/stephen/grokking/grok_1764706121/380.pth
# Saved model to /home/stephen/grokking/grok_1764706121/390.pth
# 400_-6.1700_2.9905_pen=7.616e-02
# Saved model to /home/stephen/grokking/grok_1764706121/400.pth
# Saved model to /home/stephen/grokking/grok_1764706121/410.pth
# Saved model to /home/stephen/grokking/grok_1764706121/420.pth
# Saved model to /home/stephen/grokking/grok_1764706121/430.pth
# Saved model to /home/stephen/grokking/grok_1764706121/440.pth
# Saved model to /home/stephen/grokking/grok_1764706121/450.pth
# Saved model to /home/stephen/grokking/grok_1764706121/460.pth
# Saved model to /home/stephen/grokking/grok_1764706121/470.pth
# Saved model to /home/stephen/grokking/grok_1764706121/480.pth
# Saved model to /home/stephen/grokking/grok_1764706121/490.pth
# 500_-7.2706_3.0508_pen=7.397e-02
# Saved model to /home/stephen/grokking/grok_1764706121/500.pth
# Saved model to /home/stephen/grokking/grok_1764706121/510.pth
# Saved model to /home/stephen/grokking/grok_1764706121/520.pth
# Saved model to /home/stephen/grokking/grok_1764706121/530.pth
# Saved model to /home/stephen/grokking/grok_1764706121/540.pth
# Saved model to /home/stephen/grokking/grok_1764706121/550.pth
# Saved model to /home/stephen/grokking/grok_1764706121/560.pth
# Saved model to /home/stephen/grokking/grok_1764706121/570.pth
# Saved model to /home/stephen/grokking/grok_1764706121/580.pth
# Saved model to /home/stephen/grokking/grok_1764706121/590.pth
# 600_-8.3507_3.1115_pen=6.842e-02
# Saved model to /home/stephen/grokking/grok_1764706121/600.pth
# Saved model to /home/stephen/grokking/grok_1764706121/610.pth
# Saved model to /home/stephen/grokking/grok_1764706121/620.pth
# Saved model to /home/stephen/grokking/grok_1764706121/630.pth
# Saved model to /home/stephen/grokking/grok_1764706121/640.pth
# Saved model to /home/stephen/grokking/grok_1764706121/650.pth
# Saved model to /home/stephen/grokking/grok_1764706121/660.pth
# Saved model to /home/stephen/grokking/grok_1764706121/670.pth
# Saved model to /home/stephen/grokking/grok_1764706121/680.pth
# Saved model to /home/stephen/grokking/grok_1764706121/690.pth
# 700_-9.4096_3.1702_pen=5.884e-02
# Saved model to /home/stephen/grokking/grok_1764706121/700.pth
# Saved model to /home/stephen/grokking/grok_1764706121/710.pth
# Saved model to /home/stephen/grokking/grok_1764706121/720.pth
# Saved model to /home/stephen/grokking/grok_1764706121/730.pth
# Saved model to /home/stephen/grokking/grok_1764706121/740.pth
# Saved model to /home/stephen/grokking/grok_1764706121/750.pth
# Saved model to /home/stephen/grokking/grok_1764706121/760.pth
# Saved model to /home/stephen/grokking/grok_1764706121/770.pth
# Saved model to /home/stephen/grokking/grok_1764706121/780.pth
# Saved model to /home/stephen/grokking/grok_1764706121/790.pth
# 800_-10.4368_3.2263_pen=4.853e-02
# Saved model to /home/stephen/grokking/grok_1764706121/800.pth
# Saved model to /home/stephen/grokking/grok_1764706121/810.pth
# Saved model to /home/stephen/grokking/grok_1764706121/820.pth
# Saved model to /home/stephen/grokking/grok_1764706121/830.pth
# Saved model to /home/stephen/grokking/grok_1764706121/840.pth
# Saved model to /home/stephen/grokking/grok_1764706121/850.pth
# Saved model to /home/stephen/grokking/grok_1764706121/860.pth
# Saved model to /home/stephen/grokking/grok_1764706121/870.pth
# Saved model to /home/stephen/grokking/grok_1764706121/880.pth
# Saved model to /home/stephen/grokking/grok_1764706121/890.pth
# 900_-11.4055_3.2767_pen=4.101e-02
# Saved model to /home/stephen/grokking/grok_1764706121/900.pth
# Saved model to /home/stephen/grokking/grok_1764706121/910.pth
# Saved model to /home/stephen/grokking/grok_1764706121/920.pth
# Saved model to /home/stephen/grokking/grok_1764706121/930.pth
# Saved model to /home/stephen/grokking/grok_1764706121/940.pth
# Saved model to /home/stephen/grokking/grok_1764706121/950.pth
# Saved model to /home/stephen/grokking/grok_1764706121/960.pth
# Saved model to /home/stephen/grokking/grok_1764706121/970.pth
# Saved model to /home/stephen/grokking/grok_1764706121/980.pth
# Saved model to /home/stephen/grokking/grok_1764706121/990.pth
# 1000_-12.2408_3.3180_pen=3.288e-02
# Saved model to /home/stephen/grokking/grok_1764706121/1000.pth
# Saved model to /home/stephen/grokking/grok_1764706121/1010.pth
# Saved model to /home/stephen/grokking/grok_1764706121/1020.pth
# Saved model to /home/stephen/grokking/grok_1764706121/1030.pth
# Saved model to /home/stephen/grokking/grok_1764706121/1040.pth
# Saved model to /home/stephen/grokking/grok_1764706121/1050.pth
# Saved model to /home/stephen/grokking/grok_1764706121/1060.pth
# Saved model to /home/stephen/grokking/grok_1764706121/1070.pth
# Saved model to /home/stephen/grokking/grok_1764706121/1080.pth
# Saved model to /home/stephen/grokking/grok_1764706121/1090.pth
# 1100_-12.8950_3.3516_pen=2.228e-02
# Saved model to /home/stephen/grokking/grok_1764706121/1100.pth
# Saved model to /home/stephen/grokking/grok_1764706121/1110.pth
# Saved model to /home/stephen/grokking/grok_1764706121/1120.pth
# Saved model to /home/stephen/grokking/grok_1764706121/1130.pth
# Saved model to /home/stephen/grokking/grok_1764706121/1140.pth
# Saved model to /home/stephen/grokking/grok_1764706121/1150.pth
# Saved model to /home/stephen/grokking/grok_1764706121/1160.pth
# Saved model to /home/stephen/grokking/grok_1764706121/1170.pth
# Saved model to /home/stephen/grokking/grok_1764706121/1180.pth
# Saved model to /home/stephen/grokking/grok_1764706121/1190.pth
# 1200_-13.4123_3.3779_pen=1.350e-02
# Saved model to /home/stephen/grokking/grok_1764706121/1200.pth
# Saved model to /home/stephen/grokking/grok_1764706121/1210.pth
# Saved model to /home/stephen/grokking/grok_1764706121/1220.pth
# Saved model to /home/stephen/grokking/grok_1764706121/1230.pth
# Saved model to /home/stephen/grokking/grok_1764706121/1240.pth
# Saved model to /home/stephen/grokking/grok_1764706121/1250.pth
# Saved model to /home/stephen/grokking/grok_1764706121/1260.pth
# Saved model to /home/stephen/grokking/grok_1764706121/1270.pth
# Saved model to /home/stephen/grokking/grok_1764706121/1280.pth
# Saved model to /home/stephen/grokking/grok_1764706121/1290.pth
# 1300_-13.8163_3.3922_pen=8.572e-03
# Saved model to /home/stephen/grokking/grok_1764706121/1300.pth
# Saved model to /home/stephen/grokking/grok_1764706121/1310.pth
# Saved model to /home/stephen/grokking/grok_1764706121/1320.pth
# Saved model to /home/stephen/grokking/grok_1764706121/1330.pth
# Saved model to /home/stephen/grokking/grok_1764706121/1340.pth
# Saved model to /home/stephen/grokking/grok_1764706121/1350.pth
# Saved model to /home/stephen/grokking/grok_1764706121/1360.pth
# Saved model to /home/stephen/grokking/grok_1764706121/1370.pth
# Saved model to /home/stephen/grokking/grok_1764706121/1380.pth
# Saved model to /home/stephen/grokking/grok_1764706121/1390.pth
# 1400_-14.0924_3.3967_pen=6.259e-03
# Saved model to /home/stephen/grokking/grok_1764706121/1400.pth
# Saved model to /home/stephen/grokking/grok_1764706121/1410.pth
# Saved model to /home/stephen/grokking/grok_1764706121/1420.pth
# Saved model to /home/stephen/grokking/grok_1764706121/1430.pth
# Saved model to /home/stephen/grokking/grok_1764706121/1440.pth
# Saved model to /home/stephen/grokking/grok_1764706121/1450.pth
# Saved model to /home/stephen/grokking/grok_1764706121/1460.pth
# Saved model to /home/stephen/grokking/grok_1764706121/1470.pth
# Saved model to /home/stephen/grokking/grok_1764706121/1480.pth
# Saved model to /home/stephen/grokking/grok_1764706121/1490.pth
# 1500_-14.2510_3.3942_pen=5.191e-03
# Saved model to /home/stephen/grokking/grok_1764706121/1500.pth
# Saved model to /home/stephen/grokking/grok_1764706121/1510.pth
# Saved model to /home/stephen/grokking/grok_1764706121/1520.pth
# Saved model to /home/stephen/grokking/grok_1764706121/1530.pth
# Saved model to /home/stephen/grokking/grok_1764706121/1540.pth
# Saved model to /home/stephen/grokking/grok_1764706121/1550.pth
# Saved model to /home/stephen/grokking/grok_1764706121/1560.pth
# Saved model to /home/stephen/grokking/grok_1764706121/1570.pth
# Saved model to /home/stephen/grokking/grok_1764706121/1580.pth
# Saved model to /home/stephen/grokking/grok_1764706121/1590.pth
# 1600_-14.3350_3.3876_pen=4.671e-03
# Saved model to /home/stephen/grokking/grok_1764706121/1600.pth
# Saved model to /home/stephen/grokking/grok_1764706121/1610.pth
# Saved model to /home/stephen/grokking/grok_1764706121/1620.pth
# Saved model to /home/stephen/grokking/grok_1764706121/1630.pth
# Saved model to /home/stephen/grokking/grok_1764706121/1640.pth
# Saved model to /home/stephen/grokking/grok_1764706121/1650.pth
# Saved model to /home/stephen/grokking/grok_1764706121/1660.pth
# Saved model to /home/stephen/grokking/grok_1764706121/1670.pth
# Saved model to /home/stephen/grokking/grok_1764706121/1680.pth
# Saved model to /home/stephen/grokking/grok_1764706121/1690.pth
# 1700_-14.3835_3.3791_pen=4.398e-03
# Saved model to /home/stephen/grokking/grok_1764706121/1700.pth
# Saved model to /home/stephen/grokking/grok_1764706121/1710.pth
# Saved model to /home/stephen/grokking/grok_1764706121/1720.pth
# Saved model to /home/stephen/grokking/grok_1764706121/1730.pth
# Saved model to /home/stephen/grokking/grok_1764706121/1740.pth
# Saved model to /home/stephen/grokking/grok_1764706121/1750.pth
# Saved model to /home/stephen/grokking/grok_1764706121/1760.pth
# Saved model to /home/stephen/grokking/grok_1764706121/1770.pth
# Saved model to /home/stephen/grokking/grok_1764706121/1780.pth
# Saved model to /home/stephen/grokking/grok_1764706121/1790.pth
# 1800_-14.4091_3.3698_pen=4.240e-03
# Saved model to /home/stephen/grokking/grok_1764706121/1800.pth
# Saved model to /home/stephen/grokking/grok_1764706121/1810.pth
# Saved model to /home/stephen/grokking/grok_1764706121/1820.pth
# Saved model to /home/stephen/grokking/grok_1764706121/1830.pth
# Saved model to /home/stephen/grokking/grok_1764706121/1840.pth
# Saved model to /home/stephen/grokking/grok_1764706121/1850.pth
# Saved model to /home/stephen/grokking/grok_1764706121/1860.pth
# Saved model to /home/stephen/grokking/grok_1764706121/1870.pth
# Saved model to /home/stephen/grokking/grok_1764706121/1880.pth
# Saved model to /home/stephen/grokking/grok_1764706121/1890.pth
# 1900_-14.4280_3.3604_pen=4.139e-03
# Saved model to /home/stephen/grokking/grok_1764706121/1900.pth
# Saved model to /home/stephen/grokking/grok_1764706121/1910.pth
# Saved model to /home/stephen/grokking/grok_1764706121/1920.pth
# Saved model to /home/stephen/grokking/grok_1764706121/1930.pth
# Saved model to /home/stephen/grokking/grok_1764706121/1940.pth
# Saved model to /home/stephen/grokking/grok_1764706121/1950.pth
# Saved model to /home/stephen/grokking/grok_1764706121/1960.pth
# Saved model to /home/stephen/grokking/grok_1764706121/1970.pth
# Saved model to /home/stephen/grokking/grok_1764706121/1980.pth
# Saved model to /home/stephen/grokking/grok_1764706121/1990.pth
# 2000_-14.4406_3.3507_pen=4.063e-03
# Saved model to /home/stephen/grokking/grok_1764706121/2000.pth
# Saved model to /home/stephen/grokking/grok_1764706121/2010.pth
# Saved model to /home/stephen/grokking/grok_1764706121/2020.pth
# Saved model to /home/stephen/grokking/grok_1764706121/2030.pth
# Saved model to /home/stephen/grokking/grok_1764706121/2040.pth
# Saved model to /home/stephen/grokking/grok_1764706121/2050.pth
# Saved model to /home/stephen/grokking/grok_1764706121/2060.pth
# Saved model to /home/stephen/grokking/grok_1764706121/2070.pth
# Saved model to /home/stephen/grokking/grok_1764706121/2080.pth
# Saved model to /home/stephen/grokking/grok_1764706121/2090.pth
# 2100_-14.4506_3.3403_pen=4.001e-03
# Saved model to /home/stephen/grokking/grok_1764706121/2100.pth
# Saved model to /home/stephen/grokking/grok_1764706121/2110.pth
# Saved model to /home/stephen/grokking/grok_1764706121/2120.pth
# Saved model to /home/stephen/grokking/grok_1764706121/2130.pth
# Saved model to /home/stephen/grokking/grok_1764706121/2140.pth
# Saved model to /home/stephen/grokking/grok_1764706121/2150.pth
# Saved model to /home/stephen/grokking/grok_1764706121/2160.pth
# Saved model to /home/stephen/grokking/grok_1764706121/2170.pth
# Saved model to /home/stephen/grokking/grok_1764706121/2180.pth
# Saved model to /home/stephen/grokking/grok_1764706121/2190.pth
# 2200_-14.4613_3.3296_pen=3.943e-03
# Saved model to /home/stephen/grokking/grok_1764706121/2200.pth
# Saved model to /home/stephen/grokking/grok_1764706121/2210.pth
# Saved model to /home/stephen/grokking/grok_1764706121/2220.pth
# Saved model to /home/stephen/grokking/grok_1764706121/2230.pth
# Saved model to /home/stephen/grokking/grok_1764706121/2240.pth
# Saved model to /home/stephen/grokking/grok_1764706121/2250.pth
# Saved model to /home/stephen/grokking/grok_1764706121/2260.pth
# Saved model to /home/stephen/grokking/grok_1764706121/2270.pth
# Saved model to /home/stephen/grokking/grok_1764706121/2280.pth
# Saved model to /home/stephen/grokking/grok_1764706121/2290.pth
# 2300_-14.4719_3.3180_pen=3.888e-03
# Saved model to /home/stephen/grokking/grok_1764706121/2300.pth
# Saved model to /home/stephen/grokking/grok_1764706121/2310.pth
# Saved model to /home/stephen/grokking/grok_1764706121/2320.pth
# Saved model to /home/stephen/grokking/grok_1764706121/2330.pth
# Saved model to /home/stephen/grokking/grok_1764706121/2340.pth
# Saved model to /home/stephen/grokking/grok_1764706121/2350.pth
# Saved model to /home/stephen/grokking/grok_1764706121/2360.pth
# Saved model to /home/stephen/grokking/grok_1764706121/2370.pth
# Saved model to /home/stephen/grokking/grok_1764706121/2380.pth
# Saved model to /home/stephen/grokking/grok_1764706121/2390.pth
# 2400_-14.4812_3.3054_pen=3.834e-03
# Saved model to /home/stephen/grokking/grok_1764706121/2400.pth
# Saved model to /home/stephen/grokking/grok_1764706121/2410.pth
# Saved model to /home/stephen/grokking/grok_1764706121/2420.pth
# Saved model to /home/stephen/grokking/grok_1764706121/2430.pth
# Saved model to /home/stephen/grokking/grok_1764706121/2440.pth
# Saved model to /home/stephen/grokking/grok_1764706121/2450.pth
# Saved model to /home/stephen/grokking/grok_1764706121/2460.pth
# Saved model to /home/stephen/grokking/grok_1764706121/2470.pth
# Saved model to /home/stephen/grokking/grok_1764706121/2480.pth
# Saved model to /home/stephen/grokking/grok_1764706121/2490.pth
# 2500_-14.4910_3.2920_pen=3.777e-03
# Saved model to /home/stephen/grokking/grok_1764706121/2500.pth
# Saved model to /home/stephen/grokking/grok_1764706121/2510.pth
# Saved model to /home/stephen/grokking/grok_1764706121/2520.pth
# Saved model to /home/stephen/grokking/grok_1764706121/2530.pth
# Saved model to /home/stephen/grokking/grok_1764706121/2540.pth
# Saved model to /home/stephen/grokking/grok_1764706121/2550.pth
# Saved model to /home/stephen/grokking/grok_1764706121/2560.pth
# Saved model to /home/stephen/grokking/grok_1764706121/2570.pth
# Saved model to /home/stephen/grokking/grok_1764706121/2580.pth
# Saved model to /home/stephen/grokking/grok_1764706121/2590.pth
# 2600_-14.5033_3.2772_pen=3.720e-03
# Saved model to /home/stephen/grokking/grok_1764706121/2600.pth
# Saved model to /home/stephen/grokking/grok_1764706121/2610.pth
# Saved model to /home/stephen/grokking/grok_1764706121/2620.pth
# Saved model to /home/stephen/grokking/grok_1764706121/2630.pth
# Saved model to /home/stephen/grokking/grok_1764706121/2640.pth
# Saved model to /home/stephen/grokking/grok_1764706121/2650.pth
# Saved model to /home/stephen/grokking/grok_1764706121/2660.pth
# Saved model to /home/stephen/grokking/grok_1764706121/2670.pth
# Saved model to /home/stephen/grokking/grok_1764706121/2680.pth
# Saved model to /home/stephen/grokking/grok_1764706121/2690.pth
# 2700_-14.5143_3.2612_pen=3.666e-03
# Saved model to /home/stephen/grokking/grok_1764706121/2700.pth
# Saved model to /home/stephen/grokking/grok_1764706121/2710.pth
# Saved model to /home/stephen/grokking/grok_1764706121/2720.pth
# Saved model to /home/stephen/grokking/grok_1764706121/2730.pth
# Saved model to /home/stephen/grokking/grok_1764706121/2740.pth
# Saved model to /home/stephen/grokking/grok_1764706121/2750.pth
# Saved model to /home/stephen/grokking/grok_1764706121/2760.pth
# Saved model to /home/stephen/grokking/grok_1764706121/2770.pth
# Saved model to /home/stephen/grokking/grok_1764706121/2780.pth
# Saved model to /home/stephen/grokking/grok_1764706121/2790.pth
# 2800_-14.5204_3.2430_pen=3.609e-03
# Saved model to /home/stephen/grokking/grok_1764706121/2800.pth
# Saved model to /home/stephen/grokking/grok_1764706121/2810.pth
# Saved model to /home/stephen/grokking/grok_1764706121/2820.pth
# Saved model to /home/stephen/grokking/grok_1764706121/2830.pth
# Saved model to /home/stephen/grokking/grok_1764706121/2840.pth
# Saved model to /home/stephen/grokking/grok_1764706121/2850.pth
# Saved model to /home/stephen/grokking/grok_1764706121/2860.pth
# Saved model to /home/stephen/grokking/grok_1764706121/2870.pth
# Saved model to /home/stephen/grokking/grok_1764706121/2880.pth
# Saved model to /home/stephen/grokking/grok_1764706121/2890.pth
# 2900_-14.5341_3.2234_pen=3.551e-03
# Saved model to /home/stephen/grokking/grok_1764706121/2900.pth
# Saved model to /home/stephen/grokking/grok_1764706121/2910.pth
# Saved model to /home/stephen/grokking/grok_1764706121/2920.pth
# Saved model to /home/stephen/grokking/grok_1764706121/2930.pth
# Saved model to /home/stephen/grokking/grok_1764706121/2940.pth
# Saved model to /home/stephen/grokking/grok_1764706121/2950.pth
# Saved model to /home/stephen/grokking/grok_1764706121/2960.pth
# Saved model to /home/stephen/grokking/grok_1764706121/2970.pth
# Saved model to /home/stephen/grokking/grok_1764706121/2980.pth
# Saved model to /home/stephen/grokking/grok_1764706121/2990.pth
# 3000_-14.5439_3.2027_pen=3.494e-03
# Saved model to /home/stephen/grokking/grok_1764706121/3000.pth
# Saved model to /home/stephen/grokking/grok_1764706121/3010.pth
# Saved model to /home/stephen/grokking/grok_1764706121/3020.pth
# Saved model to /home/stephen/grokking/grok_1764706121/3030.pth
# Saved model to /home/stephen/grokking/grok_1764706121/3040.pth
# Saved model to /home/stephen/grokking/grok_1764706121/3050.pth
# Saved model to /home/stephen/grokking/grok_1764706121/3060.pth
# Saved model to /home/stephen/grokking/grok_1764706121/3070.pth
# Saved model to /home/stephen/grokking/grok_1764706121/3080.pth
# Saved model to /home/stephen/grokking/grok_1764706121/3090.pth
# 3100_-14.5558_3.1802_pen=3.435e-03
# Saved model to /home/stephen/grokking/grok_1764706121/3100.pth
# Saved model to /home/stephen/grokking/grok_1764706121/3110.pth
# Saved model to /home/stephen/grokking/grok_1764706121/3120.pth
# Saved model to /home/stephen/grokking/grok_1764706121/3130.pth
# Saved model to /home/stephen/grokking/grok_1764706121/3140.pth
# Saved model to /home/stephen/grokking/grok_1764706121/3150.pth
# Saved model to /home/stephen/grokking/grok_1764706121/3160.pth
# Saved model to /home/stephen/grokking/grok_1764706121/3170.pth
# Saved model to /home/stephen/grokking/grok_1764706121/3180.pth
# Saved model to /home/stephen/grokking/grok_1764706121/3190.pth
# 3200_-14.5647_3.1560_pen=3.375e-03
# Saved model to /home/stephen/grokking/grok_1764706121/3200.pth
# Saved model to /home/stephen/grokking/grok_1764706121/3210.pth
# Saved model to /home/stephen/grokking/grok_1764706121/3220.pth
# Saved model to /home/stephen/grokking/grok_1764706121/3230.pth
# Saved model to /home/stephen/grokking/grok_1764706121/3240.pth
# Saved model to /home/stephen/grokking/grok_1764706121/3250.pth
# Saved model to /home/stephen/grokking/grok_1764706121/3260.pth
# Saved model to /home/stephen/grokking/grok_1764706121/3270.pth
# Saved model to /home/stephen/grokking/grok_1764706121/3280.pth
# Saved model to /home/stephen/grokking/grok_1764706121/3290.pth
# 3300_-14.5785_3.1300_pen=3.314e-03
# Saved model to /home/stephen/grokking/grok_1764706121/3300.pth
# Saved model to /home/stephen/grokking/grok_1764706121/3310.pth
# Saved model to /home/stephen/grokking/grok_1764706121/3320.pth
# Saved model to /home/stephen/grokking/grok_1764706121/3330.pth
# Saved model to /home/stephen/grokking/grok_1764706121/3340.pth
# Saved model to /home/stephen/grokking/grok_1764706121/3350.pth
# Saved model to /home/stephen/grokking/grok_1764706121/3360.pth
# Saved model to /home/stephen/grokking/grok_1764706121/3370.pth
# Saved model to /home/stephen/grokking/grok_1764706121/3380.pth
# Saved model to /home/stephen/grokking/grok_1764706121/3390.pth
# 3400_-14.5857_3.1027_pen=3.252e-03
# Saved model to /home/stephen/grokking/grok_1764706121/3400.pth
# Saved model to /home/stephen/grokking/grok_1764706121/3410.pth
# Saved model to /home/stephen/grokking/grok_1764706121/3420.pth
# Saved model to /home/stephen/grokking/grok_1764706121/3430.pth
# Saved model to /home/stephen/grokking/grok_1764706121/3440.pth
# Saved model to /home/stephen/grokking/grok_1764706121/3450.pth
# Saved model to /home/stephen/grokking/grok_1764706121/3460.pth
# Saved model to /home/stephen/grokking/grok_1764706121/3470.pth
# Saved model to /home/stephen/grokking/grok_1764706121/3480.pth
# Saved model to /home/stephen/grokking/grok_1764706121/3490.pth
# 3500_-14.5992_3.0741_pen=3.192e-03
# Saved model to /home/stephen/grokking/grok_1764706121/3500.pth
# Saved model to /home/stephen/grokking/grok_1764706121/3510.pth
# Saved model to /home/stephen/grokking/grok_1764706121/3520.pth
# Saved model to /home/stephen/grokking/grok_1764706121/3530.pth
# Saved model to /home/stephen/grokking/grok_1764706121/3540.pth
# Saved model to /home/stephen/grokking/grok_1764706121/3550.pth
# Saved model to /home/stephen/grokking/grok_1764706121/3560.pth
# Saved model to /home/stephen/grokking/grok_1764706121/3570.pth
# Saved model to /home/stephen/grokking/grok_1764706121/3580.pth
# Saved model to /home/stephen/grokking/grok_1764706121/3590.pth
# 3600_-14.6101_3.0443_pen=3.134e-03
# Saved model to /home/stephen/grokking/grok_1764706121/3600.pth
# Saved model to /home/stephen/grokking/grok_1764706121/3610.pth
# Saved model to /home/stephen/grokking/grok_1764706121/3620.pth
# Saved model to /home/stephen/grokking/grok_1764706121/3630.pth
# Saved model to /home/stephen/grokking/grok_1764706121/3640.pth
# Saved model to /home/stephen/grokking/grok_1764706121/3650.pth
# Saved model to /home/stephen/grokking/grok_1764706121/3660.pth
# Saved model to /home/stephen/grokking/grok_1764706121/3670.pth
# Saved model to /home/stephen/grokking/grok_1764706121/3680.pth
# Saved model to /home/stephen/grokking/grok_1764706121/3690.pth
# 3700_-14.6234_3.0127_pen=3.078e-03
# Saved model to /home/stephen/grokking/grok_1764706121/3700.pth
# Saved model to /home/stephen/grokking/grok_1764706121/3710.pth
# Saved model to /home/stephen/grokking/grok_1764706121/3720.pth
# Saved model to /home/stephen/grokking/grok_1764706121/3730.pth
# Saved model to /home/stephen/grokking/grok_1764706121/3740.pth
# Saved model to /home/stephen/grokking/grok_1764706121/3750.pth
# Saved model to /home/stephen/grokking/grok_1764706121/3760.pth
# Saved model to /home/stephen/grokking/grok_1764706121/3770.pth
# Saved model to /home/stephen/grokking/grok_1764706121/3780.pth
# Saved model to /home/stephen/grokking/grok_1764706121/3790.pth
# 3800_-14.6300_2.9796_pen=3.025e-03
# Saved model to /home/stephen/grokking/grok_1764706121/3800.pth
# Saved model to /home/stephen/grokking/grok_1764706121/3810.pth
# Saved model to /home/stephen/grokking/grok_1764706121/3820.pth
# Saved model to /home/stephen/grokking/grok_1764706121/3830.pth
# Saved model to /home/stephen/grokking/grok_1764706121/3840.pth
# Saved model to /home/stephen/grokking/grok_1764706121/3850.pth
# Saved model to /home/stephen/grokking/grok_1764706121/3860.pth
# Saved model to /home/stephen/grokking/grok_1764706121/3870.pth
# Saved model to /home/stephen/grokking/grok_1764706121/3880.pth
# Saved model to /home/stephen/grokking/grok_1764706121/3890.pth
# 3900_-14.6414_2.9450_pen=2.969e-03
# Saved model to /home/stephen/grokking/grok_1764706121/3900.pth
# Saved model to /home/stephen/grokking/grok_1764706121/3910.pth
# Saved model to /home/stephen/grokking/grok_1764706121/3920.pth
# Saved model to /home/stephen/grokking/grok_1764706121/3930.pth
# Saved model to /home/stephen/grokking/grok_1764706121/3940.pth
# Saved model to /home/stephen/grokking/grok_1764706121/3950.pth
# Saved model to /home/stephen/grokking/grok_1764706121/3960.pth
# Saved model to /home/stephen/grokking/grok_1764706121/3970.pth
# Saved model to /home/stephen/grokking/grok_1764706121/3980.pth
# Saved model to /home/stephen/grokking/grok_1764706121/3990.pth
# 4000_-14.6540_2.9096_pen=2.915e-03
# Saved model to /home/stephen/grokking/grok_1764706121/4000.pth
# Saved model to /home/stephen/grokking/grok_1764706121/4010.pth
# Saved model to /home/stephen/grokking/grok_1764706121/4020.pth
# Saved model to /home/stephen/grokking/grok_1764706121/4030.pth
# Saved model to /home/stephen/grokking/grok_1764706121/4040.pth
# Saved model to /home/stephen/grokking/grok_1764706121/4050.pth
# Saved model to /home/stephen/grokking/grok_1764706121/4060.pth
# Saved model to /home/stephen/grokking/grok_1764706121/4070.pth
# Saved model to /home/stephen/grokking/grok_1764706121/4080.pth
# Saved model to /home/stephen/grokking/grok_1764706121/4090.pth
# 4100_-14.6677_2.8726_pen=2.861e-03
# Saved model to /home/stephen/grokking/grok_1764706121/4100.pth
# Saved model to /home/stephen/grokking/grok_1764706121/4110.pth
# Saved model to /home/stephen/grokking/grok_1764706121/4120.pth
# Saved model to /home/stephen/grokking/grok_1764706121/4130.pth
# Saved model to /home/stephen/grokking/grok_1764706121/4140.pth
# Saved model to /home/stephen/grokking/grok_1764706121/4150.pth
# Saved model to /home/stephen/grokking/grok_1764706121/4160.pth
# Saved model to /home/stephen/grokking/grok_1764706121/4170.pth
# Saved model to /home/stephen/grokking/grok_1764706121/4180.pth
# Saved model to /home/stephen/grokking/grok_1764706121/4190.pth
# 4200_-14.6726_2.8344_pen=2.808e-03
# Saved model to /home/stephen/grokking/grok_1764706121/4200.pth
# Saved model to /home/stephen/grokking/grok_1764706121/4210.pth
# Saved model to /home/stephen/grokking/grok_1764706121/4220.pth
# Saved model to /home/stephen/grokking/grok_1764706121/4230.pth
# Saved model to /home/stephen/grokking/grok_1764706121/4240.pth
# Saved model to /home/stephen/grokking/grok_1764706121/4250.pth
# Saved model to /home/stephen/grokking/grok_1764706121/4260.pth
# Saved model to /home/stephen/grokking/grok_1764706121/4270.pth
# Saved model to /home/stephen/grokking/grok_1764706121/4280.pth
# Saved model to /home/stephen/grokking/grok_1764706121/4290.pth
# 4300_-14.6858_2.7938_pen=2.753e-03
# Saved model to /home/stephen/grokking/grok_1764706121/4300.pth
# Saved model to /home/stephen/grokking/grok_1764706121/4310.pth
# Saved model to /home/stephen/grokking/grok_1764706121/4320.pth
# Saved model to /home/stephen/grokking/grok_1764706121/4330.pth
# Saved model to /home/stephen/grokking/grok_1764706121/4340.pth
# Saved model to /home/stephen/grokking/grok_1764706121/4350.pth
# Saved model to /home/stephen/grokking/grok_1764706121/4360.pth
# Saved model to /home/stephen/grokking/grok_1764706121/4370.pth
# Saved model to /home/stephen/grokking/grok_1764706121/4380.pth
# Saved model to /home/stephen/grokking/grok_1764706121/4390.pth
# 4400_-14.6992_2.7496_pen=2.694e-03
# Saved model to /home/stephen/grokking/grok_1764706121/4400.pth
# Saved model to /home/stephen/grokking/grok_1764706121/4410.pth
# Saved model to /home/stephen/grokking/grok_1764706121/4420.pth
# Saved model to /home/stephen/grokking/grok_1764706121/4430.pth
# Saved model to /home/stephen/grokking/grok_1764706121/4440.pth
# Saved model to /home/stephen/grokking/grok_1764706121/4450.pth
# Saved model to /home/stephen/grokking/grok_1764706121/4460.pth
# Saved model to /home/stephen/grokking/grok_1764706121/4470.pth
# Saved model to /home/stephen/grokking/grok_1764706121/4480.pth
# Saved model to /home/stephen/grokking/grok_1764706121/4490.pth
# 4500_-14.7170_2.7023_pen=2.639e-03
# Saved model to /home/stephen/grokking/grok_1764706121/4500.pth
# Saved model to /home/stephen/grokking/grok_1764706121/4510.pth
# Saved model to /home/stephen/grokking/grok_1764706121/4520.pth
# Saved model to /home/stephen/grokking/grok_1764706121/4530.pth
# Saved model to /home/stephen/grokking/grok_1764706121/4540.pth
# Saved model to /home/stephen/grokking/grok_1764706121/4550.pth
# Saved model to /home/stephen/grokking/grok_1764706121/4560.pth
# Saved model to /home/stephen/grokking/grok_1764706121/4570.pth
# Saved model to /home/stephen/grokking/grok_1764706121/4580.pth
# Saved model to /home/stephen/grokking/grok_1764706121/4590.pth
# 4600_-14.7302_2.6526_pen=2.583e-03
# Saved model to /home/stephen/grokking/grok_1764706121/4600.pth
# Saved model to /home/stephen/grokking/grok_1764706121/4610.pth
# Saved model to /home/stephen/grokking/grok_1764706121/4620.pth
# Saved model to /home/stephen/grokking/grok_1764706121/4630.pth
# Saved model to /home/stephen/grokking/grok_1764706121/4640.pth
# Saved model to /home/stephen/grokking/grok_1764706121/4650.pth
# Saved model to /home/stephen/grokking/grok_1764706121/4660.pth
# Saved model to /home/stephen/grokking/grok_1764706121/4670.pth
# Saved model to /home/stephen/grokking/grok_1764706121/4680.pth
# Saved model to /home/stephen/grokking/grok_1764706121/4690.pth
# 4700_-14.7350_2.5980_pen=2.525e-03
# Saved model to /home/stephen/grokking/grok_1764706121/4700.pth
# Saved model to /home/stephen/grokking/grok_1764706121/4710.pth
# Saved model to /home/stephen/grokking/grok_1764706121/4720.pth
# Saved model to /home/stephen/grokking/grok_1764706121/4730.pth
# Saved model to /home/stephen/grokking/grok_1764706121/4740.pth
# Saved model to /home/stephen/grokking/grok_1764706121/4750.pth
# Saved model to /home/stephen/grokking/grok_1764706121/4760.pth
# Saved model to /home/stephen/grokking/grok_1764706121/4770.pth
# Saved model to /home/stephen/grokking/grok_1764706121/4780.pth
# Saved model to /home/stephen/grokking/grok_1764706121/4790.pth
# 4800_-14.7570_2.5378_pen=2.464e-03
# Saved model to /home/stephen/grokking/grok_1764706121/4800.pth
# Saved model to /home/stephen/grokking/grok_1764706121/4810.pth
# Saved model to /home/stephen/grokking/grok_1764706121/4820.pth
# Saved model to /home/stephen/grokking/grok_1764706121/4830.pth
# Saved model to /home/stephen/grokking/grok_1764706121/4840.pth
# Saved model to /home/stephen/grokking/grok_1764706121/4850.pth
# Saved model to /home/stephen/grokking/grok_1764706121/4860.pth
# Saved model to /home/stephen/grokking/grok_1764706121/4870.pth
# Saved model to /home/stephen/grokking/grok_1764706121/4880.pth
# Saved model to /home/stephen/grokking/grok_1764706121/4890.pth
# 4900_-14.7812_2.4702_pen=2.400e-03
# Saved model to /home/stephen/grokking/grok_1764706121/4900.pth
# Saved model to /home/stephen/grokking/grok_1764706121/4910.pth
# Saved model to /home/stephen/grokking/grok_1764706121/4920.pth
# Saved model to /home/stephen/grokking/grok_1764706121/4930.pth
# Saved model to /home/stephen/grokking/grok_1764706121/4940.pth
# Saved model to /home/stephen/grokking/grok_1764706121/4950.pth
# Saved model to /home/stephen/grokking/grok_1764706121/4960.pth
# Saved model to /home/stephen/grokking/grok_1764706121/4970.pth
# Saved model to /home/stephen/grokking/grok_1764706121/4980.pth
# Saved model to /home/stephen/grokking/grok_1764706121/4990.pth
# 5000_-14.8063_2.3925_pen=2.332e-03
# Saved model to /home/stephen/grokking/grok_1764706121/5000.pth
# Saved model to /home/stephen/grokking/grok_1764706121/5010.pth
# Saved model to /home/stephen/grokking/grok_1764706121/5020.pth
# Saved model to /home/stephen/grokking/grok_1764706121/5030.pth
# Saved model to /home/stephen/grokking/grok_1764706121/5040.pth
# Saved model to /home/stephen/grokking/grok_1764706121/5050.pth
# Saved model to /home/stephen/grokking/grok_1764706121/5060.pth
# Saved model to /home/stephen/grokking/grok_1764706121/5070.pth
# Saved model to /home/stephen/grokking/grok_1764706121/5080.pth
# Saved model to /home/stephen/grokking/grok_1764706121/5090.pth
# 5100_-14.8274_2.3044_pen=2.261e-03
# Saved model to /home/stephen/grokking/grok_1764706121/5100.pth
# Saved model to /home/stephen/grokking/grok_1764706121/5110.pth
# Saved model to /home/stephen/grokking/grok_1764706121/5120.pth
# Saved model to /home/stephen/grokking/grok_1764706121/5130.pth
# Saved model to /home/stephen/grokking/grok_1764706121/5140.pth
# Saved model to /home/stephen/grokking/grok_1764706121/5150.pth
# Saved model to /home/stephen/grokking/grok_1764706121/5160.pth
# Saved model to /home/stephen/grokking/grok_1764706121/5170.pth
# Saved model to /home/stephen/grokking/grok_1764706121/5180.pth
# Saved model to /home/stephen/grokking/grok_1764706121/5190.pth
# 5200_-14.8560_2.2006_pen=2.190e-03
# Saved model to /home/stephen/grokking/grok_1764706121/5200.pth
# Saved model to /home/stephen/grokking/grok_1764706121/5210.pth
# Saved model to /home/stephen/grokking/grok_1764706121/5220.pth
# Saved model to /home/stephen/grokking/grok_1764706121/5230.pth
# Saved model to /home/stephen/grokking/grok_1764706121/5240.pth
# Saved model to /home/stephen/grokking/grok_1764706121/5250.pth
# Saved model to /home/stephen/grokking/grok_1764706121/5260.pth
# Saved model to /home/stephen/grokking/grok_1764706121/5270.pth
# Saved model to /home/stephen/grokking/grok_1764706121/5280.pth
# Saved model to /home/stephen/grokking/grok_1764706121/5290.pth
# 5300_-14.8760_2.0734_pen=2.112e-03
# Saved model to /home/stephen/grokking/grok_1764706121/5300.pth
# Saved model to /home/stephen/grokking/grok_1764706121/5310.pth
# Saved model to /home/stephen/grokking/grok_1764706121/5320.pth
# Saved model to /home/stephen/grokking/grok_1764706121/5330.pth
# Saved model to /home/stephen/grokking/grok_1764706121/5340.pth
# Saved model to /home/stephen/grokking/grok_1764706121/5350.pth
# Saved model to /home/stephen/grokking/grok_1764706121/5360.pth
# Saved model to /home/stephen/grokking/grok_1764706121/5370.pth
# Saved model to /home/stephen/grokking/grok_1764706121/5380.pth
# Saved model to /home/stephen/grokking/grok_1764706121/5390.pth
# 5400_-14.9200_1.9066_pen=2.026e-03
# Saved model to /home/stephen/grokking/grok_1764706121/5400.pth
# Saved model to /home/stephen/grokking/grok_1764706121/5410.pth
# Saved model to /home/stephen/grokking/grok_1764706121/5420.pth
# Saved model to /home/stephen/grokking/grok_1764706121/5430.pth
# Saved model to /home/stephen/grokking/grok_1764706121/5440.pth
# Saved model to /home/stephen/grokking/grok_1764706121/5450.pth
# Saved model to /home/stephen/grokking/grok_1764706121/5460.pth
# Saved model to /home/stephen/grokking/grok_1764706121/5470.pth
# Saved model to /home/stephen/grokking/grok_1764706121/5480.pth
# Saved model to /home/stephen/grokking/grok_1764706121/5490.pth
# 5500_-14.9741_1.6709_pen=1.922e-03
# Saved model to /home/stephen/grokking/grok_1764706121/5500.pth
# Saved model to /home/stephen/grokking/grok_1764706121/5510.pth
# Saved model to /home/stephen/grokking/grok_1764706121/5520.pth
# Saved model to /home/stephen/grokking/grok_1764706121/5530.pth
# Saved model to /home/stephen/grokking/grok_1764706121/5540.pth
# Saved model to /home/stephen/grokking/grok_1764706121/5550.pth
# Saved model to /home/stephen/grokking/grok_1764706121/5560.pth
# Saved model to /home/stephen/grokking/grok_1764706121/5570.pth
# Saved model to /home/stephen/grokking/grok_1764706121/5580.pth
# Saved model to /home/stephen/grokking/grok_1764706121/5590.pth
# 5600_-15.0448_1.3230_pen=1.795e-03
# Saved model to /home/stephen/grokking/grok_1764706121/5600.pth
# Saved model to /home/stephen/grokking/grok_1764706121/5610.pth
# Saved model to /home/stephen/grokking/grok_1764706121/5620.pth
# Saved model to /home/stephen/grokking/grok_1764706121/5630.pth
# Saved model to /home/stephen/grokking/grok_1764706121/5640.pth
# Saved model to /home/stephen/grokking/grok_1764706121/5650.pth
# Saved model to /home/stephen/grokking/grok_1764706121/5660.pth
# Saved model to /home/stephen/grokking/grok_1764706121/5670.pth
# Saved model to /home/stephen/grokking/grok_1764706121/5680.pth
# Saved model to /home/stephen/grokking/grok_1764706121/5690.pth
# 5700_-15.1091_0.8427_pen=1.653e-03
# Saved model to /home/stephen/grokking/grok_1764706121/5700.pth
# Saved model to /home/stephen/grokking/grok_1764706121/5710.pth
# Saved model to /home/stephen/grokking/grok_1764706121/5720.pth
# Saved model to /home/stephen/grokking/grok_1764706121/5730.pth
# Saved model to /home/stephen/grokking/grok_1764706121/5740.pth
# Saved model to /home/stephen/grokking/grok_1764706121/5750.pth
# Saved model to /home/stephen/grokking/grok_1764706121/5760.pth
# Saved model to /home/stephen/grokking/grok_1764706121/5770.pth
# Saved model to /home/stephen/grokking/grok_1764706121/5780.pth
# Saved model to /home/stephen/grokking/grok_1764706121/5790.pth
# 5800_-15.1721_0.2965_pen=1.517e-03
# Saved model to /home/stephen/grokking/grok_1764706121/5800.pth
# Saved model to /home/stephen/grokking/grok_1764706121/5810.pth
# Saved model to /home/stephen/grokking/grok_1764706121/5820.pth
# Saved model to /home/stephen/grokking/grok_1764706121/5830.pth
# Saved model to /home/stephen/grokking/grok_1764706121/5840.pth
# Saved model to /home/stephen/grokking/grok_1764706121/5850.pth
# Saved model to /home/stephen/grokking/grok_1764706121/5860.pth
# Saved model to /home/stephen/grokking/grok_1764706121/5870.pth
# Saved model to /home/stephen/grokking/grok_1764706121/5880.pth
# Saved model to /home/stephen/grokking/grok_1764706121/5890.pth
# 5900_-15.2115_-0.2352_pen=1.399e-03
# Saved model to /home/stephen/grokking/grok_1764706121/5900.pth
# Saved model to /home/stephen/grokking/grok_1764706121/5910.pth
# Saved model to /home/stephen/grokking/grok_1764706121/5920.pth
# Saved model to /home/stephen/grokking/grok_1764706121/5930.pth
# Saved model to /home/stephen/grokking/grok_1764706121/5940.pth
# Saved model to /home/stephen/grokking/grok_1764706121/5950.pth
# Saved model to /home/stephen/grokking/grok_1764706121/5960.pth
# Saved model to /home/stephen/grokking/grok_1764706121/5970.pth
# Saved model to /home/stephen/grokking/grok_1764706121/5980.pth
# Saved model to /home/stephen/grokking/grok_1764706121/5990.pth
# 6000_-15.2683_-0.7396_pen=1.304e-03
# Saved model to /home/stephen/grokking/grok_1764706121/6000.pth
# Saved model to /home/stephen/grokking/grok_1764706121/6010.pth
# Saved model to /home/stephen/grokking/grok_1764706121/6020.pth
# Saved model to /home/stephen/grokking/grok_1764706121/6030.pth
# Saved model to /home/stephen/grokking/grok_1764706121/6040.pth
# Saved model to /home/stephen/grokking/grok_1764706121/6050.pth
# Saved model to /home/stephen/grokking/grok_1764706121/6060.pth
# Saved model to /home/stephen/grokking/grok_1764706121/6070.pth
# Saved model to /home/stephen/grokking/grok_1764706121/6080.pth
# Saved model to /home/stephen/grokking/grok_1764706121/6090.pth
# 6100_-15.3345_-1.3126_pen=1.218e-03
# Saved model to /home/stephen/grokking/grok_1764706121/6100.pth
# Saved model to /home/stephen/grokking/grok_1764706121/6110.pth
# Saved model to /home/stephen/grokking/grok_1764706121/6120.pth
# Saved model to /home/stephen/grokking/grok_1764706121/6130.pth
# Saved model to /home/stephen/grokking/grok_1764706121/6140.pth
# Saved model to /home/stephen/grokking/grok_1764706121/6150.pth
# Saved model to /home/stephen/grokking/grok_1764706121/6160.pth
# Saved model to /home/stephen/grokking/grok_1764706121/6170.pth
# Saved model to /home/stephen/grokking/grok_1764706121/6180.pth
# Saved model to /home/stephen/grokking/grok_1764706121/6190.pth
# 6200_-15.4364_-2.1669_pen=1.124e-03
# Saved model to /home/stephen/grokking/grok_1764706121/6200.pth
# Saved model to /home/stephen/grokking/grok_1764706121/6210.pth
# Saved model to /home/stephen/grokking/grok_1764706121/6220.pth
# Saved model to /home/stephen/grokking/grok_1764706121/6230.pth
# Saved model to /home/stephen/grokking/grok_1764706121/6240.pth
# Saved model to /home/stephen/grokking/grok_1764706121/6250.pth
# Saved model to /home/stephen/grokking/grok_1764706121/6260.pth
# Saved model to /home/stephen/grokking/grok_1764706121/6270.pth
# Saved model to /home/stephen/grokking/grok_1764706121/6280.pth
# Saved model to /home/stephen/grokking/grok_1764706121/6290.pth
# 6300_-15.5586_-3.7245_pen=1.019e-03
# Saved model to /home/stephen/grokking/grok_1764706121/6300.pth
# Saved model to /home/stephen/grokking/grok_1764706121/6310.pth
# Saved model to /home/stephen/grokking/grok_1764706121/6320.pth
# Saved model to /home/stephen/grokking/grok_1764706121/6330.pth
# Saved model to /home/stephen/grokking/grok_1764706121/6340.pth
# Saved model to /home/stephen/grokking/grok_1764706121/6350.pth
# Saved model to /home/stephen/grokking/grok_1764706121/6360.pth
# Saved model to /home/stephen/grokking/grok_1764706121/6370.pth
# Saved model to /home/stephen/grokking/grok_1764706121/6380.pth
# Saved model to /home/stephen/grokking/grok_1764706121/6390.pth
# 6400_-15.6452_-6.1589_pen=9.330e-04
# Saved model to /home/stephen/grokking/grok_1764706121/6400.pth
# Saved model to /home/stephen/grokking/grok_1764706121/6410.pth
# Saved model to /home/stephen/grokking/grok_1764706121/6420.pth
# Saved model to /home/stephen/grokking/grok_1764706121/6430.pth
# Saved model to /home/stephen/grokking/grok_1764706121/6440.pth
# Saved model to /home/stephen/grokking/grok_1764706121/6450.pth
# Saved model to /home/stephen/grokking/grok_1764706121/6460.pth
# Saved model to /home/stephen/grokking/grok_1764706121/6470.pth
# Saved model to /home/stephen/grokking/grok_1764706121/6480.pth
# Saved model to /home/stephen/grokking/grok_1764706121/6490.pth
# 6500_-15.6953_-8.8405_pen=8.840e-04
# Saved model to /home/stephen/grokking/grok_1764706121/6500.pth
# Saved model to /home/stephen/grokking/grok_1764706121/6510.pth
# Saved model to /home/stephen/grokking/grok_1764706121/6520.pth
# Saved model to /home/stephen/grokking/grok_1764706121/6530.pth
# Saved model to /home/stephen/grokking/grok_1764706121/6540.pth
# Saved model to /home/stephen/grokking/grok_1764706121/6550.pth
# Saved model to /home/stephen/grokking/grok_1764706121/6560.pth
# Saved model to /home/stephen/grokking/grok_1764706121/6570.pth
# Saved model to /home/stephen/grokking/grok_1764706121/6580.pth
# Saved model to /home/stephen/grokking/grok_1764706121/6590.pth
# 6600_-15.7222_-10.8998_pen=8.590e-04
# Saved model to /home/stephen/grokking/grok_1764706121/6600.pth
# Saved model to /home/stephen/grokking/grok_1764706121/6610.pth
# Saved model to /home/stephen/grokking/grok_1764706121/6620.pth
# Saved model to /home/stephen/grokking/grok_1764706121/6630.pth
# Saved model to /home/stephen/grokking/grok_1764706121/6640.pth
# Saved model to /home/stephen/grokking/grok_1764706121/6650.pth
# Saved model to /home/stephen/grokking/grok_1764706121/6660.pth
# Saved model to /home/stephen/grokking/grok_1764706121/6670.pth
# Saved model to /home/stephen/grokking/grok_1764706121/6680.pth
# Saved model to /home/stephen/grokking/grok_1764706121/6690.pth
# 6700_-15.7409_-12.2344_pen=8.451e-04
# Saved model to /home/stephen/grokking/grok_1764706121/6700.pth
# Saved model to /home/stephen/grokking/grok_1764706121/6710.pth
# Saved model to /home/stephen/grokking/grok_1764706121/6720.pth
# Saved model to /home/stephen/grokking/grok_1764706121/6730.pth
# Saved model to /home/stephen/grokking/grok_1764706121/6740.pth
# Saved model to /home/stephen/grokking/grok_1764706121/6750.pth
# Saved model to /home/stephen/grokking/grok_1764706121/6760.pth
# Saved model to /home/stephen/grokking/grok_1764706121/6770.pth
# Saved model to /home/stephen/grokking/grok_1764706121/6780.pth
# Saved model to /home/stephen/grokking/grok_1764706121/6790.pth
# 6800_-15.7580_-12.9741_pen=8.356e-04
# Saved model to /home/stephen/grokking/grok_1764706121/6800.pth
# Saved model to /home/stephen/grokking/grok_1764706121/6810.pth
# Saved model to /home/stephen/grokking/grok_1764706121/6820.pth
# Saved model to /home/stephen/grokking/grok_1764706121/6830.pth
# Saved model to /home/stephen/grokking/grok_1764706121/6840.pth
# Saved model to /home/stephen/grokking/grok_1764706121/6850.pth
# Saved model to /home/stephen/grokking/grok_1764706121/6860.pth
# Saved model to /home/stephen/grokking/grok_1764706121/6870.pth
# Saved model to /home/stephen/grokking/grok_1764706121/6880.pth
# Saved model to /home/stephen/grokking/grok_1764706121/6890.pth
# 6900_-15.7745_-13.3775_pen=8.277e-04
# Saved model to /home/stephen/grokking/grok_1764706121/6900.pth
# Saved model to /home/stephen/grokking/grok_1764706121/6910.pth
# Saved model to /home/stephen/grokking/grok_1764706121/6920.pth
# Saved model to /home/stephen/grokking/grok_1764706121/6930.pth
# Saved model to /home/stephen/grokking/grok_1764706121/6940.pth
# Saved model to /home/stephen/grokking/grok_1764706121/6950.pth
# Saved model to /home/stephen/grokking/grok_1764706121/6960.pth
# Saved model to /home/stephen/grokking/grok_1764706121/6970.pth
# Saved model to /home/stephen/grokking/grok_1764706121/6980.pth
# Saved model to /home/stephen/grokking/grok_1764706121/6990.pth
# 7000_-15.7895_-13.6302_pen=8.200e-04
# Saved model to /home/stephen/grokking/grok_1764706121/7000.pth
# Saved model to /home/stephen/grokking/grok_1764706121/7010.pth
# Saved model to /home/stephen/grokking/grok_1764706121/7020.pth
# Saved model to /home/stephen/grokking/grok_1764706121/7030.pth
# Saved model to /home/stephen/grokking/grok_1764706121/7040.pth
# Saved model to /home/stephen/grokking/grok_1764706121/7050.pth
# Saved model to /home/stephen/grokking/grok_1764706121/7060.pth
# Saved model to /home/stephen/grokking/grok_1764706121/7070.pth
# Saved model to /home/stephen/grokking/grok_1764706121/7080.pth
# Saved model to /home/stephen/grokking/grok_1764706121/7090.pth
# 7100_-15.8043_-13.8302_pen=8.123e-04
# Saved model to /home/stephen/grokking/grok_1764706121/7100.pth
# Saved model to /home/stephen/grokking/grok_1764706121/7110.pth
# Saved model to /home/stephen/grokking/grok_1764706121/7120.pth
# Saved model to /home/stephen/grokking/grok_1764706121/7130.pth
# Saved model to /home/stephen/grokking/grok_1764706121/7140.pth
# Saved model to /home/stephen/grokking/grok_1764706121/7150.pth
# Saved model to /home/stephen/grokking/grok_1764706121/7160.pth
# Saved model to /home/stephen/grokking/grok_1764706121/7170.pth
# Saved model to /home/stephen/grokking/grok_1764706121/7180.pth
# Saved model to /home/stephen/grokking/grok_1764706121/7190.pth
# 7200_-15.8173_-14.0356_pen=8.041e-04
# Saved model to /home/stephen/grokking/grok_1764706121/7200.pth
# Saved model to /home/stephen/grokking/grok_1764706121/7210.pth
# ...
# Saved model to /home/stephen/grokking/grok_1764706121/17650.pth
# Saved model to /home/stephen/grokking/grok_1764706121/17660.pth
# Saved model to /home/stephen/grokking/grok_1764706121/17670.pth
# Saved model to /home/stephen/grokking/grok_1764706121/17680.pth
# Saved model to /home/stephen/grokking/grok_1764706121/17690.pth
# 17700_-15.9790_-15.3111_pen=6.634e-04
# Saved model to /home/stephen/grokking/grok_1764706121/17700.pth
# Saved model to /home/stephen/grokking/grok_1764706121/17710.pth
# Saved model to /home/stephen/grokking/grok_1764706121/17720.pth
# Saved model to /home/stephen/grokking/grok_1764706121/17730.pth
# Saved model to /home/stephen/grokking/grok_1764706121/17740.pth
# Saved model to /home/stephen/grokking/grok_1764706121/17750.pth
# Saved model to /home/stephen/grokking/grok_1764706121/17760.pth
# Saved model to /home/stephen/grokking/grok_1764706121/17770.pth
# Saved model to /home/stephen/grokking/grok_1764706121/17780.pth
# Saved model to /home/stephen/grokking/grok_1764706121/17790.pth
# 17800_-15.9808_-15.3148_pen=6.632e-04
# Saved model to /home/stephen/grokking/grok_1764706121/17800.pth
# Saved model to /home/stephen/grokking/grok_1764706121/17810.pth
# Saved model to /home/stephen/grokking/grok_1764706121/17820.pth
# Saved model to /home/stephen/grokking/grok_1764706121/17830.pth
# Saved model to /home/stephen/grokking/grok_1764706121/17840.pth
# Saved model to /home/stephen/grokking/grok_1764706121/17850.pth
# Saved model to /home/stephen/grokking/grok_1764706121/17860.pth
# Saved model to /home/stephen/grokking/grok_1764706121/17870.pth
# Saved model to /home/stephen/grokking/grok_1764706121/17880.pth
# Saved model to /home/stephen/grokking/grok_1764706121/17890.pth
# 17900_-15.9818_-15.3168_pen=6.630e-04
# Saved model to /home/stephen/grokking/grok_1764706121/17900.pth
# Saved model to /home/stephen/grokking/grok_1764706121/17910.pth
# Saved model to /home/stephen/grokking/grok_1764706121/17920.pth
# Saved model to /home/stephen/grokking/grok_1764706121/17930.pth
# Saved model to /home/stephen/grokking/grok_1764706121/17940.pth
# Saved model to /home/stephen/grokking/grok_1764706121/17950.pth
# Saved model to /home/stephen/grokking/grok_1764706121/17960.pth
# Saved model to /home/stephen/grokking/grok_1764706121/17970.pth
# Saved model to /home/stephen/grokking/grok_1764706121/17980.pth
# Saved model to /home/stephen/grokking/grok_1764706121/17990.pth
# 18000_-15.9829_-15.3189_pen=6.627e-04
# Saved model to /home/stephen/grokking/grok_1764706121/18000.pth
# Saved model to /home/stephen/grokking/grok_1764706121/18010.pth
# Saved model to /home/stephen/grokking/grok_1764706121/18020.pth
# Saved model to /home/stephen/grokking/grok_1764706121/18030.pth
# Saved model to /home/stephen/grokking/grok_1764706121/18040.pth
# Saved model to /home/stephen/grokking/grok_1764706121/18050.pth
# Saved model to /home/stephen/grokking/grok_1764706121/18060.pth
# Saved model to /home/stephen/grokking/grok_1764706121/18070.pth
# Saved model to /home/stephen/grokking/grok_1764706121/18080.pth
# Saved model to /home/stephen/grokking/grok_1764706121/18090.pth
# 18100_-15.9829_-15.3204_pen=6.625e-04
# Saved model to /home/stephen/grokking/grok_1764706121/18100.pth
# Saved model to /home/stephen/grokking/grok_1764706121/18110.pth
# Saved model to /home/stephen/grokking/grok_1764706121/18120.pth
# Saved model to /home/stephen/grokking/grok_1764706121/18130.pth
# Saved model to /home/stephen/grokking/grok_1764706121/18140.pth
# Saved model to /home/stephen/grokking/grok_1764706121/18150.pth
# Saved model to /home/stephen/grokking/grok_1764706121/18160.pth
# Saved model to /home/stephen/grokking/grok_1764706121/18170.pth
# Saved model to /home/stephen/grokking/grok_1764706121/18180.pth
# Saved model to /home/stephen/grokking/grok_1764706121/18190.pth
# 18200_-15.9840_-15.3214_pen=6.622e-04
# Saved model to /home/stephen/grokking/grok_1764706121/18200.pth
# Saved model to /home/stephen/grokking/grok_1764706121/18210.pth
# Saved model to /home/stephen/grokking/grok_1764706121/18220.pth
# Saved model to /home/stephen/grokking/grok_1764706121/18230.pth
# Saved model to /home/stephen/grokking/grok_1764706121/18240.pth
# Saved model to /home/stephen/grokking/grok_1764706121/18250.pth
# Saved model to /home/stephen/grokking/grok_1764706121/18260.pth
# Saved model to /home/stephen/grokking/grok_1764706121/18270.pth
# Saved model to /home/stephen/grokking/grok_1764706121/18280.pth
# Saved model to /home/stephen/grokking/grok_1764706121/18290.pth
# 18300_-15.9842_-15.3226_pen=6.620e-04
# Saved model to /home/stephen/grokking/grok_1764706121/18300.pth
# Saved model to /home/stephen/grokking/grok_1764706121/18310.pth
# Saved model to /home/stephen/grokking/grok_1764706121/18320.pth
# Saved model to /home/stephen/grokking/grok_1764706121/18330.pth
# Saved model to /home/stephen/grokking/grok_1764706121/18340.pth
# Saved model to /home/stephen/grokking/grok_1764706121/18350.pth
# Saved model to /home/stephen/grokking/grok_1764706121/18360.pth
# Saved model to /home/stephen/grokking/grok_1764706121/18370.pth
# Saved model to /home/stephen/grokking/grok_1764706121/18380.pth
# Saved model to /home/stephen/grokking/grok_1764706121/18390.pth
# 18400_-15.9836_-15.3216_pen=6.618e-04
# Saved model to /home/stephen/grokking/grok_1764706121/18400.pth
# Saved model to /home/stephen/grokking/grok_1764706121/18410.pth
# Saved model to /home/stephen/grokking/grok_1764706121/18420.pth
# Saved model to /home/stephen/grokking/grok_1764706121/18430.pth
# Saved model to /home/stephen/grokking/grok_1764706121/18440.pth
# Saved model to /home/stephen/grokking/grok_1764706121/18450.pth
# Saved model to /home/stephen/grokking/grok_1764706121/18460.pth
# Saved model to /home/stephen/grokking/grok_1764706121/18470.pth
# Saved model to /home/stephen/grokking/grok_1764706121/18480.pth
# Saved model to /home/stephen/grokking/grok_1764706121/18490.pth
# 18500_-15.9871_-15.3248_pen=6.616e-04
# Saved model to /home/stephen/grokking/grok_1764706121/18500.pth
# Saved model to /home/stephen/grokking/grok_1764706121/18510.pth
# Saved model to /home/stephen/grokking/grok_1764706121/18520.pth
# Saved model to /home/stephen/grokking/grok_1764706121/18530.pth
# Saved model to /home/stephen/grokking/grok_1764706121/18540.pth
# Saved model to /home/stephen/grokking/grok_1764706121/18550.pth
# Saved model to /home/stephen/grokking/grok_1764706121/18560.pth
# Saved model to /home/stephen/grokking/grok_1764706121/18570.pth
# Saved model to /home/stephen/grokking/grok_1764706121/18580.pth
# Saved model to /home/stephen/grokking/grok_1764706121/18590.pth
# 18600_-15.9864_-15.3250_pen=6.613e-04
# Saved model to /home/stephen/grokking/grok_1764706121/18600.pth
# Saved model to /home/stephen/grokking/grok_1764706121/18610.pth
# Saved model to /home/stephen/grokking/grok_1764706121/18620.pth
# Saved model to /home/stephen/grokking/grok_1764706121/18630.pth
# Saved model to /home/stephen/grokking/grok_1764706121/18640.pth
# Saved model to /home/stephen/grokking/grok_1764706121/18650.pth
# Saved model to /home/stephen/grokking/grok_1764706121/18660.pth
# Saved model to /home/stephen/grokking/grok_1764706121/18670.pth
# Saved model to /home/stephen/grokking/grok_1764706121/18680.pth
# Saved model to /home/stephen/grokking/grok_1764706121/18690.pth
# 18700_-15.9868_-15.3258_pen=6.611e-04
# Saved model to /home/stephen/grokking/grok_1764706121/18700.pth
# Saved model to /home/stephen/grokking/grok_1764706121/18710.pth
# Saved model to /home/stephen/grokking/grok_1764706121/18720.pth
# Saved model to /home/stephen/grokking/grok_1764706121/18730.pth
# Saved model to /home/stephen/grokking/grok_1764706121/18740.pth
# Saved model to /home/stephen/grokking/grok_1764706121/18750.pth
# Saved model to /home/stephen/grokking/grok_1764706121/18760.pth
# Saved model to /home/stephen/grokking/grok_1764706121/18770.pth
# Saved model to /home/stephen/grokking/grok_1764706121/18780.pth
# Saved model to /home/stephen/grokking/grok_1764706121/18790.pth
# 18800_-15.9877_-15.3275_pen=6.609e-04
# Saved model to /home/stephen/grokking/grok_1764706121/18800.pth
# Saved model to /home/stephen/grokking/grok_1764706121/18810.pth
# Saved model to /home/stephen/grokking/grok_1764706121/18820.pth
# Saved model to /home/stephen/grokking/grok_1764706121/18830.pth
# Saved model to /home/stephen/grokking/grok_1764706121/18840.pth
# Saved model to /home/stephen/grokking/grok_1764706121/18850.pth
# Saved model to /home/stephen/grokking/grok_1764706121/18860.pth
# Saved model to /home/stephen/grokking/grok_1764706121/18870.pth
# Saved model to /home/stephen/grokking/grok_1764706121/18880.pth
# Saved model to /home/stephen/grokking/grok_1764706121/18890.pth
# 18900_-15.9884_-15.3297_pen=6.606e-04
# Saved model to /home/stephen/grokking/grok_1764706121/18900.pth
# Saved model to /home/stephen/grokking/grok_1764706121/18910.pth
# Saved model to /home/stephen/grokking/grok_1764706121/18920.pth
# Saved model to /home/stephen/grokking/grok_1764706121/18930.pth
# Saved model to /home/stephen/grokking/grok_1764706121/18940.pth
# Saved model to /home/stephen/grokking/grok_1764706121/18950.pth
# Saved model to /home/stephen/grokking/grok_1764706121/18960.pth
# Saved model to /home/stephen/grokking/grok_1764706121/18970.pth
# Saved model to /home/stephen/grokking/grok_1764706121/18980.pth
# Saved model to /home/stephen/grokking/grok_1764706121/18990.pth
# 19000_-15.9882_-15.3312_pen=6.603e-04
# Saved model to /home/stephen/grokking/grok_1764706121/19000.pth
# Saved model to /home/stephen/grokking/grok_1764706121/19010.pth
# Saved model to /home/stephen/grokking/grok_1764706121/19020.pth
# Saved model to /home/stephen/grokking/grok_1764706121/19030.pth
# Saved model to /home/stephen/grokking/grok_1764706121/19040.pth
# Saved model to /home/stephen/grokking/grok_1764706121/19050.pth
# Saved model to /home/stephen/grokking/grok_1764706121/19060.pth
# Saved model to /home/stephen/grokking/grok_1764706121/19070.pth
# Saved model to /home/stephen/grokking/grok_1764706121/19080.pth
# Saved model to /home/stephen/grokking/grok_1764706121/19090.pth
# 19100_-15.9895_-15.3336_pen=6.601e-04
# Saved model to /home/stephen/grokking/grok_1764706121/19100.pth
# Saved model to /home/stephen/grokking/grok_1764706121/19110.pth
# Saved model to /home/stephen/grokking/grok_1764706121/19120.pth
# Saved model to /home/stephen/grokking/grok_1764706121/19130.pth
# Saved model to /home/stephen/grokking/grok_1764706121/19140.pth
# Saved model to /home/stephen/grokking/grok_1764706121/19150.pth
# Saved model to /home/stephen/grokking/grok_1764706121/19160.pth
# Saved model to /home/stephen/grokking/grok_1764706121/19170.pth
# Saved model to /home/stephen/grokking/grok_1764706121/19180.pth
# Saved model to /home/stephen/grokking/grok_1764706121/19190.pth
# 19200_-15.9891_-15.3342_pen=6.599e-04
# Saved model to /home/stephen/grokking/grok_1764706121/19200.pth
# Saved model to /home/stephen/grokking/grok_1764706121/19210.pth
# Saved model to /home/stephen/grokking/grok_1764706121/19220.pth
# Saved model to /home/stephen/grokking/grok_1764706121/19230.pth
# Saved model to /home/stephen/grokking/grok_1764706121/19240.pth
# Saved model to /home/stephen/grokking/grok_1764706121/19250.pth
# Saved model to /home/stephen/grokking/grok_1764706121/19260.pth
# Saved model to /home/stephen/grokking/grok_1764706121/19270.pth
# Saved model to /home/stephen/grokking/grok_1764706121/19280.pth
# Saved model to /home/stephen/grokking/grok_1764706121/19290.pth
# 19300_-15.9909_-15.3370_pen=6.598e-04
# Saved model to /home/stephen/grokking/grok_1764706121/19300.pth
# Saved model to /home/stephen/grokking/grok_1764706121/19310.pth
# Saved model to /home/stephen/grokking/grok_1764706121/19320.pth
# Saved model to /home/stephen/grokking/grok_1764706121/19330.pth
# Saved model to /home/stephen/grokking/grok_1764706121/19340.pth
# Saved model to /home/stephen/grokking/grok_1764706121/19350.pth
# Saved model to /home/stephen/grokking/grok_1764706121/19360.pth
# Saved model to /home/stephen/grokking/grok_1764706121/19370.pth
# Saved model to /home/stephen/grokking/grok_1764706121/19380.pth
# Saved model to /home/stephen/grokking/grok_1764706121/19390.pth
# 19400_-15.9896_-15.3370_pen=6.595e-04
# Saved model to /home/stephen/grokking/grok_1764706121/19400.pth
# Saved model to /home/stephen/grokking/grok_1764706121/19410.pth
# Saved model to /home/stephen/grokking/grok_1764706121/19420.pth
# Saved model to /home/stephen/grokking/grok_1764706121/19430.pth
# Saved model to /home/stephen/grokking/grok_1764706121/19440.pth
# Saved model to /home/stephen/grokking/grok_1764706121/19450.pth
# Saved model to /home/stephen/grokking/grok_1764706121/19460.pth
# Saved model to /home/stephen/grokking/grok_1764706121/19470.pth
# Saved model to /home/stephen/grokking/grok_1764706121/19480.pth
# Saved model to /home/stephen/grokking/grok_1764706121/19490.pth
# 19500_-15.9915_-15.3398_pen=6.594e-04
# Saved model to /home/stephen/grokking/grok_1764706121/19500.pth
# Saved model to /home/stephen/grokking/grok_1764706121/19510.pth
# Saved model to /home/stephen/grokking/grok_1764706121/19520.pth
# Saved model to /home/stephen/grokking/grok_1764706121/19530.pth
# Saved model to /home/stephen/grokking/grok_1764706121/19540.pth
# Saved model to /home/stephen/grokking/grok_1764706121/19550.pth
# Saved model to /home/stephen/grokking/grok_1764706121/19560.pth
# Saved model to /home/stephen/grokking/grok_1764706121/19570.pth
# Saved model to /home/stephen/grokking/grok_1764706121/19580.pth
# Saved model to /home/stephen/grokking/grok_1764706121/19590.pth
# 19600_-15.9905_-15.3398_pen=6.592e-04
# Saved model to /home/stephen/grokking/grok_1764706121/19600.pth
# Saved model to /home/stephen/grokking/grok_1764706121/19610.pth
# Saved model to /home/stephen/grokking/grok_1764706121/19620.pth
# Saved model to /home/stephen/grokking/grok_1764706121/19630.pth
# Saved model to /home/stephen/grokking/grok_1764706121/19640.pth
# Saved model to /home/stephen/grokking/grok_1764706121/19650.pth
# Saved model to /home/stephen/grokking/grok_1764706121/19660.pth
# Saved model to /home/stephen/grokking/grok_1764706121/19670.pth
# Saved model to /home/stephen/grokking/grok_1764706121/19680.pth
# Saved model to /home/stephen/grokking/grok_1764706121/19690.pth
# 19700_-15.9913_-15.3412_pen=6.590e-04
# Saved model to /home/stephen/grokking/grok_1764706121/19700.pth
# Saved model to /home/stephen/grokking/grok_1764706121/19710.pth
# Saved model to /home/stephen/grokking/grok_1764706121/19720.pth
# Saved model to /home/stephen/grokking/grok_1764706121/19730.pth
# Saved model to /home/stephen/grokking/grok_1764706121/19740.pth
# Saved model to /home/stephen/grokking/grok_1764706121/19750.pth
# Saved model to /home/stephen/grokking/grok_1764706121/19760.pth
# Saved model to /home/stephen/grokking/grok_1764706121/19770.pth
# Saved model to /home/stephen/grokking/grok_1764706121/19780.pth
# Saved model to /home/stephen/grokking/grok_1764706121/19790.pth
# 19800_-15.9917_-15.3419_pen=6.589e-04
# Saved model to /home/stephen/grokking/grok_1764706121/19800.pth
# Saved model to /home/stephen/grokking/grok_1764706121/19810.pth
# Saved model to /home/stephen/grokking/grok_1764706121/19820.pth
# Saved model to /home/stephen/grokking/grok_1764706121/19830.pth
# Saved model to /home/stephen/grokking/grok_1764706121/19840.pth
# Saved model to /home/stephen/grokking/grok_1764706121/19850.pth
# Saved model to /home/stephen/grokking/grok_1764706121/19860.pth
# Saved model to /home/stephen/grokking/grok_1764706121/19870.pth
# Saved model to /home/stephen/grokking/grok_1764706121/19880.pth
# Saved model to /home/stephen/grokking/grok_1764706121/19890.pth
# 19900_-15.9908_-15.3422_pen=6.587e-04
# Saved model to /home/stephen/grokking/grok_1764706121/19900.pth
# Saved model to /home/stephen/grokking/grok_1764706121/19910.pth
# Saved model to /home/stephen/grokking/grok_1764706121/19920.pth
# Saved model to /home/stephen/grokking/grok_1764706121/19930.pth
# Saved model to /home/stephen/grokking/grok_1764706121/19940.pth
# Saved model to /home/stephen/grokking/grok_1764706121/19950.pth
# Saved model to /home/stephen/grokking/grok_1764706121/19960.pth
# Saved model to /home/stephen/grokking/grok_1764706121/19970.pth
# Saved model to /home/stephen/grokking/grok_1764706121/19980.pth
# Saved model to /home/stephen/grokking/grok_1764706121/19990.pth
# Saved model to /home/stephen/grokking/grok_1764706121/final.pth

# %% [markdown]
# ## Viz Results

# %%
CHILL_BROWN='#948979'
YELLOW='#ffd35a'
YELLOW_FADE='#7f6a2d'
BLUE='#65c8d0'
GREEN='#6e9671' 
CHILL_GREEN='#6c946f'
CHILL_BLUE='#3d5c6f'
FRESH_TAN='#dfd0b9'
CYAN='#00FFFF'

# %%
plt.plot(train_accs)
plt.plot(test_accs)

# %%
plt.clf()        
fig=plt.figure(0,(14,6), facecolor='k') 
ax=fig.add_subplot(111, facecolor='k')

plt.plot(train_accs[:500], c=BLUE, linewidth=2.5, alpha=0.95) #'#dfd0b9')
plt.plot(test_accs[:500], c=YELLOW, linewidth=2.5, alpha=0.95) #'#dfd0b9')
plt.tick_params(axis='x', colors='#948979', labelsize=16)  # Add labelsize here
plt.tick_params(axis='y', colors='#948979', labelsize=16)  # Add labelsize here

plt.gca().spines['top'].set_color('#948979')
plt.gca().spines['bottom'].set_color('#948979')
plt.gca().spines['left'].set_color('#948979')
plt.gca().spines['right'].set_color('#948979')
plt.subplots_adjust(bottom=0.2)  # Add fixed bottom margin
# plt.xlim([-10, len(to_plot)+10])
plt.ylim([0,1.05]) #Bad idea to fix or is it fine?
plt.grid(True, color='#948979', alpha=0.3)

# %%
plt.clf()        
fig=plt.figure(0,(14,6), facecolor='k') 
ax=fig.add_subplot(111, facecolor='k')

plt.plot(train_accs, c=BLUE, linewidth=2.5, alpha=0.95) #'#dfd0b9')
plt.plot(test_accs, c=YELLOW, linewidth=2.5, alpha=0.95) #'#dfd0b9')
plt.tick_params(axis='x', colors='#948979', labelsize=16)  # Add labelsize here
plt.tick_params(axis='y', colors='#948979', labelsize=16)  # Add labelsize here

plt.gca().spines['top'].set_color('#948979')
plt.gca().spines['bottom'].set_color('#948979')
plt.gca().spines['left'].set_color('#948979')
plt.gca().spines['right'].set_color('#948979')
plt.subplots_adjust(bottom=0.2)  # Add fixed bottom margin
# plt.xlim([-10, len(to_plot)+10])
plt.ylim([0,1.05]) #Bad idea to fix or is it fine?
plt.grid(True, color='#948979', alpha=0.3)

# %%
from tqdm import tqdm

# %%
all_data = torch.tensor([(i, j, p) for i in range(p) for j in range(p)]).to('cuda')
labels = torch.tensor([fn(i, j) for i, j, _ in all_data]).to('cuda')
cache = {}
model.remove_all_hooks()
model.cache_all(cache)
# Final position only
original_logits = model(all_data)[:, -1]
# Remove equals sign from output logits
original_logits = original_logits[:, :-1]
original_loss = cross_entropy_high_precision(original_logits, labels)
print(f"Original loss: {original_loss.item()}")

#Ok let's try pre -> the og. 
mr = einops.rearrange(cache['blocks.0.mlp.hook_pre'], "(x y) ... -> x y ...", x=p).detach().cpu().numpy()
# Out:
# Original loss: 1.9101361238572092e-07

# %%
# ---- Helper for classifying term type ----
def classify_term_type(kx, ky, is_dc):
    if is_dc:
        return "dc"
    if kx != 0 and ky == 0:
        return "row"
    if kx == 0 and ky != 0:
        return "col"
    if kx == 0 and ky == 0:
        return "dc"
    return "cross"  # kx != 0 and ky != 0


# ---- Loop over neurons and build DataFrame ----
all_rows = []

for neuron_idx in tqdm(range(512)):
    # 113 x 113 slice for this neuron
    m_slice = mr[:, :, 2, neuron_idx]

    components, Nx, Ny = compute_frequency_components(m_slice)
    terms = components_to_terms(components, Nx, Ny, num_freqs=4, include_dc=True)

    # Max amplitude (non-DC) for this neuron, for "strong" comparison later
    non_dc_terms = [t for t in terms if not t.get("is_dc", False)]
    max_amp = max((t["amplitude"] for t in non_dc_terms), default=0.0)

    for rank, t in enumerate(terms):
        is_dc = t.get("is_dc", False)
        kx = t["kx"]
        ky = t["ky"]
        amp = t["amplitude"]
        phase = t["phase"]

        term_type = classify_term_type(kx, ky, is_dc)

        all_rows.append({
            "neuron_idx": neuron_idx,
            "term_rank": rank,          # 0 = DC if include_dc=True
            "is_dc": is_dc,
            "term_type": term_type,     # "dc", "row", "col", "cross"
            "kx": kx,
            "ky": ky,
            "amplitude": amp,
            "phase": phase,
            "max_amp_neuron": max_amp,  # per neuron
        })

df = pd.DataFrame(all_rows)
df['relative_amplitude']=df['amplitude']/df['max_amp_neuron']
# Out:
# 100%|██████████████████████| 512/512 [00:20<00:00, 24.50it/s]

# %%
df['kx'].value_counts()
# Out:
# kx
# 0     1141
# 23     741
# 4      382
# 3       96
# 6       96
# 46      68
# 8       36
# Name: count, dtype: int64

# %%
dff=df[df['kx']==4]
dff=dff[dff['ky']==4]

# %%
dff.sort_values(by='relative_amplitude', ascending=False)[:15]
# Out:
#       neuron_idx  term_rank  is_dc term_type  kx  ky  amplitude     phase  \
# 2546         509          1  False     cross   4   4   0.390023  0.233352
# 531          106          1  False     cross   4   4   0.221226 -0.067248
# 181           36          1  False     cross   4   4   0.184459 -0.069385
# 741          148          1  False     cross   4   4   0.279705  0.418475
# 546          109          1  False     cross   4   4   0.320408  0.399475
# 2076         415          1  False     cross   4   4   0.315025 -1.310774
# 1291         258          1  False     cross   4   4   0.469855  0.345498
# 31             6          1  False     cross   4   4   0.206995  0.407779
# 2141         428          1  False     cross   4   4   0.179768  0.408920
# 727          145          2  False     cross   4   4   0.229648  0.213263
# 1367         273          2  False     cross   4   4   0.158909  0.754474
# 912          182          2  False     cross   4   4   0.165645 -0.219110
# 2368         473          3  False     cross   4   4   0.134485  0.310770
# 2343         468          3  False     cross   4   4   0.137197  0.074013
# 573          114          3  False     cross   4   4   0.139014 -0.016517
#
#       max_amp_neuron  relative_amplitude
# 2546        0.390023            1.000000
# 531         0.221226            1.000000
# 181         0.184459            1.000000
# 741         0.279705            1.000000
# 546         0.320408            1.000000
# 2076        0.315025            1.000000
# 1291        0.469855            1.000000
# 31          0.206995            1.000000
# 2141        0.179768            1.000000
# 727         0.229718            0.999695
# 1367        0.164888            0.963740
# 912         0.177001            0.935843
# 2368        0.153748            0.874714
# 2343        0.169591            0.808990
# 573         0.173505            0.801211

# %%
neuron_idx=509
FT = np.fft.fft2(mr[:,:,2,neuron_idx])

components, Nx, Ny = compute_frequency_components(mr[:,:,2,neuron_idx])
terms = components_to_terms(components, Nx, Ny, num_freqs=4, include_dc=True)
code_str = generate_python_reconstructor(terms, Nx, Ny,
                                         func_name="approx_M",
                                         decimals=3)
print(code_str)
# Out:
# def approx_M(i, j):
#     val = 4.731
#     val += 0.39 * np.cos(2*np.pi*((4*i)/113) + 0.233) * np.cos(2*np.pi*((4*j)/113) + 0.233)
#     val += 0.39 * np.cos(2*np.pi*((4*i)/113) + -0.0) * np.cos(2*np.pi*((109*j)/113) + -0.0)
#     val += 0.245 * np.cos(2*np.pi*((23*i)/113) + -1.376) * np.cos(2*np.pi*((23*j)/113) + -1.376)
#     val += 0.191 * np.cos(2*np.pi*((8*i)/113) + -2.912)
#     return val

# %%
def approx_M(i, j):
    val = 4.731
    val += 0.39 * np.cos(2*np.pi*((4*i)/113) + 0.233) * np.cos(2*np.pi*((4*j)/113) + 0.233)
    val += 0.39 * np.cos(2*np.pi*((4*i)/113) + -0.0) * np.cos(2*np.pi*((109*j)/113) + -0.0)
    val += 0.245 * np.cos(2*np.pi*((23*i)/113) + -1.376) * np.cos(2*np.pi*((23*j)/113) + -1.376)
    val += 0.191 * np.cos(2*np.pi*((8*i)/113) + -2.912)
    return val

# %%
m_approx=np.zeros((p,p))
for i in range(p):
    for j in range(p):
        m_approx[i,j]=approx_M(i,j)

fig=plt.figure(0, (12, 6))
fig.add_subplot(1,3,1); plt.imshow(mr[:,:,2,neuron_idx]); plt.axis('off')
fig.add_subplot(1,3,2); plt.imshow(np.abs(FT));  plt.axis('off')
fig.add_subplot(1,3,3); plt.imshow(m_approx); plt.axis('off');

# %%
run_name
# Out:
# 'grok_1764706121'
