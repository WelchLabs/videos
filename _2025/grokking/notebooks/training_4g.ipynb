# %% [markdown]
# ## Training 4a

# %%
seed=852778
frac_train=0.25 
weight_decay = 1.0 #@param
freq_penalty_weight = 1e-3

# %%
# Import stuff
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import numpy as np
import einops
import tqdm.notebook as tqdm

import random
import time

# from google.colab import drive
from pathlib import Path
import pickle
import os

import matplotlib.pyplot as plt
# %matplotlib inline
import plotly.express as px
import plotly.io as pio
pio.renderers.default = "colab"
import plotly.graph_objects as go

from torch.utils.data import DataLoader

from functools import *
import pandas as pd
import gc

# import comet_ml
import itertools

# %% [markdown]
# ## Support Functions

# %%
# A helper class to get access to intermediate activations (inspired by Garcon)
# It's a dummy module that is the identity function by default
# I can wrap any intermediate activation in a HookPoint and get a convenient 
# way to add PyTorch hooks
class HookPoint(nn.Module):
    def __init__(self):
        super().__init__()
        self.fwd_hooks = []
        self.bwd_hooks = []
    
    def give_name(self, name):
        # Called by the model at initialisation
        self.name = name
    
    def add_hook(self, hook, dir='fwd'):
        # Hook format is fn(activation, hook_name)
        # Change it into PyTorch hook format (this includes input and output, 
        # which are the same for a HookPoint)
        def full_hook(module, module_input, module_output):
            return hook(module_output, name=self.name)
        if dir=='fwd':
            handle = self.register_forward_hook(full_hook)
            self.fwd_hooks.append(handle)
        elif dir=='bwd':
            handle = self.register_backward_hook(full_hook)
            self.bwd_hooks.append(handle)
        else:
            raise ValueError(f"Invalid direction {dir}")
    
    def remove_hooks(self, dir='fwd'):
        if (dir=='fwd') or (dir=='both'):
            for hook in self.fwd_hooks:
                hook.remove()
            self.fwd_hooks = []
        if (dir=='bwd') or (dir=='both'):
            for hook in self.bwd_hooks:
                hook.remove()
            self.bwd_hooks = []
        if dir not in ['fwd', 'bwd', 'both']:
            raise ValueError(f"Invalid direction {dir}")
    
    def forward(self, x):
        return x

# %%
# Define network architecture
# I defined my own transformer from scratch so I'd fully understand each component 
# - I expect this wasn't necessary or particularly important, and a bunch of this 
# replicates existing PyTorch functionality

# Embed & Unembed
class Embed(nn.Module):
    def __init__(self, d_vocab, d_model):
        super().__init__()
        self.W_E = nn.Parameter(torch.randn(d_model, d_vocab)/np.sqrt(d_model))
    
    def forward(self, x):
        return torch.einsum('dbp -> bpd', self.W_E[:, x])

class Unembed(nn.Module):
    def __init__(self, d_vocab, d_model):
        super().__init__()
        self.W_U = nn.Parameter(torch.randn(d_model, d_vocab)/np.sqrt(d_vocab))
    
    def forward(self, x):
        return (x @ self.W_U)

# Positional Embeddings
class PosEmbed(nn.Module):
    def __init__(self, max_ctx, d_model):
        super().__init__()
        self.W_pos = nn.Parameter(torch.randn(max_ctx, d_model)/np.sqrt(d_model))
    
    def forward(self, x):
        return x+self.W_pos[:x.shape[-2]]

# LayerNorm
class LayerNorm(nn.Module):
    def __init__(self, d_model, epsilon = 1e-4, model=[None]):
        super().__init__()
        self.model = model
        self.w_ln = nn.Parameter(torch.ones(d_model))
        self.b_ln = nn.Parameter(torch.zeros(d_model))
        self.epsilon = epsilon
    
    def forward(self, x):
        if self.model[0].use_ln:
            x = x - x.mean(axis=-1)[..., None]
            x = x / (x.std(axis=-1)[..., None] + self.epsilon)
            x = x * self.w_ln
            x = x + self.b_ln
            return x
        else:
            return x

# Attention
class Attention(nn.Module):
    def __init__(self, d_model, num_heads, d_head, n_ctx, model):
        super().__init__()
        self.model = model
        self.W_K = nn.Parameter(torch.randn(num_heads, d_head, d_model)/np.sqrt(d_model))
        self.W_Q = nn.Parameter(torch.randn(num_heads, d_head, d_model)/np.sqrt(d_model))
        self.W_V = nn.Parameter(torch.randn(num_heads, d_head, d_model)/np.sqrt(d_model))
        self.W_O = nn.Parameter(torch.randn(d_model, d_head * num_heads)/np.sqrt(d_model))
        self.register_buffer('mask', torch.tril(torch.ones((n_ctx, n_ctx))))
        self.d_head = d_head
        self.hook_k = HookPoint()
        self.hook_q = HookPoint()
        self.hook_v = HookPoint()
        self.hook_z = HookPoint()
        self.hook_attn = HookPoint()
        self.hook_attn_pre = HookPoint()

    def forward(self, x):
        k = self.hook_k(torch.einsum('ihd,bpd->biph', self.W_K, x))
        q = self.hook_q(torch.einsum('ihd,bpd->biph', self.W_Q, x))
        v = self.hook_v(torch.einsum('ihd,bpd->biph', self.W_V, x))
        attn_scores_pre = torch.einsum('biph,biqh->biqp', k, q)
        attn_scores_masked = torch.tril(attn_scores_pre) - 1e10 * (1 - self.mask[:x.shape[-2], :x.shape[-2]])
        attn_matrix = self.hook_attn(F.softmax(self.hook_attn_pre(attn_scores_masked/np.sqrt(self.d_head)), dim=-1))
        z = self.hook_z(torch.einsum('biph,biqp->biqh', v, attn_matrix))
        z_flat = einops.rearrange(z, 'b i q h -> b q (i h)')
        out = torch.einsum('df,bqf->bqd', self.W_O, z_flat)
        return out

# MLP Layers
class MLP(nn.Module):
    def __init__(self, d_model, d_mlp, act_type, model):
        super().__init__()
        self.model = model
        self.W_in = nn.Parameter(torch.randn(d_mlp, d_model)/np.sqrt(d_model))
        self.b_in = nn.Parameter(torch.zeros(d_mlp))
        self.W_out = nn.Parameter(torch.randn(d_model, d_mlp)/np.sqrt(d_model))
        self.b_out = nn.Parameter(torch.zeros(d_model))
        self.act_type = act_type
        # self.ln = LayerNorm(d_mlp, model=self.model)
        self.hook_pre = HookPoint()
        self.hook_post = HookPoint()
        assert act_type in ['ReLU', 'GeLU']
        
    def forward(self, x):
        x = self.hook_pre(torch.einsum('md,bpd->bpm', self.W_in, x) + self.b_in)
        if self.act_type=='ReLU':
            x = F.relu(x)
        elif self.act_type=='GeLU':
            x = F.gelu(x)
        x = self.hook_post(x)
        x = torch.einsum('dm,bpm->bpd', self.W_out, x) + self.b_out
        return x

# Transformer Block
class TransformerBlock(nn.Module):
    def __init__(self, d_model, d_mlp, d_head, num_heads, n_ctx, act_type, model):
        super().__init__()
        self.model = model
        # self.ln1 = LayerNorm(d_model, model=self.model)
        self.attn = Attention(d_model, num_heads, d_head, n_ctx, model=self.model)
        # self.ln2 = LayerNorm(d_model, model=self.model)
        self.mlp = MLP(d_model, d_mlp, act_type, model=self.model)
        self.hook_attn_out = HookPoint()
        self.hook_mlp_out = HookPoint()
        self.hook_resid_pre = HookPoint()
        self.hook_resid_mid = HookPoint()
        self.hook_resid_post = HookPoint()
    
    def forward(self, x):
        x = self.hook_resid_mid(x + self.hook_attn_out(self.attn((self.hook_resid_pre(x)))))
        x = self.hook_resid_post(x + self.hook_mlp_out(self.mlp((x))))
        return x

# Full transformer
class Transformer(nn.Module):
    def __init__(self, num_layers, d_vocab, d_model, d_mlp, d_head, num_heads, n_ctx, act_type, use_cache=False, use_ln=True):
        super().__init__()
        self.cache = {}
        self.use_cache = use_cache

        self.embed = Embed(d_vocab, d_model)
        self.pos_embed = PosEmbed(n_ctx, d_model)
        self.blocks = nn.ModuleList([TransformerBlock(d_model, d_mlp, d_head, num_heads, n_ctx, act_type, model=[self]) for i in range(num_layers)])
        # self.ln = LayerNorm(d_model, model=[self])
        self.unembed = Unembed(d_vocab, d_model)
        self.use_ln = use_ln

        for name, module in self.named_modules():
            if type(module)==HookPoint:
                module.give_name(name)
    
    def forward(self, x):
        x = self.embed(x)
        x = self.pos_embed(x)
        for block in self.blocks:
            x = block(x)
        # x = self.ln(x)
        x = self.unembed(x)
        return x

    def set_use_cache(self, use_cache):
        self.use_cache = use_cache
    
    def hook_points(self):
        return [module for name, module in self.named_modules() if 'hook' in name]

    def remove_all_hooks(self):
        for hp in self.hook_points():
            hp.remove_hooks('fwd')
            hp.remove_hooks('bwd')
    
    def cache_all(self, cache, incl_bwd=False):
        # Caches all activations wrapped in a HookPoint
        def save_hook(tensor, name):
            cache[name] = tensor.detach()
        def save_hook_back(tensor, name):
            cache[name+'_grad'] = tensor[0].detach()
        for hp in self.hook_points():
            hp.add_hook(save_hook, 'fwd')
            if incl_bwd:
                hp.add_hook(save_hook_back, 'bwd')

# %%
# Helper functions
def cuda_memory():
    print(torch.cuda.memory_allocated()/1e9)

def cross_entropy_high_precision(logits, labels):
    # Shapes: batch x vocab, batch
    # Cast logits to float64 because log_softmax has a float32 underflow on overly 
    # confident data and can only return multiples of 1.2e-7 (the smallest float x
    # such that 1+x is different from 1 in float32). This leads to loss spikes 
    # and dodgy gradients
    logprobs = F.log_softmax(logits.to(torch.float64), dim=-1)
    prediction_logprobs = torch.gather(logprobs, index=labels[:, None], dim=-1)
    loss = -torch.mean(prediction_logprobs)
    return loss

def full_loss(model, data):
    # Take the final position only
    logits = model(data)[:, -1]
    labels = torch.tensor([fn(i, j) for i, j, _ in data]).to('cuda')
    return cross_entropy_high_precision(logits, labels)

def test_logits(logits, bias_correction=False, original_logits=None, mode='all'):
    # Calculates cross entropy loss of logits representing a batch of all p^2 
    # possible inputs
    # Batch dimension is assumed to be first
    if logits.shape[1]==p*p:
        logits = logits.T
    if logits.shape==torch.Size([p*p, p+1]):
        logits = logits[:, :-1]
    logits = logits.reshape(p*p, p)
    if bias_correction:
        # Applies bias correction - we correct for any missing bias terms, 
        # independent of the input, by centering the new logits along the batch 
        # dimension, and then adding the average original logits across all inputs
        logits = einops.reduce(original_logits - logits, 'batch ... -> ...', 'mean') + logits
    if mode=='train':
        return cross_entropy_high_precision(logits[is_train], labels[is_train])
    elif mode=='test':
        return cross_entropy_high_precision(logits[is_test], labels[is_test])
    elif mode=='all':
        return cross_entropy_high_precision(logits, labels)

def unflatten_first(tensor):
    if tensor.shape[0]==p*p:
        return einops.rearrange(tensor, '(x y) ... -> x y ...', x=p, y=p)
    else: 
        return tensor
def cos(x, y):
    return (x.dot(y))/x.norm()/y.norm()
def mod_div(a, b):
    return (a*pow(b, p-2, p))%p
def normalize(tensor, axis=0):
    return tensor/(tensor).pow(2).sum(keepdim=True, axis=axis).sqrt()
def extract_freq_2d(tensor, freq):
    # Takes in a pxpx... or batch x ... tensor, returns a 3x3x... tensor of the 
    # Linear and quadratic terms of frequency freq
    tensor = unflatten_first(tensor)
    # Extracts the linear and quadratic terms corresponding to frequency freq
    index_1d = [0, 2*freq-1, 2*freq]
    # Some dumb manipulation to use fancy array indexing rules
    # Gets the rows and columns in index_1d
    return tensor[[[i]*3 for i in index_1d], [index_1d]*3]
def get_cov(tensor, norm=True):
    # Calculate covariance matrix
    if norm:
        tensor = normalize(tensor, axis=1)
    return tensor @ tensor.T
def is_close(a, b):
    return ((a-b).pow(2).sum()/(a.pow(2).sum().sqrt())/(b.pow(2).sum().sqrt())).item()

# %%
def compute_frequency_components(m):
    """
    Compute canonical frequency components of a real 2D signal m using fft2.

    Returns:
        components: list of dicts with keys:
            - 'kx': frequency index in x (rows)
            - 'ky': frequency index in y (cols)
            - 'coeff': complex FFT coefficient at (kx, ky)
        Nx, Ny: dimensions of the input
    """
    m = np.asarray(m)
    Nx, Ny = m.shape
    F = np.fft.fft2(m)

    components = []
    seen = set()

    for kx in range(Nx):
        for ky in range(Ny):
            # Conjugate partner indices for real-valued input
            kx_conj = (-kx) % Nx
            ky_conj = (-ky) % Ny

            pair = tuple(sorted([(kx, ky), (kx_conj, ky_conj)]))
            if pair in seen:
                continue
            seen.add(pair)

            # Always store the "smaller" one in lexicographic order
            kx_rep, ky_rep = pair[0]
            coeff = F[kx_rep, ky_rep]
            components.append({
                "kx": kx_rep,
                "ky": ky_rep,
                "coeff": coeff
            })

    return components, Nx, Ny


def components_to_terms(components, Nx, Ny, num_freqs, include_dc=True):
    """
    Convert FFT components into real cosine terms with amplitude & phase.

    Args:
        components: output from compute_frequency_components
        Nx, Ny: grid size
        num_freqs: number of *non-DC* frequencies to keep
        include_dc: whether to include the constant (DC) term

    Returns:
        terms: list of dicts with keys:
            - 'kx', 'ky'
            - 'amplitude'  (real, >= 0)
            - 'phase'      (in radians)
            - 'is_dc'      (bool, True only for the constant term)
    """
    terms = []
    dc_term = None

    for c in components:
        kx = c["kx"]
        ky = c["ky"]
        coeff = c["coeff"]

        # DC component (constant offset)
        if kx == 0 and ky == 0:
            dc_value = coeff.real / (Nx * Ny)
            dc_term = {
                "kx": 0,
                "ky": 0,
                "amplitude": dc_value,  # directly the constant offset
                "phase": 0.0,
                "is_dc": True,
            }
        else:
            # For real signals, combine (k, l) and (-k, -l) into:
            #   2*|F|/(Nx*Ny) * cos(2π(kx i/Nx + ky j/Ny) + phase)
            amp = 2.0 * np.abs(coeff) / (Nx * Ny)
            phase = np.angle(coeff)
            terms.append({
                "kx": kx,
                "ky": ky,
                "amplitude": amp,
                "phase": phase,
                "is_dc": False,
            })

    # Sort non-DC terms by amplitude (largest first)
    terms.sort(key=lambda t: t["amplitude"], reverse=True)

    # Keep only the top num_freqs
    terms = terms[:num_freqs]

    # Optionally prepend DC term
    if include_dc and dc_term is not None:
        terms = [dc_term] + terms

    return terms

def generate_python_reconstructor(terms, Nx, Ny, func_name="recon_func", decimals=4):
    """
    Generate a Python function as a string that reconstructs the signal
    using explicit 1D and product-of-cosine terms from a sparse Fourier representation.

    Types of terms:
      - DC term (constant)
      - Row-only:   A * cos(2π * (kx*i/Nx) + φ)
      - Col-only:   B * cos(2π * (ky*j/Ny) + φ)
      - Product:    C * cos(2π * (kx*i/Nx) + φ) * cos(2π * (ky*j/Ny) + φ)

    You must have `import numpy as np` in the scope where you paste/run this.
    """
    lines = []
    lines.append(f"def {func_name}(i, j):")

    if not terms:
        lines.append("    return 0.0")
        return "\n".join(lines)

    # Separate DC from others
    dc_terms = [t for t in terms if t.get("is_dc", False)]
    non_dc_terms = [t for t in terms if not t.get("is_dc", False)]

    if dc_terms:
        dc_val = round(dc_terms[0]["amplitude"], decimals)
        lines.append(f"    val = {dc_val}")
    else:
        lines.append("    val = 0.0")

    for t in non_dc_terms:
        kx, ky = t["kx"], t["ky"]
        A = round(t["amplitude"], decimals)
        phi = round(t["phase"], decimals)

        if A == 0:
            continue

        if kx != 0 and ky == 0:
            # Row-only cosine
            line = (
                f"    val += {A} * np.cos(2*np.pi*(({kx}*i)/{Nx}) + {phi})"
            )
        elif kx == 0 and ky != 0:
            # Column-only cosine
            line = (
                f"    val += {A} * np.cos(2*np.pi*(({ky}*j)/{Ny}) + {phi})"
            )
        else:
            # Product-of-cosines term (your desired "third" type)
            line = (
                f"    val += {A} * np.cos(2*np.pi*(({kx}*i)/{Nx}) + {phi})"
                f" * np.cos(2*np.pi*(({ky}*j)/{Ny}) + {phi})"
            )

        lines.append(line)

    lines.append("    return val")

    return "\n".join(lines)

# %%
def set_seed(seed):
        torch.manual_seed(seed)
        torch.cuda.manual_seed_all(seed) # For all CUDA devices
        np.random.seed(seed)
        random.seed(seed)
        torch.backends.cudnn.deterministic = True
        torch.backends.cudnn.benchmark = False # Set to False for determinism

# %%
def embedding_frequency_penalty(model: Transformer) -> torch.Tensor:
    """
    Encourage neighboring tokens in the embedding space to be similar.
    This is a graph-Laplacian-style smoothness penalty on W_E, which
    corresponds to penalizing high-frequency Fourier modes on Z_p.

    W_E has shape [d_model, d_vocab].
    We smooth along the vocab dimension (the modular arithmetic axis).
    """
    E = model.embed.W_E  # [d_model, d_vocab]

    # Differences between consecutive tokens (0-1, 1-2, ..., (V-2)-(V-1))
    diff = E[:, 1:] - E[:, :-1]  # [d_model, d_vocab-1]

    # Wrap-around difference to respect modular structure: token V-1 vs 0
    wrap = E[:, :1] - E[:, -1:]  # [d_model, 1]

    # Mean squared differences (Laplacian smoothness)
    penalty = (diff.pow(2).mean() + wrap.pow(2).mean())
    return penalty

# %% [markdown]
# ## Hyperparameters

# %%
root = Path('/home/stephen/grokking')



p=113
# seed=2 ##Set at top

lr=1e-3 #@param

p=113 #@param
d_model = 128 #@param
fn_name = 'add' #@param ['add', 'subtract', 'x2xyy2','rand']
num_epochs = 20000 #@param
save_models = True #@param
save_every = 10 # Maybe crank this down
# Stop training when test loss is <stopping_thresh
stopping_thresh = -1 #@param

num_layers = 1
batch_style = 'full'
d_vocab = p+1
n_ctx = 3
d_mlp = 4*d_model
num_heads = 4
assert d_model % num_heads == 0
d_head = d_model//num_heads
act_type = 'ReLU' #@param ['ReLU', 'GeLU']
# batch_size = 512
use_ln = False
random_answers = np.random.randint(low=0, high=p, size=(p, p))
fns_dict = {'add': lambda x,y:(x+y)%p, 'subtract': lambda x,y:(x-y)%p, 'x2xyy2':lambda x,y:(x**2+x*y+y**2)%p, 'rand':lambda x,y:random_answers[x][y]}
fn = fns_dict[fn_name]

# %%
frac_train, seed
# Out:
# (0.25, 852778)

# %%
def gen_train_test(frac_train, num, seed=0):
    # Generate train and test split
    pairs = [(i, j, num) for i in range(num) for j in range(num)]
    random.seed(seed)
    random.shuffle(pairs)
    div = int(frac_train*len(pairs))
    return pairs[:div], pairs[div:]

train, test = gen_train_test(frac_train, p, seed)
print(len(train), len(test))
# Out:
# 3192 9577

# %%
# Creates an array of Boolean indices according to whether each data point is in 
# train or test
# Used to index into the big batch of all possible data
is_train = []
is_test = []
for x in range(p):
    for y in range(p):
        if (x, y, 113) in train:
            is_train.append(True)
            is_test.append(False)
        else:
            is_train.append(False)
            is_test.append(True)
is_train = np.array(is_train)
is_test = np.array(is_test)

# %% [markdown]
# ## Training Loop

# %%
set_seed(seed)
model = Transformer(num_layers=num_layers, d_vocab=d_vocab, d_model=d_model, d_mlp=d_mlp, d_head=d_head, num_heads=num_heads, n_ctx=n_ctx, act_type=act_type, use_cache=False, use_ln=use_ln)
model.to('cuda')
optimizer = optim.AdamW(model.parameters(), lr=lr, weight_decay=weight_decay, betas=(0.9, 0.98))
scheduler = optim.lr_scheduler.LambdaLR(optimizer, lambda step: min(step/10, 1))
run_name = f"grok_{int(time.time())}"
print(f'Run name {run_name}')
if save_models:
    os.mkdir(root/run_name)
    save_dict = {'model':model.state_dict(), 'train_data':train, 'test_data':test}
    torch.save(save_dict, root/run_name/'init.pth')
train_losses = []
test_losses = []
train_accs = []
test_accs = []
for epoch in range(num_epochs):

    # 1. Compute base cross-entropy losses (no regularization)
    train_ce_loss = full_loss(model, train)
    test_loss = full_loss(model, test)  # leave test as-is

    # 2. Compute smoothness / frequency penalty on embeddings
    freq_pen = embedding_frequency_penalty(model)

    # 3. Total train loss = CE + λ * penalty
    train_loss = train_ce_loss + freq_penalty_weight * freq_pen

    # 4. Track (usually you want to log CE only for grokking plots)
    train_losses.append(train_ce_loss.item())
    test_losses.append(test_loss.item())

    logits = model(train)[:, -1]
    labels = torch.tensor([fn(i, j) for i, j, _ in train]).to('cuda')
    train_acc=((logits.detach().cpu().argmax(1)==labels.detach().cpu()).sum()/len(labels)).item()
    train_accs.append(train_acc)
    
    logits = model(test)[:, -1]
    labels = torch.tensor([fn(i, j) for i, j, _ in test]).to('cuda')
    test_acc=((logits.detach().cpu().argmax(1)==labels.detach().cpu()).sum()/len(labels)).item()
    test_accs.append(test_acc)

    if epoch % 100 == 0:
        print(
            f"{epoch}_"
            f"{np.log(train_ce_loss.item()):.4f}_"
            f"{np.log(test_loss.item()):.4f}_"
            f"pen={freq_pen.item():.3e}"
        )

    # 5. Backprop / step
    train_loss.backward()
    optimizer.step()
    scheduler.step()
    optimizer.zero_grad()
    if test_loss.item() < stopping_thresh:
        break
    if (save_models) and (epoch%save_every == 0):
        if test_loss.item() < stopping_thresh:
            break
        save_dict = {
            'model': model.state_dict(),
            'optimizer': optimizer.state_dict(),
            'scheduler': scheduler.state_dict(),
            'train_loss': train_loss,
            'test_loss': test_loss,
            'epoch': epoch,
        }
        torch.save(save_dict, root/run_name/f"{epoch}.pth")
        print(f"Saved model to {root/run_name/f'{epoch}.pth'}")
if not save_models:
    os.mkdir(root/run_name)
save_dict = {
    'model': model.state_dict(),
    'optimizer': optimizer.state_dict(),
    'scheduler': scheduler.state_dict(),
    'train_loss': train_loss,
    'test_loss': test_loss,
    'train_losses': train_losses,
    'test_losses': test_losses,
    'train_accs': train_accs,
    'test_accs':test_accs,
    'epoch': epoch,
}
torch.save(save_dict, root/run_name/f"final.pth")
print(f"Saved model to {root/run_name/f'final.pth'}")

# save_models = False
# Out:
# Run name grok_1764706150
# 0_1.5651_1.5624_pen=3.258e-02
# Saved model to /home/stephen/grokking/grok_1764706150/0.pth
# Saved model to /home/stephen/grokking/grok_1764706150/10.pth
# Saved model to /home/stephen/grokking/grok_1764706150/20.pth
# Saved model to /home/stephen/grokking/grok_1764706150/30.pth
# Saved model to /home/stephen/grokking/grok_1764706150/40.pth
# Saved model to /home/stephen/grokking/grok_1764706150/50.pth
# Saved model to /home/stephen/grokking/grok_1764706150/60.pth
# Saved model to /home/stephen/grokking/grok_1764706150/70.pth
# Saved model to /home/stephen/grokking/grok_1764706150/80.pth
# Saved model to /home/stephen/grokking/grok_1764706150/90.pth
# 100_0.8013_2.0794_pen=5.465e-02
# Saved model to /home/stephen/grokking/grok_1764706150/100.pth
# Saved model to /home/stephen/grokking/grok_1764706150/110.pth
# Saved model to /home/stephen/grokking/grok_1764706150/120.pth
# Saved model to /home/stephen/grokking/grok_1764706150/130.pth
# Saved model to /home/stephen/grokking/grok_1764706150/140.pth
# Saved model to /home/stephen/grokking/grok_1764706150/150.pth
# Saved model to /home/stephen/grokking/grok_1764706150/160.pth
# Saved model to /home/stephen/grokking/grok_1764706150/170.pth
# Saved model to /home/stephen/grokking/grok_1764706150/180.pth
# Saved model to /home/stephen/grokking/grok_1764706150/190.pth
# 200_-4.0431_2.8409_pen=7.985e-02
# Saved model to /home/stephen/grokking/grok_1764706150/200.pth
# Saved model to /home/stephen/grokking/grok_1764706150/210.pth
# Saved model to /home/stephen/grokking/grok_1764706150/220.pth
# Saved model to /home/stephen/grokking/grok_1764706150/230.pth
# Saved model to /home/stephen/grokking/grok_1764706150/240.pth
# Saved model to /home/stephen/grokking/grok_1764706150/250.pth
# Saved model to /home/stephen/grokking/grok_1764706150/260.pth
# Saved model to /home/stephen/grokking/grok_1764706150/270.pth
# Saved model to /home/stephen/grokking/grok_1764706150/280.pth
# Saved model to /home/stephen/grokking/grok_1764706150/290.pth
# 300_-5.0642_2.8651_pen=7.913e-02
# Saved model to /home/stephen/grokking/grok_1764706150/300.pth
# Saved model to /home/stephen/grokking/grok_1764706150/310.pth
# Saved model to /home/stephen/grokking/grok_1764706150/320.pth
# Saved model to /home/stephen/grokking/grok_1764706150/330.pth
# Saved model to /home/stephen/grokking/grok_1764706150/340.pth
# Saved model to /home/stephen/grokking/grok_1764706150/350.pth
# Saved model to /home/stephen/grokking/grok_1764706150/360.pth
# Saved model to /home/stephen/grokking/grok_1764706150/370.pth
# Saved model to /home/stephen/grokking/grok_1764706150/380.pth
# Saved model to /home/stephen/grokking/grok_1764706150/390.pth
# 400_-6.1938_2.9180_pen=7.815e-02
# Saved model to /home/stephen/grokking/grok_1764706150/400.pth
# Saved model to /home/stephen/grokking/grok_1764706150/410.pth
# Saved model to /home/stephen/grokking/grok_1764706150/420.pth
# Saved model to /home/stephen/grokking/grok_1764706150/430.pth
# Saved model to /home/stephen/grokking/grok_1764706150/440.pth
# Saved model to /home/stephen/grokking/grok_1764706150/450.pth
# Saved model to /home/stephen/grokking/grok_1764706150/460.pth
# Saved model to /home/stephen/grokking/grok_1764706150/470.pth
# Saved model to /home/stephen/grokking/grok_1764706150/480.pth
# Saved model to /home/stephen/grokking/grok_1764706150/490.pth
# 500_-7.2961_2.9737_pen=7.521e-02
# Saved model to /home/stephen/grokking/grok_1764706150/500.pth
# Saved model to /home/stephen/grokking/grok_1764706150/510.pth
# Saved model to /home/stephen/grokking/grok_1764706150/520.pth
# Saved model to /home/stephen/grokking/grok_1764706150/530.pth
# Saved model to /home/stephen/grokking/grok_1764706150/540.pth
# Saved model to /home/stephen/grokking/grok_1764706150/550.pth
# Saved model to /home/stephen/grokking/grok_1764706150/560.pth
# Saved model to /home/stephen/grokking/grok_1764706150/570.pth
# Saved model to /home/stephen/grokking/grok_1764706150/580.pth
# Saved model to /home/stephen/grokking/grok_1764706150/590.pth
# 600_-8.3783_3.0299_pen=6.833e-02
# Saved model to /home/stephen/grokking/grok_1764706150/600.pth
# Saved model to /home/stephen/grokking/grok_1764706150/610.pth
# Saved model to /home/stephen/grokking/grok_1764706150/620.pth
# Saved model to /home/stephen/grokking/grok_1764706150/630.pth
# Saved model to /home/stephen/grokking/grok_1764706150/640.pth
# Saved model to /home/stephen/grokking/grok_1764706150/650.pth
# Saved model to /home/stephen/grokking/grok_1764706150/660.pth
# Saved model to /home/stephen/grokking/grok_1764706150/670.pth
# Saved model to /home/stephen/grokking/grok_1764706150/680.pth
# Saved model to /home/stephen/grokking/grok_1764706150/690.pth
# 700_-9.4385_3.0849_pen=5.767e-02
# Saved model to /home/stephen/grokking/grok_1764706150/700.pth
# Saved model to /home/stephen/grokking/grok_1764706150/710.pth
# Saved model to /home/stephen/grokking/grok_1764706150/720.pth
# Saved model to /home/stephen/grokking/grok_1764706150/730.pth
# Saved model to /home/stephen/grokking/grok_1764706150/740.pth
# Saved model to /home/stephen/grokking/grok_1764706150/750.pth
# Saved model to /home/stephen/grokking/grok_1764706150/760.pth
# Saved model to /home/stephen/grokking/grok_1764706150/770.pth
# Saved model to /home/stephen/grokking/grok_1764706150/780.pth
# Saved model to /home/stephen/grokking/grok_1764706150/790.pth
# 800_-10.4691_3.1373_pen=4.713e-02
# Saved model to /home/stephen/grokking/grok_1764706150/800.pth
# Saved model to /home/stephen/grokking/grok_1764706150/810.pth
# Saved model to /home/stephen/grokking/grok_1764706150/820.pth
# Saved model to /home/stephen/grokking/grok_1764706150/830.pth
# Saved model to /home/stephen/grokking/grok_1764706150/840.pth
# Saved model to /home/stephen/grokking/grok_1764706150/850.pth
# Saved model to /home/stephen/grokking/grok_1764706150/860.pth
# Saved model to /home/stephen/grokking/grok_1764706150/870.pth
# Saved model to /home/stephen/grokking/grok_1764706150/880.pth
# Saved model to /home/stephen/grokking/grok_1764706150/890.pth
# 900_-11.4434_3.1839_pen=3.982e-02
# Saved model to /home/stephen/grokking/grok_1764706150/900.pth
# Saved model to /home/stephen/grokking/grok_1764706150/910.pth
# Saved model to /home/stephen/grokking/grok_1764706150/920.pth
# Saved model to /home/stephen/grokking/grok_1764706150/930.pth
# Saved model to /home/stephen/grokking/grok_1764706150/940.pth
# Saved model to /home/stephen/grokking/grok_1764706150/950.pth
# Saved model to /home/stephen/grokking/grok_1764706150/960.pth
# Saved model to /home/stephen/grokking/grok_1764706150/970.pth
# Saved model to /home/stephen/grokking/grok_1764706150/980.pth
# Saved model to /home/stephen/grokking/grok_1764706150/990.pth
# 1000_-12.2847_3.2206_pen=3.169e-02
# Saved model to /home/stephen/grokking/grok_1764706150/1000.pth
# Saved model to /home/stephen/grokking/grok_1764706150/1010.pth
# Saved model to /home/stephen/grokking/grok_1764706150/1020.pth
# Saved model to /home/stephen/grokking/grok_1764706150/1030.pth
# Saved model to /home/stephen/grokking/grok_1764706150/1040.pth
# Saved model to /home/stephen/grokking/grok_1764706150/1050.pth
# Saved model to /home/stephen/grokking/grok_1764706150/1060.pth
# Saved model to /home/stephen/grokking/grok_1764706150/1070.pth
# Saved model to /home/stephen/grokking/grok_1764706150/1080.pth
# Saved model to /home/stephen/grokking/grok_1764706150/1090.pth
# 1100_-12.9474_3.2491_pen=2.123e-02
# Saved model to /home/stephen/grokking/grok_1764706150/1100.pth
# Saved model to /home/stephen/grokking/grok_1764706150/1110.pth
# Saved model to /home/stephen/grokking/grok_1764706150/1120.pth
# Saved model to /home/stephen/grokking/grok_1764706150/1130.pth
# Saved model to /home/stephen/grokking/grok_1764706150/1140.pth
# Saved model to /home/stephen/grokking/grok_1764706150/1150.pth
# Saved model to /home/stephen/grokking/grok_1764706150/1160.pth
# Saved model to /home/stephen/grokking/grok_1764706150/1170.pth
# Saved model to /home/stephen/grokking/grok_1764706150/1180.pth
# Saved model to /home/stephen/grokking/grok_1764706150/1190.pth
# 1200_-13.4781_3.2669_pen=1.269e-02
# Saved model to /home/stephen/grokking/grok_1764706150/1200.pth
# Saved model to /home/stephen/grokking/grok_1764706150/1210.pth
# Saved model to /home/stephen/grokking/grok_1764706150/1220.pth
# Saved model to /home/stephen/grokking/grok_1764706150/1230.pth
# Saved model to /home/stephen/grokking/grok_1764706150/1240.pth
# Saved model to /home/stephen/grokking/grok_1764706150/1250.pth
# Saved model to /home/stephen/grokking/grok_1764706150/1260.pth
# Saved model to /home/stephen/grokking/grok_1764706150/1270.pth
# Saved model to /home/stephen/grokking/grok_1764706150/1280.pth
# Saved model to /home/stephen/grokking/grok_1764706150/1290.pth
# 1300_-13.8916_3.2706_pen=7.987e-03
# Saved model to /home/stephen/grokking/grok_1764706150/1300.pth
# Saved model to /home/stephen/grokking/grok_1764706150/1310.pth
# Saved model to /home/stephen/grokking/grok_1764706150/1320.pth
# Saved model to /home/stephen/grokking/grok_1764706150/1330.pth
# Saved model to /home/stephen/grokking/grok_1764706150/1340.pth
# Saved model to /home/stephen/grokking/grok_1764706150/1350.pth
# Saved model to /home/stephen/grokking/grok_1764706150/1360.pth
# Saved model to /home/stephen/grokking/grok_1764706150/1370.pth
# Saved model to /home/stephen/grokking/grok_1764706150/1380.pth
# Saved model to /home/stephen/grokking/grok_1764706150/1390.pth
# 1400_-14.1771_3.2636_pen=5.777e-03
# Saved model to /home/stephen/grokking/grok_1764706150/1400.pth
# Saved model to /home/stephen/grokking/grok_1764706150/1410.pth
# Saved model to /home/stephen/grokking/grok_1764706150/1420.pth
# Saved model to /home/stephen/grokking/grok_1764706150/1430.pth
# Saved model to /home/stephen/grokking/grok_1764706150/1440.pth
# Saved model to /home/stephen/grokking/grok_1764706150/1450.pth
# Saved model to /home/stephen/grokking/grok_1764706150/1460.pth
# Saved model to /home/stephen/grokking/grok_1764706150/1470.pth
# Saved model to /home/stephen/grokking/grok_1764706150/1480.pth
# Saved model to /home/stephen/grokking/grok_1764706150/1490.pth
# 1500_-14.3469_3.2497_pen=4.745e-03
# Saved model to /home/stephen/grokking/grok_1764706150/1500.pth
# Saved model to /home/stephen/grokking/grok_1764706150/1510.pth
# Saved model to /home/stephen/grokking/grok_1764706150/1520.pth
# Saved model to /home/stephen/grokking/grok_1764706150/1530.pth
# Saved model to /home/stephen/grokking/grok_1764706150/1540.pth
# Saved model to /home/stephen/grokking/grok_1764706150/1550.pth
# Saved model to /home/stephen/grokking/grok_1764706150/1560.pth
# Saved model to /home/stephen/grokking/grok_1764706150/1570.pth
# Saved model to /home/stephen/grokking/grok_1764706150/1580.pth
# Saved model to /home/stephen/grokking/grok_1764706150/1590.pth
# 1600_-14.4363_3.2325_pen=4.234e-03
# Saved model to /home/stephen/grokking/grok_1764706150/1600.pth
# Saved model to /home/stephen/grokking/grok_1764706150/1610.pth
# Saved model to /home/stephen/grokking/grok_1764706150/1620.pth
# Saved model to /home/stephen/grokking/grok_1764706150/1630.pth
# Saved model to /home/stephen/grokking/grok_1764706150/1640.pth
# Saved model to /home/stephen/grokking/grok_1764706150/1650.pth
# Saved model to /home/stephen/grokking/grok_1764706150/1660.pth
# Saved model to /home/stephen/grokking/grok_1764706150/1670.pth
# Saved model to /home/stephen/grokking/grok_1764706150/1680.pth
# Saved model to /home/stephen/grokking/grok_1764706150/1690.pth
# 1700_-14.4884_3.2133_pen=3.955e-03
# Saved model to /home/stephen/grokking/grok_1764706150/1700.pth
# Saved model to /home/stephen/grokking/grok_1764706150/1710.pth
# Saved model to /home/stephen/grokking/grok_1764706150/1720.pth
# Saved model to /home/stephen/grokking/grok_1764706150/1730.pth
# Saved model to /home/stephen/grokking/grok_1764706150/1740.pth
# Saved model to /home/stephen/grokking/grok_1764706150/1750.pth
# Saved model to /home/stephen/grokking/grok_1764706150/1760.pth
# Saved model to /home/stephen/grokking/grok_1764706150/1770.pth
# Saved model to /home/stephen/grokking/grok_1764706150/1780.pth
# Saved model to /home/stephen/grokking/grok_1764706150/1790.pth
# 1800_-14.5193_3.1933_pen=3.783e-03
# Saved model to /home/stephen/grokking/grok_1764706150/1800.pth
# Saved model to /home/stephen/grokking/grok_1764706150/1810.pth
# Saved model to /home/stephen/grokking/grok_1764706150/1820.pth
# Saved model to /home/stephen/grokking/grok_1764706150/1830.pth
# Saved model to /home/stephen/grokking/grok_1764706150/1840.pth
# Saved model to /home/stephen/grokking/grok_1764706150/1850.pth
# Saved model to /home/stephen/grokking/grok_1764706150/1860.pth
# Saved model to /home/stephen/grokking/grok_1764706150/1870.pth
# Saved model to /home/stephen/grokking/grok_1764706150/1880.pth
# Saved model to /home/stephen/grokking/grok_1764706150/1890.pth
# 1900_-14.5367_3.1728_pen=3.664e-03
# Saved model to /home/stephen/grokking/grok_1764706150/1900.pth
# Saved model to /home/stephen/grokking/grok_1764706150/1910.pth
# Saved model to /home/stephen/grokking/grok_1764706150/1920.pth
# Saved model to /home/stephen/grokking/grok_1764706150/1930.pth
# Saved model to /home/stephen/grokking/grok_1764706150/1940.pth
# Saved model to /home/stephen/grokking/grok_1764706150/1950.pth
# Saved model to /home/stephen/grokking/grok_1764706150/1960.pth
# Saved model to /home/stephen/grokking/grok_1764706150/1970.pth
# Saved model to /home/stephen/grokking/grok_1764706150/1980.pth
# Saved model to /home/stephen/grokking/grok_1764706150/1990.pth
# 2000_-14.5569_3.1520_pen=3.572e-03
# Saved model to /home/stephen/grokking/grok_1764706150/2000.pth
# Saved model to /home/stephen/grokking/grok_1764706150/2010.pth
# Saved model to /home/stephen/grokking/grok_1764706150/2020.pth
# Saved model to /home/stephen/grokking/grok_1764706150/2030.pth
# Saved model to /home/stephen/grokking/grok_1764706150/2040.pth
# Saved model to /home/stephen/grokking/grok_1764706150/2050.pth
# Saved model to /home/stephen/grokking/grok_1764706150/2060.pth
# Saved model to /home/stephen/grokking/grok_1764706150/2070.pth
# Saved model to /home/stephen/grokking/grok_1764706150/2080.pth
# Saved model to /home/stephen/grokking/grok_1764706150/2090.pth
# 2100_-14.5705_3.1307_pen=3.492e-03
# Saved model to /home/stephen/grokking/grok_1764706150/2100.pth
# Saved model to /home/stephen/grokking/grok_1764706150/2110.pth
# Saved model to /home/stephen/grokking/grok_1764706150/2120.pth
# Saved model to /home/stephen/grokking/grok_1764706150/2130.pth
# Saved model to /home/stephen/grokking/grok_1764706150/2140.pth
# Saved model to /home/stephen/grokking/grok_1764706150/2150.pth
# Saved model to /home/stephen/grokking/grok_1764706150/2160.pth
# Saved model to /home/stephen/grokking/grok_1764706150/2170.pth
# Saved model to /home/stephen/grokking/grok_1764706150/2180.pth
# Saved model to /home/stephen/grokking/grok_1764706150/2190.pth
# 2200_-14.5832_3.1087_pen=3.418e-03
# Saved model to /home/stephen/grokking/grok_1764706150/2200.pth
# Saved model to /home/stephen/grokking/grok_1764706150/2210.pth
# Saved model to /home/stephen/grokking/grok_1764706150/2220.pth
# Saved model to /home/stephen/grokking/grok_1764706150/2230.pth
# Saved model to /home/stephen/grokking/grok_1764706150/2240.pth
# Saved model to /home/stephen/grokking/grok_1764706150/2250.pth
# Saved model to /home/stephen/grokking/grok_1764706150/2260.pth
# Saved model to /home/stephen/grokking/grok_1764706150/2270.pth
# Saved model to /home/stephen/grokking/grok_1764706150/2280.pth
# Saved model to /home/stephen/grokking/grok_1764706150/2290.pth
# 2300_-14.5987_3.0864_pen=3.348e-03
# Saved model to /home/stephen/grokking/grok_1764706150/2300.pth
# Saved model to /home/stephen/grokking/grok_1764706150/2310.pth
# Saved model to /home/stephen/grokking/grok_1764706150/2320.pth
# Saved model to /home/stephen/grokking/grok_1764706150/2330.pth
# Saved model to /home/stephen/grokking/grok_1764706150/2340.pth
# Saved model to /home/stephen/grokking/grok_1764706150/2350.pth
# Saved model to /home/stephen/grokking/grok_1764706150/2360.pth
# Saved model to /home/stephen/grokking/grok_1764706150/2370.pth
# Saved model to /home/stephen/grokking/grok_1764706150/2380.pth
# Saved model to /home/stephen/grokking/grok_1764706150/2390.pth
# 2400_-14.6025_3.0642_pen=3.279e-03
# Saved model to /home/stephen/grokking/grok_1764706150/2400.pth
# Saved model to /home/stephen/grokking/grok_1764706150/2410.pth
# Saved model to /home/stephen/grokking/grok_1764706150/2420.pth
# Saved model to /home/stephen/grokking/grok_1764706150/2430.pth
# Saved model to /home/stephen/grokking/grok_1764706150/2440.pth
# Saved model to /home/stephen/grokking/grok_1764706150/2450.pth
# Saved model to /home/stephen/grokking/grok_1764706150/2460.pth
# Saved model to /home/stephen/grokking/grok_1764706150/2470.pth
# Saved model to /home/stephen/grokking/grok_1764706150/2480.pth
# Saved model to /home/stephen/grokking/grok_1764706150/2490.pth
# 2500_-14.6204_3.0428_pen=3.212e-03
# Saved model to /home/stephen/grokking/grok_1764706150/2500.pth
# Saved model to /home/stephen/grokking/grok_1764706150/2510.pth
# Saved model to /home/stephen/grokking/grok_1764706150/2520.pth
# Saved model to /home/stephen/grokking/grok_1764706150/2530.pth
# Saved model to /home/stephen/grokking/grok_1764706150/2540.pth
# Saved model to /home/stephen/grokking/grok_1764706150/2550.pth
# Saved model to /home/stephen/grokking/grok_1764706150/2560.pth
# Saved model to /home/stephen/grokking/grok_1764706150/2570.pth
# Saved model to /home/stephen/grokking/grok_1764706150/2580.pth
# Saved model to /home/stephen/grokking/grok_1764706150/2590.pth
# 2600_-14.6326_3.0219_pen=3.151e-03
# Saved model to /home/stephen/grokking/grok_1764706150/2600.pth
# Saved model to /home/stephen/grokking/grok_1764706150/2610.pth
# Saved model to /home/stephen/grokking/grok_1764706150/2620.pth
# Saved model to /home/stephen/grokking/grok_1764706150/2630.pth
# Saved model to /home/stephen/grokking/grok_1764706150/2640.pth
# Saved model to /home/stephen/grokking/grok_1764706150/2650.pth
# Saved model to /home/stephen/grokking/grok_1764706150/2660.pth
# Saved model to /home/stephen/grokking/grok_1764706150/2670.pth
# Saved model to /home/stephen/grokking/grok_1764706150/2680.pth
# Saved model to /home/stephen/grokking/grok_1764706150/2690.pth
# 2700_-14.6462_3.0013_pen=3.090e-03
# Saved model to /home/stephen/grokking/grok_1764706150/2700.pth
# Saved model to /home/stephen/grokking/grok_1764706150/2710.pth
# Saved model to /home/stephen/grokking/grok_1764706150/2720.pth
# Saved model to /home/stephen/grokking/grok_1764706150/2730.pth
# Saved model to /home/stephen/grokking/grok_1764706150/2740.pth
# Saved model to /home/stephen/grokking/grok_1764706150/2750.pth
# Saved model to /home/stephen/grokking/grok_1764706150/2760.pth
# Saved model to /home/stephen/grokking/grok_1764706150/2770.pth
# Saved model to /home/stephen/grokking/grok_1764706150/2780.pth
# Saved model to /home/stephen/grokking/grok_1764706150/2790.pth
# 2800_-14.6504_2.9818_pen=3.035e-03
# Saved model to /home/stephen/grokking/grok_1764706150/2800.pth
# Saved model to /home/stephen/grokking/grok_1764706150/2810.pth
# Saved model to /home/stephen/grokking/grok_1764706150/2820.pth
# Saved model to /home/stephen/grokking/grok_1764706150/2830.pth
# Saved model to /home/stephen/grokking/grok_1764706150/2840.pth
# Saved model to /home/stephen/grokking/grok_1764706150/2850.pth
# Saved model to /home/stephen/grokking/grok_1764706150/2860.pth
# Saved model to /home/stephen/grokking/grok_1764706150/2870.pth
# Saved model to /home/stephen/grokking/grok_1764706150/2880.pth
# Saved model to /home/stephen/grokking/grok_1764706150/2890.pth
# 2900_-14.6691_2.9626_pen=2.982e-03
# Saved model to /home/stephen/grokking/grok_1764706150/2900.pth
# Saved model to /home/stephen/grokking/grok_1764706150/2910.pth
# Saved model to /home/stephen/grokking/grok_1764706150/2920.pth
# Saved model to /home/stephen/grokking/grok_1764706150/2930.pth
# Saved model to /home/stephen/grokking/grok_1764706150/2940.pth
# Saved model to /home/stephen/grokking/grok_1764706150/2950.pth
# Saved model to /home/stephen/grokking/grok_1764706150/2960.pth
# Saved model to /home/stephen/grokking/grok_1764706150/2970.pth
# Saved model to /home/stephen/grokking/grok_1764706150/2980.pth
# Saved model to /home/stephen/grokking/grok_1764706150/2990.pth
# 3000_-14.6769_2.9433_pen=2.931e-03
# Saved model to /home/stephen/grokking/grok_1764706150/3000.pth
# Saved model to /home/stephen/grokking/grok_1764706150/3010.pth
# Saved model to /home/stephen/grokking/grok_1764706150/3020.pth
# Saved model to /home/stephen/grokking/grok_1764706150/3030.pth
# Saved model to /home/stephen/grokking/grok_1764706150/3040.pth
# Saved model to /home/stephen/grokking/grok_1764706150/3050.pth
# Saved model to /home/stephen/grokking/grok_1764706150/3060.pth
# Saved model to /home/stephen/grokking/grok_1764706150/3070.pth
# Saved model to /home/stephen/grokking/grok_1764706150/3080.pth
# Saved model to /home/stephen/grokking/grok_1764706150/3090.pth
# 3100_-14.6836_2.9250_pen=2.884e-03
# Saved model to /home/stephen/grokking/grok_1764706150/3100.pth
# Saved model to /home/stephen/grokking/grok_1764706150/3110.pth
# Saved model to /home/stephen/grokking/grok_1764706150/3120.pth
# Saved model to /home/stephen/grokking/grok_1764706150/3130.pth
# Saved model to /home/stephen/grokking/grok_1764706150/3140.pth
# Saved model to /home/stephen/grokking/grok_1764706150/3150.pth
# Saved model to /home/stephen/grokking/grok_1764706150/3160.pth
# Saved model to /home/stephen/grokking/grok_1764706150/3170.pth
# Saved model to /home/stephen/grokking/grok_1764706150/3180.pth
# Saved model to /home/stephen/grokking/grok_1764706150/3190.pth
# 3200_-14.6901_2.9080_pen=2.844e-03
# Saved model to /home/stephen/grokking/grok_1764706150/3200.pth
# Saved model to /home/stephen/grokking/grok_1764706150/3210.pth
# Saved model to /home/stephen/grokking/grok_1764706150/3220.pth
# Saved model to /home/stephen/grokking/grok_1764706150/3230.pth
# Saved model to /home/stephen/grokking/grok_1764706150/3240.pth
# Saved model to /home/stephen/grokking/grok_1764706150/3250.pth
# Saved model to /home/stephen/grokking/grok_1764706150/3260.pth
# Saved model to /home/stephen/grokking/grok_1764706150/3270.pth
# Saved model to /home/stephen/grokking/grok_1764706150/3280.pth
# Saved model to /home/stephen/grokking/grok_1764706150/3290.pth
# 3300_-14.7065_2.8916_pen=2.804e-03
# Saved model to /home/stephen/grokking/grok_1764706150/3300.pth
# Saved model to /home/stephen/grokking/grok_1764706150/3310.pth
# Saved model to /home/stephen/grokking/grok_1764706150/3320.pth
# Saved model to /home/stephen/grokking/grok_1764706150/3330.pth
# Saved model to /home/stephen/grokking/grok_1764706150/3340.pth
# Saved model to /home/stephen/grokking/grok_1764706150/3350.pth
# Saved model to /home/stephen/grokking/grok_1764706150/3360.pth
# Saved model to /home/stephen/grokking/grok_1764706150/3370.pth
# Saved model to /home/stephen/grokking/grok_1764706150/3380.pth
# Saved model to /home/stephen/grokking/grok_1764706150/3390.pth
# 3400_-14.7121_2.8759_pen=2.765e-03
# Saved model to /home/stephen/grokking/grok_1764706150/3400.pth
# Saved model to /home/stephen/grokking/grok_1764706150/3410.pth
# Saved model to /home/stephen/grokking/grok_1764706150/3420.pth
# Saved model to /home/stephen/grokking/grok_1764706150/3430.pth
# Saved model to /home/stephen/grokking/grok_1764706150/3440.pth
# Saved model to /home/stephen/grokking/grok_1764706150/3450.pth
# Saved model to /home/stephen/grokking/grok_1764706150/3460.pth
# Saved model to /home/stephen/grokking/grok_1764706150/3470.pth
# Saved model to /home/stephen/grokking/grok_1764706150/3480.pth
# Saved model to /home/stephen/grokking/grok_1764706150/3490.pth
# 3500_-14.7135_2.8609_pen=2.727e-03
# Saved model to /home/stephen/grokking/grok_1764706150/3500.pth
# Saved model to /home/stephen/grokking/grok_1764706150/3510.pth
# Saved model to /home/stephen/grokking/grok_1764706150/3520.pth
# Saved model to /home/stephen/grokking/grok_1764706150/3530.pth
# Saved model to /home/stephen/grokking/grok_1764706150/3540.pth
# Saved model to /home/stephen/grokking/grok_1764706150/3550.pth
# Saved model to /home/stephen/grokking/grok_1764706150/3560.pth
# Saved model to /home/stephen/grokking/grok_1764706150/3570.pth
# Saved model to /home/stephen/grokking/grok_1764706150/3580.pth
# Saved model to /home/stephen/grokking/grok_1764706150/3590.pth
# 3600_-14.7321_2.8459_pen=2.691e-03
# Saved model to /home/stephen/grokking/grok_1764706150/3600.pth
# Saved model to /home/stephen/grokking/grok_1764706150/3610.pth
# Saved model to /home/stephen/grokking/grok_1764706150/3620.pth
# Saved model to /home/stephen/grokking/grok_1764706150/3630.pth
# Saved model to /home/stephen/grokking/grok_1764706150/3640.pth
# Saved model to /home/stephen/grokking/grok_1764706150/3650.pth
# Saved model to /home/stephen/grokking/grok_1764706150/3660.pth
# Saved model to /home/stephen/grokking/grok_1764706150/3670.pth
# Saved model to /home/stephen/grokking/grok_1764706150/3680.pth
# Saved model to /home/stephen/grokking/grok_1764706150/3690.pth
# 3700_-14.7018_2.8314_pen=2.654e-03
# Saved model to /home/stephen/grokking/grok_1764706150/3700.pth
# Saved model to /home/stephen/grokking/grok_1764706150/3710.pth
# Saved model to /home/stephen/grokking/grok_1764706150/3720.pth
# Saved model to /home/stephen/grokking/grok_1764706150/3730.pth
# Saved model to /home/stephen/grokking/grok_1764706150/3740.pth
# Saved model to /home/stephen/grokking/grok_1764706150/3750.pth
# Saved model to /home/stephen/grokking/grok_1764706150/3760.pth
# Saved model to /home/stephen/grokking/grok_1764706150/3770.pth
# Saved model to /home/stephen/grokking/grok_1764706150/3780.pth
# Saved model to /home/stephen/grokking/grok_1764706150/3790.pth
# 3800_-14.7429_2.8163_pen=2.624e-03
# Saved model to /home/stephen/grokking/grok_1764706150/3800.pth
# Saved model to /home/stephen/grokking/grok_1764706150/3810.pth
# Saved model to /home/stephen/grokking/grok_1764706150/3820.pth
# Saved model to /home/stephen/grokking/grok_1764706150/3830.pth
# Saved model to /home/stephen/grokking/grok_1764706150/3840.pth
# Saved model to /home/stephen/grokking/grok_1764706150/3850.pth
# Saved model to /home/stephen/grokking/grok_1764706150/3860.pth
# Saved model to /home/stephen/grokking/grok_1764706150/3870.pth
# Saved model to /home/stephen/grokking/grok_1764706150/3880.pth
# Saved model to /home/stephen/grokking/grok_1764706150/3890.pth
# 3900_-14.7393_2.8014_pen=2.593e-03
# Saved model to /home/stephen/grokking/grok_1764706150/3900.pth
# Saved model to /home/stephen/grokking/grok_1764706150/3910.pth
# Saved model to /home/stephen/grokking/grok_1764706150/3920.pth
# Saved model to /home/stephen/grokking/grok_1764706150/3930.pth
# Saved model to /home/stephen/grokking/grok_1764706150/3940.pth
# Saved model to /home/stephen/grokking/grok_1764706150/3950.pth
# Saved model to /home/stephen/grokking/grok_1764706150/3960.pth
# Saved model to /home/stephen/grokking/grok_1764706150/3970.pth
# Saved model to /home/stephen/grokking/grok_1764706150/3980.pth
# Saved model to /home/stephen/grokking/grok_1764706150/3990.pth
# 4000_-14.7501_2.7863_pen=2.561e-03
# Saved model to /home/stephen/grokking/grok_1764706150/4000.pth
# Saved model to /home/stephen/grokking/grok_1764706150/4010.pth
# Saved model to /home/stephen/grokking/grok_1764706150/4020.pth
# Saved model to /home/stephen/grokking/grok_1764706150/4030.pth
# Saved model to /home/stephen/grokking/grok_1764706150/4040.pth
# Saved model to /home/stephen/grokking/grok_1764706150/4050.pth
# Saved model to /home/stephen/grokking/grok_1764706150/4060.pth
# Saved model to /home/stephen/grokking/grok_1764706150/4070.pth
# Saved model to /home/stephen/grokking/grok_1764706150/4080.pth
# Saved model to /home/stephen/grokking/grok_1764706150/4090.pth
# 4100_-14.7650_2.7720_pen=2.531e-03
# Saved model to /home/stephen/grokking/grok_1764706150/4100.pth
# Saved model to /home/stephen/grokking/grok_1764706150/4110.pth
# Saved model to /home/stephen/grokking/grok_1764706150/4120.pth
# Saved model to /home/stephen/grokking/grok_1764706150/4130.pth
# Saved model to /home/stephen/grokking/grok_1764706150/4140.pth
# Saved model to /home/stephen/grokking/grok_1764706150/4150.pth
# Saved model to /home/stephen/grokking/grok_1764706150/4160.pth
# Saved model to /home/stephen/grokking/grok_1764706150/4170.pth
# Saved model to /home/stephen/grokking/grok_1764706150/4180.pth
# Saved model to /home/stephen/grokking/grok_1764706150/4190.pth
# 4200_-14.7595_2.7581_pen=2.504e-03
# Saved model to /home/stephen/grokking/grok_1764706150/4200.pth
# Saved model to /home/stephen/grokking/grok_1764706150/4210.pth
# Saved model to /home/stephen/grokking/grok_1764706150/4220.pth
# Saved model to /home/stephen/grokking/grok_1764706150/4230.pth
# Saved model to /home/stephen/grokking/grok_1764706150/4240.pth
# Saved model to /home/stephen/grokking/grok_1764706150/4250.pth
# Saved model to /home/stephen/grokking/grok_1764706150/4260.pth
# Saved model to /home/stephen/grokking/grok_1764706150/4270.pth
# Saved model to /home/stephen/grokking/grok_1764706150/4280.pth
# Saved model to /home/stephen/grokking/grok_1764706150/4290.pth
# 4300_-14.7771_2.7432_pen=2.472e-03
# Saved model to /home/stephen/grokking/grok_1764706150/4300.pth
# Saved model to /home/stephen/grokking/grok_1764706150/4310.pth
# Saved model to /home/stephen/grokking/grok_1764706150/4320.pth
# Saved model to /home/stephen/grokking/grok_1764706150/4330.pth
# Saved model to /home/stephen/grokking/grok_1764706150/4340.pth
# Saved model to /home/stephen/grokking/grok_1764706150/4350.pth
# Saved model to /home/stephen/grokking/grok_1764706150/4360.pth
# Saved model to /home/stephen/grokking/grok_1764706150/4370.pth
# Saved model to /home/stephen/grokking/grok_1764706150/4380.pth
# Saved model to /home/stephen/grokking/grok_1764706150/4390.pth
# 4400_-14.7823_2.7291_pen=2.444e-03
# Saved model to /home/stephen/grokking/grok_1764706150/4400.pth
# Saved model to /home/stephen/grokking/grok_1764706150/4410.pth
# Saved model to /home/stephen/grokking/grok_1764706150/4420.pth
# Saved model to /home/stephen/grokking/grok_1764706150/4430.pth
# Saved model to /home/stephen/grokking/grok_1764706150/4440.pth
# Saved model to /home/stephen/grokking/grok_1764706150/4450.pth
# Saved model to /home/stephen/grokking/grok_1764706150/4460.pth
# Saved model to /home/stephen/grokking/grok_1764706150/4470.pth
# Saved model to /home/stephen/grokking/grok_1764706150/4480.pth
# Saved model to /home/stephen/grokking/grok_1764706150/4490.pth
# 4500_-14.7824_2.7146_pen=2.414e-03
# Saved model to /home/stephen/grokking/grok_1764706150/4500.pth
# Saved model to /home/stephen/grokking/grok_1764706150/4510.pth
# Saved model to /home/stephen/grokking/grok_1764706150/4520.pth
# Saved model to /home/stephen/grokking/grok_1764706150/4530.pth
# Saved model to /home/stephen/grokking/grok_1764706150/4540.pth
# Saved model to /home/stephen/grokking/grok_1764706150/4550.pth
# Saved model to /home/stephen/grokking/grok_1764706150/4560.pth
# Saved model to /home/stephen/grokking/grok_1764706150/4570.pth
# Saved model to /home/stephen/grokking/grok_1764706150/4580.pth
# Saved model to /home/stephen/grokking/grok_1764706150/4590.pth
# 4600_-14.7882_2.6996_pen=2.386e-03
# Saved model to /home/stephen/grokking/grok_1764706150/4600.pth
# Saved model to /home/stephen/grokking/grok_1764706150/4610.pth
# Saved model to /home/stephen/grokking/grok_1764706150/4620.pth
# Saved model to /home/stephen/grokking/grok_1764706150/4630.pth
# Saved model to /home/stephen/grokking/grok_1764706150/4640.pth
# Saved model to /home/stephen/grokking/grok_1764706150/4650.pth
# Saved model to /home/stephen/grokking/grok_1764706150/4660.pth
# Saved model to /home/stephen/grokking/grok_1764706150/4670.pth
# Saved model to /home/stephen/grokking/grok_1764706150/4680.pth
# Saved model to /home/stephen/grokking/grok_1764706150/4690.pth
# 4700_-14.7969_2.6842_pen=2.358e-03
# Saved model to /home/stephen/grokking/grok_1764706150/4700.pth
# Saved model to /home/stephen/grokking/grok_1764706150/4710.pth
# Saved model to /home/stephen/grokking/grok_1764706150/4720.pth
# Saved model to /home/stephen/grokking/grok_1764706150/4730.pth
# Saved model to /home/stephen/grokking/grok_1764706150/4740.pth
# Saved model to /home/stephen/grokking/grok_1764706150/4750.pth
# Saved model to /home/stephen/grokking/grok_1764706150/4760.pth
# Saved model to /home/stephen/grokking/grok_1764706150/4770.pth
# Saved model to /home/stephen/grokking/grok_1764706150/4780.pth
# Saved model to /home/stephen/grokking/grok_1764706150/4790.pth
# 4800_-14.7962_2.6693_pen=2.331e-03
# Saved model to /home/stephen/grokking/grok_1764706150/4800.pth
# Saved model to /home/stephen/grokking/grok_1764706150/4810.pth
# Saved model to /home/stephen/grokking/grok_1764706150/4820.pth
# Saved model to /home/stephen/grokking/grok_1764706150/4830.pth
# Saved model to /home/stephen/grokking/grok_1764706150/4840.pth
# Saved model to /home/stephen/grokking/grok_1764706150/4850.pth
# Saved model to /home/stephen/grokking/grok_1764706150/4860.pth
# Saved model to /home/stephen/grokking/grok_1764706150/4870.pth
# Saved model to /home/stephen/grokking/grok_1764706150/4880.pth
# Saved model to /home/stephen/grokking/grok_1764706150/4890.pth
# 4900_-14.8172_2.6548_pen=2.306e-03
# Saved model to /home/stephen/grokking/grok_1764706150/4900.pth
# Saved model to /home/stephen/grokking/grok_1764706150/4910.pth
# Saved model to /home/stephen/grokking/grok_1764706150/4920.pth
# Saved model to /home/stephen/grokking/grok_1764706150/4930.pth
# Saved model to /home/stephen/grokking/grok_1764706150/4940.pth
# Saved model to /home/stephen/grokking/grok_1764706150/4950.pth
# Saved model to /home/stephen/grokking/grok_1764706150/4960.pth
# Saved model to /home/stephen/grokking/grok_1764706150/4970.pth
# Saved model to /home/stephen/grokking/grok_1764706150/4980.pth
# Saved model to /home/stephen/grokking/grok_1764706150/4990.pth
# 5000_-14.8321_2.6396_pen=2.282e-03
# Saved model to /home/stephen/grokking/grok_1764706150/5000.pth
# Saved model to /home/stephen/grokking/grok_1764706150/5010.pth
# Saved model to /home/stephen/grokking/grok_1764706150/5020.pth
# Saved model to /home/stephen/grokking/grok_1764706150/5030.pth
# Saved model to /home/stephen/grokking/grok_1764706150/5040.pth
# Saved model to /home/stephen/grokking/grok_1764706150/5050.pth
# Saved model to /home/stephen/grokking/grok_1764706150/5060.pth
# Saved model to /home/stephen/grokking/grok_1764706150/5070.pth
# Saved model to /home/stephen/grokking/grok_1764706150/5080.pth
# Saved model to /home/stephen/grokking/grok_1764706150/5090.pth
# 5100_-14.8430_2.6242_pen=2.259e-03
# Saved model to /home/stephen/grokking/grok_1764706150/5100.pth
# Saved model to /home/stephen/grokking/grok_1764706150/5110.pth
# Saved model to /home/stephen/grokking/grok_1764706150/5120.pth
# Saved model to /home/stephen/grokking/grok_1764706150/5130.pth
# Saved model to /home/stephen/grokking/grok_1764706150/5140.pth
# Saved model to /home/stephen/grokking/grok_1764706150/5150.pth
# Saved model to /home/stephen/grokking/grok_1764706150/5160.pth
# Saved model to /home/stephen/grokking/grok_1764706150/5170.pth
# Saved model to /home/stephen/grokking/grok_1764706150/5180.pth
# Saved model to /home/stephen/grokking/grok_1764706150/5190.pth
# 5200_-14.8298_2.6070_pen=2.230e-03
# Saved model to /home/stephen/grokking/grok_1764706150/5200.pth
# Saved model to /home/stephen/grokking/grok_1764706150/5210.pth
# Saved model to /home/stephen/grokking/grok_1764706150/5220.pth
# Saved model to /home/stephen/grokking/grok_1764706150/5230.pth
# Saved model to /home/stephen/grokking/grok_1764706150/5240.pth
# Saved model to /home/stephen/grokking/grok_1764706150/5250.pth
# Saved model to /home/stephen/grokking/grok_1764706150/5260.pth
# Saved model to /home/stephen/grokking/grok_1764706150/5270.pth
# Saved model to /home/stephen/grokking/grok_1764706150/5280.pth
# Saved model to /home/stephen/grokking/grok_1764706150/5290.pth
# 5300_-14.8337_2.5899_pen=2.204e-03
# Saved model to /home/stephen/grokking/grok_1764706150/5300.pth
# Saved model to /home/stephen/grokking/grok_1764706150/5310.pth
# Saved model to /home/stephen/grokking/grok_1764706150/5320.pth
# Saved model to /home/stephen/grokking/grok_1764706150/5330.pth
# Saved model to /home/stephen/grokking/grok_1764706150/5340.pth
# Saved model to /home/stephen/grokking/grok_1764706150/5350.pth
# Saved model to /home/stephen/grokking/grok_1764706150/5360.pth
# Saved model to /home/stephen/grokking/grok_1764706150/5370.pth
# Saved model to /home/stephen/grokking/grok_1764706150/5380.pth
# Saved model to /home/stephen/grokking/grok_1764706150/5390.pth
# 5400_-14.8457_2.5734_pen=2.181e-03
# Saved model to /home/stephen/grokking/grok_1764706150/5400.pth
# Saved model to /home/stephen/grokking/grok_1764706150/5410.pth
# Saved model to /home/stephen/grokking/grok_1764706150/5420.pth
# Saved model to /home/stephen/grokking/grok_1764706150/5430.pth
# Saved model to /home/stephen/grokking/grok_1764706150/5440.pth
# Saved model to /home/stephen/grokking/grok_1764706150/5450.pth
# Saved model to /home/stephen/grokking/grok_1764706150/5460.pth
# Saved model to /home/stephen/grokking/grok_1764706150/5470.pth
# Saved model to /home/stephen/grokking/grok_1764706150/5480.pth
# Saved model to /home/stephen/grokking/grok_1764706150/5490.pth
# 5500_-14.8656_2.5563_pen=2.158e-03
# Saved model to /home/stephen/grokking/grok_1764706150/5500.pth
# Saved model to /home/stephen/grokking/grok_1764706150/5510.pth
# Saved model to /home/stephen/grokking/grok_1764706150/5520.pth
# Saved model to /home/stephen/grokking/grok_1764706150/5530.pth
# Saved model to /home/stephen/grokking/grok_1764706150/5540.pth
# Saved model to /home/stephen/grokking/grok_1764706150/5550.pth
# Saved model to /home/stephen/grokking/grok_1764706150/5560.pth
# Saved model to /home/stephen/grokking/grok_1764706150/5570.pth
# Saved model to /home/stephen/grokking/grok_1764706150/5580.pth
# Saved model to /home/stephen/grokking/grok_1764706150/5590.pth
# 5600_-14.8668_2.5395_pen=2.137e-03
# Saved model to /home/stephen/grokking/grok_1764706150/5600.pth
# Saved model to /home/stephen/grokking/grok_1764706150/5610.pth
# Saved model to /home/stephen/grokking/grok_1764706150/5620.pth
# Saved model to /home/stephen/grokking/grok_1764706150/5630.pth
# Saved model to /home/stephen/grokking/grok_1764706150/5640.pth
# Saved model to /home/stephen/grokking/grok_1764706150/5650.pth
# Saved model to /home/stephen/grokking/grok_1764706150/5660.pth
# Saved model to /home/stephen/grokking/grok_1764706150/5670.pth
# Saved model to /home/stephen/grokking/grok_1764706150/5680.pth
# Saved model to /home/stephen/grokking/grok_1764706150/5690.pth
# 5700_-14.8667_2.5218_pen=2.114e-03
# Saved model to /home/stephen/grokking/grok_1764706150/5700.pth
# Saved model to /home/stephen/grokking/grok_1764706150/5710.pth
# Saved model to /home/stephen/grokking/grok_1764706150/5720.pth
# Saved model to /home/stephen/grokking/grok_1764706150/5730.pth
# Saved model to /home/stephen/grokking/grok_1764706150/5740.pth
# Saved model to /home/stephen/grokking/grok_1764706150/5750.pth
# Saved model to /home/stephen/grokking/grok_1764706150/5760.pth
# Saved model to /home/stephen/grokking/grok_1764706150/5770.pth
# Saved model to /home/stephen/grokking/grok_1764706150/5780.pth
# Saved model to /home/stephen/grokking/grok_1764706150/5790.pth
# 5800_-14.8845_2.5042_pen=2.094e-03
# Saved model to /home/stephen/grokking/grok_1764706150/5800.pth
# Saved model to /home/stephen/grokking/grok_1764706150/5810.pth
# Saved model to /home/stephen/grokking/grok_1764706150/5820.pth
# Saved model to /home/stephen/grokking/grok_1764706150/5830.pth
# Saved model to /home/stephen/grokking/grok_1764706150/5840.pth
# Saved model to /home/stephen/grokking/grok_1764706150/5850.pth
# Saved model to /home/stephen/grokking/grok_1764706150/5860.pth
# Saved model to /home/stephen/grokking/grok_1764706150/5870.pth
# Saved model to /home/stephen/grokking/grok_1764706150/5880.pth
# Saved model to /home/stephen/grokking/grok_1764706150/5890.pth
# 5900_-14.8741_2.4852_pen=2.073e-03
# Saved model to /home/stephen/grokking/grok_1764706150/5900.pth
# Saved model to /home/stephen/grokking/grok_1764706150/5910.pth
# Saved model to /home/stephen/grokking/grok_1764706150/5920.pth
# Saved model to /home/stephen/grokking/grok_1764706150/5930.pth
# Saved model to /home/stephen/grokking/grok_1764706150/5940.pth
# Saved model to /home/stephen/grokking/grok_1764706150/5950.pth
# Saved model to /home/stephen/grokking/grok_1764706150/5960.pth
# Saved model to /home/stephen/grokking/grok_1764706150/5970.pth
# Saved model to /home/stephen/grokking/grok_1764706150/5980.pth
# Saved model to /home/stephen/grokking/grok_1764706150/5990.pth
# 6000_-14.8706_2.4661_pen=2.053e-03
# Saved model to /home/stephen/grokking/grok_1764706150/6000.pth
# Saved model to /home/stephen/grokking/grok_1764706150/6010.pth
# Saved model to /home/stephen/grokking/grok_1764706150/6020.pth
# Saved model to /home/stephen/grokking/grok_1764706150/6030.pth
# Saved model to /home/stephen/grokking/grok_1764706150/6040.pth
# Saved model to /home/stephen/grokking/grok_1764706150/6050.pth
# Saved model to /home/stephen/grokking/grok_1764706150/6060.pth
# Saved model to /home/stephen/grokking/grok_1764706150/6070.pth
# Saved model to /home/stephen/grokking/grok_1764706150/6080.pth
# Saved model to /home/stephen/grokking/grok_1764706150/6090.pth
# 6100_-14.8830_2.4471_pen=2.034e-03
# Saved model to /home/stephen/grokking/grok_1764706150/6100.pth
# Saved model to /home/stephen/grokking/grok_1764706150/6110.pth
# Saved model to /home/stephen/grokking/grok_1764706150/6120.pth
# Saved model to /home/stephen/grokking/grok_1764706150/6130.pth
# Saved model to /home/stephen/grokking/grok_1764706150/6140.pth
# Saved model to /home/stephen/grokking/grok_1764706150/6150.pth
# Saved model to /home/stephen/grokking/grok_1764706150/6160.pth
# Saved model to /home/stephen/grokking/grok_1764706150/6170.pth
# Saved model to /home/stephen/grokking/grok_1764706150/6180.pth
# Saved model to /home/stephen/grokking/grok_1764706150/6190.pth
# 6200_-14.8933_2.4273_pen=2.016e-03
# Saved model to /home/stephen/grokking/grok_1764706150/6200.pth
# Saved model to /home/stephen/grokking/grok_1764706150/6210.pth
# Saved model to /home/stephen/grokking/grok_1764706150/6220.pth
# Saved model to /home/stephen/grokking/grok_1764706150/6230.pth
# Saved model to /home/stephen/grokking/grok_1764706150/6240.pth
# Saved model to /home/stephen/grokking/grok_1764706150/6250.pth
# Saved model to /home/stephen/grokking/grok_1764706150/6260.pth
# Saved model to /home/stephen/grokking/grok_1764706150/6270.pth
# Saved model to /home/stephen/grokking/grok_1764706150/6280.pth
# Saved model to /home/stephen/grokking/grok_1764706150/6290.pth
# 6300_-14.9134_2.4042_pen=1.995e-03
# Saved model to /home/stephen/grokking/grok_1764706150/6300.pth
# Saved model to /home/stephen/grokking/grok_1764706150/6310.pth
# Saved model to /home/stephen/grokking/grok_1764706150/6320.pth
# Saved model to /home/stephen/grokking/grok_1764706150/6330.pth
# Saved model to /home/stephen/grokking/grok_1764706150/6340.pth
# Saved model to /home/stephen/grokking/grok_1764706150/6350.pth
# Saved model to /home/stephen/grokking/grok_1764706150/6360.pth
# Saved model to /home/stephen/grokking/grok_1764706150/6370.pth
# Saved model to /home/stephen/grokking/grok_1764706150/6380.pth
# Saved model to /home/stephen/grokking/grok_1764706150/6390.pth
# 6400_-14.8917_2.3785_pen=1.975e-03
# Saved model to /home/stephen/grokking/grok_1764706150/6400.pth
# Saved model to /home/stephen/grokking/grok_1764706150/6410.pth
# Saved model to /home/stephen/grokking/grok_1764706150/6420.pth
# Saved model to /home/stephen/grokking/grok_1764706150/6430.pth
# Saved model to /home/stephen/grokking/grok_1764706150/6440.pth
# Saved model to /home/stephen/grokking/grok_1764706150/6450.pth
# Saved model to /home/stephen/grokking/grok_1764706150/6460.pth
# Saved model to /home/stephen/grokking/grok_1764706150/6470.pth
# Saved model to /home/stephen/grokking/grok_1764706150/6480.pth
# Saved model to /home/stephen/grokking/grok_1764706150/6490.pth
# 6500_-14.9045_2.3547_pen=1.955e-03
# Saved model to /home/stephen/grokking/grok_1764706150/6500.pth
# Saved model to /home/stephen/grokking/grok_1764706150/6510.pth
# Saved model to /home/stephen/grokking/grok_1764706150/6520.pth
# Saved model to /home/stephen/grokking/grok_1764706150/6530.pth
# Saved model to /home/stephen/grokking/grok_1764706150/6540.pth
# Saved model to /home/stephen/grokking/grok_1764706150/6550.pth
# Saved model to /home/stephen/grokking/grok_1764706150/6560.pth
# Saved model to /home/stephen/grokking/grok_1764706150/6570.pth
# Saved model to /home/stephen/grokking/grok_1764706150/6580.pth
# Saved model to /home/stephen/grokking/grok_1764706150/6590.pth
# 6600_-14.9482_2.3298_pen=1.939e-03
# Saved model to /home/stephen/grokking/grok_1764706150/6600.pth
# Saved model to /home/stephen/grokking/grok_1764706150/6610.pth
# Saved model to /home/stephen/grokking/grok_1764706150/6620.pth
# Saved model to /home/stephen/grokking/grok_1764706150/6630.pth
# Saved model to /home/stephen/grokking/grok_1764706150/6640.pth
# Saved model to /home/stephen/grokking/grok_1764706150/6650.pth
# Saved model to /home/stephen/grokking/grok_1764706150/6660.pth
# Saved model to /home/stephen/grokking/grok_1764706150/6670.pth
# Saved model to /home/stephen/grokking/grok_1764706150/6680.pth
# Saved model to /home/stephen/grokking/grok_1764706150/6690.pth
# 6700_-14.9189_2.3026_pen=1.916e-03
# Saved model to /home/stephen/grokking/grok_1764706150/6700.pth
# Saved model to /home/stephen/grokking/grok_1764706150/6710.pth
# Saved model to /home/stephen/grokking/grok_1764706150/6720.pth
# Saved model to /home/stephen/grokking/grok_1764706150/6730.pth
# Saved model to /home/stephen/grokking/grok_1764706150/6740.pth
# Saved model to /home/stephen/grokking/grok_1764706150/6750.pth
# Saved model to /home/stephen/grokking/grok_1764706150/6760.pth
# Saved model to /home/stephen/grokking/grok_1764706150/6770.pth
# Saved model to /home/stephen/grokking/grok_1764706150/6780.pth
# Saved model to /home/stephen/grokking/grok_1764706150/6790.pth
# 6800_-14.9444_2.2743_pen=1.898e-03
# Saved model to /home/stephen/grokking/grok_1764706150/6800.pth
# Saved model to /home/stephen/grokking/grok_1764706150/6810.pth
# Saved model to /home/stephen/grokking/grok_1764706150/6820.pth
# Saved model to /home/stephen/grokking/grok_1764706150/6830.pth
# Saved model to /home/stephen/grokking/grok_1764706150/6840.pth
# Saved model to /home/stephen/grokking/grok_1764706150/6850.pth
# Saved model to /home/stephen/grokking/grok_1764706150/6860.pth
# Saved model to /home/stephen/grokking/grok_1764706150/6870.pth
# Saved model to /home/stephen/grokking/grok_1764706150/6880.pth
# Saved model to /home/stephen/grokking/grok_1764706150/6890.pth
# 6900_-14.9577_2.2444_pen=1.882e-03
# Saved model to /home/stephen/grokking/grok_1764706150/6900.pth
# Saved model to /home/stephen/grokking/grok_1764706150/6910.pth
# Saved model to /home/stephen/grokking/grok_1764706150/6920.pth
# Saved model to /home/stephen/grokking/grok_1764706150/6930.pth
# Saved model to /home/stephen/grokking/grok_1764706150/6940.pth
# Saved model to /home/stephen/grokking/grok_1764706150/6950.pth
# Saved model to /home/stephen/grokking/grok_1764706150/6960.pth
# Saved model to /home/stephen/grokking/grok_1764706150/6970.pth
# Saved model to /home/stephen/grokking/grok_1764706150/6980.pth
# Saved model to /home/stephen/grokking/grok_1764706150/6990.pth
# 7000_-14.8845_2.2152_pen=1.864e-03
# Saved model to /home/stephen/grokking/grok_1764706150/7000.pth
# Saved model to /home/stephen/grokking/grok_1764706150/7010.pth
# Saved model to /home/stephen/grokking/grok_1764706150/7020.pth
# Saved model to /home/stephen/grokking/grok_1764706150/7030.pth
# Saved model to /home/stephen/grokking/grok_1764706150/7040.pth
# Saved model to /home/stephen/grokking/grok_1764706150/7050.pth
# Saved model to /home/stephen/grokking/grok_1764706150/7060.pth
# Saved model to /home/stephen/grokking/grok_1764706150/7070.pth
# Saved model to /home/stephen/grokking/grok_1764706150/7080.pth
# Saved model to /home/stephen/grokking/grok_1764706150/7090.pth
# 7100_-14.9811_2.1818_pen=1.846e-03
# Saved model to /home/stephen/grokking/grok_1764706150/7100.pth
# Saved model to /home/stephen/grokking/grok_1764706150/7110.pth
# Saved model to /home/stephen/grokking/grok_1764706150/7120.pth
# Saved model to /home/stephen/grokking/grok_1764706150/7130.pth
# Saved model to /home/stephen/grokking/grok_1764706150/7140.pth
# Saved model to /home/stephen/grokking/grok_1764706150/7150.pth
# Saved model to /home/stephen/grokking/grok_1764706150/7160.pth
# Saved model to /home/stephen/grokking/grok_1764706150/7170.pth
# Saved model to /home/stephen/grokking/grok_1764706150/7180.pth
# Saved model to /home/stephen/grokking/grok_1764706150/7190.pth
# 7200_-7.5613_1.7208_pen=2.117e-03
# Saved model to /home/stephen/grokking/grok_1764706150/7200.pth
# Saved model to /home/stephen/grokking/grok_1764706150/7210.pth
# Saved model to /home/stephen/grokking/grok_1764706150/7220.pth
# ...
# Saved model to /home/stephen/grokking/grok_1764706150/17650.pth
# Saved model to /home/stephen/grokking/grok_1764706150/17660.pth
# Saved model to /home/stephen/grokking/grok_1764706150/17670.pth
# Saved model to /home/stephen/grokking/grok_1764706150/17680.pth
# Saved model to /home/stephen/grokking/grok_1764706150/17690.pth
# 17700_-15.9183_-14.9483_pen=8.008e-04
# Saved model to /home/stephen/grokking/grok_1764706150/17700.pth
# Saved model to /home/stephen/grokking/grok_1764706150/17710.pth
# Saved model to /home/stephen/grokking/grok_1764706150/17720.pth
# Saved model to /home/stephen/grokking/grok_1764706150/17730.pth
# Saved model to /home/stephen/grokking/grok_1764706150/17740.pth
# Saved model to /home/stephen/grokking/grok_1764706150/17750.pth
# Saved model to /home/stephen/grokking/grok_1764706150/17760.pth
# Saved model to /home/stephen/grokking/grok_1764706150/17770.pth
# Saved model to /home/stephen/grokking/grok_1764706150/17780.pth
# Saved model to /home/stephen/grokking/grok_1764706150/17790.pth
# 17800_-15.9115_-14.9595_pen=8.036e-04
# Saved model to /home/stephen/grokking/grok_1764706150/17800.pth
# Saved model to /home/stephen/grokking/grok_1764706150/17810.pth
# Saved model to /home/stephen/grokking/grok_1764706150/17820.pth
# Saved model to /home/stephen/grokking/grok_1764706150/17830.pth
# Saved model to /home/stephen/grokking/grok_1764706150/17840.pth
# Saved model to /home/stephen/grokking/grok_1764706150/17850.pth
# Saved model to /home/stephen/grokking/grok_1764706150/17860.pth
# Saved model to /home/stephen/grokking/grok_1764706150/17870.pth
# Saved model to /home/stephen/grokking/grok_1764706150/17880.pth
# Saved model to /home/stephen/grokking/grok_1764706150/17890.pth
# 17900_-15.9122_-14.9731_pen=8.065e-04
# Saved model to /home/stephen/grokking/grok_1764706150/17900.pth
# Saved model to /home/stephen/grokking/grok_1764706150/17910.pth
# Saved model to /home/stephen/grokking/grok_1764706150/17920.pth
# Saved model to /home/stephen/grokking/grok_1764706150/17930.pth
# Saved model to /home/stephen/grokking/grok_1764706150/17940.pth
# Saved model to /home/stephen/grokking/grok_1764706150/17950.pth
# Saved model to /home/stephen/grokking/grok_1764706150/17960.pth
# Saved model to /home/stephen/grokking/grok_1764706150/17970.pth
# Saved model to /home/stephen/grokking/grok_1764706150/17980.pth
# Saved model to /home/stephen/grokking/grok_1764706150/17990.pth
# 18000_-15.9060_-14.9829_pen=8.150e-04
# Saved model to /home/stephen/grokking/grok_1764706150/18000.pth
# Saved model to /home/stephen/grokking/grok_1764706150/18010.pth
# Saved model to /home/stephen/grokking/grok_1764706150/18020.pth
# Saved model to /home/stephen/grokking/grok_1764706150/18030.pth
# Saved model to /home/stephen/grokking/grok_1764706150/18040.pth
# Saved model to /home/stephen/grokking/grok_1764706150/18050.pth
# Saved model to /home/stephen/grokking/grok_1764706150/18060.pth
# Saved model to /home/stephen/grokking/grok_1764706150/18070.pth
# Saved model to /home/stephen/grokking/grok_1764706150/18080.pth
# Saved model to /home/stephen/grokking/grok_1764706150/18090.pth
# 18100_-15.9069_-14.9925_pen=8.149e-04
# Saved model to /home/stephen/grokking/grok_1764706150/18100.pth
# Saved model to /home/stephen/grokking/grok_1764706150/18110.pth
# Saved model to /home/stephen/grokking/grok_1764706150/18120.pth
# Saved model to /home/stephen/grokking/grok_1764706150/18130.pth
# Saved model to /home/stephen/grokking/grok_1764706150/18140.pth
# Saved model to /home/stephen/grokking/grok_1764706150/18150.pth
# Saved model to /home/stephen/grokking/grok_1764706150/18160.pth
# Saved model to /home/stephen/grokking/grok_1764706150/18170.pth
# Saved model to /home/stephen/grokking/grok_1764706150/18180.pth
# Saved model to /home/stephen/grokking/grok_1764706150/18190.pth
# 18200_-15.9069_-14.9977_pen=8.187e-04
# Saved model to /home/stephen/grokking/grok_1764706150/18200.pth
# Saved model to /home/stephen/grokking/grok_1764706150/18210.pth
# Saved model to /home/stephen/grokking/grok_1764706150/18220.pth
# Saved model to /home/stephen/grokking/grok_1764706150/18230.pth
# Saved model to /home/stephen/grokking/grok_1764706150/18240.pth
# Saved model to /home/stephen/grokking/grok_1764706150/18250.pth
# Saved model to /home/stephen/grokking/grok_1764706150/18260.pth
# Saved model to /home/stephen/grokking/grok_1764706150/18270.pth
# Saved model to /home/stephen/grokking/grok_1764706150/18280.pth
# Saved model to /home/stephen/grokking/grok_1764706150/18290.pth
# 18300_-15.9088_-15.0068_pen=8.190e-04
# Saved model to /home/stephen/grokking/grok_1764706150/18300.pth
# Saved model to /home/stephen/grokking/grok_1764706150/18310.pth
# Saved model to /home/stephen/grokking/grok_1764706150/18320.pth
# Saved model to /home/stephen/grokking/grok_1764706150/18330.pth
# Saved model to /home/stephen/grokking/grok_1764706150/18340.pth
# Saved model to /home/stephen/grokking/grok_1764706150/18350.pth
# Saved model to /home/stephen/grokking/grok_1764706150/18360.pth
# Saved model to /home/stephen/grokking/grok_1764706150/18370.pth
# Saved model to /home/stephen/grokking/grok_1764706150/18380.pth
# Saved model to /home/stephen/grokking/grok_1764706150/18390.pth
# 18400_-1.8977_-1.5210_pen=1.045e-03
# Saved model to /home/stephen/grokking/grok_1764706150/18400.pth
# Saved model to /home/stephen/grokking/grok_1764706150/18410.pth
# Saved model to /home/stephen/grokking/grok_1764706150/18420.pth
# Saved model to /home/stephen/grokking/grok_1764706150/18430.pth
# Saved model to /home/stephen/grokking/grok_1764706150/18440.pth
# Saved model to /home/stephen/grokking/grok_1764706150/18450.pth
# Saved model to /home/stephen/grokking/grok_1764706150/18460.pth
# Saved model to /home/stephen/grokking/grok_1764706150/18470.pth
# Saved model to /home/stephen/grokking/grok_1764706150/18480.pth
# Saved model to /home/stephen/grokking/grok_1764706150/18490.pth
# 18500_-7.0267_-5.9605_pen=1.494e-03
# Saved model to /home/stephen/grokking/grok_1764706150/18500.pth
# Saved model to /home/stephen/grokking/grok_1764706150/18510.pth
# Saved model to /home/stephen/grokking/grok_1764706150/18520.pth
# Saved model to /home/stephen/grokking/grok_1764706150/18530.pth
# Saved model to /home/stephen/grokking/grok_1764706150/18540.pth
# Saved model to /home/stephen/grokking/grok_1764706150/18550.pth
# Saved model to /home/stephen/grokking/grok_1764706150/18560.pth
# Saved model to /home/stephen/grokking/grok_1764706150/18570.pth
# Saved model to /home/stephen/grokking/grok_1764706150/18580.pth
# Saved model to /home/stephen/grokking/grok_1764706150/18590.pth
# 18600_-5.9157_-5.5313_pen=1.555e-03
# Saved model to /home/stephen/grokking/grok_1764706150/18600.pth
# Saved model to /home/stephen/grokking/grok_1764706150/18610.pth
# Saved model to /home/stephen/grokking/grok_1764706150/18620.pth
# Saved model to /home/stephen/grokking/grok_1764706150/18630.pth
# Saved model to /home/stephen/grokking/grok_1764706150/18640.pth
# Saved model to /home/stephen/grokking/grok_1764706150/18650.pth
# Saved model to /home/stephen/grokking/grok_1764706150/18660.pth
# Saved model to /home/stephen/grokking/grok_1764706150/18670.pth
# Saved model to /home/stephen/grokking/grok_1764706150/18680.pth
# Saved model to /home/stephen/grokking/grok_1764706150/18690.pth
# 18700_-6.5804_-6.1231_pen=2.047e-03
# Saved model to /home/stephen/grokking/grok_1764706150/18700.pth
# Saved model to /home/stephen/grokking/grok_1764706150/18710.pth
# Saved model to /home/stephen/grokking/grok_1764706150/18720.pth
# Saved model to /home/stephen/grokking/grok_1764706150/18730.pth
# Saved model to /home/stephen/grokking/grok_1764706150/18740.pth
# Saved model to /home/stephen/grokking/grok_1764706150/18750.pth
# Saved model to /home/stephen/grokking/grok_1764706150/18760.pth
# Saved model to /home/stephen/grokking/grok_1764706150/18770.pth
# Saved model to /home/stephen/grokking/grok_1764706150/18780.pth
# Saved model to /home/stephen/grokking/grok_1764706150/18790.pth
# 18800_-7.5396_-6.9355_pen=2.715e-03
# Saved model to /home/stephen/grokking/grok_1764706150/18800.pth
# Saved model to /home/stephen/grokking/grok_1764706150/18810.pth
# Saved model to /home/stephen/grokking/grok_1764706150/18820.pth
# Saved model to /home/stephen/grokking/grok_1764706150/18830.pth
# Saved model to /home/stephen/grokking/grok_1764706150/18840.pth
# Saved model to /home/stephen/grokking/grok_1764706150/18850.pth
# Saved model to /home/stephen/grokking/grok_1764706150/18860.pth
# Saved model to /home/stephen/grokking/grok_1764706150/18870.pth
# Saved model to /home/stephen/grokking/grok_1764706150/18880.pth
# Saved model to /home/stephen/grokking/grok_1764706150/18890.pth
# 18900_-8.5608_-7.7566_pen=3.420e-03
# Saved model to /home/stephen/grokking/grok_1764706150/18900.pth
# Saved model to /home/stephen/grokking/grok_1764706150/18910.pth
# Saved model to /home/stephen/grokking/grok_1764706150/18920.pth
# Saved model to /home/stephen/grokking/grok_1764706150/18930.pth
# Saved model to /home/stephen/grokking/grok_1764706150/18940.pth
# Saved model to /home/stephen/grokking/grok_1764706150/18950.pth
# Saved model to /home/stephen/grokking/grok_1764706150/18960.pth
# Saved model to /home/stephen/grokking/grok_1764706150/18970.pth
# Saved model to /home/stephen/grokking/grok_1764706150/18980.pth
# Saved model to /home/stephen/grokking/grok_1764706150/18990.pth
# 19000_-9.6150_-8.6001_pen=4.015e-03
# Saved model to /home/stephen/grokking/grok_1764706150/19000.pth
# Saved model to /home/stephen/grokking/grok_1764706150/19010.pth
# Saved model to /home/stephen/grokking/grok_1764706150/19020.pth
# Saved model to /home/stephen/grokking/grok_1764706150/19030.pth
# Saved model to /home/stephen/grokking/grok_1764706150/19040.pth
# Saved model to /home/stephen/grokking/grok_1764706150/19050.pth
# Saved model to /home/stephen/grokking/grok_1764706150/19060.pth
# Saved model to /home/stephen/grokking/grok_1764706150/19070.pth
# Saved model to /home/stephen/grokking/grok_1764706150/19080.pth
# Saved model to /home/stephen/grokking/grok_1764706150/19090.pth
# 19100_-10.6444_-9.3641_pen=4.421e-03
# Saved model to /home/stephen/grokking/grok_1764706150/19100.pth
# Saved model to /home/stephen/grokking/grok_1764706150/19110.pth
# Saved model to /home/stephen/grokking/grok_1764706150/19120.pth
# Saved model to /home/stephen/grokking/grok_1764706150/19130.pth
# Saved model to /home/stephen/grokking/grok_1764706150/19140.pth
# Saved model to /home/stephen/grokking/grok_1764706150/19150.pth
# Saved model to /home/stephen/grokking/grok_1764706150/19160.pth
# Saved model to /home/stephen/grokking/grok_1764706150/19170.pth
# Saved model to /home/stephen/grokking/grok_1764706150/19180.pth
# Saved model to /home/stephen/grokking/grok_1764706150/19190.pth
# 19200_-11.6584_-10.0371_pen=4.585e-03
# Saved model to /home/stephen/grokking/grok_1764706150/19200.pth
# Saved model to /home/stephen/grokking/grok_1764706150/19210.pth
# Saved model to /home/stephen/grokking/grok_1764706150/19220.pth
# Saved model to /home/stephen/grokking/grok_1764706150/19230.pth
# Saved model to /home/stephen/grokking/grok_1764706150/19240.pth
# Saved model to /home/stephen/grokking/grok_1764706150/19250.pth
# Saved model to /home/stephen/grokking/grok_1764706150/19260.pth
# Saved model to /home/stephen/grokking/grok_1764706150/19270.pth
# Saved model to /home/stephen/grokking/grok_1764706150/19280.pth
# Saved model to /home/stephen/grokking/grok_1764706150/19290.pth
# 19300_-12.6311_-10.5813_pen=4.440e-03
# Saved model to /home/stephen/grokking/grok_1764706150/19300.pth
# Saved model to /home/stephen/grokking/grok_1764706150/19310.pth
# Saved model to /home/stephen/grokking/grok_1764706150/19320.pth
# Saved model to /home/stephen/grokking/grok_1764706150/19330.pth
# Saved model to /home/stephen/grokking/grok_1764706150/19340.pth
# Saved model to /home/stephen/grokking/grok_1764706150/19350.pth
# Saved model to /home/stephen/grokking/grok_1764706150/19360.pth
# Saved model to /home/stephen/grokking/grok_1764706150/19370.pth
# Saved model to /home/stephen/grokking/grok_1764706150/19380.pth
# Saved model to /home/stephen/grokking/grok_1764706150/19390.pth
# 19400_-13.5204_-10.9611_pen=3.865e-03
# Saved model to /home/stephen/grokking/grok_1764706150/19400.pth
# Saved model to /home/stephen/grokking/grok_1764706150/19410.pth
# Saved model to /home/stephen/grokking/grok_1764706150/19420.pth
# Saved model to /home/stephen/grokking/grok_1764706150/19430.pth
# Saved model to /home/stephen/grokking/grok_1764706150/19440.pth
# Saved model to /home/stephen/grokking/grok_1764706150/19450.pth
# Saved model to /home/stephen/grokking/grok_1764706150/19460.pth
# Saved model to /home/stephen/grokking/grok_1764706150/19470.pth
# Saved model to /home/stephen/grokking/grok_1764706150/19480.pth
# Saved model to /home/stephen/grokking/grok_1764706150/19490.pth
# 19500_-14.2787_-11.2069_pen=2.901e-03
# Saved model to /home/stephen/grokking/grok_1764706150/19500.pth
# Saved model to /home/stephen/grokking/grok_1764706150/19510.pth
# Saved model to /home/stephen/grokking/grok_1764706150/19520.pth
# Saved model to /home/stephen/grokking/grok_1764706150/19530.pth
# Saved model to /home/stephen/grokking/grok_1764706150/19540.pth
# Saved model to /home/stephen/grokking/grok_1764706150/19550.pth
# Saved model to /home/stephen/grokking/grok_1764706150/19560.pth
# Saved model to /home/stephen/grokking/grok_1764706150/19570.pth
# Saved model to /home/stephen/grokking/grok_1764706150/19580.pth
# Saved model to /home/stephen/grokking/grok_1764706150/19590.pth
# 19600_-14.8858_-11.5487_pen=1.930e-03
# Saved model to /home/stephen/grokking/grok_1764706150/19600.pth
# Saved model to /home/stephen/grokking/grok_1764706150/19610.pth
# Saved model to /home/stephen/grokking/grok_1764706150/19620.pth
# Saved model to /home/stephen/grokking/grok_1764706150/19630.pth
# Saved model to /home/stephen/grokking/grok_1764706150/19640.pth
# Saved model to /home/stephen/grokking/grok_1764706150/19650.pth
# Saved model to /home/stephen/grokking/grok_1764706150/19660.pth
# Saved model to /home/stephen/grokking/grok_1764706150/19670.pth
# Saved model to /home/stephen/grokking/grok_1764706150/19680.pth
# Saved model to /home/stephen/grokking/grok_1764706150/19690.pth
# 19700_-15.3425_-11.9906_pen=1.310e-03
# Saved model to /home/stephen/grokking/grok_1764706150/19700.pth
# Saved model to /home/stephen/grokking/grok_1764706150/19710.pth
# Saved model to /home/stephen/grokking/grok_1764706150/19720.pth
# Saved model to /home/stephen/grokking/grok_1764706150/19730.pth
# Saved model to /home/stephen/grokking/grok_1764706150/19740.pth
# Saved model to /home/stephen/grokking/grok_1764706150/19750.pth
# Saved model to /home/stephen/grokking/grok_1764706150/19760.pth
# Saved model to /home/stephen/grokking/grok_1764706150/19770.pth
# Saved model to /home/stephen/grokking/grok_1764706150/19780.pth
# Saved model to /home/stephen/grokking/grok_1764706150/19790.pth
# 19800_-15.6484_-12.4010_pen=1.018e-03
# Saved model to /home/stephen/grokking/grok_1764706150/19800.pth
# Saved model to /home/stephen/grokking/grok_1764706150/19810.pth
# Saved model to /home/stephen/grokking/grok_1764706150/19820.pth
# Saved model to /home/stephen/grokking/grok_1764706150/19830.pth
# Saved model to /home/stephen/grokking/grok_1764706150/19840.pth
# Saved model to /home/stephen/grokking/grok_1764706150/19850.pth
# Saved model to /home/stephen/grokking/grok_1764706150/19860.pth
# Saved model to /home/stephen/grokking/grok_1764706150/19870.pth
# Saved model to /home/stephen/grokking/grok_1764706150/19880.pth
# Saved model to /home/stephen/grokking/grok_1764706150/19890.pth
# 19900_-15.8161_-12.7735_pen=8.901e-04
# Saved model to /home/stephen/grokking/grok_1764706150/19900.pth
# Saved model to /home/stephen/grokking/grok_1764706150/19910.pth
# Saved model to /home/stephen/grokking/grok_1764706150/19920.pth
# Saved model to /home/stephen/grokking/grok_1764706150/19930.pth
# Saved model to /home/stephen/grokking/grok_1764706150/19940.pth
# Saved model to /home/stephen/grokking/grok_1764706150/19950.pth
# Saved model to /home/stephen/grokking/grok_1764706150/19960.pth
# Saved model to /home/stephen/grokking/grok_1764706150/19970.pth
# Saved model to /home/stephen/grokking/grok_1764706150/19980.pth
# Saved model to /home/stephen/grokking/grok_1764706150/19990.pth
# Saved model to /home/stephen/grokking/grok_1764706150/final.pth

# %% [markdown]
# ## Viz Results

# %%
CHILL_BROWN='#948979'
YELLOW='#ffd35a'
YELLOW_FADE='#7f6a2d'
BLUE='#65c8d0'
GREEN='#6e9671' 
CHILL_GREEN='#6c946f'
CHILL_BLUE='#3d5c6f'
FRESH_TAN='#dfd0b9'
CYAN='#00FFFF'

# %%
plt.plot(train_accs)
plt.plot(test_accs)

# %%
plt.clf()        
fig=plt.figure(0,(14,6), facecolor='k') 
ax=fig.add_subplot(111, facecolor='k')

plt.plot(train_accs[:500], c=BLUE, linewidth=2.5, alpha=0.95) #'#dfd0b9')
plt.plot(test_accs[:500], c=YELLOW, linewidth=2.5, alpha=0.95) #'#dfd0b9')
plt.tick_params(axis='x', colors='#948979', labelsize=16)  # Add labelsize here
plt.tick_params(axis='y', colors='#948979', labelsize=16)  # Add labelsize here

plt.gca().spines['top'].set_color('#948979')
plt.gca().spines['bottom'].set_color('#948979')
plt.gca().spines['left'].set_color('#948979')
plt.gca().spines['right'].set_color('#948979')
plt.subplots_adjust(bottom=0.2)  # Add fixed bottom margin
# plt.xlim([-10, len(to_plot)+10])
plt.ylim([0,1.05]) #Bad idea to fix or is it fine?
plt.grid(True, color='#948979', alpha=0.3)

# %%
plt.clf()        
fig=plt.figure(0,(14,6), facecolor='k') 
ax=fig.add_subplot(111, facecolor='k')

plt.plot(train_accs, c=BLUE, linewidth=2.5, alpha=0.95) #'#dfd0b9')
plt.plot(test_accs, c=YELLOW, linewidth=2.5, alpha=0.95) #'#dfd0b9')
plt.tick_params(axis='x', colors='#948979', labelsize=16)  # Add labelsize here
plt.tick_params(axis='y', colors='#948979', labelsize=16)  # Add labelsize here

plt.gca().spines['top'].set_color('#948979')
plt.gca().spines['bottom'].set_color('#948979')
plt.gca().spines['left'].set_color('#948979')
plt.gca().spines['right'].set_color('#948979')
plt.subplots_adjust(bottom=0.2)  # Add fixed bottom margin
# plt.xlim([-10, len(to_plot)+10])
plt.ylim([0,1.05]) #Bad idea to fix or is it fine?
plt.grid(True, color='#948979', alpha=0.3)

# %%
from tqdm import tqdm

# %%
all_data = torch.tensor([(i, j, p) for i in range(p) for j in range(p)]).to('cuda')
labels = torch.tensor([fn(i, j) for i, j, _ in all_data]).to('cuda')
cache = {}
model.remove_all_hooks()
model.cache_all(cache)
# Final position only
original_logits = model(all_data)[:, -1]
# Remove equals sign from output logits
original_logits = original_logits[:, :-1]
original_loss = cross_entropy_high_precision(original_logits, labels)
print(f"Original loss: {original_loss.item()}")

#Ok let's try pre -> the og. 
mr = einops.rearrange(cache['blocks.0.mlp.hook_pre'], "(x y) ... -> x y ...", x=p).detach().cpu().numpy() 

# np.save(str(root/run_name)+'/mlp_hook_pre', mr)
# Out:
# Original loss: 1.4312809736788748e-06

# %%
# ---- Helper for classifying term type ----
def classify_term_type(kx, ky, is_dc):
    if is_dc:
        return "dc"
    if kx != 0 and ky == 0:
        return "row"
    if kx == 0 and ky != 0:
        return "col"
    if kx == 0 and ky == 0:
        return "dc"
    return "cross"  # kx != 0 and ky != 0


# ---- Loop over neurons and build DataFrame ----
all_rows = []

for neuron_idx in tqdm(range(512)):
    # 113 x 113 slice for this neuron
    m_slice = mr[:, :, 2, neuron_idx]

    components, Nx, Ny = compute_frequency_components(m_slice)
    terms = components_to_terms(components, Nx, Ny, num_freqs=4, include_dc=True)

    # Max amplitude (non-DC) for this neuron, for "strong" comparison later
    non_dc_terms = [t for t in terms if not t.get("is_dc", False)]
    max_amp = max((t["amplitude"] for t in non_dc_terms), default=0.0)

    for rank, t in enumerate(terms):
        is_dc = t.get("is_dc", False)
        kx = t["kx"]
        ky = t["ky"]
        amp = t["amplitude"]
        phase = t["phase"]

        term_type = classify_term_type(kx, ky, is_dc)

        all_rows.append({
            "neuron_idx": neuron_idx,
            "term_rank": rank,          # 0 = DC if include_dc=True
            "is_dc": is_dc,
            "term_type": term_type,     # "dc", "row", "col", "cross"
            "kx": kx,
            "ky": ky,
            "amplitude": amp,
            "phase": phase,
            "max_amp_neuron": max_amp,  # per neuron
        })

df = pd.DataFrame(all_rows)
df['relative_amplitude']=df['amplitude']/df['max_amp_neuron']
# Out:
# 100%|██████████████████████| 512/512 [00:15<00:00, 32.18it/s]

# %%
df['kx'].value_counts()
# Out:
# kx
# 0     1333
# 34     391
# 8      356
# 6      268
# 45      98
# 1       68
# 2       25
# 16      17
# 12       4
# Name: count, dtype: int64

# %%
dff=df[df['kx']==4]
dff=dff[dff['ky']==4]

# %%
dff.sort_values(by='relative_amplitude', ascending=False)[:15]
# Out:
# Empty DataFrame
# Columns: [neuron_idx, term_rank, is_dc, term_type, kx, ky, amplitude, phase, max_amp_neuron, relative_amplitude]
# Index: []

# %%
neuron_idx=219
FT = np.fft.fft2(mr[:,:,2,neuron_idx])

components, Nx, Ny = compute_frequency_components(mr[:,:,2,neuron_idx])
terms = components_to_terms(components, Nx, Ny, num_freqs=4, include_dc=True)
code_str = generate_python_reconstructor(terms, Nx, Ny,
                                         func_name="approx_M",
                                         decimals=3)
print(code_str)
# Out:
# def approx_M(i, j):
#     val = 0.106
#     val += 1.77 * np.cos(2*np.pi*((1*j)/113) + -2.478)
#     val += 1.769 * np.cos(2*np.pi*((1*i)/113) + -2.478)
#     val += 0.401 * np.cos(2*np.pi*((6*j)/113) + 1.5)
#     val += 0.391 * np.cos(2*np.pi*((6*i)/113) + 1.486)
#     return val

# %%
def approx_M(i, j):
    val = 0.795
    val += 0.289 * np.cos(2*np.pi*((4*i)/113) + 1.103)
    val += 0.288 * np.cos(2*np.pi*((4*j)/113) + 1.096)
    val += 0.179 * np.cos(2*np.pi*((4*i)/113) + 0.134) * np.cos(2*np.pi*((4*j)/113) + 0.134)
    val += 0.105 * np.cos(2*np.pi*((8*j)/113) + -2.984)
    return val

# %%
m_approx=np.zeros((p,p))
for i in range(p):
    for j in range(p):
        m_approx[i,j]=approx_M(i,j)

fig=plt.figure(0, (12, 6))
fig.add_subplot(1,3,1); plt.imshow(mr[:,:,2,neuron_idx]); plt.axis('off')
fig.add_subplot(1,3,2); plt.imshow(np.abs(FT));  plt.axis('off')
fig.add_subplot(1,3,3); plt.imshow(m_approx); plt.axis('off');
